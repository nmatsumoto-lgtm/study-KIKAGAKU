# %% [markdown]
# <a href="https://colab.research.google.com/github/nmatsumoto-lgtm/study-KIKAGAKU/blob/main/%E4%B8%8D%E5%8B%95%E7%94%A3%E4%BE%A1%E6%A0%BC%E4%BA%88%E6%B8%AC%E3%82%A2%E3%83%97%E3%83%AA_Ver_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install lightgbm==4.5.0 optuna==3.6.1 joblib pandas numpy scikit-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 19.0 MB/s eta 0:00:00

# %%
from __future__ import annotations
import json
from pathlib import Path
from dataclasses import dataclass


import numpy as np
import pandas as pd
import optuna
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_log_error
from joblib import dump
from optuna.samplers import TPESampler

# %%
# ===== 再現性セット（最上部の import の後に）=====
import os, random
SEED = 42  # ← 好きな固定値（既存の SEED=0 があれば 0 のままでもOK）
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
import os, re
import numpy as np
import pandas as pd

# 1) アップした元CSVのパス（ファイル名は自分のに合わせて変更）
SRC = "/content/平均売買㎡単価推移_東京都中央区.csv"

# 2) 出力先（学習コードが読む場所）
DST_DIR = "data/external"
DST = f"{DST_DIR}/avg_psm.csv"
os.makedirs(DST_DIR, exist_ok=True)

# 3) 読み込み
df = pd.read_csv(SRC)

# 4) 列の推定（period or year/month, そして avg_psm_yen）
cols_lower = {c.lower(): c for c in df.columns}

def pick_price_col(df):
    # まず既に英名があればそれを使う
    if "avg_psm_yen" in cols_lower:
        return cols_lower["avg_psm_yen"]
    # 日本語っぽい列名の自動検出（「平均」「㎡」「単価」「売買」などを含む列）
    for c in df.columns:
        s = str(c)
        if ("㎡" in s or "平米" in s or "m2" in s.lower()) and ("単価" in s or "価格" in s or "売買" in s):
            return c
    # 予備
    for c in df.columns:
        if "psm" in c.lower():
            return c
    raise ValueError("平均㎡単価の列が見つかりません。'avg_psm_yen' または日本語列名（例: '平均㎡売買単価'）を用意してください。")

def to_num(x):
    # "1,647,000 円" みたいな表記を数値化
    return (str(x)
            .replace(",", "")
            .replace("円", "")
            .replace("¥", "")
            .strip())

price_col = pick_price_col(df)
df[price_col] = pd.to_numeric(df[price_col].map(to_num), errors="coerce")

# period or year/month を作成
if "period" in cols_lower:
    period_col = cols_lower["period"]
    df["period"] = pd.to_numeric(df[period_col], errors="coerce").astype("Int64")
else:
    # 年月の列名を推測（year, month / 年, 月, 年月など）
    def pick_year_col():
        for k in ["year", "年"]:
            if k in cols_lower: return cols_lower[k]
        for c in df.columns:
            if re.search(r"年", str(c)): return c
        return None
    def pick_month_col():
        for k in ["month", "月"]:
            if k in cols_lower: return cols_lower[k]
        for c in df.columns:
            if re.search(r"月", str(c)): return c
        return None
    ycol = pick_year_col()
    mcol = pick_month_col()
    if ycol is not None and mcol is not None:
        yy = pd.to_numeric(df[ycol], errors="coerce").astype("Int64")
        mm = pd.to_numeric(df[mcol], errors="coerce").astype("Int64")
        df["period"] = (yy*100 + mm).astype("Int64")
    else:
        # "YYYYMM" 形式の列（例: 年月, yyyymm）を探す
        c_ym = None
        for c in df.columns:
            s = str(c).lower()
            if "yyyymm" in s or "年月" in s:
                c_ym = c; break
        if c_ym is None:
            raise ValueError("period か year/month（または 年/月/年月）の列が見つかりません。")
        df["period"] = pd.to_numeric(df[c_ym], errors="coerce").astype("Int64")

# 5) 最低限の2列だけに整形して保存
out = df[["period", price_col]].rename(columns={price_col: "avg_psm_yen"}).dropna()
out["period"] = out["period"].astype(int)
out["avg_psm_yen"] = out["avg_psm_yen"].astype(float)
out = out.sort_values("period")

out.to_csv(DST, index=False, encoding="utf-8-sig")
print("Saved ->", DST)
print(out.head())
# Out:
# Saved -> data/external/avg_psm.csv
#    period  avg_psm_yen
# 0  202406    1290000.0
# 1  202408    1330000.0
# 2  202410    1380000.0
# 3  202412    1440000.0
# 4  202502    1520000.0

# %%
SEED = 0
np.random.seed(SEED)

# %%
IN = Path("data/interim/train_tabular.csv")
OUT_DIR = Path("models"); OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# === 追加（先頭の定数定義あたり）========================
IDX_CSV = Path("data/external/avg_psm.csv")  # 平均㎡単価CSV
USE_DEFLATE = True  # ← True: ②デフレート学習を有効化 / False: ①の特徴量化のみ
# =======================================================

# %%
# === 追加：指数CSVを読み込み、月次(YYYYMM)に整えて返す =========
def _load_avg_psm_monthly(csv_path: Path) -> pd.DataFrame:
    idx = pd.read_csv(csv_path)

    # period が無ければ year,month から作成
    cols = {c.lower(): c for c in idx.columns}
    if "period" not in cols:
        ycol = cols.get("year"); mcol = cols.get("month")
        if ycol is None or mcol is None:
            raise ValueError("avg_psm.csv には period か year,month が必要です。")
        idx["period"] = idx[ycol].astype(int) * 100 + idx[mcol].astype(int)

    # 月次にリサンプリング（2か月置き→月次へ・線形補間）
    idx["ym"] = pd.to_datetime(idx["period"].astype(str), format="%Y%m")
    idx = (idx[["ym", "avg_psm_yen"]]
             .set_index("ym")
             .resample("MS")
             .interpolate("time")
             .ffill()
             .reset_index())
    idx["period"] = (idx["ym"].dt.year * 100 + idx["ym"].dt.month).astype(int)

    # MoM/YoYなど派生（任意）
    idx = idx.sort_values("period").reset_index(drop=True)
    idx["log_idx_psm"] = np.log(idx["avg_psm_yen"].astype(float))
    idx["idx_mom"] = idx["avg_psm_yen"].pct_change().fillna(0.0)
    idx["idx_yoy"] = idx["avg_psm_yen"].pct_change(12).fillna(0.0)
    return idx[["period", "avg_psm_yen", "log_idx_psm", "idx_mom", "idx_yoy"]]
# =========================================================

def compute_calibration(period_arr, idx_csv: Path, smooth_months: int = 2) -> float:
    """
    学習末月の外部平均㎡単価と最新月の外部平均㎡単価の比（移動平均で平滑化）を返す。
    deflate有無に関わらず、最終の円スケールに掛けるだけでOK。
    """
    try:
        idx = _load_avg_psm_monthly(idx_csv).sort_values("period")
        last_train = int(np.max(period_arr))

        p_train = idx.loc[idx["period"] <= last_train, "avg_psm_yen"]
        if len(p_train) == 0:
            return 1.0
        base = float(p_train.tail(smooth_months).mean())

        latest = float(idx["avg_psm_yen"].tail(smooth_months).mean())
        return latest / base if base > 0 else 1.0
    except Exception:
        return 1.0

# %%
# === 中央区 5エリア：駅→エリアの固定マップ ===
STATION_TO_AREA = {
    # ① 銀座・京橋
    "銀座": "銀座・京橋",
    "東銀座": "銀座・京橋",
    "銀座一丁目": "銀座・京橋",
    "京橋(東京)": "銀座・京橋",
    "宝町(東京)": "銀座・京橋",
    "新橋": "銀座・京橋",
    "汐留": "銀座・京橋",
    "東京": "銀座・京橋",  # 日本橋側に寄せたい場合は「日本橋・人形町」へ変更可

    # ② 日本橋・人形町
    "日本橋(東京)": "日本橋・人形町",
    "三越前": "日本橋・人形町",
    "新日本橋": "日本橋・人形町",
    "茅場町": "日本橋・人形町",
    "人形町": "日本橋・人形町",
    "水天宮前": "日本橋・人形町",
    "浜町": "日本橋・人形町",
    "東日本橋": "日本橋・人形町",
    "小伝馬町": "日本橋・人形町",
    "馬喰横山": "日本橋・人形町",
    "馬喰町": "日本橋・人形町",

    # ③ 月島・勝どき・晴海
    "月島": "月島・勝どき・晴海",
    "勝どき": "月島・勝どき・晴海",

    # ④ 築地・八丁堀
    "築地": "築地・八丁堀",
    "築地市場": "築地・八丁堀",
    "新富町(東京)": "築地・八丁堀",
    "八丁堀(東京)": "築地・八丁堀",
}

AREA_LIST = ["銀座・京橋", "日本橋・人形町", "月島・勝どき・晴海", "築地・八丁堀", "佃・新川・湊", "その他"]

def station_to_area(station_name: str) -> str:
    """駅名を5エリアに変換。未登録は 'その他'。"""
    if not isinstance(station_name, str) or station_name.strip() == "":
        return "その他"
    return STATION_TO_AREA.get(station_name.strip(), "その他")

# %%
# ============================
# 1) データ読み込み & 追加特徴量
# ============================

def _oof_target_median(df: pd.DataFrame, key: str, y: np.ndarray, n_splits: int = 5) -> np.ndarray:
    """キー列ごとの OOF 中央値エンコーディング（リーク防止）。
    戻り値は各行に対応する OOF 推定値（学習折ごとに学習外の中央値を使う）。
    """
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    oof = np.zeros(len(df), dtype=float)
    for tr_idx, va_idx in kf.split(df):
        med = (
            pd.DataFrame({key: df.iloc[tr_idx][key].values, "y": y[tr_idx]})
            .groupby(key)["y"].median()
        )
        oof[va_idx] = df.iloc[va_idx][key].map(med).fillna(med.median()).values
    return oof

def _oof_target_mean(df, key, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    oof = np.zeros(len(df), dtype=float)
    for tr_idx, va_idx in kf.split(df):
        m = (pd.DataFrame({key: df.iloc[tr_idx][key].values, "y": y[tr_idx]})
             .groupby(key)["y"].mean())
        oof[va_idx] = df.iloc[va_idx][key].map(m).fillna(m.mean()).values
    return oof

def build_table_and_features() -> tuple[pd.DataFrame, list[str], list[str], list[str], list[int]]:
    df = pd.read_csv(IN)

    # ===== 対数ターゲット =====
    y = df["price_yen"].astype(float).values
    # ★ 追加：指数CSVを読み込み & マージ
    idx = _load_avg_psm_monthly(IDX_CSV)

    # 学習データ側 period が無ければ作成（あなたのCSVには既にありますが保険）
    if "period" not in df.columns and {"year","month"} <= set(df.columns):
        df["period"] = df["year"].astype(int)*100 + df["month"].astype(int)

    # マージ（相場水準をくっつける）
    df = df.merge(idx, on="period", how="left")

    # 先に駅の緯度経度キャッシュを作る（これが stations_geo.csv を作成）
    _ = build_or_load_station_geocodes(
        df["station"].astype(str).dropna().unique().tolist()
    )

    # === ViT画像特徴（駅 × 徒歩ビン × 多方向 × マルチスケール）を追加 ===
    df, vit_cols = add_vit_features_ring_to_df(
        df,
        walk_bins=[(0,5),(6,10),(11,15),(16,20)],
        directions=8,
        meters_per_min=80.0,
        zooms=[18,19],
        grid=3,
        crop_px=512,
    )

        # 欠損は前方/後方で埋める（学習期間内なら埋まります）
    for c in ["avg_psm_yen","log_idx_psm","idx_mom","idx_yoy"]:
        df[c] = df[c].fillna(method="ffill").fillna(method="bfill")


    # build_table_and_features() 内の y_log 計算部を置き換え
    y_series = df["price_yen"].astype(float)          # Seriesで持つ
    avg_series = df["avg_psm_yen"].astype(float)

    if USE_DEFLATE:
        y_log = np.log1p(y_series) - np.log(avg_series)
    else:
        y_log = np.log1p(y_series)

    # 以降、配列が必要な箇所だけ最後に .values
    y_log = y_log.values


    # # ★ ここが“②デフレート学習”の切替ポイント
    # if USE_DEFLATE:
    #     # 相場水準(avg_psm)を引いた「相対価格（対数）」を学習
    #     y_log = np.log1p(y) - np.log(df["avg_psm_yen"].astype(float).values)
    # else:
    #     # 従来どおり
    #     y_log = np.log1p(y)

    # # ===== 対数ターゲット =====
    # y = df["price_yen"].astype(float).values
    # y_log = np.log1p(y)

    # ===== 5エリアを駅から自動付与（入力は駅のまま）=====
    df["area_group"] = df["station"].astype(str).apply(station_to_area)

    # ===== 追加特徴量 =====
    df["access_score"] = 1.0 / (1.0 + df["walk_min"].astype(float))
    df["sqrt_area"]    = np.sqrt(np.clip(df["area_sqm"].astype(float), 0, None))
    df["log_area"]     = np.log1p(np.clip(df["area_sqm"].astype(float), 0, None))
    df["age_sqrt"]     = np.sqrt(np.clip(df["築年数"].astype(float), 0, None))
    df["area_x_access"]= df["area_sqm"].astype(float) * df["access_score"].astype(float)

    # ===== 頻度特徴量 =====
    station_cnt = df["station"].value_counts()
    layout_cnt  = df["layout"].value_counts()
    area_cnt    = df["area_group"].value_counts()

    df["station_count"] = df["station"].map(station_cnt).fillna(0).astype(int)
    df["layout_count"]  = df["layout"].map(layout_cnt).fillna(0).astype(int)
    df["area_count"]    = df["area_group"].map(area_cnt).fillna(0).astype(int)

    # ===== OOF 目標エンコード（対数ターゲットで中央値）=====
    df["station_oof_median_log"] = _oof_target_median(df, "station",     y_log)
    df["layout_oof_median_log"]  = _oof_target_median(df, "layout",      y_log)
    df["area_oof_median_log"]    = _oof_target_median(df, "area_group",  y_log)

    # ===== OOF 目標エンコード（対数ターゲットで平均）=====  ←★ ここを追加
    df["station_oof_mean_log"] = _oof_target_mean(df, "station",    y_log)
    df["layout_oof_mean_log"]  = _oof_target_mean(df, "layout",     y_log)
    df["area_oof_mean_log"]    = _oof_target_mean(df, "area_group", y_log)


    # ===== 推論用に学習時統計を準備 =====
    station_med_map = (
        pd.DataFrame({"station": df["station"], "y_log": y_log})
        .groupby("station")["y_log"].median().to_dict()
    )
    layout_med_map = (
        pd.DataFrame({"layout": df["layout"], "y_log": y_log})
        .groupby("layout")["y_log"].median().to_dict()
    )
    area_med_map = (
        pd.DataFrame({"area_group": df["area_group"], "y_log": y_log})
        .groupby("area_group")["y_log"].median().to_dict()
    )

    # ←★ ここから “平均” を追加
    station_mean_map = (
        pd.DataFrame({"station": df["station"], "y_log": y_log})
        .groupby("station")["y_log"].mean().to_dict()
    )
    layout_mean_map = (
        pd.DataFrame({"layout": df["layout"], "y_log": y_log})
        .groupby("layout")["y_log"].mean().to_dict()
    )
    area_mean_map = (
        pd.DataFrame({"area_group": df["area_group"], "y_log": y_log})
        .groupby("area_group")["y_log"].mean().to_dict()
    )

    global_station_med = float(np.median(list(station_med_map.values()))) if len(station_med_map) else float(np.median(y_log))
    global_layout_med  = float(np.median(list(layout_med_map.values())))  if len(layout_med_map)  else float(np.median(y_log))
    global_area_med    = float(np.median(list(area_med_map.values())))    if len(area_med_map)    else float(np.median(y_log))

    # 参考：平均の“全体値”も欲しければ
    global_station_mean = float(np.mean(list(station_mean_map.values()))) if len(station_mean_map) else float(np.mean(y_log))
    global_layout_mean  = float(np.mean(list(layout_mean_map.values())))  if len(layout_mean_map)  else float(np.mean(y_log))
    global_area_mean    = float(np.mean(list(area_mean_map.values())))    if len(area_mean_map)    else float(np.mean(y_log))

    # ===== カテゴリ列（area を先頭に追加）=====
    feat_cat = ["area_group", "station", "layout"]

    # ===== 数値列 =====
    feat_num_base = ["walk_min", "築年数", "area_sqm"]
    feat_num_extra = [
        "access_score", "sqrt_area", "log_area", "age_sqrt",
        "area_x_access",
        "station_count", "layout_count", "area_count",
        "station_oof_median_log", "layout_oof_median_log", "area_oof_median_log",
        "station_oof_mean_log", "layout_oof_mean_log", "area_oof_mean_log",
        # ★ 追加：指数の特徴量（①）
        "log_idx_psm",   # 水準（対数）
        "idx_mom",       # 前月比
        "idx_yoy",       # 前年同月比
    ]
    feat_num_extra += vit_cols   # ← これを追加
    feat_num_all = feat_num_base + feat_num_extra

    # 単調制約を「名前で」安全に指定
    mono_dict = {name: 0 for name in feat_num_all}
    mono_dict.update({
        "walk_min": -1,      # 遠いほど↓
        "築年数": -1,         # 古いほど↓
        "area_sqm": +1,      # 広いほど↑
        # ← 派生も一貫させる
        "access_score": +1,  # 駅近スコアが高いほど↑（walk_minと反対符号に注意だが整合的）
        "sqrt_area": +1,
        "log_area": +1,
        "age_sqrt": -1,
     })
    monotone_constraints = [0] * len(feat_cat) + [mono_dict[c] for c in feat_num_all]

    # # ===== 単調性制約（[cat..., num...] の順）=====
    # n_cat = len(feat_cat)
    # # walk_min↓, 築年数↓, area_sqm↑、その他は制約なし
    # mono_num = [-1, -1, +1] + [0] * (len(feat_num_all) - 3)
    # monotone_constraints = [0] * n_cat + mono_num

    # ===== ここから：新しいほど重くする sample_weight =====
    # 年月を「通算月」に変換（最新月との差＝どれだけ古いか）
    year_s  = pd.to_numeric(df["year"],  errors="coerce").astype(int)
    month_s = pd.to_numeric(df["month"], errors="coerce").astype(int)

    latest_m = int(year_s.max())*12 + int(month_s.max())          # スカラ
    this_m   = (year_s*12 + month_s)                               # Series（ベクトル計算）
    months_old = (latest_m - this_m).clip(lower=0)

    HALF_LIFE_MONTHS = 12.0  # 半減期（例：12ヶ月）。強めに効かせたいなら 6 にする等
    w = np.power(0.5, months_old / HALF_LIFE_MONTHS)
    w = np.clip(w, 0.2, None)  # 古すぎるデータにも最低限の重み（お好みで調整）
    sample_weight = w.values.astype(float)
    # ===== ここまで =====

    # ===== エンコードして学習用テーブル =====
    oe = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
    X_cat = oe.fit_transform(df[feat_cat].fillna("NA")).astype("int32")
    X_num = df[feat_num_all].astype(float).values
    X = np.hstack([X_cat, X_num])

    cat_cols = [f"cat__{c}" for c in feat_cat]
    num_cols = feat_num_all.copy()
    X_df = pd.DataFrame(X, columns=cat_cols + num_cols)
    categorical_feature = cat_cols

    meta = {
        "feat_cat": feat_cat,
        "feat_num": num_cols,
        "categorical_feature": categorical_feature,
        "monotone_constraints": monotone_constraints,
    }

    # ===== 推論用マップ（station→area を含めて保存）=====
    infer_maps = {
        "station_count_map": station_cnt.to_dict(),
        "layout_count_map":  layout_cnt.to_dict(),
        "area_count_map":    area_cnt.to_dict(),

        "station_median_log_map": station_med_map,
        "layout_median_log_map":  layout_med_map,
        "area_median_log_map":    area_med_map,

        "global_station_median_log": global_station_med,
        "global_layout_median_log":  global_layout_med,
        "global_area_median_log":    global_area_med,

        # ↓↓↓ 追加（平均）
        "station_mean_log_map": station_mean_map,
        "layout_mean_log_map":  layout_mean_map,
        "area_mean_log_map":    area_mean_map,

        "global_station_median_log": global_station_med,
        "global_layout_median_log":  global_layout_med,
        "global_area_median_log":    global_area_med,

        # （必要なら平均の全体値も）
        "global_station_mean_log": global_station_mean,
        "global_layout_mean_log":  global_layout_mean,
        "global_area_mean_log":    global_area_mean,

        "station_to_area_map": {s: station_to_area(s) for s in sorted(df["station"].astype(str).unique())},
        "area_groups": AREA_LIST,

        "feat_cat": feat_cat,
        "feat_num": num_cols,

        # 駅→エリア（推論で駅入力から自動付与）
        "station_to_area_map": {s: station_to_area(s) for s in sorted(df["station"].astype(str).unique())},
        "area_groups": AREA_LIST,

        "feat_cat": feat_cat,
        "feat_num": num_cols,
    }

    avg_psm_arr = df["avg_psm_yen"].to_numpy() if "avg_psm_yen" in df.columns else None
    period_arr = df["period"].to_numpy().astype(int)

    # 返り値（従来どおり）
    return (X_df, y_log, categorical_feature, monotone_constraints, meta, oe,infer_maps, sample_weight, avg_psm_arr,np.log1p(df["price_yen"].astype(float).values),period_arr)

# %%
# ============================
# 2) Optuna でハイパラ探索（時系列CV）
# ============================
def tune_with_optuna(
    X_df, y_log, y_log_true, categorical_feature, monotone_constraints,
    period_arr,  # ★追加（YYYYMMの配列）
    n_trials=200, sample_weight=None, avg_psm=None
) -> tuple[dict, int, float]:

    from sklearn.model_selection import TimeSeriesSplit  # 先頭に移しても可

    # 並び替え（古い→新しい）
    order = np.argsort(period_arr)
    X_ord = X_df.iloc[order]
    y_ord = y_log[order]
    y_true_ord = y_log_true[order]
    w_ord = None if sample_weight is None else sample_weight[order]
    avg_ord = None if avg_psm is None else avg_psm[order]

    tscv = TimeSeriesSplit(n_splits=5)

    def objective(trial: optuna.Trial) -> float:
        params = {
            "objective": "rmse", "metric": "rmse",
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
            "num_leaves": trial.suggest_int("num_leaves", 31, 255),
            "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 200),
            "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 1.0),
            "bagging_fraction": trial.suggest_float("bagging_fraction", 0.6, 1.0),
            "bagging_freq": trial.suggest_int("bagging_freq", 0, 10),
            "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0.0, 5.0),
            "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
            "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
            "verbosity": -1, "seed": SEED,
            "monotone_constraints": monotone_constraints,
        }

        rmsles, best_iters = [], []
        for tr_rel, va_rel in tscv.split(X_ord):
            X_tr, X_va = X_ord.iloc[tr_rel], X_ord.iloc[va_rel]
            y_tr, y_va = y_ord[tr_rel], y_ord[va_rel]
            w_tr = None if w_ord is None else w_ord[tr_rel]
            w_va = None if w_ord is None else w_ord[va_rel]

            dtr = lgb.Dataset(
                X_tr, label=y_tr, weight=w_tr,
                categorical_feature=categorical_feature, free_raw_data=True
            )
            dva = lgb.Dataset(
                X_va, label=y_va, weight=w_va,
                categorical_feature=categorical_feature, free_raw_data=True
            )

            model = lgb.train(
                params, dtr, valid_sets=[dva],
                num_boost_round=4000,
                callbacks=[lgb.early_stopping(200, verbose=False)]
            )
            pred_log = model.predict(X_va, num_iteration=model.best_iteration)

            if USE_DEFLATE and (avg_ord is not None):
                # 相対ログ + 相場ログ → 円に戻してRMSLE
                yhat_yen  = np.expm1(pred_log + np.log(avg_ord[va_rel]))
                ytrue_yen = np.expm1(y_true_ord[va_rel])
                rmsle = float(np.sqrt(mean_squared_log_error(ytrue_yen, yhat_yen)))
            else:
                rmsle = float(np.sqrt(mean_squared_log_error(np.expm1(y_va), np.expm1(pred_log))))

            rmsles.append(rmsle)
            best_iters.append(model.best_iteration)

        trial.set_user_attr("best_iters", best_iters)
        return float(np.mean(rmsles))

    study = optuna.create_study(direction="minimize",sampler=TPESampler(seed=SEED))
    study.optimize(objective, n_trials=n_trials)

    best_params = study.best_params
    best_iters_list = study.best_trial.user_attrs.get("best_iters", [1000])
    best_round = int(np.clip(np.mean(best_iters_list), 100, 4000))
    best_score = study.best_value
    return best_params, best_round, best_score

# %%
# !pip -q install transformers==4.44.2 timm pillow requests mercantile scikit-learn tqdm joblib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 842.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 99.7 MB/s eta 0:00:00

# %%
import os, time, io, math, json, re, hashlib, random
from pathlib import Path
from typing import Tuple, List, Dict

import numpy as np
import pandas as pd
import requests
from PIL import Image
import mercantile
from tqdm import tqdm
from joblib import dump, load

import torch
from transformers import AutoImageProcessor, ViTModel
from sklearn.decomposition import PCA

# 既存の SEED を流用（無ければ固定）
try:
    SEED
except NameError:
    SEED = 42
np.random.seed(SEED); random.seed(SEED)
torch.manual_seed(SEED)

# ===== 1) パスと定数 ==========================================================
DATA_EXT = Path("data/external"); DATA_EXT.mkdir(parents=True, exist_ok=True)
IMG_CACHE_DIR = DATA_EXT / "gsi_tiles"; IMG_CACHE_DIR.mkdir(parents=True, exist_ok=True)
EMBED_DIR = DATA_EXT / "img_embed"; EMBED_DIR.mkdir(parents=True, exist_ok=True)
EMBED_PARQUET = DATA_EXT / "img_vit_pca.parquet"
PCA_PATH = Path("models/vit_pca.joblib"); PCA_PATH.parent.mkdir(parents=True, exist_ok=True)

STATIONS_GEO_CSV = DATA_EXT / "stations_geo.csv"  # 駅の緯度経度キャッシュ
GSI_URL = "https://cyberjapandata.gsi.go.jp/xyz/ort/{z}/{x}/{y}.jpg"  # 航空写真（オルソ）

# タイル設定：ズーム18で 3x3 を貼り合わせ→中央を 512x512 にクロップ
ZOOM = 18
GRID = 3               # 3x3
TILE_SIZE = 256        # GSIタイルは256px
CROP_PX = 512          # 中央を切り出すサイズ

UA = "ChuoWardPriceModel/1.0 (contact: your-email@example.com)"  # 利用規約に沿ってUA表記
REQ_TIMEOUT = 10

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# ===== 2) 駅ジオコーディング（Nominatim）======================================
def _nominatim_search_station(name: str) -> Tuple[float, float] | None:
    """
    OSM Nominatimで駅名から緯度経度を引く（日本限定）。結果は stations_geo.csv にキャッシュ。
    """
    try:
        params = {"q": f"{name} 駅, Tokyo, Japan", "format": "jsonv2", "limit": 1, "countrycodes": "jp"}
        r = requests.get("https://nominatim.openstreetmap.org/search", params=params,
                         headers={"User-Agent": UA}, timeout=REQ_TIMEOUT)
        r.raise_for_status()
        data = r.json()
        if not data:
            return None
        lat = float(data[0]["lat"]); lon = float(data[0]["lon"])
        return lat, lon
    except Exception:
        return None

# 中央区で良く使う駅の“保険”（未解決時に使用）
FALLBACK_STATION_LL = {
    "銀座": (35.6719, 139.7653),
    "東銀座": (35.6697, 139.7679),
    "銀座一丁目": (35.6733, 139.7671),
    "京橋(東京)": (35.6763, 139.7703),
    "宝町(東京)": (35.6746, 139.7740),
    "新橋": (35.6663, 139.7589),
    "汐留": (35.6648, 139.7615),
    "東京": (35.6812, 139.7671),
    "日本橋(東京)": (35.6830, 139.7744),
    "三越前": (35.6870, 139.7745),
    "新日本橋": (35.6895, 139.7740),
    "茅場町": (35.6808, 139.7792),
    "人形町": (35.6864, 139.7825),
    "水天宮前": (35.6838, 139.7841),
    "浜町": (35.6886, 139.7875),
    "東日本橋": (35.6902, 139.7827),
    "小伝馬町": (35.6909, 139.7793),
    "馬喰横山": (35.6923, 139.7822),
    "馬喰町": (35.6918, 139.7826),
    "月島": (35.6646, 139.7842),
    "勝どき": (35.6590, 139.7746),
    "築地": (35.6673, 139.7706),
    "築地市場": (35.6645, 139.7628),
    "新富町(東京)": (35.6692, 139.7723),
    "八丁堀(東京)": (35.6740, 139.7770),
    "佃": (35.6696, 139.7870),
    "新川": (35.6727, 139.7834),
    "湊": (35.6703, 139.7819),
}

def build_or_load_station_geocodes(stations: List[str]) -> pd.DataFrame:
    """
    stations（駅名のユニーク配列）を入力に、stations_geo.csv を作成/更新して返す。
    """
    if STATIONS_GEO_CSV.exists():
        geo = pd.read_csv(STATIONS_GEO_CSV)
    else:
        geo = pd.DataFrame(columns=["station", "lat", "lon"])

    known = {s: (float(a), float(b)) for s, a, b in geo[["station","lat","lon"]].itertuples(index=False)}
    new_rows = []
    session = requests.Session()

    for s in tqdm(sorted(set(stations)), desc="Geocoding stations"):
        if s in known:
            continue
        latlon = _nominatim_search_station(s)
        if latlon is None:
            latlon = FALLBACK_STATION_LL.get(s)
        if latlon is None:
            # 最後の保険：駅名から(0,0)は避ける→スキップ。後で手入力してもOK。
            continue
        lat, lon = latlon
        new_rows.append({"station": s, "lat": lat, "lon": lon})
        time.sleep(1.0)  # Nominatimのレート制限を尊重

    if new_rows:
        geo = pd.concat([geo, pd.DataFrame(new_rows)], ignore_index=True)
        geo.drop_duplicates(subset=["station"], keep="last", inplace=True)
        geo.to_csv(STATIONS_GEO_CSV, index=False, encoding="utf-8-sig")

    return geo

# ===== 3) GSIタイル取得 → 3x3 モザイク → 中央512pxを切り出し ====================
def _cache_path_for_tile(z: int, x: int, y: int) -> Path:
    return IMG_CACHE_DIR / f"{z}_{x}_{y}.jpg"

def _fetch_tile(z: int, x: int, y: int, session: requests.Session) -> Image.Image | None:
    p = _cache_path_for_tile(z,x,y)
    if p.exists():
        try:
            return Image.open(p).convert("RGB")
        except Exception:
            p.unlink(missing_ok=True)
    url = GSI_URL.format(z=z, x=x, y=y)
    try:
        r = session.get(url, headers={"User-Agent": UA}, timeout=REQ_TIMEOUT)
        r.raise_for_status()
        img = Image.open(io.BytesIO(r.content)).convert("RGB")
        img.save(p)
        return img
    except Exception:
        return None

def fetch_center_patch(lat: float, lon: float, z: int = ZOOM, grid: int = GRID, crop_px: int = CROP_PX) -> Image.Image | None:
    """
    緯度経度を中心に z のタイルで grid×grid を取得し、中央 crop_px×crop_px を返す
    """
    session = requests.Session()
    center = mercantile.tile(lon, lat, z)
    half = grid // 2
    mosaic = Image.new("RGB", (TILE_SIZE*grid, TILE_SIZE*grid), (255,255,255))

    for dy in range(-half, half+1):
        for dx in range(-half, half+1):
            x = center.x + dx; y = center.y + dy
            tile = _fetch_tile(z, x, y, session)
            if tile is None:
                return None
            px = (dx + half) * TILE_SIZE
            py = (dy + half) * TILE_SIZE
            mosaic.paste(tile, (px, py))

    # 中央を切り出し
    left = (mosaic.width - crop_px)//2
    top  = (mosaic.height - crop_px)//2
    return mosaic.crop((left, top, left+crop_px, top+crop_px))

# ===== 4) ViT で埋め込み =======================================================
_VIT_PROCESSOR = None
_VIT_MODEL = None

def _load_vit():
    global _VIT_PROCESSOR, _VIT_MODEL
    if _VIT_MODEL is None:
        _VIT_PROCESSOR = AutoImageProcessor.from_pretrained("google/vit-base-patch16-224")
        _VIT_MODEL = ViTModel.from_pretrained("google/vit-base-patch16-224")
        _VIT_MODEL.to(DEVICE)
        _VIT_MODEL.eval()

def embed_vit(image_pil: Image.Image) -> np.ndarray:
    """
    ViTのpooler_output（[CLS]）を 768次元ベクトルで返す
    """
    _load_vit()
    with torch.no_grad():
        inputs = _VIT_PROCESSOR(images=image_pil, return_tensors="pt")
        inputs = {k: v.to(DEVICE) for k, v in inputs.items()}
        outputs = _VIT_MODEL(**inputs)
        # ViTModel は pooler_output（tanh済み）と last_hidden_state を返す
        vec = outputs.pooler_output.squeeze(0).detach().cpu().numpy()  # (768,)
    return vec

# ===== 5) 駅ごとに埋め込み → PCA(16) → Parquet出力 =============================
def build_or_load_vit_pca_by_station(st_geo: pd.DataFrame) -> pd.DataFrame:
    """
    入力: station, lat, lon
    出力: stationごとの img_pca_00..15 を含む DataFrame
    中間: EMBED_DIR に .npy をキャッシュ、PCAは models/vit_pca.joblib に保存
    """
    # まず埋め込み（駅ごと）
    embs = []
    stations_done = []
    for s, lat, lon in tqdm(st_geo[["station","lat","lon"]].itertuples(index=False),
                            total=len(st_geo), desc="Building ViT embeddings"):
        # キャッシュ
        key = hashlib.md5(f"{s}_{lat:.6f}_{lon:.6f}_z{ZOOM}_g{GRID}_c{CROP_PX}".encode()).hexdigest()[:16]
        npy_path = EMBED_DIR / f"{key}.npy"
        if npy_path.exists():
            vec = np.load(npy_path)
        else:
            img = fetch_center_patch(lat, lon, z=ZOOM, grid=GRID, crop_px=CROP_PX)
            if img is None:
                # タイル取得失敗時はスキップ
                continue
            vec = embed_vit(img)  # (768,)
            np.save(npy_path, vec)
        embs.append(vec)
        stations_done.append(s)

    if not embs:
        raise RuntimeError("ViT埋め込みが一件も作成できませんでした。ネットワークやタイル取得を確認してください。")

    E = np.vstack(embs)  # (N,768)

    # PCAを fit/transform（既存があれば再利用）
    if PCA_PATH.exists():
        pca = load(PCA_PATH)
        Zp = pca.transform(E)
    else:
        pca = PCA(n_components=16, random_state=SEED)
        Zp = pca.fit_transform(E)
        dump(pca, PCA_PATH)

    cols = [f"img_pca_{i:02d}" for i in range(Zp.shape[1])]
    out = pd.DataFrame(Zp, columns=cols)
    out.insert(0, "station", stations_done)

    # 保存（学習の都度読み込み可）
    out.to_parquet(EMBED_PARQUET, index=False)
    return out

# ===== 6) 学習テーブルへの結合ユーティリティ ================================
def add_vit_features_to_df(df: pd.DataFrame) -> Tuple[pd.DataFrame, List[str]]:
    """
    あなたの build_table_and_features() の中で呼ぶ想定。
    - df には 'station' 列が必要
    - 駅の緯度経度を stations_geo.csv で用意（無ければ自動作成）
    - station単位のViT-PCA特徴をJOINして返す
    戻り値: (df_with_feats, 追加した列名リスト)
    """
    assert "station" in df.columns, "dfに 'station' 列が必要です。"

    # 1) 駅の緯度経度を用意（初回は自動作成）
    st_list = df["station"].astype(str).dropna().unique().tolist()
    st_geo = build_or_load_station_geocodes(st_list)  # → stations_geo.csv
    if st_geo.empty:
        raise RuntimeError("stations_geo.csv の作成に失敗。駅名の表記ゆれを確認してください。")

    # 2) 駅ごとのViT-PCAを作成/読込
    if EMBED_PARQUET.exists():
        st_pca = pd.read_parquet(EMBED_PARQUET)
    else:
        st_pca = build_or_load_vit_pca_by_station(st_geo)

    # 3) JOIN（stationキー）
    before = len(df)
    df2 = df.merge(st_pca, on="station", how="left")
    assert len(df2) == before, "JOIN後に行数が変わっています。stationキーの表記を確認してください。"

    img_cols = [c for c in df2.columns if c.startswith("img_pca_")]
    if not img_cols:
        raise RuntimeError("img_pca_* 列が見つかりません。埋め込み作成に失敗しています。")

    return df2, img_cols
# ============ ここから：駅×徒歩ビン×多方向×マルチスケール 版 ============

# 別名の保存先（既存と衝突しないように）
EMBED_RING_PARQUET = DATA_EXT / "img_vit_pca_ring.parquet"
PCA_RING_PATH = Path("models/vit_pca_ring.joblib")

def _bearing_angles(n: int) -> List[float]:
    # 0度=東、反時計回り。地理的厳密性は不要なので簡易でOK
    return [i * 360.0 / n for i in range(n)]

def _offset_latlon(lat: float, lon: float, meters: float, bearing_deg: float) -> Tuple[float, float]:
    # 東京近辺なら十分な平面近似（厳密にやるならpyprojを使用）
    rad = math.radians(bearing_deg)
    dlat = (meters * math.sin(rad)) / 111320.0
    dlon = (meters * math.cos(rad)) / (111320.0 * math.cos(math.radians(lat)))
    return lat + dlat, lon + dlon

def _build_ring_embeddings_for_station(
    station: str,
    lat: float,
    lon: float,
    walk_bins: List[Tuple[int, int]],
    directions: int,
    meters_per_min: float,
    zooms: List[int],
    grid: int,
    crop_px: int,
) -> Dict[str, np.ndarray]:
    """
    各 徒歩ビン（例: (0,5),(6,10)...）について、
      - 中間半径の円周上を directions 分割（8方向など）
      - 各方向点で zooms（18/19など）ごとに画像を切り出し→ViT埋め込み
      - ベクトルを平均して 1ビン=1ベクトル（768次元）に
    戻り値: { 'b05': vec768, 'b10': vec768, ... }
    """
    angles = _bearing_angles(directions)
    out: Dict[str, np.ndarray] = {}

    for lo, hi in walk_bins:
        r_inner = max(lo, 0) * meters_per_min
        r_outer = max(hi, 1) * meters_per_min
        # 軽量に中間半径1点。精度を上げたいなら radii に2点以上入れてOK
        radii = [0.5 * (r_inner + r_outer)]

        vecs = []
        for radius_m in radii:
            for ang in angles:
                lat2, lon2 = _offset_latlon(lat, lon, radius_m, ang)
                for z in zooms:
                    img = fetch_center_patch(lat2, lon2, z=z, grid=grid, crop_px=crop_px)
                    if img is None:
                        continue
                    # 埋め込みキャッシュ（半径・角度・ズームもキーに入れる）
                    key_str = f"{station}_{lat2:.6f}_{lon2:.6f}_z{z}_g{grid}_c{crop_px}"
                    key = hashlib.md5(key_str.encode()).hexdigest()[:16]
                    npy = EMBED_DIR / f"{key}.npy"
                    if npy.exists():
                        vec = np.load(npy)
                    else:
                        vec = embed_vit(img)
                        np.save(npy, vec)
                    vecs.append(vec)

        if vecs:
            mean_vec = np.mean(np.vstack(vecs), axis=0)
            out[f"b{int(hi):02d}"] = mean_vec  # 例: (0,5)->b05, (6,10)->b10

    return out

def build_or_load_ring_pca(
    walk_bins: List[Tuple[int, int]],
    directions: int,
    meters_per_min: float,
    zooms: List[int],
    grid: int,
    crop_px: int,
    n_components: int = 16,
    random_state: int = 42,
) -> pd.DataFrame:
    """
    駅×徒歩ビンのViT(768)平均ベクトルを作成し、PCA(16)に圧縮。
    形式: station, bin, img_pca_00..15 を Parquet に保存/読込。
    """
    if EMBED_RING_PARQUET.exists() and PCA_RING_PATH.exists():
        return pd.read_parquet(EMBED_RING_PARQUET)

    # 駅の緯度経度は既存のキャッシュ関数を使って用意
    # 既に stations_geo.csv があるはずなので再ジオコーディング不要
    if STATIONS_GEO_CSV.exists():
        geo = pd.read_csv(STATIONS_GEO_CSV)
    else:
        raise FileNotFoundError(f"Not found: {STATIONS_GEO_CSV}. 先に build_or_load_station_geocodes(...) を実行してください。")

    rows = []
    for station, lat, lon in tqdm(geo[["station","lat","lon"]].itertuples(index=False),
                                  total=len(geo), desc="Build ring embeddings"):
        ring = _build_ring_embeddings_for_station(
            station=str(station), lat=float(lat), lon=float(lon),
            walk_bins=walk_bins, directions=directions, meters_per_min=meters_per_min,
            zooms=zooms, grid=grid, crop_px=crop_px,
        )
        for bin_label, vec in ring.items():
            rows.append({"station": station, "bin": bin_label, "vec": vec})

    if not rows:
        raise RuntimeError("リング埋め込みが一件も作成できませんでした。ネットワークや駅名表記を確認してください。")

    E = np.vstack([r["vec"] for r in rows])
    if PCA_RING_PATH.exists():
        pca = load(PCA_RING_PATH)
        Z = pca.transform(E)
    else:
        pca = PCA(n_components=n_components, random_state=random_state)
        Z = pca.fit_transform(E)
        dump(pca, PCA_RING_PATH)

    cols = [f"img_pca_{i:02d}" for i in range(Z.shape[1])]
    out = pd.DataFrame(Z, columns=cols)
    out.insert(0, "bin", [r["bin"] for r in rows])
    out.insert(0, "station", [r["station"] for r in rows])
    out.to_parquet(EMBED_RING_PARQUET, index=False)
    return out

def _walk_bin_label(walk_min: float, walk_bins: List[Tuple[int, int]]) -> str:
    for lo, hi in walk_bins:
        if lo <= walk_min <= hi:
            return f"b{int(hi):02d}"
    # 範囲外は一番近いビンへ
    if walk_min < walk_bins[0][0]:
        return f"b{int(walk_bins[0][1]):02d}"
    return f"b{int(walk_bins[-1][1]):02d}"

def add_vit_features_ring_to_df(
    df: pd.DataFrame,
    walk_bins=[(0,5),(6,10),(11,15),(16,20)],
    directions=8,
    meters_per_min=80.0,
    zooms=[18,19],
    grid=3,
    crop_px=512,
):
    """
    入力 df（列: station, walk_min 必須）に、
    駅×徒歩ビンの画像PCA特徴を “元行と1対1” でJOINして返す。
    追加列は 'img_ring_pca_00..15'
    """
    need = {"station", "walk_min"}
    if not need.issubset(df.columns):
        raise ValueError(f"dfには {need} 列が必要です。")

    ring_pca = build_or_load_ring_pca(
        walk_bins=walk_bins, directions=directions, meters_per_min=meters_per_min,
        zooms=zooms, grid=grid, crop_px=crop_px,
    )

    def label_walk_bin(v, walk_bins):
        """v を walk_bins のどれかの区間に割り当てて 'b{上端:02d}' を返す。該当なしは None。"""
        if pd.isna(v):
            return None
        try:
            x = float(v)
        except (TypeError, ValueError):
            return None
        for lo, hi in walk_bins:  # walk_bins は [(lo, hi), ...] を想定
            if lo <= x <= hi:     # 両端含む。必要なら < / <= を調整
                return f"b{int(hi):02d}"
        return None

    work = df[["station", "walk_min"]].copy()
    work["bin"] = [label_walk_bin(v, walk_bins) for v in work["walk_min"].values]

    # # 1) 元データごとに “該当ビン” を付与（indexを保持）
    # work = df[["station","walk_min"]].copy()
    # work["bin"] = [
    #     (f"b{int(b[1]):02d}" if (float(v) >= b[0] and float(v) <= b[1]) else None)
    #     if pd.notna(v) else None
    #     for v in work["walk_min"].values
    #     for b in [None]  # ダミー（内包表現の書式簡略）
    # ]
    # 上の内包は読みにくいので元の関数を使う方が良ければ：
    # work["bin"] = [
    #     _walk_bin_label(float(v), walk_bins) if pd.notna(v) else f"b{int(walk_bins[0][1]):02d}"
    #     for v in work["walk_min"].values
    # ]

    work["bin"] = [
        _walk_bin_label(float(v), walk_bins) if pd.notna(v) else f"b{int(walk_bins[0][1]):02d}"
        for v in work["walk_min"].values
    ]

    # 2) （station, bin）で 1対1 マージ（行数は絶対に増やさない）
    merged = work.merge(ring_pca, on=["station","bin"], how="left")
    pca_cols = [c for c in ring_pca.columns if c.startswith("img_pca_")]
    rename_map = {c: c.replace("img_pca_", "img_ring_pca_") for c in pca_cols}
    merged = merged.rename(columns=rename_map)

    # 3) 元の順序・行数で列だけ足す（indexを使って join）
    merged.index = df.index  # 同じ順序にそろえる
    out = df.join(merged[list(rename_map.values())])

    # 行数が増えていないことを強制チェック
    assert len(out) == len(df), "リング特徴の結合で行数が変わっています。"
    added_cols = list(rename_map.values())
    return out, added_cols

# %%
# ============================
# 3) 最終学習（ポイント & 分位点）
# ============================

def train_final_models(
    X_df: pd.DataFrame,
    y_log: np.ndarray,
    categorical_feature: list[str],
    monotone_constraints: list[int],
    best_params: dict,
    best_round: int,
    sample_weight: np.ndarray | None = None  # ★ 追加
):
    base_params = dict(best_params)
    base_params.update({
        "objective": "rmse",
        "metric": "rmse",
        "verbosity": -1,
        "seed": SEED,
        # ★ ポイントモデルでは単調性制約を使う
        "monotone_constraints": monotone_constraints,
    })

    # 生データを解放しない（categorical_feature を後で使えるように）
    dtrain = lgb.Dataset(
        X_df,
        label=y_log,
        weight=sample_weight,
        categorical_feature=categorical_feature,
        free_raw_data=False
    )

    # ---- ポイント（対数価格）----
    model_point = lgb.train(base_params, dtrain, num_boost_round=best_round)

    # ---- smearing（log1p → 円の戻し補正）----
    pred_log_tr = model_point.predict(X_df, num_iteration=getattr(model_point, "best_iteration", None))
    resid = y_log - pred_log_tr  # eps = y_log - yhat_log
    # ★ 直近重視の設計と整合：重み付き平均（重みが無いときは従来どおり）
    smearing = (
        float(np.average(np.exp(resid), weights=sample_weight))
        if sample_weight is not None else
        float(np.mean(np.exp(resid)))
    )

    # ---- 分位点（q10/q90）----
    models_q = {}
    for alpha, tag in [(0.1, "q10"), (0.9, "q90")]:
        q_params = dict(best_params)
        q_params.update({
            "objective": "quantile",
            "alpha": alpha,
            "metric": "quantile",
            "verbosity": -1,
            "seed": SEED,
            # ★ ここが重要：quantile では単調性制約を外す
            # "monotone_constraints": monotone_constraints,  # ←入れない
        })
        models_q[tag] = lgb.train(q_params, dtrain, num_boost_round=best_round)

    return model_point, models_q, smearing

# %%
# ===== 入力CSV→中間CSVの自動生成（なければ作る） =====
from pathlib import Path
import pandas as pd, numpy as np, re
from datetime import datetime

RAW_CSV = Path("/content/Tokyo_Chuo Ward_20242_20251.csv")
IN = Path("data/interim/train_tabular.csv")
ST_OUT = Path("data/interim/stations.csv")
IN.parent.mkdir(parents=True, exist_ok=True)

# ===== _read_chuo_and_save() の先頭付近に追加（関数の外でOK）=====
def _parse_period(s):
    """'2025年8月', '2025/08', '2025-8', '2025年第2四半期' などを (year, month) に直す"""
    import re, math
    if pd.isna(s): return (np.nan, np.nan)
    s = str(s)

    # 年月パターン
    m = re.search(r"(\d{4})[年/\-\. ]+(\d{1,2})", s)
    if m:
        y, mo = int(m.group(1)), int(m.group(2))
        mo = int(np.clip(mo, 1, 12))
        return (y, mo)

    # 四半期パターン
    m = re.search(r"(\d{4})年?第?([1-4])四半期", s)
    if m:
        y, q = int(m.group(1)), int(m.group(2))
        q2m = {1:1, 2:4, 3:7, 4:10}
        return (y, q2m[q])

    # 年だけ
    m = re.search(r"(\d{4})年", s)
    if m:
        return (int(m.group(1)), 1)

    return (np.nan, np.nan)

def _read_chuo_and_save(raw_csv: Path, out_csv: Path, stations_csv: Path):
    # エンコーディングを順に試す（Excel想定）
    last_err = None
    for enc in ("cp932", "utf-8-sig", "utf-8", "utf-16", "utf-16le", "utf-16be"):
        try:
            raw = pd.read_csv(raw_csv, encoding=enc)
            break
        except Exception as e:
            last_err = e
            raw = None
    if raw is None:
        raise last_err

    def _to_year(x):
        if pd.isna(x):
            return np.nan
        m = re.search(r"(\d{4})年", str(x))
        return int(m.group(1)) if m else np.nan

    # 必要列だけ取り出し
    df = raw[["最寄駅：名称","最寄駅：距離（分）","間取り","面積（㎡）","建築年","取引価格（総額）"]].copy()

    build_year = df["建築年"].apply(_to_year)
    current_year = datetime.now().year
    df["築年数"] = (current_year - build_year).clip(lower=0)

    for col in ["最寄駅：距離（分）","面積（㎡）","築年数"]:
        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(df[col].median())

    def _normalize_layout(s):
        if not isinstance(s, str):
            return "その他"
        s = (s.upper()
               .replace("Ｌ","L").replace("Ｄ","D").replace("Ｋ","K").replace("Ｒ","R"))
        m = re.search(r"(\d+)(LDK|DK|K|R)", s)
        return m.group(0) if m else "その他"

    # ★ ここは _normalize_layout の「外」（= 同じインデント階層）
    period_col = None
    for c in ["取引時期", "取引時点", "成約年月", "契約年月", "年月", "取引年月"]:
        if c in raw.columns:
            period_col = c
            break

    if period_col is not None:
        ym = raw[period_col].apply(_parse_period)
        year  = ym.apply(lambda t: t[0]).astype("Int64")
        month = ym.apply(lambda t: t[1]).astype("Int64")
    else:
        year  = pd.Series([np.nan] * len(raw), dtype="Int64")
        month = pd.Series([np.nan] * len(raw), dtype="Int64")

    # 欠損処理
    if year.isna().all():
        now = datetime.now()
        year  = pd.Series([now.year]  * len(raw))
        month = pd.Series([now.month] * len(raw))
    else:
        year  = year.fillna(method="ffill").fillna(method="bfill").astype(int)
        month = month.fillna(method="ffill").fillna(method="bfill").astype(int)

    # 学習用テーブル作成
    train = df.rename(columns={
        "最寄駅：名称": "station",
        "最寄駅：距離（分）": "walk_min",
        "面積（㎡）": "area_sqm",
        "取引価格（総額）": "price_yen",
    })[["station","walk_min","築年数","area_sqm","price_yen"]].copy()

    train["layout"] = df["間取り"].astype(str).apply(_normalize_layout)
    train["year"]   = year.astype(int)
    train["month"]  = month.astype(int)
    train["period"] = train["year"] * 100 + train["month"]

    # 保存
    train.to_csv(out_csv, index=False)

    # 駅リスト保存（utf-8-sig）
    s = (raw["最寄駅：名称"].astype(str)
           .replace({"nan": np.nan, "None": np.nan, "": np.nan})
           .dropna()
           .str.normalize("NFKC")
           .str.replace("（","(",regex=False).str.replace("）",")",regex=False)
           .str.replace("　"," ",regex=False).str.strip()
           .str.replace(r"\s+"," ",regex=True))
    pd.Series(sorted(s.unique())).to_csv(stations_csv, index=False, header=False, encoding="utf-8-sig")

# まだ中間CSVがない場合は作る
# if not IN.exists():
#     if not RAW_CSV.exists():
#         raise FileNotFoundError(f"Raw CSV が見つかりません: {RAW_CSV.resolve()}")
#     _read_chuo_and_save(RAW_CSV, IN, ST_OUT)
# ★ 一度だけ True にしてCSVを作り直す（year/month/period列を付与）
FORCE_REBUILD = True   # 生成が終わったら False に戻す/この行を消す

if FORCE_REBUILD or not IN.exists():
   if not RAW_CSV.exists():
      raise FileNotFoundError(f"Raw CSV が見つかりません: {RAW_CSV.resolve()}")
   _read_chuo_and_save(RAW_CSV, IN, ST_OUT)
# Out:
# /tmp/ipython-input-2984227913.py:97: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   year  = year.fillna(method="ffill").fillna(method="bfill").astype(int)
# /tmp/ipython-input-2984227913.py:98: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   month = month.fillna(method="ffill").fillna(method="bfill").astype(int)

# %%
tmp = pd.read_csv(IN)
print(tmp.columns.tolist())
# 'year', 'month', 'period' が含まれていること
print(tmp.head())
# Out:
# ['station', 'walk_min', '築年数', 'area_sqm', 'price_yen', 'layout', 'year', 'month', 'period']
#    station  walk_min   築年数  area_sqm  price_yen layout  year  month  period
# 0  新富町(東京)       3.0  24.0        75  140000000   ３LDK  2024      4  202404
# 1  新富町(東京)       3.0  46.0        40   26000000     ２K  2024      4  202404
# 2  新富町(東京)       3.0  18.0        45   56000000   １LDK  2024      4  202404
# 3  新富町(東京)       1.0  27.0        35   47000000   １LDK  2024      4  202404
# 4  新富町(東京)       3.0  18.0        45   58000000   １LDK  2024      4  202404

# %%
# ===== CONFIG BOOTSTRAP (place this right above the __main__ block) =====
from pathlib import Path

# 1) 既に定義済みなら上書きしない／未定義なら補完
if 'IN' not in globals() or not isinstance(IN, Path):
    IN = Path("data/interim/train_tabular.csv")
if 'OUT_DIR' not in globals() or not isinstance(OUT_DIR, Path):
    OUT_DIR = Path("models")
OUT_DIR.mkdir(parents=True, exist_ok=True)

if 'IDX_CSV' not in globals() or not isinstance(IDX_CSV, (str, Path)):
    IDX_CSV = Path("data/external/avg_psm.csv")
if 'USE_DEFLATE' not in globals():
    USE_DEFLATE = True

# 2) 必要なら中間CSVを自動生成（関数とRAWが揃っているときだけ）
if not IN.exists():
    RAW_CSV = Path("/content/Tokyo_Chuo Ward_20242_20251.csv")
    ST_OUT = Path("data/interim/stations.csv"); ST_OUT.parent.mkdir(parents=True, exist_ok=True)

    if '_read_chuo_and_save' in globals() and RAW_CSV.exists():
        print(f"[INFO] build {IN} from {RAW_CSV} ...")
        _read_chuo_and_save(RAW_CSV, IN, ST_OUT)
    else:
        raise FileNotFoundError(
            f"[INPUT NOT FOUND] {IN.resolve()}\n"
            "・上のセルで IN/IDX_CSV/OUT_DIR を定義してから実行してください。\n"
            "・または RAW_CSV をアップロードして _read_chuo_and_save(...) を先に定義→実行してください。"
        )

print(f"[OK] IN={IN.resolve()}")
print(f"[OK] OUT_DIR={OUT_DIR.resolve()}")
print(f"[OK] IDX_CSV={Path(IDX_CSV).resolve() if isinstance(IDX_CSV, (str, Path)) else IDX_CSV}")
# Out:
# [OK] IN=/content/data/interim/train_tabular.csv
# [OK] OUT_DIR=/content/models
# [OK] IDX_CSV=/content/data/external/avg_psm.csv

# %%
# ============================
# 4) 実行
# ============================

if __name__ == "__main__":
    assert IN.exists(), f"Not found: {IN}"

    # ★ infer_maps まで受け取る（関数が infer_maps を返す実装になっている前提）
    X_df, y_log, cat_cols, mono_cons, meta, oe, infer_maps, sample_weight, avg_psm_arr, y_log_true, period_arr = build_table_and_features()

    print(f"Train rows: {len(X_df):,}, cols: {X_df.shape[1]} (cats={len(cat_cols)})")

    best_params, best_round, best_score = tune_with_optuna(
    X_df, y_log, y_log_true, cat_cols, mono_cons, period_arr,   # ★ period_arr を追加
    n_trials=200, sample_weight=sample_weight, avg_psm=avg_psm_arr
)
    print("[OPTUNA] best RMSLE:", round(best_score, 4))
    print("[OPTUNA] best params:")
    for k, v in best_params.items():
        print(f"  {k}: {v}")
    print("[OPTUNA] best_round:", best_round)

    model_point, models_q, smearing = train_final_models(
        X_df, y_log, cat_cols, mono_cons, best_params, best_round,
    sample_weight=sample_weight
    )

    # 直近水準の倍率キャリブを外部指数から計算（保存の前！）
    calib = compute_calibration(period_arr, IDX_CSV, smooth_months=2)
    print(f"[CALIB] multiplier to latest: {calib:.4f}")

    # ===== 保存 =====
    # 予測時に使うメタ情報（列順や制約）とエンコーダを一緒に保存しておく
    dump({
        "model": model_point,
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen",
        "smearing": smearing,
        "calibration": calib,          # ★追加
        "use_deflate": USE_DEFLATE,    # ★追加（推論コード用に）
    }, OUT_DIR / "lgbm_optuna_point.pkl")

    dump({
        "model": models_q["q10"],
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen",
        "alpha": 0.1,
        "smearing": smearing,
        "calibration": calib,          # ★追加
        "use_deflate": USE_DEFLATE,    # ★追加（推論コード用に）
    }, OUT_DIR / "lgbm_optuna_q10.pkl")

    dump({
        "model": models_q["q90"],
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen",
        "alpha": 0.9,
        "smearing": smearing,
        "calibration": calib,          # ★追加
        "use_deflate": USE_DEFLATE,    # ★追加（推論コード用に）
    }, OUT_DIR / "lgbm_optuna_q90.pkl")

    with open(OUT_DIR / "feature_config.json", "w", encoding="utf-8") as f:
        json.dump({
            "feat_cat": meta["feat_cat"],
            "feat_num": meta["feat_num"],
            "categorical_feature": meta["categorical_feature"],
            "monotone_constraints": meta["monotone_constraints"],
            "notes": "y is log1p(price_yen). During inference, apply expm1 to predictions.",
        }, f, ensure_ascii=False, indent=2)

    # ★ 推論用マップも保存（カッコを閉じるのを忘れない）
    with open(OUT_DIR / "infer_maps.json", "w", encoding="utf-8") as f:
        json.dump(infer_maps, f, ensure_ascii=False, indent=2)

    print("Saved models →", OUT_DIR)
# Out:
# Geocoding stations: 100%|██████████| 26/26 [00:02<00:00, 11.95it/s]
# /tmp/ipython-input-2560219852.py:61: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[c] = df[c].fillna(method="ffill").fillna(method="bfill")
# [I 2025-09-15 01:10:23,696] A new study created in memory with name: no-name-e08e7e34-2e21-4a82-87ed-4ef1a2efb3db
# [I 2025-09-15 01:10:23,854] Trial 0 finished with value: 0.3924732674391597 and parameters: {'learning_rate': 0.05176340429875833, 'num_leaves': 191, 'min_data_in_leaf': 125, 'feature_fraction': 0.8179532731987588, 'bagging_fraction': 0.7694619197355619, 'bagging_freq': 7, 'min_gain_to_split': 2.1879360563134624, 'lambda_l1': 1.0615904599004014, 'lambda_l2': 4.709392030276881}. Best is trial 0 with value: 0.3924732674391597.
# Train rows: 1,784, cols: 39 (cats=3)
# [I 2025-09-15 01:10:24,084] Trial 1 finished with value: 0.2590641930352242 and parameters: {'learning_rate': 0.03154052496956797, 'num_leaves': 209, 'min_data_in_leaf': 111, 'feature_fraction': 0.827217824437573, 'bagging_fraction': 0.9702386553170644, 'bagging_freq': 0, 'min_gain_to_split': 0.43564649850770354, 'lambda_l1': 1.5204270129130175e-08, 'lambda_l2': 0.31158648353398066}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:24,254] Trial 2 finished with value: 0.3729213647725489 and parameters: {'learning_rate': 0.10289760686796066, 'num_leaves': 226, 'min_data_in_leaf': 196, 'feature_fraction': 0.9196634256866895, 'bagging_fraction': 0.7845917449011728, 'bagging_freq': 8, 'min_gain_to_split': 0.5913721293446661, 'lambda_l1': 0.005744988873954126, 'lambda_l2': 1.9506510537765813e-07}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:24,395] Trial 3 finished with value: 0.311238877364543 and parameters: {'learning_rate': 0.16945039949066026, 'num_leaves': 148, 'min_data_in_leaf': 89, 'feature_fraction': 0.7058222448418507, 'bagging_fraction': 0.9096934757736866, 'bagging_freq': 5, 'min_gain_to_split': 2.8421697443432423, 'lambda_l1': 1.4760742495197955e-08, 'lambda_l2': 0.003620090882797527}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:24,522] Trial 4 finished with value: 0.42373707410359646 and parameters: {'learning_rate': 0.06256837783419193, 'num_leaves': 169, 'min_data_in_leaf': 190, 'feature_fraction': 0.8727281196413934, 'bagging_fraction': 0.7438031602295144, 'bagging_freq': 4, 'min_gain_to_split': 3.4881559796363244, 'lambda_l1': 3.483607722774873e-08, 'lambda_l2': 0.010020754882942}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:24,649] Trial 5 finished with value: 0.41323336670652144 and parameters: {'learning_rate': 0.07456241820636361, 'num_leaves': 78, 'min_data_in_leaf': 34, 'feature_fraction': 0.7261713403696736, 'bagging_fraction': 0.745484308377049, 'bagging_freq': 6, 'min_gain_to_split': 2.193007567311602, 'lambda_l1': 7.858950304147583, 'lambda_l2': 8.287113686365243e-08}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:24,884] Trial 6 finished with value: 0.3567631777827347 and parameters: {'learning_rate': 0.018696268012559407, 'num_leaves': 67, 'min_data_in_leaf': 134, 'feature_fraction': 0.7013166410159128, 'bagging_fraction': 0.7865243091425225, 'bagging_freq': 2, 'min_gain_to_split': 0.7948479182275986, 'lambda_l1': 9.848640172873773e-08, 'lambda_l2': 0.008071724032088088}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:25,128] Trial 7 finished with value: 0.35579691249463147 and parameters: {'learning_rate': 0.015127952931538244, 'num_leaves': 75, 'min_data_in_leaf': 80, 'feature_fraction': 0.9283972919391741, 'bagging_fraction': 0.6388405103172244, 'bagging_freq': 9, 'min_gain_to_split': 0.48049203946981534, 'lambda_l1': 6.139530838198258, 'lambda_l2': 0.00016514324529254103}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:25,308] Trial 8 finished with value: 0.36955039891126723 and parameters: {'learning_rate': 0.18655009491114, 'num_leaves': 167, 'min_data_in_leaf': 151, 'feature_fraction': 0.6156751169017283, 'bagging_fraction': 0.7131227850305638, 'bagging_freq': 1, 'min_gain_to_split': 1.4807009876107247, 'lambda_l1': 1.1709799813329268e-07, 'lambda_l2': 7.275261607979148e-06}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:25,486] Trial 9 finished with value: 0.3594024174722815 and parameters: {'learning_rate': 0.034591435253679685, 'num_leaves': 45, 'min_data_in_leaf': 142, 'feature_fraction': 0.8266405816826301, 'bagging_fraction': 0.7061557963757782, 'bagging_freq': 5, 'min_gain_to_split': 0.4697025537922084, 'lambda_l1': 0.0015258732517912485, 'lambda_l2': 2.3102861693191303}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:25,743] Trial 10 finished with value: 0.3298700253244574 and parameters: {'learning_rate': 0.026313243719781314, 'num_leaves': 252, 'min_data_in_leaf': 13, 'feature_fraction': 0.9718561420111322, 'bagging_fraction': 0.9874235852979864, 'bagging_freq': 0, 'min_gain_to_split': 4.266444012048565, 'lambda_l1': 3.812573778417783e-06, 'lambda_l2': 0.1576163230730776}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:25,910] Trial 11 finished with value: 0.31022448576658934 and parameters: {'learning_rate': 0.1963897039336736, 'num_leaves': 124, 'min_data_in_leaf': 79, 'feature_fraction': 0.7336547345887859, 'bagging_fraction': 0.941933353477239, 'bagging_freq': 3, 'min_gain_to_split': 3.153147734051915, 'lambda_l1': 5.472680033298529e-06, 'lambda_l2': 0.0020554981135760013}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:26,126] Trial 12 finished with value: 0.34470980786780825 and parameters: {'learning_rate': 0.029994630887823576, 'num_leaves': 113, 'min_data_in_leaf': 55, 'feature_fraction': 0.761002745881162, 'bagging_fraction': 0.8925544545393606, 'bagging_freq': 3, 'min_gain_to_split': 4.703132171701716, 'lambda_l1': 1.8464626590054624e-05, 'lambda_l2': 0.00018209025984283314}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:26,463] Trial 13 finished with value: 0.32873909333769513 and parameters: {'learning_rate': 0.0104734539761103, 'num_leaves': 106, 'min_data_in_leaf': 105, 'feature_fraction': 0.6270136740544179, 'bagging_fraction': 0.9966653349505291, 'bagging_freq': 0, 'min_gain_to_split': 3.2847998828328775, 'lambda_l1': 4.243597632266006e-06, 'lambda_l2': 0.17235871773429867}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:26,642] Trial 14 finished with value: 0.2755378531626134 and parameters: {'learning_rate': 0.11191293910735194, 'num_leaves': 205, 'min_data_in_leaf': 63, 'feature_fraction': 0.7697290059002225, 'bagging_fraction': 0.8828672827489938, 'bagging_freq': 2, 'min_gain_to_split': 1.419255063685207, 'lambda_l1': 5.7547551550948315e-05, 'lambda_l2': 7.280839535804753e-06}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:26,810] Trial 15 finished with value: 0.2753792694989311 and parameters: {'learning_rate': 0.09580155796250439, 'num_leaves': 214, 'min_data_in_leaf': 49, 'feature_fraction': 0.8528057033837755, 'bagging_fraction': 0.850192272167609, 'bagging_freq': 2, 'min_gain_to_split': 1.3930335438129569, 'lambda_l1': 0.10112699832080597, 'lambda_l2': 4.3376796093213965e-06}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:10:27,600] Trial 16 finished with value: 0.23521314962172402 and parameters: {'learning_rate': 0.04100379402482349, 'num_leaves': 250, 'min_data_in_leaf': 110, 'feature_fraction': 0.8533979699031061, 'bagging_fraction': 0.8614849151905116, 'bagging_freq': 1, 'min_gain_to_split': 0.016504669608224498, 'lambda_l1': 0.0754388300231872, 'lambda_l2': 3.5078756137711755e-06}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:10:28,015] Trial 17 finished with value: 0.3248680069137788 and parameters: {'learning_rate': 0.040473758735960846, 'num_leaves': 255, 'min_data_in_leaf': 164, 'feature_fraction': 0.8908780805798382, 'bagging_fraction': 0.8433373601708026, 'bagging_freq': 0, 'min_gain_to_split': 0.01296129609539982, 'lambda_l1': 0.03274375558738424, 'lambda_l2': 1.6632420209060216e-08}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:10:28,463] Trial 18 finished with value: 0.28144671369035246 and parameters: {'learning_rate': 0.02224728520689278, 'num_leaves': 228, 'min_data_in_leaf': 118, 'feature_fraction': 0.976669324808731, 'bagging_fraction': 0.9407549214394862, 'bagging_freq': 1, 'min_gain_to_split': 1.0402757312178261, 'lambda_l1': 0.00031408944989802956, 'lambda_l2': 9.204008004204431e-07}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:10:28,766] Trial 19 finished with value: 0.2961696896875944 and parameters: {'learning_rate': 0.04275204727279851, 'num_leaves': 189, 'min_data_in_leaf': 103, 'feature_fraction': 0.7880319552413594, 'bagging_fraction': 0.8214040515296359, 'bagging_freq': 1, 'min_gain_to_split': 1.656066554055904, 'lambda_l1': 0.13722766058970015, 'lambda_l2': 4.022568907004666e-05}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:10:30,174] Trial 20 finished with value: 0.32817815415540724 and parameters: {'learning_rate': 0.011949809812196486, 'num_leaves': 236, 'min_data_in_leaf': 180, 'feature_fraction': 0.8384201900092699, 'bagging_fraction': 0.9510822927516864, 'bagging_freq': 10, 'min_gain_to_split': 0.01132627839293976, 'lambda_l1': 3.333774952321156e-07, 'lambda_l2': 0.15596268382509007}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:10:30,364] Trial 21 finished with value: 0.265294292170327 and parameters: {'learning_rate': 0.07112133760302723, 'num_leaves': 208, 'min_data_in_leaf': 46, 'feature_fraction': 0.8542476996660545, 'bagging_fraction': 0.8445612636480443, 'bagging_freq': 2, 'min_gain_to_split': 1.0348809252392803, 'lambda_l1': 0.13087681903838458, 'lambda_l2': 4.391052876407009e-06}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:10:31,011] Trial 22 finished with value: 0.22674258798650698 and parameters: {'learning_rate': 0.06442637237877033, 'num_leaves': 198, 'min_data_in_leaf': 96, 'feature_fraction': 0.9003038148609065, 'bagging_fraction': 0.8618495781703216, 'bagging_freq': 3, 'min_gain_to_split': 0.002669635093123013, 'lambda_l1': 0.007704288519366065, 'lambda_l2': 8.671002568144424e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:31,460] Trial 23 finished with value: 0.2422749697274679 and parameters: {'learning_rate': 0.03640054291990616, 'num_leaves': 183, 'min_data_in_leaf': 116, 'feature_fraction': 0.9107702656406316, 'bagging_fraction': 0.8741534786359838, 'bagging_freq': 4, 'min_gain_to_split': 0.02432051897517451, 'lambda_l1': 0.008236584427836958, 'lambda_l2': 4.92696931076956e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:31,769] Trial 24 finished with value: 0.22730398635381088 and parameters: {'learning_rate': 0.054853987482098666, 'num_leaves': 176, 'min_data_in_leaf': 89, 'feature_fraction': 0.9267276329740006, 'bagging_fraction': 0.8727566839287973, 'bagging_freq': 4, 'min_gain_to_split': 0.03194460369011835, 'lambda_l1': 0.006543587818302081, 'lambda_l2': 5.287069763505016e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:31,969] Trial 25 finished with value: 0.2767743602337214 and parameters: {'learning_rate': 0.04957517735388509, 'num_leaves': 154, 'min_data_in_leaf': 95, 'feature_fraction': 0.9446391329037549, 'bagging_fraction': 0.9152452479975249, 'bagging_freq': 4, 'min_gain_to_split': 0.9808360212390712, 'lambda_l1': 0.0006052949396669011, 'lambda_l2': 1.0963917452484431e-08}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:32,201] Trial 26 finished with value: 0.24557208722114945 and parameters: {'learning_rate': 0.055974338150454814, 'num_leaves': 239, 'min_data_in_leaf': 70, 'feature_fraction': 0.9927737330936679, 'bagging_fraction': 0.829265932466143, 'bagging_freq': 6, 'min_gain_to_split': 0.26285737033474205, 'lambda_l1': 0.5719044759012035, 'lambda_l2': 3.6226851797117455e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:32,369] Trial 27 finished with value: 0.2997746678809984 and parameters: {'learning_rate': 0.09065704879168264, 'num_leaves': 128, 'min_data_in_leaf': 87, 'feature_fraction': 0.8924312212499107, 'bagging_fraction': 0.8088129427282205, 'bagging_freq': 3, 'min_gain_to_split': 1.7714851835980365, 'lambda_l1': 0.013050154105290233, 'lambda_l2': 1.2109044093413328e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:32,572] Trial 28 finished with value: 0.3030370315318569 and parameters: {'learning_rate': 0.06605083177033338, 'num_leaves': 170, 'min_data_in_leaf': 130, 'feature_fraction': 0.9583253689771997, 'bagging_fraction': 0.8648785985933766, 'bagging_freq': 3, 'min_gain_to_split': 1.1383036313909756, 'lambda_l1': 0.0011411030386211936, 'lambda_l2': 1.0585964376600756e-06}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:32,732] Trial 29 finished with value: 0.3632191061848077 and parameters: {'learning_rate': 0.12945142175043575, 'num_leaves': 196, 'min_data_in_leaf': 160, 'feature_fraction': 0.7975026483396321, 'bagging_fraction': 0.9124841933171561, 'bagging_freq': 6, 'min_gain_to_split': 0.7829900115040289, 'lambda_l1': 1.2037854354467148, 'lambda_l2': 3.1232698816525305e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:32,911] Trial 30 finished with value: 0.32176221732802757 and parameters: {'learning_rate': 0.04867744047925191, 'num_leaves': 182, 'min_data_in_leaf': 98, 'feature_fraction': 0.8787755913522964, 'bagging_fraction': 0.7623044347723663, 'bagging_freq': 7, 'min_gain_to_split': 2.0103251036354206, 'lambda_l1': 0.00020291188795794885, 'lambda_l2': 4.744814010569935e-08}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:33,185] Trial 31 finished with value: 0.2558940734143436 and parameters: {'learning_rate': 0.04370915920990273, 'num_leaves': 182, 'min_data_in_leaf': 117, 'feature_fraction': 0.8946173211608317, 'bagging_fraction': 0.8683949904661478, 'bagging_freq': 4, 'min_gain_to_split': 0.14190111620631846, 'lambda_l1': 0.005261684482017528, 'lambda_l2': 6.553579195916215e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:33,440] Trial 32 finished with value: 0.2700922788816338 and parameters: {'learning_rate': 0.03639685822416214, 'num_leaves': 159, 'min_data_in_leaf': 121, 'feature_fraction': 0.913143868285123, 'bagging_fraction': 0.8775604455015265, 'bagging_freq': 4, 'min_gain_to_split': 0.3454649059270171, 'lambda_l1': 0.02454899036943837, 'lambda_l2': 6.347694842565063e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:33,683] Trial 33 finished with value: 0.2850876364380309 and parameters: {'learning_rate': 0.028057749169166608, 'num_leaves': 222, 'min_data_in_leaf': 106, 'feature_fraction': 0.9363059757854553, 'bagging_fraction': 0.8073387227033195, 'bagging_freq': 5, 'min_gain_to_split': 0.7311832883000761, 'lambda_l1': 0.00345791913692216, 'lambda_l2': 2.6228155388919995e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:33,882] Trial 34 finished with value: 0.24576275794893698 and parameters: {'learning_rate': 0.08012845401568836, 'num_leaves': 138, 'min_data_in_leaf': 70, 'feature_fraction': 0.9144500960295863, 'bagging_fraction': 0.8943081779293858, 'bagging_freq': 4, 'min_gain_to_split': 0.3207885789438625, 'lambda_l1': 0.4849408288968538, 'lambda_l2': 1.4949546938491454e-06}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:34,097] Trial 35 finished with value: 0.3212716220053734 and parameters: {'learning_rate': 0.055135307010090236, 'num_leaves': 195, 'min_data_in_leaf': 139, 'feature_fraction': 0.8615686027256804, 'bagging_fraction': 0.9275540499869198, 'bagging_freq': 3, 'min_gain_to_split': 0.5539883644826571, 'lambda_l1': 0.03861767126747588, 'lambda_l2': 2.7733860733169075e-08}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:34,333] Trial 36 finished with value: 0.320499000493274 and parameters: {'learning_rate': 0.023131246019033123, 'num_leaves': 179, 'min_data_in_leaf': 91, 'feature_fraction': 0.912342939337889, 'bagging_fraction': 0.8574499205295114, 'bagging_freq': 7, 'min_gain_to_split': 2.5853748476724476, 'lambda_l1': 0.009434790576924387, 'lambda_l2': 2.5151471720392585e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:34,927] Trial 37 finished with value: 0.24321183658384976 and parameters: {'learning_rate': 0.05790105896371599, 'num_leaves': 144, 'min_data_in_leaf': 113, 'feature_fraction': 0.9496961226508782, 'bagging_fraction': 0.7878338737147175, 'bagging_freq': 1, 'min_gain_to_split': 0.03728826731280016, 'lambda_l1': 0.002837139619160802, 'lambda_l2': 1.7040847807695917e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:35,159] Trial 38 finished with value: 0.29874252779881644 and parameters: {'learning_rate': 0.035017508198960434, 'num_leaves': 243, 'min_data_in_leaf': 124, 'feature_fraction': 0.8137078875178243, 'bagging_fraction': 0.966323651115561, 'bagging_freq': 5, 'min_gain_to_split': 0.6463740058097781, 'lambda_l1': 2.3207791650510714, 'lambda_l2': 0.0005661522458853812}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:35,323] Trial 39 finished with value: 0.3387677025210555 and parameters: {'learning_rate': 0.12505096793758005, 'num_leaves': 216, 'min_data_in_leaf': 85, 'feature_fraction': 0.8760254802271383, 'bagging_fraction': 0.8272223536024363, 'bagging_freq': 2, 'min_gain_to_split': 3.982446663788174, 'lambda_l1': 0.07124898820354807, 'lambda_l2': 9.476169362180536e-08}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:35,509] Trial 40 finished with value: 0.35631068285134593 and parameters: {'learning_rate': 0.07938088613072619, 'num_leaves': 201, 'min_data_in_leaf': 146, 'feature_fraction': 0.8375743367364885, 'bagging_fraction': 0.6378840763242417, 'bagging_freq': 4, 'min_gain_to_split': 0.2290062395392357, 'lambda_l1': 0.00011110306384905244, 'lambda_l2': 2.3706311086148112e-06}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:36,339] Trial 41 finished with value: 0.24584208674817068 and parameters: {'learning_rate': 0.0616065722570429, 'num_leaves': 146, 'min_data_in_leaf': 112, 'feature_fraction': 0.9517645634185633, 'bagging_fraction': 0.7247543793629899, 'bagging_freq': 1, 'min_gain_to_split': 0.04124836425343226, 'lambda_l1': 0.0027480310238625766, 'lambda_l2': 4.281301317184899e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:36,735] Trial 42 finished with value: 0.2630180302359988 and parameters: {'learning_rate': 0.05990791491136457, 'num_leaves': 168, 'min_data_in_leaf': 111, 'feature_fraction': 0.996481036451921, 'bagging_fraction': 0.7920114385175787, 'bagging_freq': 1, 'min_gain_to_split': 0.4436866010935905, 'lambda_l1': 0.012151227586164165, 'lambda_l2': 2.055178706785519e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:37,881] Trial 43 finished with value: 0.311331408528641 and parameters: {'learning_rate': 0.037788867100795466, 'num_leaves': 158, 'min_data_in_leaf': 126, 'feature_fraction': 0.9283762823094213, 'bagging_fraction': 0.7841839852396425, 'bagging_freq': 3, 'min_gain_to_split': 0.001160868021027471, 'lambda_l1': 0.0018450035113524547, 'lambda_l2': 3.2944203276208537e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:38,100] Trial 44 finished with value: 0.2592585244915796 and parameters: {'learning_rate': 0.04836504904018912, 'num_leaves': 134, 'min_data_in_leaf': 76, 'feature_fraction': 0.9671560944417662, 'bagging_fraction': 0.8990000050069237, 'bagging_freq': 5, 'min_gain_to_split': 0.5842076328833282, 'lambda_l1': 0.2739748157981893, 'lambda_l2': 1.291826420089072e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:38,376] Trial 45 finished with value: 0.24841752014719556 and parameters: {'learning_rate': 0.03043851588938733, 'num_leaves': 98, 'min_data_in_leaf': 98, 'feature_fraction': 0.8979880647619932, 'bagging_fraction': 0.6720437422326874, 'bagging_freq': 0, 'min_gain_to_split': 0.29318494981774734, 'lambda_l1': 0.000507633557908742, 'lambda_l2': 2.194881146158028e-06}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:38,547] Trial 46 finished with value: 0.3596439061440218 and parameters: {'learning_rate': 0.06909426932960842, 'num_leaves': 175, 'min_data_in_leaf': 137, 'feature_fraction': 0.9362060569937388, 'bagging_fraction': 0.7683567416405093, 'bagging_freq': 2, 'min_gain_to_split': 0.8518949512856305, 'lambda_l1': 0.005312490822735365, 'lambda_l2': 1.0960102614261882e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:39,033] Trial 47 finished with value: 0.2611105858457895 and parameters: {'learning_rate': 0.05273161228595847, 'num_leaves': 188, 'min_data_in_leaf': 111, 'feature_fraction': 0.9200251257819854, 'bagging_fraction': 0.8349774562950474, 'bagging_freq': 1, 'min_gain_to_split': 0.4742257052157498, 'lambda_l1': 0.020601787846203822, 'lambda_l2': 0.0002879106199645001}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:39,428] Trial 48 finished with value: 0.24417795257623162 and parameters: {'learning_rate': 0.018963463269419563, 'num_leaves': 147, 'min_data_in_leaf': 84, 'feature_fraction': 0.8688673134108502, 'bagging_fraction': 0.8745776474800139, 'bagging_freq': 6, 'min_gain_to_split': 0.23418333861315296, 'lambda_l1': 0.0009768848410580664, 'lambda_l2': 4.962730894754859e-08}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:39,593] Trial 49 finished with value: 0.3919878215759508 and parameters: {'learning_rate': 0.08710619581475039, 'num_leaves': 118, 'min_data_in_leaf': 152, 'feature_fraction': 0.9803576400702051, 'bagging_fraction': 0.6004838598001793, 'bagging_freq': 2, 'min_gain_to_split': 1.2874133631097864, 'lambda_l1': 7.008621946781582e-05, 'lambda_l2': 8.155691848022555e-05}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:39,807] Trial 50 finished with value: 0.27034525494051886 and parameters: {'learning_rate': 0.03276374565022417, 'num_leaves': 92, 'min_data_in_leaf': 100, 'feature_fraction': 0.6536345103231103, 'bagging_fraction': 0.7535757521054831, 'bagging_freq': 0, 'min_gain_to_split': 0.8313751877618145, 'lambda_l1': 0.05639443921190627, 'lambda_l2': 4.221661949913873e-06}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:40,234] Trial 51 finished with value: 0.24239561120905667 and parameters: {'learning_rate': 0.018779661117993857, 'num_leaves': 148, 'min_data_in_leaf': 83, 'feature_fraction': 0.8644414737588717, 'bagging_fraction': 0.860776095717111, 'bagging_freq': 6, 'min_gain_to_split': 0.19463611400331854, 'lambda_l1': 0.0008465268508534423, 'lambda_l2': 4.235841273222043e-08}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:40,674] Trial 52 finished with value: 0.23386122147591762 and parameters: {'learning_rate': 0.017548956130316016, 'num_leaves': 162, 'min_data_in_leaf': 61, 'feature_fraction': 0.8977558997763895, 'bagging_fraction': 0.8140993967145925, 'bagging_freq': 4, 'min_gain_to_split': 0.22301821158584967, 'lambda_l1': 2.1876960802527805e-05, 'lambda_l2': 1.4561443154100762e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:41,025] Trial 53 finished with value: 0.24334007339364203 and parameters: {'learning_rate': 0.018886576010580778, 'num_leaves': 163, 'min_data_in_leaf': 53, 'feature_fraction': 0.8144100896381794, 'bagging_fraction': 0.8542343654223536, 'bagging_freq': 5, 'min_gain_to_split': 0.4788158053178929, 'lambda_l1': 0.00021213759756991666, 'lambda_l2': 1.5174591107440733e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:41,515] Trial 54 finished with value: 0.23260714130967863 and parameters: {'learning_rate': 0.014963085840510062, 'num_leaves': 154, 'min_data_in_leaf': 63, 'feature_fraction': 0.898127941080421, 'bagging_fraction': 0.8828789508729389, 'bagging_freq': 4, 'min_gain_to_split': 0.20086812188663344, 'lambda_l1': 3.335627688453475e-05, 'lambda_l2': 3.085977697270653e-08}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:41,926] Trial 55 finished with value: 0.24411055674801396 and parameters: {'learning_rate': 0.015376769946509035, 'num_leaves': 175, 'min_data_in_leaf': 36, 'feature_fraction': 0.9030700452979677, 'bagging_fraction': 0.887722510476679, 'bagging_freq': 4, 'min_gain_to_split': 0.6460791204544792, 'lambda_l1': 1.6516235821079938e-05, 'lambda_l2': 5.530925605144307e-07}. Best is trial 22 with value: 0.22674258798650698.
# [I 2025-09-15 01:10:42,423] Trial 56 finished with value: 0.22602121668236164 and parameters: {'learning_rate': 0.013173065973709855, 'num_leaves': 226, 'min_data_in_leaf': 23, 'feature_fraction': 0.8450893447476197, 'bagging_fraction': 0.8132477094372623, 'bagging_freq': 5, 'min_gain_to_split': 0.36951710886629885, 'lambda_l1': 3.102050267334506e-05, 'lambda_l2': 1.2299489881978618e-08}. Best is trial 56 with value: 0.22602121668236164.
# [I 2025-09-15 01:10:42,968] Trial 57 finished with value: 0.22188803767282245 and parameters: {'learning_rate': 0.013123813461804239, 'num_leaves': 228, 'min_data_in_leaf': 12, 'feature_fraction': 0.8438292655022899, 'bagging_fraction': 0.808660926081216, 'bagging_freq': 5, 'min_gain_to_split': 0.3229975607489518, 'lambda_l1': 2.203136031773015e-06, 'lambda_l2': 1.8958299381345555e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:43,257] Trial 58 finished with value: 0.35231113815754433 and parameters: {'learning_rate': 0.012351680778073295, 'num_leaves': 224, 'min_data_in_leaf': 13, 'feature_fraction': 0.8391595673951094, 'bagging_fraction': 0.816160154059687, 'bagging_freq': 5, 'min_gain_to_split': 4.906289533086159, 'lambda_l1': 1.0859691746547536e-06, 'lambda_l2': 2.01679013204668e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:43,624] Trial 59 finished with value: 0.25647300554833075 and parameters: {'learning_rate': 0.015040102711039133, 'num_leaves': 32, 'min_data_in_leaf': 28, 'feature_fraction': 0.7785316684924071, 'bagging_fraction': 0.801793747888129, 'bagging_freq': 4, 'min_gain_to_split': 0.9351072494985492, 'lambda_l1': 9.881723521447714e-06, 'lambda_l2': 1.3002038537443942e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:44,046] Trial 60 finished with value: 0.26753859361943894 and parameters: {'learning_rate': 0.01072742696633161, 'num_leaves': 232, 'min_data_in_leaf': 29, 'feature_fraction': 0.8288365161349331, 'bagging_fraction': 0.8425513410269456, 'bagging_freq': 8, 'min_gain_to_split': 1.2176201921516323, 'lambda_l1': 1.3379983063725348e-06, 'lambda_l2': 8.761802668293254e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:44,538] Trial 61 finished with value: 0.22789812116260832 and parameters: {'learning_rate': 0.013868646586770644, 'num_leaves': 216, 'min_data_in_leaf': 20, 'feature_fraction': 0.8826252359563829, 'bagging_fraction': 0.8242148630466193, 'bagging_freq': 5, 'min_gain_to_split': 0.3669714284644098, 'lambda_l1': 2.8582125728704586e-05, 'lambda_l2': 1.031362982967712e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:45,014] Trial 62 finished with value: 0.22680817521213542 and parameters: {'learning_rate': 0.015882119912612843, 'num_leaves': 208, 'min_data_in_leaf': 19, 'feature_fraction': 0.880362838879195, 'bagging_fraction': 0.7799046010543793, 'bagging_freq': 6, 'min_gain_to_split': 0.37254213768546646, 'lambda_l1': 3.9921728062984886e-05, 'lambda_l2': 2.5626490431776744e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:45,490] Trial 63 finished with value: 0.22843865761974386 and parameters: {'learning_rate': 0.013806712735091882, 'num_leaves': 215, 'min_data_in_leaf': 18, 'feature_fraction': 0.8764221780403029, 'bagging_fraction': 0.7736676221692881, 'bagging_freq': 6, 'min_gain_to_split': 0.39197219951236384, 'lambda_l1': 3.8188859152158035e-05, 'lambda_l2': 2.881610625006457e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:46,015] Trial 64 finished with value: 0.22966772522260936 and parameters: {'learning_rate': 0.012285955940970357, 'num_leaves': 213, 'min_data_in_leaf': 10, 'feature_fraction': 0.8782947211894823, 'bagging_fraction': 0.7748979442412576, 'bagging_freq': 7, 'min_gain_to_split': 0.4124236984368243, 'lambda_l1': 1.0650310009666778e-06, 'lambda_l2': 1.2379255881180913e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:46,411] Trial 65 finished with value: 0.24422952557237193 and parameters: {'learning_rate': 0.013970004894467043, 'num_leaves': 202, 'min_data_in_leaf': 18, 'feature_fraction': 0.8488759187187938, 'bagging_fraction': 0.7978005920372621, 'bagging_freq': 6, 'min_gain_to_split': 0.6941882173764272, 'lambda_l1': 3.000152780103873e-06, 'lambda_l2': 1.0010067071340354e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:46,906] Trial 66 finished with value: 0.22955598265079766 and parameters: {'learning_rate': 0.013369232455942242, 'num_leaves': 245, 'min_data_in_leaf': 21, 'feature_fraction': 0.883677706126988, 'bagging_fraction': 0.7335453198348347, 'bagging_freq': 6, 'min_gain_to_split': 0.38155453612974793, 'lambda_l1': 8.127830567667169e-06, 'lambda_l2': 5.7412093467238784e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:47,305] Trial 67 finished with value: 0.2742118883230131 and parameters: {'learning_rate': 0.010195609490737601, 'num_leaves': 222, 'min_data_in_leaf': 41, 'feature_fraction': 0.8488710526542843, 'bagging_fraction': 0.7016604134125531, 'bagging_freq': 8, 'min_gain_to_split': 1.0677184302593172, 'lambda_l1': 4.059037932791934e-05, 'lambda_l2': 2.3817325024794125e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:47,644] Trial 68 finished with value: 0.30562626021262296 and parameters: {'learning_rate': 0.011392564261600766, 'num_leaves': 209, 'min_data_in_leaf': 24, 'feature_fraction': 0.8241161804434975, 'bagging_fraction': 0.7454998885683519, 'bagging_freq': 5, 'min_gain_to_split': 2.33260871927712, 'lambda_l1': 2.8479885997409043e-07, 'lambda_l2': 6.93266804115733e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:48,073] Trial 69 finished with value: 0.2413292605280865 and parameters: {'learning_rate': 0.016646036928909404, 'num_leaves': 232, 'min_data_in_leaf': 36, 'feature_fraction': 0.8023468456523263, 'bagging_fraction': 0.7788803293140384, 'bagging_freq': 5, 'min_gain_to_split': 0.569352204412339, 'lambda_l1': 0.00012319942701104845, 'lambda_l2': 2.2858993992141782e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:48,341] Trial 70 finished with value: 0.318932526987731 and parameters: {'learning_rate': 0.022067003522893036, 'num_leaves': 215, 'min_data_in_leaf': 15, 'feature_fraction': 0.883908171396319, 'bagging_fraction': 0.7570513002573659, 'bagging_freq': 6, 'min_gain_to_split': 3.0803450987203678, 'lambda_l1': 2.229937143694482e-06, 'lambda_l2': 2.142529467283038e-07}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:48,821] Trial 71 finished with value: 0.22968288424253475 and parameters: {'learning_rate': 0.013793209675152966, 'num_leaves': 247, 'min_data_in_leaf': 23, 'feature_fraction': 0.8833544547224437, 'bagging_fraction': 0.7198842838409839, 'bagging_freq': 6, 'min_gain_to_split': 0.3724316487603463, 'lambda_l1': 1.1077724859246517e-05, 'lambda_l2': 0.029076603197501265}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:49,276] Trial 72 finished with value: 0.2508524717046816 and parameters: {'learning_rate': 0.0128418267656025, 'num_leaves': 240, 'min_data_in_leaf': 21, 'feature_fraction': 0.8584393902273904, 'bagging_fraction': 0.7424324582652226, 'bagging_freq': 7, 'min_gain_to_split': 0.7578210347327814, 'lambda_l1': 5.750059015034916e-06, 'lambda_l2': 5.600230898464339e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:49,802] Trial 73 finished with value: 0.22301635456589128 and parameters: {'learning_rate': 0.013863731908937313, 'num_leaves': 229, 'min_data_in_leaf': 43, 'feature_fraction': 0.9262706844016478, 'bagging_fraction': 0.7323082723087632, 'bagging_freq': 7, 'min_gain_to_split': 0.13299866240029484, 'lambda_l1': 8.647668546496197e-06, 'lambda_l2': 3.90227417563218e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:10:50,459] Trial 74 finished with value: 0.2157575418004664 and parameters: {'learning_rate': 0.011287865912285039, 'num_leaves': 195, 'min_data_in_leaf': 31, 'feature_fraction': 0.9207807414629768, 'bagging_fraction': 0.6958168545234338, 'bagging_freq': 7, 'min_gain_to_split': 0.14453395020229443, 'lambda_l1': 7.388077504767533e-05, 'lambda_l2': 3.1179091376752264e-08}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:51,121] Trial 75 finished with value: 0.2233958566019269 and parameters: {'learning_rate': 0.011569242371339983, 'num_leaves': 194, 'min_data_in_leaf': 43, 'feature_fraction': 0.9287727919931772, 'bagging_fraction': 0.706151975614738, 'bagging_freq': 7, 'min_gain_to_split': 0.1302299112031346, 'lambda_l1': 0.00011150829054025236, 'lambda_l2': 3.090855472001954}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:52,011] Trial 76 finished with value: 0.21737546043082637 and parameters: {'learning_rate': 0.011354373332513702, 'num_leaves': 195, 'min_data_in_leaf': 45, 'feature_fraction': 0.9289438971970043, 'bagging_fraction': 0.6960092332823603, 'bagging_freq': 9, 'min_gain_to_split': 0.057620469942261686, 'lambda_l1': 6.610941992636544e-05, 'lambda_l2': 8.585314870933916}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:52,658] Trial 77 finished with value: 0.22916716351655322 and parameters: {'learning_rate': 0.01112052287199506, 'num_leaves': 199, 'min_data_in_leaf': 43, 'feature_fraction': 0.9401959707471222, 'bagging_fraction': 0.6908086172938367, 'bagging_freq': 9, 'min_gain_to_split': 0.1423536674364023, 'lambda_l1': 8.903011662719696e-05, 'lambda_l2': 7.927103454724667}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:53,415] Trial 78 finished with value: 0.21668962256143187 and parameters: {'learning_rate': 0.010080535741063662, 'num_leaves': 191, 'min_data_in_leaf': 32, 'feature_fraction': 0.9241547315147887, 'bagging_fraction': 0.6883686535637684, 'bagging_freq': 9, 'min_gain_to_split': 0.1283139046809463, 'lambda_l1': 0.0003420743724426345, 'lambda_l2': 1.9705978436736193}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:54,055] Trial 79 finished with value: 0.22233177488014264 and parameters: {'learning_rate': 0.010155855388193953, 'num_leaves': 194, 'min_data_in_leaf': 31, 'feature_fraction': 0.9655302098420435, 'bagging_fraction': 0.6717980355546597, 'bagging_freq': 10, 'min_gain_to_split': 0.16296951787293806, 'lambda_l1': 0.0003181571488447845, 'lambda_l2': 1.8142065963791052}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:54,732] Trial 80 finished with value: 0.22081739090431637 and parameters: {'learning_rate': 0.010100427250963068, 'num_leaves': 185, 'min_data_in_leaf': 30, 'feature_fraction': 0.9668112372620893, 'bagging_fraction': 0.6732492003761111, 'bagging_freq': 10, 'min_gain_to_split': 0.15523995941275015, 'lambda_l1': 0.00035206220618464666, 'lambda_l2': 1.0142411420666884}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:55,390] Trial 81 finished with value: 0.217219765566573 and parameters: {'learning_rate': 0.011583087631380525, 'num_leaves': 191, 'min_data_in_leaf': 32, 'feature_fraction': 0.9628908113580128, 'bagging_fraction': 0.6731142863580486, 'bagging_freq': 10, 'min_gain_to_split': 0.11015364392177204, 'lambda_l1': 0.0003947306266572177, 'lambda_l2': 1.5047041378717163}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:55,987] Trial 82 finished with value: 0.21672874854409113 and parameters: {'learning_rate': 0.011448607704956234, 'num_leaves': 190, 'min_data_in_leaf': 32, 'feature_fraction': 0.9860337401220564, 'bagging_fraction': 0.6647057899027823, 'bagging_freq': 10, 'min_gain_to_split': 0.11069492913414034, 'lambda_l1': 0.0003588809240794622, 'lambda_l2': 1.2990682030404486}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:56,668] Trial 83 finished with value: 0.21889362520723976 and parameters: {'learning_rate': 0.010083331403569389, 'num_leaves': 188, 'min_data_in_leaf': 32, 'feature_fraction': 0.9585721762040724, 'bagging_fraction': 0.6646937485505874, 'bagging_freq': 10, 'min_gain_to_split': 0.14228511361864768, 'lambda_l1': 0.0004357652519268997, 'lambda_l2': 0.9201454640545108}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:57,126] Trial 84 finished with value: 0.25229319671323114 and parameters: {'learning_rate': 0.010084037414285115, 'num_leaves': 189, 'min_data_in_leaf': 32, 'feature_fraction': 0.9824568543947053, 'bagging_fraction': 0.663143111009047, 'bagging_freq': 10, 'min_gain_to_split': 0.5807616440770921, 'lambda_l1': 0.00048755763389120055, 'lambda_l2': 0.9299706516616455}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:57,415] Trial 85 finished with value: 0.35058770962324426 and parameters: {'learning_rate': 0.010823679390340075, 'num_leaves': 186, 'min_data_in_leaf': 51, 'feature_fraction': 0.9569259187055771, 'bagging_fraction': 0.6606997611714348, 'bagging_freq': 9, 'min_gain_to_split': 3.6190408583698757, 'lambda_l1': 0.00027467952399194364, 'lambda_l2': 1.006458466929404}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:57,967] Trial 86 finished with value: 0.2219699010830404 and parameters: {'learning_rate': 0.011801901394517431, 'num_leaves': 194, 'min_data_in_leaf': 38, 'feature_fraction': 0.9703001477756812, 'bagging_fraction': 0.6392025694237602, 'bagging_freq': 10, 'min_gain_to_split': 0.1327013654276834, 'lambda_l1': 2.0333024107558995e-08, 'lambda_l2': 0.417375077048766}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:58,628] Trial 87 finished with value: 0.2171060611057208 and parameters: {'learning_rate': 0.011817697126286365, 'num_leaves': 180, 'min_data_in_leaf': 36, 'feature_fraction': 0.9848367456803002, 'bagging_fraction': 0.6399901842221389, 'bagging_freq': 10, 'min_gain_to_split': 0.0908159957228207, 'lambda_l1': 1.240652373491292e-07, 'lambda_l2': 0.3015958187247457}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:10:59,033] Trial 88 finished with value: 0.2539070837337317 and parameters: {'learning_rate': 0.011058682794580539, 'num_leaves': 173, 'min_data_in_leaf': 48, 'feature_fraction': 0.9849679469390841, 'bagging_fraction': 0.6893004797974602, 'bagging_freq': 9, 'min_gain_to_split': 0.5263309730660475, 'lambda_l1': 2.135485353695235e-07, 'lambda_l2': 0.0996962548708}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:11:01,032] Trial 89 finished with value: 0.21896646824746605 and parameters: {'learning_rate': 0.011975871308076242, 'num_leaves': 182, 'min_data_in_leaf': 56, 'feature_fraction': 0.9985210929395176, 'bagging_fraction': 0.6331827088717922, 'bagging_freq': 10, 'min_gain_to_split': 0.0030432285186680064, 'lambda_l1': 7.249359380290866e-08, 'lambda_l2': 7.406901113086489}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:11:01,805] Trial 90 finished with value: 0.21596831910698694 and parameters: {'learning_rate': 0.01214374415891908, 'num_leaves': 183, 'min_data_in_leaf': 33, 'feature_fraction': 0.9998070612682101, 'bagging_fraction': 0.6275006306815589, 'bagging_freq': 9, 'min_gain_to_split': 0.06555238023041955, 'lambda_l1': 9.497716677776018e-08, 'lambda_l2': 8.577586439603978}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:11:02,536] Trial 91 finished with value: 0.23629124179711686 and parameters: {'learning_rate': 0.012114185059847807, 'num_leaves': 182, 'min_data_in_leaf': 58, 'feature_fraction': 0.9936767674375271, 'bagging_fraction': 0.624370392377033, 'bagging_freq': 9, 'min_gain_to_split': 0.08878418455015424, 'lambda_l1': 9.408199186611136e-08, 'lambda_l2': 9.077553019205816}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:11:04,564] Trial 92 finished with value: 0.1970695260161059 and parameters: {'learning_rate': 0.011406554662892286, 'num_leaves': 179, 'min_data_in_leaf': 28, 'feature_fraction': 0.9592740710371461, 'bagging_fraction': 0.6443320220211108, 'bagging_freq': 10, 'min_gain_to_split': 0.010637766923309006, 'lambda_l1': 1.1081999060730397e-07, 'lambda_l2': 0.4586151771207017}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:06,306] Trial 93 finished with value: 0.19901509252726177 and parameters: {'learning_rate': 0.011485559174706752, 'num_leaves': 179, 'min_data_in_leaf': 27, 'feature_fraction': 0.9987865955116928, 'bagging_fraction': 0.6445512108090093, 'bagging_freq': 9, 'min_gain_to_split': 0.013663173667363998, 'lambda_l1': 5.098784879443109e-08, 'lambda_l2': 4.788731754383624}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:06,924] Trial 94 finished with value: 0.2319110618368482 and parameters: {'learning_rate': 0.01096514412664148, 'num_leaves': 170, 'min_data_in_leaf': 27, 'feature_fraction': 0.976523803026105, 'bagging_fraction': 0.6487967389122137, 'bagging_freq': 9, 'min_gain_to_split': 0.23485603676645683, 'lambda_l1': 3.667592184290493e-08, 'lambda_l2': 4.102184579103823}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:07,402] Trial 95 finished with value: 0.23415983214640632 and parameters: {'learning_rate': 0.0124260461309234, 'num_leaves': 204, 'min_data_in_leaf': 38, 'feature_fraction': 0.9874285026633228, 'bagging_fraction': 0.6106392268448001, 'bagging_freq': 9, 'min_gain_to_split': 0.25143592380259117, 'lambda_l1': 1.1503242480387996e-08, 'lambda_l2': 0.4183726318647883}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:07,794] Trial 96 finished with value: 0.24777092051001587 and parameters: {'learning_rate': 0.01470043317780968, 'num_leaves': 177, 'min_data_in_leaf': 34, 'feature_fraction': 0.9581632250061072, 'bagging_fraction': 0.6508042317961538, 'bagging_freq': 10, 'min_gain_to_split': 0.5054693672461388, 'lambda_l1': 4.061228916836169e-08, 'lambda_l2': 1.9334671533496837}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:08,168] Trial 97 finished with value: 0.24408332665896762 and parameters: {'learning_rate': 0.016924320288769754, 'num_leaves': 164, 'min_data_in_leaf': 46, 'feature_fraction': 0.9458446517538285, 'bagging_fraction': 0.612100137585723, 'bagging_freq': 8, 'min_gain_to_split': 0.2812426303788167, 'lambda_l1': 5.637178673278692e-08, 'lambda_l2': 4.939490459390343}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:09,031] Trial 98 finished with value: 0.20425420011467024 and parameters: {'learning_rate': 0.011467143997748272, 'num_leaves': 198, 'min_data_in_leaf': 26, 'feature_fraction': 0.9755385489613054, 'bagging_fraction': 0.68565300605924, 'bagging_freq': 10, 'min_gain_to_split': 0.05392583487019886, 'lambda_l1': 1.3926256048127265e-07, 'lambda_l2': 0.08546658882887474}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:10,117] Trial 99 finished with value: 0.19903788058696453 and parameters: {'learning_rate': 0.011527829385287836, 'num_leaves': 192, 'min_data_in_leaf': 25, 'feature_fraction': 0.988385355725671, 'bagging_fraction': 0.6852102568401665, 'bagging_freq': 9, 'min_gain_to_split': 0.030225061971817818, 'lambda_l1': 2.0059232654208337e-07, 'lambda_l2': 0.2402668114356527}. Best is trial 92 with value: 0.1970695260161059.
# [I 2025-09-15 01:11:12,498] Trial 100 finished with value: 0.19423823204150575 and parameters: {'learning_rate': 0.012838258471620463, 'num_leaves': 200, 'min_data_in_leaf': 25, 'feature_fraction': 0.9898803154265514, 'bagging_fraction': 0.6805387006145526, 'bagging_freq': 10, 'min_gain_to_split': 0.002941241683468772, 'lambda_l1': 5.992115442809247e-07, 'lambda_l2': 0.08351777291477337}. Best is trial 100 with value: 0.19423823204150575.
# [I 2025-09-15 01:11:12,988] Trial 101 finished with value: 0.2259692920805348 and parameters: {'learning_rate': 0.012882036884871198, 'num_leaves': 191, 'min_data_in_leaf': 26, 'feature_fraction': 0.9893848101836847, 'bagging_fraction': 0.6800071239291858, 'bagging_freq': 10, 'min_gain_to_split': 0.2842892086834663, 'lambda_l1': 1.4686427742016925e-07, 'lambda_l2': 0.08739962322586503}. Best is trial 100 with value: 0.19423823204150575.
# [I 2025-09-15 01:11:13,751] Trial 102 finished with value: 0.2159519172548447 and parameters: {'learning_rate': 0.010672886758118623, 'num_leaves': 206, 'min_data_in_leaf': 40, 'feature_fraction': 0.9775291614027989, 'bagging_fraction': 0.652582181858455, 'bagging_freq': 10, 'min_gain_to_split': 0.0823604014317906, 'lambda_l1': 2.3922012483291544e-08, 'lambda_l2': 0.23975221740326125}. Best is trial 100 with value: 0.19423823204150575.
# [I 2025-09-15 01:11:14,810] Trial 103 finished with value: 0.20539195700486 and parameters: {'learning_rate': 0.014551321120099063, 'num_leaves': 205, 'min_data_in_leaf': 40, 'feature_fraction': 0.9736160838055016, 'bagging_fraction': 0.6527404329521543, 'bagging_freq': 9, 'min_gain_to_split': 0.01758515081529713, 'lambda_l1': 6.158997674268858e-07, 'lambda_l2': 0.03000390752227883}. Best is trial 100 with value: 0.19423823204150575.
# [I 2025-09-15 01:11:15,152] Trial 104 finished with value: 0.28883674685982885 and parameters: {'learning_rate': 0.01089126267163792, 'num_leaves': 208, 'min_data_in_leaf': 15, 'feature_fraction': 0.9772430166203981, 'bagging_fraction': 0.6536040614002707, 'bagging_freq': 8, 'min_gain_to_split': 1.591140216718023, 'lambda_l1': 4.3217956089794745e-07, 'lambda_l2': 0.03180719357721047}. Best is trial 100 with value: 0.19423823204150575.
# [I 2025-09-15 01:11:16,775] Trial 105 finished with value: 0.2029508037384712 and parameters: {'learning_rate': 0.0157244167878567, 'num_leaves': 201, 'min_data_in_leaf': 38, 'feature_fraction': 0.9978350009153737, 'bagging_fraction': 0.6831788426226676, 'bagging_freq': 9, 'min_gain_to_split': 0.005776281723056026, 'lambda_l1': 5.866146695491527e-07, 'lambda_l2': 0.007677616403871079}. Best is trial 100 with value: 0.19423823204150575.
# [I 2025-09-15 01:11:17,834] Trial 106 finished with value: 0.19732809287832268 and parameters: {'learning_rate': 0.014925821335374918, 'num_leaves': 199, 'min_data_in_leaf': 24, 'feature_fraction': 0.9978740740757919, 'bagging_fraction': 0.7129860165923582, 'bagging_freq': 9, 'min_gain_to_split': 0.016375651723063087, 'lambda_l1': 5.399897630714411e-07, 'lambda_l2': 0.005159289295238999}. Best is trial 100 with value: 0.19423823204150575.
# [I 2025-09-15 01:11:19,186] Trial 107 finished with value: 0.20714922226935123 and parameters: {'learning_rate': 0.02002367973544402, 'num_leaves': 201, 'min_data_in_leaf': 39, 'feature_fraction': 0.9962117215406566, 'bagging_fraction': 0.6276912718063137, 'bagging_freq': 9, 'min_gain_to_split': 0.0025197581592976415, 'lambda_l1': 6.176442514323474e-07, 'lambda_l2': 0.004646167380554839}. Best is trial 100 with value: 0.19423823204150575.
# ...
# [I 2025-09-15 01:12:14,550] Trial 165 finished with value: 0.21772876115767464 and parameters: {'learning_rate': 0.018144723082225905, 'num_leaves': 240, 'min_data_in_leaf': 15, 'feature_fraction': 0.9368941249607289, 'bagging_fraction': 0.6605233231168466, 'bagging_freq': 10, 'min_gain_to_split': 0.22748692167309745, 'lambda_l1': 8.267150401751988e-07, 'lambda_l2': 0.040561037126184606}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:15,034] Trial 166 finished with value: 0.20819839202553708 and parameters: {'learning_rate': 0.019230128484140754, 'num_leaves': 230, 'min_data_in_leaf': 21, 'feature_fraction': 0.986809350213093, 'bagging_fraction': 0.6864273938329148, 'bagging_freq': 10, 'min_gain_to_split': 0.09495651357071284, 'lambda_l1': 1.0414149899621419e-08, 'lambda_l2': 0.30535548020690473}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:15,467] Trial 167 finished with value: 0.22288808533858911 and parameters: {'learning_rate': 0.016337774659280074, 'num_leaves': 225, 'min_data_in_leaf': 14, 'feature_fraction': 0.944696654929236, 'bagging_fraction': 0.6984082331421455, 'bagging_freq': 10, 'min_gain_to_split': 0.3088835480496329, 'lambda_l1': 2.9581666883919236e-08, 'lambda_l2': 0.14893217847527418}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:16,328] Trial 168 finished with value: 0.1919466228219733 and parameters: {'learning_rate': 0.026081098189161354, 'num_leaves': 255, 'min_data_in_leaf': 18, 'feature_fraction': 0.9483481864626302, 'bagging_fraction': 0.7240149869744406, 'bagging_freq': 10, 'min_gain_to_split': 0.01189722818070333, 'lambda_l1': 4.2292899006612665e-08, 'lambda_l2': 0.11697971593989662}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:16,698] Trial 169 finished with value: 0.21189813049893552 and parameters: {'learning_rate': 0.026515676319585242, 'num_leaves': 255, 'min_data_in_leaf': 10, 'feature_fraction': 0.9526832746611572, 'bagging_fraction': 0.7240087152976635, 'bagging_freq': 10, 'min_gain_to_split': 0.18997298470393392, 'lambda_l1': 3.630374410485867e-08, 'lambda_l2': 0.12632864812811653}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:18,574] Trial 170 finished with value: 0.19254778169714384 and parameters: {'learning_rate': 0.03254135552035713, 'num_leaves': 250, 'min_data_in_leaf': 18, 'feature_fraction': 0.9491296716498392, 'bagging_fraction': 0.7376058657997608, 'bagging_freq': 10, 'min_gain_to_split': 0.00015482081445427264, 'lambda_l1': 5.979874972602593e-08, 'lambda_l2': 0.06761240194054166}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:19,738] Trial 171 finished with value: 0.19198789956369144 and parameters: {'learning_rate': 0.02544106025579643, 'num_leaves': 251, 'min_data_in_leaf': 18, 'feature_fraction': 0.9511108791163024, 'bagging_fraction': 0.7329483794198728, 'bagging_freq': 10, 'min_gain_to_split': 0.006910753297982715, 'lambda_l1': 5.770982711702411e-08, 'lambda_l2': 0.06728187618635005}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:20,120] Trial 172 finished with value: 0.20766406265004575 and parameters: {'learning_rate': 0.032465171311154756, 'num_leaves': 251, 'min_data_in_leaf': 18, 'feature_fraction': 0.9356949462424423, 'bagging_fraction': 0.7330520078869792, 'bagging_freq': 10, 'min_gain_to_split': 0.10444315184294142, 'lambda_l1': 6.476753060834734e-08, 'lambda_l2': 0.06959385181962825}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:20,534] Trial 173 finished with value: 0.20591504267070743 and parameters: {'learning_rate': 0.030323330426382935, 'num_leaves': 245, 'min_data_in_leaf': 15, 'feature_fraction': 0.9539783781745149, 'bagging_fraction': 0.7383969339291775, 'bagging_freq': 10, 'min_gain_to_split': 0.09654820555457484, 'lambda_l1': 1.8356272565043612e-08, 'lambda_l2': 0.20651648013066168}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:20,897] Trial 174 finished with value: 0.2187043238820215 and parameters: {'learning_rate': 0.0277667307134582, 'num_leaves': 249, 'min_data_in_leaf': 21, 'feature_fraction': 0.9430973921745204, 'bagging_fraction': 0.7254844576286243, 'bagging_freq': 10, 'min_gain_to_split': 0.21502527921580528, 'lambda_l1': 4.78018328430123e-08, 'lambda_l2': 0.09797894344839994}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:22,606] Trial 175 finished with value: 0.19120387028142471 and parameters: {'learning_rate': 0.02543439080187058, 'num_leaves': 242, 'min_data_in_leaf': 18, 'feature_fraction': 0.9496271800840541, 'bagging_fraction': 0.7581864714521447, 'bagging_freq': 10, 'min_gain_to_split': 0.0027116096113075474, 'lambda_l1': 3.4779403135533725e-08, 'lambda_l2': 0.043635624891342165}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:23,719] Trial 176 finished with value: 0.19106322023682767 and parameters: {'learning_rate': 0.025144765536274528, 'num_leaves': 244, 'min_data_in_leaf': 14, 'feature_fraction': 0.9291795785035738, 'bagging_fraction': 0.734126602704609, 'bagging_freq': 10, 'min_gain_to_split': 0.007641029700325182, 'lambda_l1': 3.377559294772318e-08, 'lambda_l2': 0.043180262776313996}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:24,181] Trial 177 finished with value: 0.2102849294686458 and parameters: {'learning_rate': 0.025717064754743862, 'num_leaves': 243, 'min_data_in_leaf': 13, 'feature_fraction': 0.9599015986522428, 'bagging_fraction': 0.742045419622022, 'bagging_freq': 10, 'min_gain_to_split': 0.13382154521640882, 'lambda_l1': 3.603899618057377e-08, 'lambda_l2': 0.045730765453122546}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:24,405] Trial 178 finished with value: 0.3330470636329445 and parameters: {'learning_rate': 0.03834399352341816, 'num_leaves': 255, 'min_data_in_leaf': 17, 'feature_fraction': 0.9341252512471548, 'bagging_fraction': 0.7216784355269302, 'bagging_freq': 10, 'min_gain_to_split': 3.519334933331004, 'lambda_l1': 4.581828044796443e-08, 'lambda_l2': 0.02851512325281236}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:24,778] Trial 179 finished with value: 0.22025913284697224 and parameters: {'learning_rate': 0.02558162899023401, 'num_leaves': 248, 'min_data_in_leaf': 10, 'feature_fraction': 0.9167042640647725, 'bagging_fraction': 0.7544997308258724, 'bagging_freq': 10, 'min_gain_to_split': 0.2906500431825251, 'lambda_l1': 2.1238087893086813e-08, 'lambda_l2': 0.045234468525886}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:25,251] Trial 180 finished with value: 0.2061122069058683 and parameters: {'learning_rate': 0.02299738667938012, 'num_leaves': 241, 'min_data_in_leaf': 17, 'feature_fraction': 0.9488876257638225, 'bagging_fraction': 0.759223433447405, 'bagging_freq': 10, 'min_gain_to_split': 0.10183704821627854, 'lambda_l1': 2.9308209682075343e-08, 'lambda_l2': 0.3314150744764066}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:25,841] Trial 181 finished with value: 0.19726077053218466 and parameters: {'learning_rate': 0.027634855792037488, 'num_leaves': 246, 'min_data_in_leaf': 21, 'feature_fraction': 0.9477335339018491, 'bagging_fraction': 0.7467031624288445, 'bagging_freq': 10, 'min_gain_to_split': 0.024894066978984452, 'lambda_l1': 6.914361233813886e-08, 'lambda_l2': 0.12856300697205753}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:26,156] Trial 182 finished with value: 0.21218442354273942 and parameters: {'learning_rate': 0.03464563490894784, 'num_leaves': 251, 'min_data_in_leaf': 14, 'feature_fraction': 0.9664627594996996, 'bagging_fraction': 0.7338503298640321, 'bagging_freq': 10, 'min_gain_to_split': 0.15284712816789384, 'lambda_l1': 7.111473449360854e-08, 'lambda_l2': 0.06266758615482397}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:27,365] Trial 183 finished with value: 0.19309157346513617 and parameters: {'learning_rate': 0.023348883127793384, 'num_leaves': 238, 'min_data_in_leaf': 19, 'feature_fraction': 0.9309147597132322, 'bagging_fraction': 0.7685730101090973, 'bagging_freq': 10, 'min_gain_to_split': 0.006966750206401354, 'lambda_l1': 1.334676995876357e-08, 'lambda_l2': 0.22315291206694388}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:27,750] Trial 184 finished with value: 0.2167808263541747 and parameters: {'learning_rate': 0.02380590561898438, 'num_leaves': 238, 'min_data_in_leaf': 13, 'feature_fraction': 0.9385788152066665, 'bagging_fraction': 0.7667411185372284, 'bagging_freq': 10, 'min_gain_to_split': 0.20622227416276703, 'lambda_l1': 1.20606708440062e-08, 'lambda_l2': 0.6078813678614594}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:28,622] Trial 185 finished with value: 0.19331002046912285 and parameters: {'learning_rate': 0.029376593970596967, 'num_leaves': 244, 'min_data_in_leaf': 18, 'feature_fraction': 0.9285928964647787, 'bagging_fraction': 0.7091839266144784, 'bagging_freq': 10, 'min_gain_to_split': 0.00985910810630844, 'lambda_l1': 1.631656361544226e-08, 'lambda_l2': 0.0969855628408418}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:29,114] Trial 186 finished with value: 0.2080935269271072 and parameters: {'learning_rate': 0.022077932003542522, 'num_leaves': 251, 'min_data_in_leaf': 22, 'feature_fraction': 0.9638475115977829, 'bagging_fraction': 0.7312694521031563, 'bagging_freq': 10, 'min_gain_to_split': 0.10000587504236022, 'lambda_l1': 2.944730488819486e-08, 'lambda_l2': 0.03462999107877859}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:30,918] Trial 187 finished with value: 0.19034546049302475 and parameters: {'learning_rate': 0.025019173512866245, 'num_leaves': 255, 'min_data_in_leaf': 13, 'feature_fraction': 0.9306196765868081, 'bagging_fraction': 0.7538909356567237, 'bagging_freq': 10, 'min_gain_to_split': 0.0035576989611585683, 'lambda_l1': 1.1126345659518742e-07, 'lambda_l2': 0.2677346695036881}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:31,278] Trial 188 finished with value: 0.21620881280698065 and parameters: {'learning_rate': 0.025889173389609724, 'num_leaves': 57, 'min_data_in_leaf': 10, 'feature_fraction': 0.9228779424684423, 'bagging_fraction': 0.7463661286937646, 'bagging_freq': 10, 'min_gain_to_split': 0.2389889353833286, 'lambda_l1': 9.983386849810767e-08, 'lambda_l2': 0.06370381625212122}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:31,614] Trial 189 finished with value: 0.22955555326007787 and parameters: {'learning_rate': 0.029389343581146202, 'num_leaves': 255, 'min_data_in_leaf': 14, 'feature_fraction': 0.9079082565259857, 'bagging_fraction': 0.7504991931439008, 'bagging_freq': 10, 'min_gain_to_split': 0.3908162551023184, 'lambda_l1': 1.5259617002371928e-07, 'lambda_l2': 0.34135968239617787}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:32,004] Trial 190 finished with value: 0.20740001442723138 and parameters: {'learning_rate': 0.03186893511177765, 'num_leaves': 248, 'min_data_in_leaf': 16, 'feature_fraction': 0.95446984649608, 'bagging_fraction': 0.7370214247750917, 'bagging_freq': 10, 'min_gain_to_split': 0.10943767681559244, 'lambda_l1': 4.513168763175737e-08, 'lambda_l2': 0.12071198243431057}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:33,248] Trial 191 finished with value: 0.19298371021131921 and parameters: {'learning_rate': 0.024324205439614433, 'num_leaves': 241, 'min_data_in_leaf': 19, 'feature_fraction': 0.932492537235421, 'bagging_fraction': 0.7606252431624902, 'bagging_freq': 10, 'min_gain_to_split': 0.005233478236549665, 'lambda_l1': 4.59785395211065e-08, 'lambda_l2': 0.24674002181749224}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:34,773] Trial 192 finished with value: 0.1928628367922925 and parameters: {'learning_rate': 0.026648905944095483, 'num_leaves': 243, 'min_data_in_leaf': 13, 'feature_fraction': 0.9419408286916761, 'bagging_fraction': 0.7615918618104172, 'bagging_freq': 10, 'min_gain_to_split': 0.00326553558677947, 'lambda_l1': 1.1302678199920624e-07, 'lambda_l2': 0.1744126674802388}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:35,165] Trial 193 finished with value: 0.21149920057207944 and parameters: {'learning_rate': 0.027025324720687343, 'num_leaves': 251, 'min_data_in_leaf': 13, 'feature_fraction': 0.9708884504157461, 'bagging_fraction': 0.7528056769140987, 'bagging_freq': 10, 'min_gain_to_split': 0.16352045584467426, 'lambda_l1': 1.1038316788724021e-07, 'lambda_l2': 0.17427210543258753}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:35,611] Trial 194 finished with value: 0.20477203258252516 and parameters: {'learning_rate': 0.028559559406326575, 'num_leaves': 246, 'min_data_in_leaf': 10, 'feature_fraction': 0.9399622310442279, 'bagging_fraction': 0.727790128342805, 'bagging_freq': 10, 'min_gain_to_split': 0.08292468972205658, 'lambda_l1': 1.757530547403437e-07, 'lambda_l2': 0.044629025569465096}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:36,995] Trial 195 finished with value: 0.1917584642150501 and parameters: {'learning_rate': 0.02589450278773982, 'num_leaves': 251, 'min_data_in_leaf': 16, 'feature_fraction': 0.9638757733351762, 'bagging_fraction': 0.7087589829562726, 'bagging_freq': 10, 'min_gain_to_split': 0.005449626151030836, 'lambda_l1': 3.0706876276815795e-07, 'lambda_l2': 0.02482021447348353}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:37,358] Trial 196 finished with value: 0.218950053725346 and parameters: {'learning_rate': 0.025182878551079806, 'num_leaves': 255, 'min_data_in_leaf': 17, 'feature_fraction': 0.9611481828239476, 'bagging_fraction': 0.7088449582779132, 'bagging_freq': 10, 'min_gain_to_split': 0.26278352561667884, 'lambda_l1': 2.329730516340675e-07, 'lambda_l2': 0.02469960794971145}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:37,786] Trial 197 finished with value: 0.21657738886422706 and parameters: {'learning_rate': 0.02089503839601024, 'num_leaves': 250, 'min_data_in_leaf': 23, 'feature_fraction': 0.9705811282245835, 'bagging_fraction': 0.7177680118746554, 'bagging_freq': 10, 'min_gain_to_split': 0.1735197981169041, 'lambda_l1': 3.115109345918804e-07, 'lambda_l2': 0.06500778086557314}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:38,273] Trial 198 finished with value: 0.20690011018496848 and parameters: {'learning_rate': 0.021998386596619398, 'num_leaves': 246, 'min_data_in_leaf': 16, 'feature_fraction': 0.9535314044885425, 'bagging_fraction': 0.7037612750114262, 'bagging_freq': 10, 'min_gain_to_split': 0.09924261683628881, 'lambda_l1': 6.44362682195894e-08, 'lambda_l2': 0.10646753665187204}. Best is trial 155 with value: 0.18849606316335793.
# [I 2025-09-15 01:12:38,536] Trial 199 finished with value: 0.3315852905155383 and parameters: {'learning_rate': 0.015663776998398868, 'num_leaves': 235, 'min_data_in_leaf': 73, 'feature_fraction': 0.9742504738285696, 'bagging_fraction': 0.7194408634826002, 'bagging_freq': 10, 'min_gain_to_split': 2.890571040714183, 'lambda_l1': 2.656397065164923e-08, 'lambda_l2': 0.03016121211092224}. Best is trial 155 with value: 0.18849606316335793.
# [OPTUNA] best RMSLE: 0.1885
# [OPTUNA] best params:
#   learning_rate: 0.014928799195949352
#   num_leaves: 251
#   min_data_in_leaf: 10
#   feature_fraction: 0.9808414320782528
#   bagging_fraction: 0.6880294994972108
#   bagging_freq: 10
#   min_gain_to_split: 0.00014362186356836702
#   lambda_l1: 1.5306214748075095e-06
#   lambda_l2: 0.2646437047270915
# [OPTUNA] best_round: 425
# [CALIB] multiplier to latest: 1.1386
# Saved models → models

# %%
import matplotlib.pyplot as plt

# 重要度を取得
importance = model_point.feature_importance(importance_type="gain")
feature_names = model_point.feature_name()

# DataFrame化
import pandas as pd
fi = pd.DataFrame({
    "feature": feature_names,
    "importance": importance
}).sort_values("importance", ascending=False)

print(fi)

# 棒グラフで可視化
plt.figure(figsize=(8, 6))
plt.barh(fi["feature"], fi["importance"])
plt.gca().invert_yaxis()
plt.title("Feature Importance (by gain)")
plt.show()
# Out:
#                    feature   importance
# 5                 area_sqm  6920.933803
# 4                      築年数  1137.348297
# 7                sqrt_area   410.778445
# 15   layout_oof_median_log   222.751697
# 10           area_x_access   175.208302
# 12            layout_count   167.646625
# 18     layout_oof_mean_log   120.890647
# 26         img_ring_pca_03    47.225898
# 9                 age_sqrt    36.874662
# 36         img_ring_pca_13    31.878402
# 14  station_oof_median_log    29.290281
# 20             log_idx_psm    25.879703
# 31         img_ring_pca_08    25.148813
# 17    station_oof_mean_log    24.764504
# 29         img_ring_pca_06    20.547683
# 23         img_ring_pca_00    20.069261
# 3                 walk_min    19.932019
# 38         img_ring_pca_15    19.526157
# 25         img_ring_pca_02    19.284940
# 33         img_ring_pca_10    18.301946
# 11           station_count    17.147378
# 28         img_ring_pca_05    17.119398
# 24         img_ring_pca_01    16.301484
# 37         img_ring_pca_14    15.738449
# 19       area_oof_mean_log    14.868386
# 2              cat__layout    12.979264
# 16     area_oof_median_log    11.525877
# 34         img_ring_pca_11     9.338619
# 30         img_ring_pca_07     9.126631
# 32         img_ring_pca_09     8.864950
# 35         img_ring_pca_12     8.429241
# 27         img_ring_pca_04     7.019658
# 6             access_score     5.507955
# 1             cat__station     5.297375
# 13              area_count     3.911178
# 21                 idx_mom     1.072588
# 0          cat__area_group     0.000000
# 22                 idx_yoy     0.000000
# 8                 log_area     0.000000
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# ===== ここから追加：学習＆検証（OOF）精度の表示 =====
from sklearn.metrics import r2_score
import numpy as np

def _fmt_metric_row(tag, rmsle, r2, rmse_y, mae_y, mape):
    print(f"[{tag}] RMSLE={rmsle:.4f} | R2(log)={r2:.4f} | RMSE(円)={rmse_y:,.0f} | MAE(円)={mae_y:,.0f} | MAPE={mape:.2f}%")

def _yen_metrics(y_true_yen: np.ndarray, y_pred_yen: np.ndarray):
    rmse_y = float(np.sqrt(np.mean((y_true_yen - y_pred_yen) ** 2)))
    mae_y  = float(np.mean(np.abs(y_true_yen - y_pred_yen)))
    mape   = float(np.mean(np.abs((y_true_yen - y_pred_yen) / np.clip(y_true_yen, 1.0, None))) * 100.0)
    return rmse_y, mae_y, mape

# --- 学習データ上の精度 ---
best_it = getattr(model_point, "best_iteration", None)
y_log_pred_tr = model_point.predict(X_df, num_iteration=best_it)

# deflated のままのRMSE（RMSLE相当）
rmsle_tr = float(np.sqrt(np.mean((y_log - y_log_pred_tr) ** 2)))
r2_tr    = float(r2_score(y_log, y_log_pred_tr))

# ←← 真の価格は必ず y_log_true から戻す！
y_true_yen = np.expm1(y_log_true)

try:
    smear = float(smearing)
except NameError:
    smear = 1.0

if USE_DEFLATE:
    # 予測（相対ログ）に相場ログを足してから円に戻す（★ df[...] ではなく avg_psm_arr を使う）
    yhat_log1p_tr = y_log_pred_tr + np.log(avg_psm_arr)
    y_pred_yen_tr = smear * np.expm1(yhat_log1p_tr)
else:
    y_pred_yen_tr = smear * np.expm1(y_log_pred_tr)

rmse_y_tr, mae_y_tr, mape_tr = _yen_metrics(y_true_yen, y_pred_yen_tr)
_fmt_metric_row("TRAIN", rmsle_tr, r2_tr, rmse_y_tr, mae_y_tr, mape_tr)

# ② KFold OOF（疑似バリデーション）での精度
from sklearn.model_selection import KFold
import lightgbm as lgb

kf = KFold(n_splits=5, shuffle=True, random_state=SEED)
oof_pred_log = np.zeros_like(y_log, dtype=float)

# best_params / best_round / cat_cols / mono_cons は既存の変数を使用
for tr_idx, va_idx in kf.split(X_df):
    X_tr, X_va = X_df.iloc[tr_idx], X_df.iloc[va_idx]
    y_tr, y_va = y_log[tr_idx], y_log[va_idx]

     # ★ 追加：重みをfoldごとにスライス
    w_tr = None if 'sample_weight' not in globals() or sample_weight is None else sample_weight[tr_idx]
    w_va = None if 'sample_weight' not in globals() or sample_weight is None else sample_weight[va_idx]

    # ★ ここで weight=... を渡す
    dtr = lgb.Dataset(
        X_tr, label=y_tr, weight=w_tr,
        categorical_feature=cat_cols, free_raw_data=True
    )
    dva = lgb.Dataset(
        X_va, label=y_va, weight=w_va,
        categorical_feature=cat_cols, free_raw_data=True
    )

    params = dict(best_params)
    params.update({
        "objective": "rmse",
        "metric": "rmse",
        "verbosity": -1,
        "seed": SEED,
        "monotone_constraints": mono_cons,
    })

    booster = lgb.train(
        params, dtr,
        num_boost_round=best_round,
        valid_sets=[dva],
        callbacks=[],  # ここでは早停なし（best_round固定）
    )
    oof_pred_log[va_idx] = booster.predict(X_va, num_iteration=getattr(booster, "best_iteration", None))

# --- OOF（疑似バリデーション）---
# log空間のRMSE（deflated RMSE）
rmsle_oof = float(np.sqrt(np.mean((y_log - oof_pred_log) ** 2)))
r2_oof    = float(r2_score(y_log, oof_pred_log))

# 円スケール（deflate時は相場ログを足す）
if USE_DEFLATE and (avg_psm_arr is not None):
    y_pred_oof_yen = np.expm1(oof_pred_log + np.log(avg_psm_arr))
else:
    y_pred_oof_yen = np.expm1(oof_pred_log)

y_true_yen = np.expm1(y_log_true)
rmse_y_oof, mae_y_oof, mape_oof = _yen_metrics(y_true_yen, y_pred_oof_yen)
_fmt_metric_row("OOF", rmsle_oof, r2_oof, rmse_y_oof, mae_y_oof, mape_oof)

# === 直近水準の倍率キャリブ（最近 K ヶ月） ===
CALIB_RECENT_K = 2   # ← 好みで 2〜3 を推奨
uniq = np.unique(period_arr)
recent = uniq[-CALIB_RECENT_K:]
mask_recent = np.isin(period_arr, recent)
ratio = y_true_yen[mask_recent] / np.clip(y_pred_oof_yen[mask_recent], 1.0, None)
calib = float(np.median(np.clip(ratio, 0.7, 1.3)))  # クリップは安定化のため
print(f"[Calib] factor={calib:.4f} (recent {CALIB_RECENT_K} months)")

# 参考：キャリブ適用後の円スケール指標も表示
rmse_y_oof_c, mae_y_oof_c, mape_oof_c = _yen_metrics(y_true_yen, calib * y_pred_oof_yen)
_fmt_metric_row("OOF × Calib", rmsle_oof, r2_oof, rmse_y_oof_c, mae_y_oof_c, mape_oof_c)

# 直近重み付き（任意）
if 'sample_weight' in globals() and sample_weight is not None:
    # log側の重み付き誤差
    def _weighted_mean(x, w): return float(np.sum(w*x)/np.sum(w))
    rmsle_oof_w = float(np.sqrt(_weighted_mean((y_log - oof_pred_log)**2, sample_weight)))
    # 円スケール重み付き
    def _yen_metrics_weighted(y_true_yen, y_pred_yen, w):
        rmse_y = float(np.sqrt(_weighted_mean((y_true_yen - y_pred_yen)**2, w)))
        mae_y  = float(_weighted_mean(np.abs(y_true_yen - y_pred_yen), w))
        mape   = float(_weighted_mean(np.abs((y_true_yen - y_pred_yen) / np.clip(y_true_yen, 1.0, None)), w) * 100.0)
        return rmse_y, mae_y, mape
    rmse_y_oof_w, mae_y_oof_w, mape_oof_w = _yen_metrics_weighted(y_true_yen, y_pred_oof_yen, sample_weight)
    rmse_y_oof_w_c, mae_y_oof_w_c, mape_oof_w_c = _yen_metrics_weighted(y_true_yen, calib * y_pred_oof_yen, sample_weight)
    _fmt_metric_row("OOF[w]",   rmsle_oof_w, r2_oof, rmse_y_oof_w,   mae_y_oof_w,   mape_oof_w)
    _fmt_metric_row("OOF[w]×C", rmsle_oof_w, r2_oof, rmse_y_oof_w_c, mae_y_oof_w_c, mape_oof_w_c)
# Out:
# [TRAIN] RMSLE=0.1147 | R2(log)=0.9738 | RMSE(円)=12,649,164 | MAE(円)=8,243,741 | MAPE=8.67%
# [OOF] RMSLE=0.1720 | R2(log)=0.9410 | RMSE(円)=18,620,314 | MAE(円)=12,029,948 | MAPE=13.03%
# [Calib] factor=1.0127 (recent 2 months)
# [OOF × Calib] RMSLE=0.1720 | R2(log)=0.9410 | RMSE(円)=18,589,106 | MAE(円)=12,079,699 | MAPE=13.22%
# [OOF[w]] RMSLE=0.1709 | R2(log)=0.9410 | RMSE(円)=18,731,214 | MAE(円)=12,106,757 | MAPE=12.95%
# [OOF[w]×C] RMSLE=0.1709 | R2(log)=0.9410 | RMSE(円)=18,673,911 | MAE(円)=12,133,864 | MAPE=13.12%

# %%
import numpy as np
import pandas as pd
from PIL import Image
from scipy.stats import spearmanr

def quick_image_stats(img: Image.Image) -> dict:
    # HSVでざっくり：緑/水/明るさ、S/V
    import numpy as np
    hsv = np.array(img.convert("HSV")).astype(np.float32)
    H = hsv[...,0] / 255.0  # 0-1
    S = hsv[...,1] / 255.0
    V = hsv[...,2] / 255.0

    green = ((H>0.22)&(H<0.45)&(S>0.25)&(V>0.25)).mean()   # 目安
    water = ((H>0.50)&(H<0.70)&(S>0.25)).mean()            # 目安（青～水色）
    return {
        "mean_v": float(V.mean()),
        "mean_s": float(S.mean()),
        "green_ratio": float(green),
        "water_ratio": float(water),
    }

def probe_component_meaning(comp="img_pca_11", sample=40):
    st_pca = pd.read_parquet(EMBED_PARQUET)
    st_geo = pd.read_csv(STATIONS_GEO_CSV)
    df = st_pca.merge(st_geo, on="station", how="inner").dropna(subset=[comp,"lat","lon"])
    # 上位/下位から各20点ずつ取り、簡易統計とSpearman相関
    top = df.nlargest(sample//2, comp)
    bot = df.nsmallest(sample//2, comp)
    sub = pd.concat([top, bot])

    stats = []
    for _, r in sub.iterrows():
        img = fetch_center_patch(float(r["lat"]), float(r["lon"]), z=ZOOM, grid=GRID, crop_px=CROP_PX)
        if img is None: continue
        d = quick_image_stats(img)
        d[comp] = r[comp]
        stats.append(d)

    stat_df = pd.DataFrame(stats)
    for c in ["green_ratio","water_ratio","mean_s","mean_v"]:
        rho, p = spearmanr(stat_df[comp], stat_df[c])
        print(f"{comp} vs {c}: Spearman rho={rho:.3f}, p={p:.3g}")

# 例）img_pca_11 の意味あいを推測
probe_component_meaning("img_pca_11")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1602819525.py in <cell line: 0>()
#      44
#      45 # 例）img_pca_11 の意味あいを推測
# ---> 46 probe_component_meaning("img_pca_11")
#
# /tmp/ipython-input-1602819525.py in probe_component_meaning(comp, sample)
#      22
#      23 def probe_component_meaning(comp="img_pca_11", sample=40):
# ---> 24     st_pca = pd.read_parquet(EMBED_PARQUET)
#      25     st_geo = pd.read_csv(STATIONS_GEO_CSV)
#      26     df = st_pca.merge(st_geo, on="station", how="inner").dropna(subset=[comp,"lat","lon"])
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     265             to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
#     266
# --> 267         path_or_handle, handles, filesystem = _get_path_or_handle(
#     268             path,
#     269             filesystem,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     138         # fsspec resources can also point to directories
#     139         # this branch is used for example when reading from non-fsspec URLs
# --> 140         handles = get_handle(
#     141             path_or_handle, mode, is_text=False, storage_options=storage_options
#     142         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/external/img_vit_pca.parquet'

# %% [markdown]
# ＃#✅コードの概要
# #データ取り込みとクリーニング
# 元の取引CSV（中央区の実績）から 駅名・徒歩分・面積・築年数・価格 を整形。
#
# 「取引時期」から year / month / period(YYYYMM) を作成。
#
# 列名の揺れ・表記揺れを吸収して、学習用のきれいな表にする。
#
# #外部指数（平均㎡単価）の生成
#
# 別CSV（「平均売買㎡単価推移_東京都中央区.csv」など）から avg_psm_yen（平均㎡単価）を抽出。
#
# 月次（YYYYMM）に補間し、MoM/YoY・log指数などの派生特徴も作る。
#
# これを学習データと period でマージして、市場水準（相場）を注入する。
#
# #デフレート（相場調整）設計
#
# 価格の対数 y=log1p(price) を、相場(log(avg_psm))を引いた相対ログに置き換えて学習（オプション）。
#
# ねらい：景気や相場全体の上げ下げを先に“取り除く（=デフレート）”ことで、物件固有の要因（面積・駅近・築年数など）を学びやすくする。
#
# 最終的な円に戻す時は、予測（相対ログ）＋相場ログ→expm1で復元。
#
# #駅→エリアの付与（地理の離散化）
#
# 駅名から 5エリア（銀座・京橋／日本橋・人形町／月島・勝どき・晴海／築地・八丁堀／佃・新川・湊） を自動付与。
#
# 地域クラスタをカテゴリ特徴として使う。
#
# #画像特徴（航空写真 × ViT × PCA）
#
# 駅名を ジオコーディング（緯度経度） → 国土地理院の航空写真タイルから 駅周辺を512pxで切り出し。
#
# **ViT（画像モデル）**で 768次元の埋め込みを作成 → **PCA(16次元)**に圧縮。
#
# 駅ごとの img_pca_00〜15 をテーブルにJOINし、**街並みの質感（緑・水面・密度・明るさなどの“見えない特徴”）**を数値化して学習に活用。
#
# #特徴量エンジニアリング
#
# 例：面積の平方根／log、駅近スコア（1/(1+徒歩分)）、面積×駅近 などの派生。
#
# 頻度特徴（駅/間取り/エリアの出現回数）。
#
# OOFターゲットエンコーディング（駅/間取り/エリアごとに、fold外の中央値・平均でエンコード）でカテゴリ情報を強化。
#
# 外部指数の log_idx_psm, idx_mom, idx_yoy を数値特徴として追加。
#
# #時間に基づく重み付け（サンプルウェイト）
#
# 新しい月ほど重く、古い月ほど軽くなる 半減期ウェイト（例：12か月） を付与。
#
# 直近の分布に合わせやすくなる。
#
# #モデル学習（Optuna × 時系列CV）
#
# TimeSeriesSplit で古→新の順を守る検証。
#
# Optunaで LightGBMのハイパラ探索（RMSLE最小化）。
#
# 単調性制約（徒歩分↓・築年数↓・面積↑ など）を適用して、常識に反しない方向に木の分岐を縛る。
#
# 本学習では：
#
# ポイント予測モデル（rmse）
#
# 分位点モデル（q10 / q90）（quantile）→ 予測区間を出せる
#
# smearing補正：log→円に戻した時のバイアスを補正する係数を学習残差から推定
#
# #検証とキャリブレーション
#
# 学習データ上・KFold OOFで RMSLE / R2(log) / RMSE円 / MAE円 / MAPE を算出。
#
# 最近Kか月のOOF結果から中央値比をとり、微小なズレを補正する Calib factor を出す。
#
# さらに外部指数の最新水準に合わせる [CALIB] multiplier to latest も計算（学習末月→最新月の指数比）。
#
# #保存・可視化・解釈
#
# 学習済みモデル（ポイント / q10 / q90）、エンコーダや列設定、calibration・use_deflate を保存。
#
# 特徴量重要度を出力（どの特徴が効いたかを確認）。
#
# 画像PCAの成分の“意味”をざっくり当てるための 相関プローブ（緑比率・水面比率・明るさなどとのSpearman相関を出す補助関数）。
#
# #もう少しだけ各設計の意図
#
# - デフレート：
# 「価格」=「相場水準」×「物件固有要因」。
# 先に相場を分離して“物件らしさ”を学ぶと、相場ショックに引っ張られにくい。推論時はふたたび相場を掛け戻すので、現時点の水準に調和する。
#
# - 画像特徴（ViT-PCA）：
# 価格に効く「目に見えない街の雰囲気（緑地、水辺、建物密度、道路幅、光/影のコントラスト…）」を駅周辺の航空写真から機械的に抽出。駅レベルに集約することで、データの安定性と計算効率を両立。
#
# - 単調性制約：
# モデルが「徒歩が遠いほど価格が上がる」みたいな逆転をしにくくし、外れ挙動を抑制。
#
# - 時系列CV＋サンプル重み：
# “未来を当てる”検証に寄せる（過去→未来の順序を守る）。さらに直近を重視して最新の傾向にフィット。
#
# - 分位点モデルとsmearing：
# ポイント予測だけでなく 区間（q10〜q90）を出す設計。ログ正規っぽい誤差を円に戻す際の平均ズレは smearing で補正。
#
# - 2段キャリブ：
# OOFの最近Kヶ月でズレを微調整（モデル側の系統誤差を抑える）。
# 外部指数の最新水準で倍率を掛け、公表される直近相場への追随性を担保。
#
# #使う人目線での“メンタルモデル”
#
# 履歴データを“時系列に正しく評価”しながら、物件固有の要因を学ぶ。
#
# 街の見た目（画像）と相場水準（指数）も取り入れ、説明変数の幅を拡張。
#
# 予測は 相対価格→相場を掛け戻す→円、最後に直近の微調整をして現実に寄せる。
#
# 結果として、安定した精度と直近の整合性を両立し、区間推定で不確実性も提示。
#
# #次に深掘りするなら
#
# デフレートON/OFFの精度比較（RMSLE/MAEの実測差）
#
# 画像PCA各成分の意味の検証（上位・下位駅のサンプル可視化）
#
# 単調性制約の強弱と特徴量の相互作用
#
# サンプル半減期（6, 12, 18ヶ月）の感度分析
#
# 分位点（q05/q95 など）やピンボール損失の最適化

# %% [markdown]
# #✅  画像特徴について
# 1. 今の仕組み
# - 1駅につき1枚の航空写真を使っています。
# - 駅の緯度経度を中心に、ズーム18でタイルを貼り合わせ → 中央部分を 512×512ピクセル（px） で切り出しています。
# - 512px というのは「画像の大きさ」で、縦512ピクセル × 横512ピクセルの四角い画像、という意味です。
#
# 2. ViTで特徴抽出
# - この画像を Vision Transformer (ViT) に入力すると、
# 出力として 768次元のベクトル（数値のリスト）が得られます。
# これは「街並みの雰囲気を数値化した座標」みたいなものです。
# 緑が多いか、水辺があるか、建物が密集しているか、などが“暗黙的に”含まれている。
#
# 3. PCAで次元圧縮
# - 768次元は多すぎるので、そのまま使うと「計算が重い」「ノイズが多い」。
# そこで 主成分分析（PCA） で圧縮して、16次元（img_pca_00 〜 img_pca_15）にまとめます。
# これで「街並みの要素」を少数の軸に整理し、機械学習モデルに使いやすくしています。
#
# 4. テーブルに追加
# - こうして作った 16列を、もともとの学習データ（駅名・面積・築年数など）にJOINして、学習に活用しています。
# つまり「1駅 = 1枚の航空写真 → 16個の数値特徴」に変換されているわけです。

# %% [markdown]
# #✅ モデル学習に使った特徴量
# #1. カテゴリ特徴（OrdinalEncoderで数値化）
# - cat__area_group（駅を5エリアに分類したカテゴリ）
# - cat__station（最寄駅名）
# - cat__layout（間取り）
#
# #2. 数値特徴
# 基本的な数値
#
# - walk_min（徒歩分数）
# - 築年数
# - area_sqm（面積㎡）
#
# 派生数値
#
# - access_score = 1 / (1 + walk_min)
# - sqrt_area = √(area_sqm)
# - log_area = log1p(area_sqm)
# - age_sqrt = √(築年数)
# - area_x_access = area_sqm × access_score
#
# 出現頻度
#
# - station_count（駅ごとの出現件数）
# - layout_count（間取りごとの出現件数）
# - area_count（エリアごとの出現件数）
#
# OOFターゲットエンコーディング
#
# - station_oof_median_log
# - layout_oof_median_log
# - area_oof_median_log
# - station_oof_mean_log
# - layout_oof_mean_log
# - area_oof_mean_log
#
# 外部指数（平均㎡単価）
#
# - log_idx_psm（指数の対数値）
# - idx_mom（前月比）
# - idx_yoy（前年比）
#
# 画像特徴（ViT + PCA）
#
# - img_pca_00
# - img_pca_01
# …
# -img_pca_15
#
# （合計16次元）

# %%
import time
import numpy as np
import pandas as pd

# These must already be defined in your environment:
# - build_table_and_features()
# - tune_with_optuna(...)
# - train_final_models(...)
# - lgb imported
# - SEED, USE_DEFLATE (global)

def _yen_metrics(y_true_yen: np.ndarray, y_pred_yen: np.ndarray):
    rmse_y = float(np.sqrt(np.mean((y_true_yen - y_pred_yen) ** 2)))
    mae_y  = float(np.mean(np.abs(y_true_yen - y_pred_yen)))
    mape   = float(np.mean(np.abs((y_true_yen - y_pred_yen) / np.clip(y_true_yen, 1.0, None))) * 100.0)
    return rmse_y, mae_y, mape

def _fmt_metric_row(tag, rmsle, r2, rmse_y, mae_y, mape):
    return dict(
        setting=tag,
        RMSLE=round(rmsle, 4),
        R2_log=round(r2, 4),
        RMSE_yen=int(rmse_y),
        MAE_yen=int(mae_y),
        MAPE_pct=round(mape, 2),
    )

def _compute_oof_scores(X_df, y_log, cat_cols, mono_cons, best_params, best_round,
                        sample_weight, avg_psm_arr, y_log_true, period_arr, use_deflate: bool):
    from sklearn.model_selection import KFold
    from sklearn.metrics import r2_score
    import lightgbm as lgb

    kf = KFold(n_splits=5, shuffle=True, random_state=SEED)
    oof_pred_log = np.zeros_like(y_log, dtype=float)

    for tr_idx, va_idx in kf.split(X_df):
        X_tr, X_va = X_df.iloc[tr_idx], X_df.iloc[va_idx]
        y_tr, y_va = y_log[tr_idx], y_log[va_idx]
        w_tr = None if sample_weight is None else sample_weight[tr_idx]
        w_va = None if sample_weight is None else sample_weight[va_idx]

        dtr = lgb.Dataset(X_tr, label=y_tr, weight=w_tr,
                          categorical_feature=cat_cols, free_raw_data=True)
        dva = lgb.Dataset(X_va, label=y_va, weight=w_va,
                          categorical_feature=cat_cols, free_raw_data=True)

        params = dict(best_params)
        params.update({
            "objective": "rmse",
            "metric": "rmse",
            "verbosity": -1,
            "seed": SEED,
            "monotone_constraints": mono_cons,
        })

        booster = lgb.train(params, dtr, num_boost_round=best_round,
                            valid_sets=[dva], callbacks=[])
        oof_pred_log[va_idx] = booster.predict(X_va, num_iteration=getattr(booster, "best_iteration", None))

    # log空間のRMSE
    rmsle_oof = float(np.sqrt(np.mean((y_log - oof_pred_log) ** 2)))
    r2_oof    = float(r2_score(y_log, oof_pred_log))

    # 円スケール
    if use_deflate and (avg_psm_arr is not None):
        y_pred_oof_yen = np.expm1(oof_pred_log + np.log(avg_psm_arr))
    else:
        y_pred_oof_yen = np.expm1(oof_pred_log)

    y_true_yen = np.expm1(y_log_true)
    rmse_y_oof, mae_y_oof, mape_oof = _yen_metrics(y_true_yen, y_pred_oof_yen)
    return rmsle_oof, r2_oof, rmse_y_oof, mae_y_oof, mape_oof

def run_setting(deflate: bool, use_images: bool, n_trials: int = 150, tag: str | None = None):
    global USE_DEFLATE
    old = USE_DEFLATE
    USE_DEFLATE = deflate
    try:
        t0 = time.time()
        X_df, y_log, cat_cols, mono_cons, meta, oe, infer_maps, sample_weight, avg_psm_arr, y_log_true, period_arr = build_table_and_features()

        if not use_images:
            img_cols = [c for c in X_df.columns if c.startswith("img_pca_")]
            X_df = X_df.drop(columns=img_cols)
            meta["feat_num"] = [c for c in meta["feat_num"] if not c.startswith("img_pca_")]


        sign_map = {
        "walk_min": -1,     # 駅から遠いほど↓
        "築年数": -1,        # 古いほど↓
        "area_sqm": +1,     # 広いほど↑
        "access_score": +1, # 近いほど↑（walk_minの反対符号）
        "sqrt_area": +1,
        "log_area": +1,
        "age_sqrt": -1,
            # 画像特徴やその他の列は既定で0（制約なし）
         }

        # X_df は [cat..., num...] の順のはず。列名を見て安全に作る
        rebuilt_mono = []
        cat_set = set(cat_cols)
        for col in X_df.columns:
            if col in cat_set:
                rebuilt_mono.append(0)
            else:
                rebuilt_mono.append(sign_map.get(col, 0))

        mono_cons = rebuilt_mono  # 以降はこの制約を使う

        best_params, best_round, best_score = tune_with_optuna(
            X_df, y_log, y_log_true, cat_cols, mono_cons, period_arr,
            n_trials=n_trials, sample_weight=sample_weight, avg_psm=avg_psm_arr
        )

        rmsle_oof, r2_oof, rmse_y, mae_y, mape = _compute_oof_scores(
            X_df, y_log, cat_cols, mono_cons, best_params, best_round,
            sample_weight, avg_psm_arr, y_log_true, period_arr, use_deflate=deflate
        )
        sec = time.time() - t0

        name = tag or f"deflate={'ON' if deflate else 'OFF'} | image={'ON' if use_images else 'OFF'}"
        row = _fmt_metric_row(name, rmsle_oof, r2_oof, rmse_y, mae_y, mape)
        row["best_round"] = int(best_round)
        row["optuna_best_rmsle"] = round(best_score, 4)
        row["minutes"] = round(sec/60.0, 1)
        row["features"] = X_df.shape[1]
        return row
    finally:
        USE_DEFLATE = old

def main():
    settings = [
        (True,  True,  "Deflate ON + Image ON"),
        (True,  False, "Deflate ON + Image OFF"),
        (False, True,  "Deflate OFF + Image ON"),
        (False, False, "Deflate OFF + Image OFF"),
    ]

    rows = []
    for d, im, tag in settings:
        print(f"=== Running: {tag} ===")
        row = run_setting(deflate=d, use_images=im, n_trials=120, tag=tag)
        print(row)
        rows.append(row)

    df = pd.DataFrame(rows).set_index("setting").sort_values("RMSLE")
    print("\\n=== Summary (lower is better for errors) ===")
    print(df)

if __name__ == "__main__":
    main()
# Out:
# === Running: Deflate ON + Image ON ===
# Geocoding stations: 100%|██████████| 26/26 [00:02<00:00, 12.12it/s]
# /tmp/ipython-input-2560219852.py:61: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[c] = df[c].fillna(method="ffill").fillna(method="bfill")
# [I 2025-09-15 01:13:04,085] A new study created in memory with name: no-name-4cb01bc2-4e23-4837-b498-79bf4c529a4a
# [I 2025-09-15 01:13:04,235] Trial 0 finished with value: 0.3924732674391598 and parameters: {'learning_rate': 0.05176340429875833, 'num_leaves': 191, 'min_data_in_leaf': 125, 'feature_fraction': 0.8179532731987588, 'bagging_fraction': 0.7694619197355619, 'bagging_freq': 7, 'min_gain_to_split': 2.1879360563134624, 'lambda_l1': 1.0615904599004014, 'lambda_l2': 4.709392030276881}. Best is trial 0 with value: 0.3924732674391598.
# [I 2025-09-15 01:13:04,465] Trial 1 finished with value: 0.2590641930352242 and parameters: {'learning_rate': 0.03154052496956797, 'num_leaves': 209, 'min_data_in_leaf': 111, 'feature_fraction': 0.827217824437573, 'bagging_fraction': 0.9702386553170644, 'bagging_freq': 0, 'min_gain_to_split': 0.43564649850770354, 'lambda_l1': 1.5204270129130175e-08, 'lambda_l2': 0.31158648353398066}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:04,602] Trial 2 finished with value: 0.372921364772549 and parameters: {'learning_rate': 0.10289760686796066, 'num_leaves': 226, 'min_data_in_leaf': 196, 'feature_fraction': 0.9196634256866895, 'bagging_fraction': 0.7845917449011728, 'bagging_freq': 8, 'min_gain_to_split': 0.5913721293446661, 'lambda_l1': 0.005744988873954126, 'lambda_l2': 1.9506510537765813e-07}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:04,730] Trial 3 finished with value: 0.311238877364543 and parameters: {'learning_rate': 0.16945039949066026, 'num_leaves': 148, 'min_data_in_leaf': 89, 'feature_fraction': 0.7058222448418507, 'bagging_fraction': 0.9096934757736866, 'bagging_freq': 5, 'min_gain_to_split': 2.8421697443432423, 'lambda_l1': 1.4760742495197955e-08, 'lambda_l2': 0.003620090882797527}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:04,861] Trial 4 finished with value: 0.42373707410359646 and parameters: {'learning_rate': 0.06256837783419193, 'num_leaves': 169, 'min_data_in_leaf': 190, 'feature_fraction': 0.8727281196413934, 'bagging_fraction': 0.7438031602295144, 'bagging_freq': 4, 'min_gain_to_split': 3.4881559796363244, 'lambda_l1': 3.483607722774873e-08, 'lambda_l2': 0.010020754882942}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:04,991] Trial 5 finished with value: 0.41323336670652144 and parameters: {'learning_rate': 0.07456241820636361, 'num_leaves': 78, 'min_data_in_leaf': 34, 'feature_fraction': 0.7261713403696736, 'bagging_fraction': 0.745484308377049, 'bagging_freq': 6, 'min_gain_to_split': 2.193007567311602, 'lambda_l1': 7.858950304147583, 'lambda_l2': 8.287113686365243e-08}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:05,240] Trial 6 finished with value: 0.3567631777827347 and parameters: {'learning_rate': 0.018696268012559407, 'num_leaves': 67, 'min_data_in_leaf': 134, 'feature_fraction': 0.7013166410159128, 'bagging_fraction': 0.7865243091425225, 'bagging_freq': 2, 'min_gain_to_split': 0.7948479182275986, 'lambda_l1': 9.848640172873773e-08, 'lambda_l2': 0.008071724032088088}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:05,496] Trial 7 finished with value: 0.35579691249463147 and parameters: {'learning_rate': 0.015127952931538244, 'num_leaves': 75, 'min_data_in_leaf': 80, 'feature_fraction': 0.9283972919391741, 'bagging_fraction': 0.6388405103172244, 'bagging_freq': 9, 'min_gain_to_split': 0.48049203946981534, 'lambda_l1': 6.139530838198258, 'lambda_l2': 0.00016514324529254103}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:05,659] Trial 8 finished with value: 0.36955039891126723 and parameters: {'learning_rate': 0.18655009491114, 'num_leaves': 167, 'min_data_in_leaf': 151, 'feature_fraction': 0.6156751169017283, 'bagging_fraction': 0.7131227850305638, 'bagging_freq': 1, 'min_gain_to_split': 1.4807009876107247, 'lambda_l1': 1.1709799813329268e-07, 'lambda_l2': 7.275261607979148e-06}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:05,867] Trial 9 finished with value: 0.3594024174722815 and parameters: {'learning_rate': 0.034591435253679685, 'num_leaves': 45, 'min_data_in_leaf': 142, 'feature_fraction': 0.8266405816826301, 'bagging_fraction': 0.7061557963757782, 'bagging_freq': 5, 'min_gain_to_split': 0.4697025537922084, 'lambda_l1': 0.0015258732517912485, 'lambda_l2': 2.3102861693191303}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:06,076] Trial 10 finished with value: 0.3298700253244574 and parameters: {'learning_rate': 0.026313243719781314, 'num_leaves': 252, 'min_data_in_leaf': 13, 'feature_fraction': 0.9718561420111322, 'bagging_fraction': 0.9874235852979864, 'bagging_freq': 0, 'min_gain_to_split': 4.266444012048565, 'lambda_l1': 3.812573778417783e-06, 'lambda_l2': 0.1576163230730776}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:06,231] Trial 11 finished with value: 0.31022448576658934 and parameters: {'learning_rate': 0.1963897039336736, 'num_leaves': 124, 'min_data_in_leaf': 79, 'feature_fraction': 0.7336547345887859, 'bagging_fraction': 0.941933353477239, 'bagging_freq': 3, 'min_gain_to_split': 3.153147734051915, 'lambda_l1': 5.472680033298529e-06, 'lambda_l2': 0.0020554981135760013}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:06,422] Trial 12 finished with value: 0.3447098078678082 and parameters: {'learning_rate': 0.029994630887823576, 'num_leaves': 113, 'min_data_in_leaf': 55, 'feature_fraction': 0.761002745881162, 'bagging_fraction': 0.8925544545393606, 'bagging_freq': 3, 'min_gain_to_split': 4.703132171701716, 'lambda_l1': 1.8464626590054624e-05, 'lambda_l2': 0.00018209025984283314}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:06,694] Trial 13 finished with value: 0.32873909333769513 and parameters: {'learning_rate': 0.0104734539761103, 'num_leaves': 106, 'min_data_in_leaf': 105, 'feature_fraction': 0.6270136740544179, 'bagging_fraction': 0.9966653349505291, 'bagging_freq': 0, 'min_gain_to_split': 3.2847998828328775, 'lambda_l1': 4.243597632266006e-06, 'lambda_l2': 0.17235871773429867}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:06,880] Trial 14 finished with value: 0.27553785316261337 and parameters: {'learning_rate': 0.11191293910735194, 'num_leaves': 205, 'min_data_in_leaf': 63, 'feature_fraction': 0.7697290059002225, 'bagging_fraction': 0.8828672827489938, 'bagging_freq': 2, 'min_gain_to_split': 1.419255063685207, 'lambda_l1': 5.7547551550948315e-05, 'lambda_l2': 7.280839535804753e-06}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:07,061] Trial 15 finished with value: 0.2753792694989311 and parameters: {'learning_rate': 0.09580155796250439, 'num_leaves': 214, 'min_data_in_leaf': 49, 'feature_fraction': 0.8528057033837755, 'bagging_fraction': 0.850192272167609, 'bagging_freq': 2, 'min_gain_to_split': 1.3930335438129569, 'lambda_l1': 0.10112699832080597, 'lambda_l2': 4.3376796093213965e-06}. Best is trial 1 with value: 0.2590641930352242.
# [I 2025-09-15 01:13:07,863] Trial 16 finished with value: 0.23521314962172402 and parameters: {'learning_rate': 0.04100379402482349, 'num_leaves': 250, 'min_data_in_leaf': 110, 'feature_fraction': 0.8533979699031061, 'bagging_fraction': 0.8614849151905116, 'bagging_freq': 1, 'min_gain_to_split': 0.016504669608224498, 'lambda_l1': 0.0754388300231872, 'lambda_l2': 3.5078756137711755e-06}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:13:08,278] Trial 17 finished with value: 0.3248680069137788 and parameters: {'learning_rate': 0.040473758735960846, 'num_leaves': 255, 'min_data_in_leaf': 164, 'feature_fraction': 0.8908780805798382, 'bagging_fraction': 0.8433373601708026, 'bagging_freq': 0, 'min_gain_to_split': 0.01296129609539982, 'lambda_l1': 0.03274375558738424, 'lambda_l2': 1.6632420209060216e-08}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:13:08,696] Trial 18 finished with value: 0.2814467136903524 and parameters: {'learning_rate': 0.02224728520689278, 'num_leaves': 228, 'min_data_in_leaf': 118, 'feature_fraction': 0.976669324808731, 'bagging_fraction': 0.9407549214394862, 'bagging_freq': 1, 'min_gain_to_split': 1.0402757312178261, 'lambda_l1': 0.00031408944989802956, 'lambda_l2': 9.204008004204431e-07}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:13:09,004] Trial 19 finished with value: 0.2961696896875944 and parameters: {'learning_rate': 0.04275204727279851, 'num_leaves': 189, 'min_data_in_leaf': 103, 'feature_fraction': 0.7880319552413594, 'bagging_fraction': 0.8214040515296359, 'bagging_freq': 1, 'min_gain_to_split': 1.656066554055904, 'lambda_l1': 0.13722766058970015, 'lambda_l2': 4.022568907004666e-05}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:13:10,372] Trial 20 finished with value: 0.32817815415540724 and parameters: {'learning_rate': 0.011949809812196486, 'num_leaves': 236, 'min_data_in_leaf': 180, 'feature_fraction': 0.8384201900092699, 'bagging_fraction': 0.9510822927516864, 'bagging_freq': 10, 'min_gain_to_split': 0.01132627839293976, 'lambda_l1': 3.333774952321156e-07, 'lambda_l2': 0.15596268382509007}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:13:10,562] Trial 21 finished with value: 0.265294292170327 and parameters: {'learning_rate': 0.07112133760302723, 'num_leaves': 208, 'min_data_in_leaf': 46, 'feature_fraction': 0.8542476996660545, 'bagging_fraction': 0.8445612636480443, 'bagging_freq': 2, 'min_gain_to_split': 1.0348809252392803, 'lambda_l1': 0.13087681903838458, 'lambda_l2': 4.391052876407009e-06}. Best is trial 16 with value: 0.23521314962172402.
# [I 2025-09-15 01:13:11,192] Trial 22 finished with value: 0.22674258798650687 and parameters: {'learning_rate': 0.06442637237877033, 'num_leaves': 198, 'min_data_in_leaf': 96, 'feature_fraction': 0.9003038148609065, 'bagging_fraction': 0.8618495781703216, 'bagging_freq': 3, 'min_gain_to_split': 0.002669635093123013, 'lambda_l1': 0.007704288519366065, 'lambda_l2': 8.671002568144424e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:11,626] Trial 23 finished with value: 0.2422749697274679 and parameters: {'learning_rate': 0.03640054291990616, 'num_leaves': 183, 'min_data_in_leaf': 116, 'feature_fraction': 0.9107702656406316, 'bagging_fraction': 0.8741534786359838, 'bagging_freq': 4, 'min_gain_to_split': 0.02432051897517451, 'lambda_l1': 0.008236584427836958, 'lambda_l2': 4.92696931076956e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:11,917] Trial 24 finished with value: 0.22730398635381083 and parameters: {'learning_rate': 0.054853987482098666, 'num_leaves': 176, 'min_data_in_leaf': 89, 'feature_fraction': 0.9267276329740006, 'bagging_fraction': 0.8727566839287973, 'bagging_freq': 4, 'min_gain_to_split': 0.03194460369011835, 'lambda_l1': 0.006543587818302081, 'lambda_l2': 5.287069763505016e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:12,120] Trial 25 finished with value: 0.2767743602337213 and parameters: {'learning_rate': 0.04957517735388509, 'num_leaves': 154, 'min_data_in_leaf': 95, 'feature_fraction': 0.9446391329037549, 'bagging_fraction': 0.9152452479975249, 'bagging_freq': 4, 'min_gain_to_split': 0.9808360212390712, 'lambda_l1': 0.0006052949396669011, 'lambda_l2': 1.0963917452484431e-08}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:12,339] Trial 26 finished with value: 0.24557208722114945 and parameters: {'learning_rate': 0.055974338150454814, 'num_leaves': 239, 'min_data_in_leaf': 70, 'feature_fraction': 0.9927737330936679, 'bagging_fraction': 0.829265932466143, 'bagging_freq': 6, 'min_gain_to_split': 0.26285737033474205, 'lambda_l1': 0.5719044759012035, 'lambda_l2': 3.6226851797117455e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:12,494] Trial 27 finished with value: 0.2997746678809984 and parameters: {'learning_rate': 0.09065704879168264, 'num_leaves': 128, 'min_data_in_leaf': 87, 'feature_fraction': 0.8924312212499107, 'bagging_fraction': 0.8088129427282205, 'bagging_freq': 3, 'min_gain_to_split': 1.7714851835980365, 'lambda_l1': 0.013050154105290233, 'lambda_l2': 1.2109044093413328e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:12,685] Trial 28 finished with value: 0.3030370315318569 and parameters: {'learning_rate': 0.06605083177033338, 'num_leaves': 170, 'min_data_in_leaf': 130, 'feature_fraction': 0.9583253689771997, 'bagging_fraction': 0.8648785985933766, 'bagging_freq': 3, 'min_gain_to_split': 1.1383036313909756, 'lambda_l1': 0.0011411030386211936, 'lambda_l2': 1.0585964376600756e-06}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:12,844] Trial 29 finished with value: 0.36321910618480774 and parameters: {'learning_rate': 0.12945142175043575, 'num_leaves': 196, 'min_data_in_leaf': 160, 'feature_fraction': 0.7975026483396321, 'bagging_fraction': 0.9124841933171561, 'bagging_freq': 6, 'min_gain_to_split': 0.7829900115040289, 'lambda_l1': 1.2037854354467148, 'lambda_l2': 3.1232698816525305e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:13,023] Trial 30 finished with value: 0.32176221732802757 and parameters: {'learning_rate': 0.04867744047925191, 'num_leaves': 182, 'min_data_in_leaf': 98, 'feature_fraction': 0.8787755913522964, 'bagging_fraction': 0.7623044347723663, 'bagging_freq': 7, 'min_gain_to_split': 2.0103251036354206, 'lambda_l1': 0.00020291188795794885, 'lambda_l2': 4.744814010569935e-08}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:13,266] Trial 31 finished with value: 0.25589407341434356 and parameters: {'learning_rate': 0.04370915920990273, 'num_leaves': 182, 'min_data_in_leaf': 117, 'feature_fraction': 0.8946173211608317, 'bagging_fraction': 0.8683949904661478, 'bagging_freq': 4, 'min_gain_to_split': 0.14190111620631846, 'lambda_l1': 0.005261684482017528, 'lambda_l2': 6.553579195916215e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:13,508] Trial 32 finished with value: 0.27009227888163373 and parameters: {'learning_rate': 0.03639685822416214, 'num_leaves': 159, 'min_data_in_leaf': 121, 'feature_fraction': 0.913143868285123, 'bagging_fraction': 0.8775604455015265, 'bagging_freq': 4, 'min_gain_to_split': 0.3454649059270171, 'lambda_l1': 0.02454899036943837, 'lambda_l2': 6.347694842565063e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:13,781] Trial 33 finished with value: 0.2850876364380309 and parameters: {'learning_rate': 0.028057749169166608, 'num_leaves': 222, 'min_data_in_leaf': 106, 'feature_fraction': 0.9363059757854553, 'bagging_fraction': 0.8073387227033195, 'bagging_freq': 5, 'min_gain_to_split': 0.7311832883000761, 'lambda_l1': 0.00345791913692216, 'lambda_l2': 2.6228155388919995e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:14,014] Trial 34 finished with value: 0.2457627579489369 and parameters: {'learning_rate': 0.08012845401568836, 'num_leaves': 138, 'min_data_in_leaf': 70, 'feature_fraction': 0.9144500960295863, 'bagging_fraction': 0.8943081779293858, 'bagging_freq': 4, 'min_gain_to_split': 0.3207885789438625, 'lambda_l1': 0.4849408288968538, 'lambda_l2': 1.4949546938491454e-06}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:14,249] Trial 35 finished with value: 0.3212716220053734 and parameters: {'learning_rate': 0.055135307010090236, 'num_leaves': 195, 'min_data_in_leaf': 139, 'feature_fraction': 0.8615686027256804, 'bagging_fraction': 0.9275540499869198, 'bagging_freq': 3, 'min_gain_to_split': 0.5539883644826571, 'lambda_l1': 0.03861767126747588, 'lambda_l2': 2.7733860733169075e-08}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:14,517] Trial 36 finished with value: 0.3204990004932739 and parameters: {'learning_rate': 0.023131246019033123, 'num_leaves': 179, 'min_data_in_leaf': 91, 'feature_fraction': 0.912342939337889, 'bagging_fraction': 0.8574499205295114, 'bagging_freq': 7, 'min_gain_to_split': 2.5853748476724476, 'lambda_l1': 0.009434790576924387, 'lambda_l2': 2.5151471720392585e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:15,122] Trial 37 finished with value: 0.24321183658384976 and parameters: {'learning_rate': 0.05790105896371599, 'num_leaves': 144, 'min_data_in_leaf': 113, 'feature_fraction': 0.9496961226508782, 'bagging_fraction': 0.7878338737147175, 'bagging_freq': 1, 'min_gain_to_split': 0.03728826731280016, 'lambda_l1': 0.002837139619160802, 'lambda_l2': 1.7040847807695917e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:15,361] Trial 38 finished with value: 0.29874252779881644 and parameters: {'learning_rate': 0.035017508198960434, 'num_leaves': 243, 'min_data_in_leaf': 124, 'feature_fraction': 0.8137078875178243, 'bagging_fraction': 0.966323651115561, 'bagging_freq': 5, 'min_gain_to_split': 0.6463740058097781, 'lambda_l1': 2.3207791650510714, 'lambda_l2': 0.0005661522458853812}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:15,525] Trial 39 finished with value: 0.3387677025210555 and parameters: {'learning_rate': 0.12505096793758005, 'num_leaves': 216, 'min_data_in_leaf': 85, 'feature_fraction': 0.8760254802271383, 'bagging_fraction': 0.8272223536024363, 'bagging_freq': 2, 'min_gain_to_split': 3.982446663788174, 'lambda_l1': 0.07124898820354807, 'lambda_l2': 9.476169362180536e-08}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:15,701] Trial 40 finished with value: 0.35631068285134593 and parameters: {'learning_rate': 0.07938088613072619, 'num_leaves': 201, 'min_data_in_leaf': 146, 'feature_fraction': 0.8375743367364885, 'bagging_fraction': 0.6378840763242417, 'bagging_freq': 4, 'min_gain_to_split': 0.2290062395392357, 'lambda_l1': 0.00011110306384905244, 'lambda_l2': 2.3706311086148112e-06}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:16,544] Trial 41 finished with value: 0.24584208674817062 and parameters: {'learning_rate': 0.0616065722570429, 'num_leaves': 146, 'min_data_in_leaf': 112, 'feature_fraction': 0.9517645634185633, 'bagging_fraction': 0.7247543793629899, 'bagging_freq': 1, 'min_gain_to_split': 0.04124836425343226, 'lambda_l1': 0.0027480310238625766, 'lambda_l2': 4.281301317184899e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:16,910] Trial 42 finished with value: 0.2630180302359988 and parameters: {'learning_rate': 0.05990791491136457, 'num_leaves': 168, 'min_data_in_leaf': 111, 'feature_fraction': 0.996481036451921, 'bagging_fraction': 0.7920114385175787, 'bagging_freq': 1, 'min_gain_to_split': 0.4436866010935905, 'lambda_l1': 0.012151227586164165, 'lambda_l2': 2.055178706785519e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:17,892] Trial 43 finished with value: 0.311331408528641 and parameters: {'learning_rate': 0.037788867100795466, 'num_leaves': 158, 'min_data_in_leaf': 126, 'feature_fraction': 0.9283762823094213, 'bagging_fraction': 0.7841839852396425, 'bagging_freq': 3, 'min_gain_to_split': 0.001160868021027471, 'lambda_l1': 0.0018450035113524547, 'lambda_l2': 3.2944203276208537e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:18,100] Trial 44 finished with value: 0.2592585244915796 and parameters: {'learning_rate': 0.04836504904018912, 'num_leaves': 134, 'min_data_in_leaf': 76, 'feature_fraction': 0.9671560944417662, 'bagging_fraction': 0.8990000050069237, 'bagging_freq': 5, 'min_gain_to_split': 0.5842076328833282, 'lambda_l1': 0.2739748157981893, 'lambda_l2': 1.291826420089072e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:18,365] Trial 45 finished with value: 0.24841752014719556 and parameters: {'learning_rate': 0.03043851588938733, 'num_leaves': 98, 'min_data_in_leaf': 98, 'feature_fraction': 0.8979880647619932, 'bagging_fraction': 0.6720437422326874, 'bagging_freq': 0, 'min_gain_to_split': 0.29318494981774734, 'lambda_l1': 0.000507633557908742, 'lambda_l2': 2.194881146158028e-06}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:18,540] Trial 46 finished with value: 0.3596439061440218 and parameters: {'learning_rate': 0.06909426932960842, 'num_leaves': 175, 'min_data_in_leaf': 137, 'feature_fraction': 0.9362060569937388, 'bagging_fraction': 0.7683567416405093, 'bagging_freq': 2, 'min_gain_to_split': 0.8518949512856305, 'lambda_l1': 0.005312490822735365, 'lambda_l2': 1.0960102614261882e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:19,001] Trial 47 finished with value: 0.26125554133604323 and parameters: {'learning_rate': 0.05273161228595847, 'num_leaves': 188, 'min_data_in_leaf': 111, 'feature_fraction': 0.9200251257819854, 'bagging_fraction': 0.8349774562950474, 'bagging_freq': 1, 'min_gain_to_split': 0.4742257052157498, 'lambda_l1': 0.020601787846203822, 'lambda_l2': 0.0002879106199645001}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:19,425] Trial 48 finished with value: 0.24417795257623162 and parameters: {'learning_rate': 0.018963463269419563, 'num_leaves': 147, 'min_data_in_leaf': 84, 'feature_fraction': 0.8688673134108502, 'bagging_fraction': 0.8745776474800139, 'bagging_freq': 6, 'min_gain_to_split': 0.23418333861315296, 'lambda_l1': 0.0009768848410580664, 'lambda_l2': 4.962730894754859e-08}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:19,588] Trial 49 finished with value: 0.3919878215759508 and parameters: {'learning_rate': 0.08710619581475039, 'num_leaves': 118, 'min_data_in_leaf': 152, 'feature_fraction': 0.9803576400702051, 'bagging_fraction': 0.6004838598001793, 'bagging_freq': 2, 'min_gain_to_split': 1.2874133631097864, 'lambda_l1': 7.008621946781582e-05, 'lambda_l2': 8.155691848022555e-05}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:19,807] Trial 50 finished with value: 0.27034525494051886 and parameters: {'learning_rate': 0.03276374565022417, 'num_leaves': 92, 'min_data_in_leaf': 100, 'feature_fraction': 0.6536345103231103, 'bagging_fraction': 0.7535757521054831, 'bagging_freq': 0, 'min_gain_to_split': 0.8313751877618145, 'lambda_l1': 0.05639443921190627, 'lambda_l2': 4.221661949913873e-06}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:20,203] Trial 51 finished with value: 0.24239561120905667 and parameters: {'learning_rate': 0.018779661117993857, 'num_leaves': 148, 'min_data_in_leaf': 83, 'feature_fraction': 0.8644414737588717, 'bagging_fraction': 0.860776095717111, 'bagging_freq': 6, 'min_gain_to_split': 0.19463611400331854, 'lambda_l1': 0.0008465268508534423, 'lambda_l2': 4.235841273222043e-08}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:20,628] Trial 52 finished with value: 0.23386122147591756 and parameters: {'learning_rate': 0.017548956130316016, 'num_leaves': 162, 'min_data_in_leaf': 61, 'feature_fraction': 0.8977558997763895, 'bagging_fraction': 0.8140993967145925, 'bagging_freq': 4, 'min_gain_to_split': 0.22301821158584967, 'lambda_l1': 2.1876960802527805e-05, 'lambda_l2': 1.4561443154100762e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:20,968] Trial 53 finished with value: 0.24334007339364208 and parameters: {'learning_rate': 0.018886576010580778, 'num_leaves': 163, 'min_data_in_leaf': 53, 'feature_fraction': 0.8144100896381794, 'bagging_fraction': 0.8542343654223536, 'bagging_freq': 5, 'min_gain_to_split': 0.4788158053178929, 'lambda_l1': 0.00021213759756991666, 'lambda_l2': 1.5174591107440733e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:21,452] Trial 54 finished with value: 0.23260714130967858 and parameters: {'learning_rate': 0.014963085840510062, 'num_leaves': 154, 'min_data_in_leaf': 63, 'feature_fraction': 0.898127941080421, 'bagging_fraction': 0.8828789508729389, 'bagging_freq': 4, 'min_gain_to_split': 0.20086812188663344, 'lambda_l1': 3.335627688453475e-05, 'lambda_l2': 3.085977697270653e-08}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:21,837] Trial 55 finished with value: 0.24411055674801396 and parameters: {'learning_rate': 0.015376769946509035, 'num_leaves': 175, 'min_data_in_leaf': 36, 'feature_fraction': 0.9030700452979677, 'bagging_fraction': 0.887722510476679, 'bagging_freq': 4, 'min_gain_to_split': 0.6460791204544792, 'lambda_l1': 1.6516235821079938e-05, 'lambda_l2': 5.530925605144307e-07}. Best is trial 22 with value: 0.22674258798650687.
# [I 2025-09-15 01:13:22,331] Trial 56 finished with value: 0.2260212166823617 and parameters: {'learning_rate': 0.013173065973709855, 'num_leaves': 226, 'min_data_in_leaf': 23, 'feature_fraction': 0.8450893447476197, 'bagging_fraction': 0.8132477094372623, 'bagging_freq': 5, 'min_gain_to_split': 0.36951710886629885, 'lambda_l1': 3.102050267334506e-05, 'lambda_l2': 1.2299489881978618e-08}. Best is trial 56 with value: 0.2260212166823617.
# [I 2025-09-15 01:13:22,820] Trial 57 finished with value: 0.22188803767282245 and parameters: {'learning_rate': 0.013123813461804239, 'num_leaves': 228, 'min_data_in_leaf': 12, 'feature_fraction': 0.8438292655022899, 'bagging_fraction': 0.808660926081216, 'bagging_freq': 5, 'min_gain_to_split': 0.3229975607489518, 'lambda_l1': 2.203136031773015e-06, 'lambda_l2': 1.8958299381345555e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:23,092] Trial 58 finished with value: 0.35231113815754433 and parameters: {'learning_rate': 0.012351680778073295, 'num_leaves': 224, 'min_data_in_leaf': 13, 'feature_fraction': 0.8391595673951094, 'bagging_fraction': 0.816160154059687, 'bagging_freq': 5, 'min_gain_to_split': 4.906289533086159, 'lambda_l1': 1.0859691746547536e-06, 'lambda_l2': 2.01679013204668e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:23,455] Trial 59 finished with value: 0.25647300554833075 and parameters: {'learning_rate': 0.015040102711039133, 'num_leaves': 32, 'min_data_in_leaf': 28, 'feature_fraction': 0.7785316684924071, 'bagging_fraction': 0.801793747888129, 'bagging_freq': 4, 'min_gain_to_split': 0.9351072494985492, 'lambda_l1': 9.881723521447714e-06, 'lambda_l2': 1.3002038537443942e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:23,873] Trial 60 finished with value: 0.26753859361943894 and parameters: {'learning_rate': 0.01072742696633161, 'num_leaves': 232, 'min_data_in_leaf': 29, 'feature_fraction': 0.8288365161349331, 'bagging_fraction': 0.8425513410269456, 'bagging_freq': 8, 'min_gain_to_split': 1.2176201921516323, 'lambda_l1': 1.3379983063725348e-06, 'lambda_l2': 8.761802668293254e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:24,410] Trial 61 finished with value: 0.2278981211626084 and parameters: {'learning_rate': 0.013868646586770644, 'num_leaves': 216, 'min_data_in_leaf': 20, 'feature_fraction': 0.8826252359563829, 'bagging_fraction': 0.8242148630466193, 'bagging_freq': 5, 'min_gain_to_split': 0.3669714284644098, 'lambda_l1': 2.8582125728704586e-05, 'lambda_l2': 1.031362982967712e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:24,838] Trial 62 finished with value: 0.22680817521213542 and parameters: {'learning_rate': 0.015882119912612843, 'num_leaves': 208, 'min_data_in_leaf': 19, 'feature_fraction': 0.880362838879195, 'bagging_fraction': 0.7799046010543793, 'bagging_freq': 6, 'min_gain_to_split': 0.37254213768546646, 'lambda_l1': 3.9921728062984886e-05, 'lambda_l2': 2.5626490431776744e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:25,362] Trial 63 finished with value: 0.22843865761974386 and parameters: {'learning_rate': 0.013806712735091882, 'num_leaves': 215, 'min_data_in_leaf': 18, 'feature_fraction': 0.8764221780403029, 'bagging_fraction': 0.7736676221692881, 'bagging_freq': 6, 'min_gain_to_split': 0.39197219951236384, 'lambda_l1': 3.8188859152158035e-05, 'lambda_l2': 2.881610625006457e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:25,919] Trial 64 finished with value: 0.22966772522260936 and parameters: {'learning_rate': 0.012285955940970357, 'num_leaves': 213, 'min_data_in_leaf': 10, 'feature_fraction': 0.8782947211894823, 'bagging_fraction': 0.7748979442412576, 'bagging_freq': 7, 'min_gain_to_split': 0.4124236984368243, 'lambda_l1': 1.0650310009666778e-06, 'lambda_l2': 1.2379255881180913e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:26,333] Trial 65 finished with value: 0.24422952557237193 and parameters: {'learning_rate': 0.013970004894467043, 'num_leaves': 202, 'min_data_in_leaf': 18, 'feature_fraction': 0.8488759187187938, 'bagging_fraction': 0.7978005920372621, 'bagging_freq': 6, 'min_gain_to_split': 0.6941882173764272, 'lambda_l1': 3.000152780103873e-06, 'lambda_l2': 1.0010067071340354e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:26,822] Trial 66 finished with value: 0.22955598265079766 and parameters: {'learning_rate': 0.013369232455942242, 'num_leaves': 245, 'min_data_in_leaf': 21, 'feature_fraction': 0.883677706126988, 'bagging_fraction': 0.7335453198348347, 'bagging_freq': 6, 'min_gain_to_split': 0.38155453612974793, 'lambda_l1': 8.127830567667169e-06, 'lambda_l2': 5.7412093467238784e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:27,207] Trial 67 finished with value: 0.2742118883230131 and parameters: {'learning_rate': 0.010195609490737601, 'num_leaves': 222, 'min_data_in_leaf': 41, 'feature_fraction': 0.8488710526542843, 'bagging_fraction': 0.7016604134125531, 'bagging_freq': 8, 'min_gain_to_split': 1.0677184302593172, 'lambda_l1': 4.059037932791934e-05, 'lambda_l2': 2.3817325024794125e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:27,553] Trial 68 finished with value: 0.30562626021262296 and parameters: {'learning_rate': 0.011392564261600766, 'num_leaves': 209, 'min_data_in_leaf': 24, 'feature_fraction': 0.8241161804434975, 'bagging_fraction': 0.7454998885683519, 'bagging_freq': 5, 'min_gain_to_split': 2.33260871927712, 'lambda_l1': 2.8479885997409043e-07, 'lambda_l2': 6.93266804115733e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:27,925] Trial 69 finished with value: 0.2413292605280865 and parameters: {'learning_rate': 0.016646036928909404, 'num_leaves': 232, 'min_data_in_leaf': 36, 'feature_fraction': 0.8023468456523263, 'bagging_fraction': 0.7788803293140384, 'bagging_freq': 5, 'min_gain_to_split': 0.569352204412339, 'lambda_l1': 0.00012319942701104845, 'lambda_l2': 2.2858993992141782e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:28,149] Trial 70 finished with value: 0.3189325269877311 and parameters: {'learning_rate': 0.022067003522893036, 'num_leaves': 215, 'min_data_in_leaf': 15, 'feature_fraction': 0.883908171396319, 'bagging_fraction': 0.7570513002573659, 'bagging_freq': 6, 'min_gain_to_split': 3.0803450987203678, 'lambda_l1': 2.229937143694482e-06, 'lambda_l2': 2.142529467283038e-07}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:28,625] Trial 71 finished with value: 0.2296828842425347 and parameters: {'learning_rate': 0.013793209675152966, 'num_leaves': 247, 'min_data_in_leaf': 23, 'feature_fraction': 0.8833544547224437, 'bagging_fraction': 0.7198842838409839, 'bagging_freq': 6, 'min_gain_to_split': 0.3724316487603463, 'lambda_l1': 1.1077724859246517e-05, 'lambda_l2': 0.029076603197501265}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:29,024] Trial 72 finished with value: 0.2508524717046816 and parameters: {'learning_rate': 0.0128418267656025, 'num_leaves': 240, 'min_data_in_leaf': 21, 'feature_fraction': 0.8584393902273904, 'bagging_fraction': 0.7424324582652226, 'bagging_freq': 7, 'min_gain_to_split': 0.7578210347327814, 'lambda_l1': 5.750059015034916e-06, 'lambda_l2': 5.600230898464339e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:29,633] Trial 73 finished with value: 0.22301635456589125 and parameters: {'learning_rate': 0.013863731908937313, 'num_leaves': 229, 'min_data_in_leaf': 43, 'feature_fraction': 0.9262706844016478, 'bagging_fraction': 0.7323082723087632, 'bagging_freq': 7, 'min_gain_to_split': 0.13299866240029484, 'lambda_l1': 8.647668546496197e-06, 'lambda_l2': 3.90227417563218e-08}. Best is trial 57 with value: 0.22188803767282245.
# [I 2025-09-15 01:13:30,437] Trial 74 finished with value: 0.2157575418004664 and parameters: {'learning_rate': 0.011287865912285039, 'num_leaves': 195, 'min_data_in_leaf': 31, 'feature_fraction': 0.9207807414629768, 'bagging_fraction': 0.6958168545234338, 'bagging_freq': 7, 'min_gain_to_split': 0.14453395020229443, 'lambda_l1': 7.388077504767533e-05, 'lambda_l2': 3.1179091376752264e-08}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:31,106] Trial 75 finished with value: 0.2233958566019269 and parameters: {'learning_rate': 0.011569242371339983, 'num_leaves': 194, 'min_data_in_leaf': 43, 'feature_fraction': 0.9287727919931772, 'bagging_fraction': 0.706151975614738, 'bagging_freq': 7, 'min_gain_to_split': 0.1302299112031346, 'lambda_l1': 0.00011150829054025236, 'lambda_l2': 3.090855472001954}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:32,046] Trial 76 finished with value: 0.21737546043082637 and parameters: {'learning_rate': 0.011354373332513702, 'num_leaves': 195, 'min_data_in_leaf': 45, 'feature_fraction': 0.9289438971970043, 'bagging_fraction': 0.6960092332823603, 'bagging_freq': 9, 'min_gain_to_split': 0.057620469942261686, 'lambda_l1': 6.610941992636544e-05, 'lambda_l2': 8.585314870933916}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:32,712] Trial 77 finished with value: 0.22916716351655322 and parameters: {'learning_rate': 0.01112052287199506, 'num_leaves': 199, 'min_data_in_leaf': 43, 'feature_fraction': 0.9401959707471222, 'bagging_fraction': 0.6908086172938367, 'bagging_freq': 9, 'min_gain_to_split': 0.1423536674364023, 'lambda_l1': 8.903011662719696e-05, 'lambda_l2': 7.927103454724667}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:33,471] Trial 78 finished with value: 0.21668962256143187 and parameters: {'learning_rate': 0.010080535741063662, 'num_leaves': 191, 'min_data_in_leaf': 32, 'feature_fraction': 0.9241547315147887, 'bagging_fraction': 0.6883686535637684, 'bagging_freq': 9, 'min_gain_to_split': 0.1283139046809463, 'lambda_l1': 0.0003420743724426345, 'lambda_l2': 1.9705978436736193}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:34,177] Trial 79 finished with value: 0.2223317748801427 and parameters: {'learning_rate': 0.010155855388193953, 'num_leaves': 194, 'min_data_in_leaf': 31, 'feature_fraction': 0.9655302098420435, 'bagging_fraction': 0.6717980355546597, 'bagging_freq': 10, 'min_gain_to_split': 0.16296951787293806, 'lambda_l1': 0.0003181571488447845, 'lambda_l2': 1.8142065963791052}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:34,853] Trial 80 finished with value: 0.22081739090431643 and parameters: {'learning_rate': 0.010100427250963068, 'num_leaves': 185, 'min_data_in_leaf': 30, 'feature_fraction': 0.9668112372620893, 'bagging_fraction': 0.6732492003761111, 'bagging_freq': 10, 'min_gain_to_split': 0.15523995941275015, 'lambda_l1': 0.00035206220618464666, 'lambda_l2': 1.0142411420666884}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:35,519] Trial 81 finished with value: 0.217219765566573 and parameters: {'learning_rate': 0.011583087631380525, 'num_leaves': 191, 'min_data_in_leaf': 32, 'feature_fraction': 0.9628908113580128, 'bagging_fraction': 0.6731142863580486, 'bagging_freq': 10, 'min_gain_to_split': 0.11015364392177204, 'lambda_l1': 0.0003947306266572177, 'lambda_l2': 1.5047041378717163}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:36,194] Trial 82 finished with value: 0.2167287485440912 and parameters: {'learning_rate': 0.011448607704956234, 'num_leaves': 190, 'min_data_in_leaf': 32, 'feature_fraction': 0.9860337401220564, 'bagging_fraction': 0.6647057899027823, 'bagging_freq': 10, 'min_gain_to_split': 0.11069492913414034, 'lambda_l1': 0.0003588809240794622, 'lambda_l2': 1.2990682030404486}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:37,008] Trial 83 finished with value: 0.21889362520723976 and parameters: {'learning_rate': 0.010083331403569389, 'num_leaves': 188, 'min_data_in_leaf': 32, 'feature_fraction': 0.9585721762040724, 'bagging_fraction': 0.6646937485505874, 'bagging_freq': 10, 'min_gain_to_split': 0.14228511361864768, 'lambda_l1': 0.0004357652519268997, 'lambda_l2': 0.9201454640545108}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:37,487] Trial 84 finished with value: 0.2522931967132312 and parameters: {'learning_rate': 0.010084037414285115, 'num_leaves': 189, 'min_data_in_leaf': 32, 'feature_fraction': 0.9824568543947053, 'bagging_fraction': 0.663143111009047, 'bagging_freq': 10, 'min_gain_to_split': 0.5807616440770921, 'lambda_l1': 0.00048755763389120055, 'lambda_l2': 0.9299706516616455}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:37,782] Trial 85 finished with value: 0.35058770962324426 and parameters: {'learning_rate': 0.010823679390340075, 'num_leaves': 186, 'min_data_in_leaf': 51, 'feature_fraction': 0.9569259187055771, 'bagging_fraction': 0.6606997611714348, 'bagging_freq': 9, 'min_gain_to_split': 3.6190408583698757, 'lambda_l1': 0.00027467952399194364, 'lambda_l2': 1.006458466929404}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:38,360] Trial 86 finished with value: 0.2219699010830404 and parameters: {'learning_rate': 0.011801901394517431, 'num_leaves': 194, 'min_data_in_leaf': 38, 'feature_fraction': 0.9703001477756812, 'bagging_fraction': 0.6392025694237602, 'bagging_freq': 10, 'min_gain_to_split': 0.1327013654276834, 'lambda_l1': 2.0333024107558995e-08, 'lambda_l2': 0.417375077048766}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:39,008] Trial 87 finished with value: 0.21710606110572087 and parameters: {'learning_rate': 0.011817697126286365, 'num_leaves': 180, 'min_data_in_leaf': 36, 'feature_fraction': 0.9848367456803002, 'bagging_fraction': 0.6399901842221389, 'bagging_freq': 10, 'min_gain_to_split': 0.0908159957228207, 'lambda_l1': 1.240652373491292e-07, 'lambda_l2': 0.3015958187247457}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:39,449] Trial 88 finished with value: 0.2539070837337317 and parameters: {'learning_rate': 0.011058682794580539, 'num_leaves': 173, 'min_data_in_leaf': 48, 'feature_fraction': 0.9849679469390841, 'bagging_fraction': 0.6893004797974602, 'bagging_freq': 9, 'min_gain_to_split': 0.5263309730660475, 'lambda_l1': 2.135485353695235e-07, 'lambda_l2': 0.0996962548708}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:41,343] Trial 89 finished with value: 0.21896646824746607 and parameters: {'learning_rate': 0.011975871308076242, 'num_leaves': 182, 'min_data_in_leaf': 56, 'feature_fraction': 0.9985210929395176, 'bagging_fraction': 0.6331827088717922, 'bagging_freq': 10, 'min_gain_to_split': 0.0030432285186680064, 'lambda_l1': 7.249359380290866e-08, 'lambda_l2': 7.406901113086489}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:42,117] Trial 90 finished with value: 0.21596831910698705 and parameters: {'learning_rate': 0.01214374415891908, 'num_leaves': 183, 'min_data_in_leaf': 33, 'feature_fraction': 0.9998070612682101, 'bagging_fraction': 0.6275006306815589, 'bagging_freq': 9, 'min_gain_to_split': 0.06555238023041955, 'lambda_l1': 9.497716677776018e-08, 'lambda_l2': 8.577586439603978}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:42,777] Trial 91 finished with value: 0.23629124179711689 and parameters: {'learning_rate': 0.012114185059847807, 'num_leaves': 182, 'min_data_in_leaf': 58, 'feature_fraction': 0.9936767674375271, 'bagging_fraction': 0.624370392377033, 'bagging_freq': 9, 'min_gain_to_split': 0.08878418455015424, 'lambda_l1': 9.408199186611136e-08, 'lambda_l2': 9.077553019205816}. Best is trial 74 with value: 0.2157575418004664.
# [I 2025-09-15 01:13:44,716] Trial 92 finished with value: 0.19706952601610578 and parameters: {'learning_rate': 0.011406554662892286, 'num_leaves': 179, 'min_data_in_leaf': 28, 'feature_fraction': 0.9592740710371461, 'bagging_fraction': 0.6443320220211108, 'bagging_freq': 10, 'min_gain_to_split': 0.010637766923309006, 'lambda_l1': 1.1081999060730397e-07, 'lambda_l2': 0.4586151771207017}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:46,675] Trial 93 finished with value: 0.19901509252726177 and parameters: {'learning_rate': 0.011485559174706752, 'num_leaves': 179, 'min_data_in_leaf': 27, 'feature_fraction': 0.9987865955116928, 'bagging_fraction': 0.6445512108090093, 'bagging_freq': 9, 'min_gain_to_split': 0.013663173667363998, 'lambda_l1': 5.098784879443109e-08, 'lambda_l2': 4.788731754383624}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:47,286] Trial 94 finished with value: 0.2319110618368482 and parameters: {'learning_rate': 0.01096514412664148, 'num_leaves': 170, 'min_data_in_leaf': 27, 'feature_fraction': 0.976523803026105, 'bagging_fraction': 0.6487967389122137, 'bagging_freq': 9, 'min_gain_to_split': 0.23485603676645683, 'lambda_l1': 3.667592184290493e-08, 'lambda_l2': 4.102184579103823}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:47,896] Trial 95 finished with value: 0.23415983214640632 and parameters: {'learning_rate': 0.0124260461309234, 'num_leaves': 204, 'min_data_in_leaf': 38, 'feature_fraction': 0.9874285026633228, 'bagging_fraction': 0.6106392268448001, 'bagging_freq': 9, 'min_gain_to_split': 0.25143592380259117, 'lambda_l1': 1.1503242480387996e-08, 'lambda_l2': 0.4183726318647883}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:48,361] Trial 96 finished with value: 0.24777092051001587 and parameters: {'learning_rate': 0.01470043317780968, 'num_leaves': 177, 'min_data_in_leaf': 34, 'feature_fraction': 0.9581632250061072, 'bagging_fraction': 0.6508042317961538, 'bagging_freq': 10, 'min_gain_to_split': 0.5054693672461388, 'lambda_l1': 4.061228916836169e-08, 'lambda_l2': 1.9334671533496837}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:48,763] Trial 97 finished with value: 0.24408332665896762 and parameters: {'learning_rate': 0.016924320288769754, 'num_leaves': 164, 'min_data_in_leaf': 46, 'feature_fraction': 0.9458446517538285, 'bagging_fraction': 0.612100137585723, 'bagging_freq': 8, 'min_gain_to_split': 0.2812426303788167, 'lambda_l1': 5.637178673278692e-08, 'lambda_l2': 4.939490459390343}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:49,653] Trial 98 finished with value: 0.20425420011467024 and parameters: {'learning_rate': 0.011467143997748272, 'num_leaves': 198, 'min_data_in_leaf': 26, 'feature_fraction': 0.9755385489613054, 'bagging_fraction': 0.68565300605924, 'bagging_freq': 10, 'min_gain_to_split': 0.05392583487019886, 'lambda_l1': 1.3926256048127265e-07, 'lambda_l2': 0.08546658882887474}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:50,714] Trial 99 finished with value: 0.19903063771584686 and parameters: {'learning_rate': 0.011527829385287836, 'num_leaves': 192, 'min_data_in_leaf': 25, 'feature_fraction': 0.988385355725671, 'bagging_fraction': 0.6852102568401665, 'bagging_freq': 9, 'min_gain_to_split': 0.030225061971817818, 'lambda_l1': 2.0059232654208337e-07, 'lambda_l2': 0.2402668114356527}. Best is trial 92 with value: 0.19706952601610578.
# [I 2025-09-15 01:13:52,877] Trial 100 finished with value: 0.19423823204150567 and parameters: {'learning_rate': 0.012838258471620463, 'num_leaves': 200, 'min_data_in_leaf': 25, 'feature_fraction': 0.9898803154265514, 'bagging_fraction': 0.6805387006145526, 'bagging_freq': 10, 'min_gain_to_split': 0.002941241683468772, 'lambda_l1': 5.992115442809247e-07, 'lambda_l2': 0.08351777291477337}. Best is trial 100 with value: 0.19423823204150567.
# [I 2025-09-15 01:13:53,363] Trial 101 finished with value: 0.2259692920805348 and parameters: {'learning_rate': 0.012882036884871198, 'num_leaves': 191, 'min_data_in_leaf': 26, 'feature_fraction': 0.9893848101836847, 'bagging_fraction': 0.6800071239291858, 'bagging_freq': 10, 'min_gain_to_split': 0.2842892086834663, 'lambda_l1': 1.4686427742016925e-07, 'lambda_l2': 0.08739962322586503}. Best is trial 100 with value: 0.19423823204150567.
# [I 2025-09-15 01:13:54,111] Trial 102 finished with value: 0.2159519172548447 and parameters: {'learning_rate': 0.010672886758118623, 'num_leaves': 206, 'min_data_in_leaf': 40, 'feature_fraction': 0.9775291614027989, 'bagging_fraction': 0.652582181858455, 'bagging_freq': 10, 'min_gain_to_split': 0.0823604014317906, 'lambda_l1': 2.3922012483291544e-08, 'lambda_l2': 0.23975221740326125}. Best is trial 100 with value: 0.19423823204150567.
# [I 2025-09-15 01:13:55,222] Trial 103 finished with value: 0.20539195700486004 and parameters: {'learning_rate': 0.014551321120099063, 'num_leaves': 205, 'min_data_in_leaf': 40, 'feature_fraction': 0.9736160838055016, 'bagging_fraction': 0.6527404329521543, 'bagging_freq': 9, 'min_gain_to_split': 0.01758515081529713, 'lambda_l1': 6.158997674268858e-07, 'lambda_l2': 0.03000390752227883}. Best is trial 100 with value: 0.19423823204150567.
# [I 2025-09-15 01:13:55,579] Trial 104 finished with value: 0.28883674685982885 and parameters: {'learning_rate': 0.01089126267163792, 'num_leaves': 208, 'min_data_in_leaf': 15, 'feature_fraction': 0.9772430166203981, 'bagging_fraction': 0.6536040614002707, 'bagging_freq': 8, 'min_gain_to_split': 1.591140216718023, 'lambda_l1': 4.3217956089794745e-07, 'lambda_l2': 0.03180719357721047}. Best is trial 100 with value: 0.19423823204150567.
# [I 2025-09-15 01:13:57,232] Trial 105 finished with value: 0.2029508037384712 and parameters: {'learning_rate': 0.0157244167878567, 'num_leaves': 201, 'min_data_in_leaf': 38, 'feature_fraction': 0.9978350009153737, 'bagging_fraction': 0.6831788426226676, 'bagging_freq': 9, 'min_gain_to_split': 0.005776281723056026, 'lambda_l1': 5.866146695491527e-07, 'lambda_l2': 0.007677616403871079}. Best is trial 100 with value: 0.19423823204150567.
# [I 2025-09-15 01:13:58,400] Trial 106 finished with value: 0.19732809287832262 and parameters: {'learning_rate': 0.014925821335374918, 'num_leaves': 199, 'min_data_in_leaf': 24, 'feature_fraction': 0.9978740740757919, 'bagging_fraction': 0.7129860165923582, 'bagging_freq': 9, 'min_gain_to_split': 0.016375651723063087, 'lambda_l1': 5.399897630714411e-07, 'lambda_l2': 0.005159289295238999}. Best is trial 100 with value: 0.19423823204150567.
# [I 2025-09-15 01:13:59,889] Trial 107 finished with value: 0.20714922226935123 and parameters: {'learning_rate': 0.02002367973544402, 'num_leaves': 201, 'min_data_in_leaf': 39, 'feature_fraction': 0.9962117215406566, 'bagging_fraction': 0.6276912718063137, 'bagging_freq': 9, 'min_gain_to_split': 0.0025197581592976415, 'lambda_l1': 6.176442514323474e-07, 'lambda_l2': 0.004646167380554839}. Best is trial 100 with value: 0.19423823204150567.
# ...
# [I 2025-09-15 01:16:48,760] Trial 87 finished with value: 0.23711315535894678 and parameters: {'learning_rate': 0.025228466416622578, 'num_leaves': 56, 'min_data_in_leaf': 22, 'feature_fraction': 0.9997665888421398, 'bagging_fraction': 0.9524265922046523, 'bagging_freq': 9, 'min_gain_to_split': 0.5343474869451408, 'lambda_l1': 0.00019759735094827704, 'lambda_l2': 3.6838391225876695e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:49,138] Trial 88 finished with value: 0.23769184375652158 and parameters: {'learning_rate': 0.020145850349929186, 'num_leaves': 90, 'min_data_in_leaf': 44, 'feature_fraction': 0.9729616478007096, 'bagging_fraction': 0.6747387189985283, 'bagging_freq': 8, 'min_gain_to_split': 0.2465222176456312, 'lambda_l1': 4.6977535825221845e-06, 'lambda_l2': 1.3191608260005e-06}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:49,753] Trial 89 finished with value: 0.21036017895741543 and parameters: {'learning_rate': 0.017986513601422133, 'num_leaves': 97, 'min_data_in_leaf': 11, 'feature_fraction': 0.9820338156413033, 'bagging_fraction': 0.9841086590530951, 'bagging_freq': 9, 'min_gain_to_split': 0.13760194384573143, 'lambda_l1': 1.401351875884789e-06, 'lambda_l2': 9.60343066249013e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:50,349] Trial 90 finished with value: 0.21116008128271452 and parameters: {'learning_rate': 0.017110154644021044, 'num_leaves': 59, 'min_data_in_leaf': 11, 'feature_fraction': 0.980840333119174, 'bagging_fraction': 0.9872664695178727, 'bagging_freq': 10, 'min_gain_to_split': 0.15126153073260662, 'lambda_l1': 1.1764833787855588e-06, 'lambda_l2': 8.598335866328617e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:50,928] Trial 91 finished with value: 0.21196164883927957 and parameters: {'learning_rate': 0.017841688706771098, 'num_leaves': 54, 'min_data_in_leaf': 12, 'feature_fraction': 0.9801077864830584, 'bagging_fraction': 0.9871472797570174, 'bagging_freq': 10, 'min_gain_to_split': 0.15524982839500306, 'lambda_l1': 9.304197178315605e-07, 'lambda_l2': 1.2582859658748765e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:51,550] Trial 92 finished with value: 0.21197285117575793 and parameters: {'learning_rate': 0.0162897797673137, 'num_leaves': 58, 'min_data_in_leaf': 13, 'feature_fraction': 0.9789333890986894, 'bagging_fraction': 0.9937932189179173, 'bagging_freq': 10, 'min_gain_to_split': 0.1529281721169483, 'lambda_l1': 1.4021967491574379e-06, 'lambda_l2': 1.0699306790090144e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:52,064] Trial 93 finished with value: 0.22053954680233473 and parameters: {'learning_rate': 0.017835321158326617, 'num_leaves': 44, 'min_data_in_leaf': 12, 'feature_fraction': 0.9669048007788988, 'bagging_fraction': 0.9862657964312823, 'bagging_freq': 10, 'min_gain_to_split': 0.27443926166015825, 'lambda_l1': 3.375208821443088e-06, 'lambda_l2': 3.447259492455791e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:52,629] Trial 94 finished with value: 0.23340077166961715 and parameters: {'learning_rate': 0.012436651990534143, 'num_leaves': 63, 'min_data_in_leaf': 10, 'feature_fraction': 0.9921758906344279, 'bagging_fraction': 0.983805599068506, 'bagging_freq': 10, 'min_gain_to_split': 0.4811006741735375, 'lambda_l1': 9.394314200485649e-06, 'lambda_l2': 2.0487334207770999e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:53,082] Trial 95 finished with value: 0.2273308882137804 and parameters: {'learning_rate': 0.016476411926516034, 'num_leaves': 47, 'min_data_in_leaf': 20, 'feature_fraction': 0.9583571548925982, 'bagging_fraction': 0.9983554022216516, 'bagging_freq': 8, 'min_gain_to_split': 0.36967876611755607, 'lambda_l1': 1.2843555964726666e-06, 'lambda_l2': 6.848508042288797e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:53,620] Trial 96 finished with value: 0.20914742331120711 and parameters: {'learning_rate': 0.022327693427542334, 'num_leaves': 51, 'min_data_in_leaf': 14, 'feature_fraction': 0.9800390259345478, 'bagging_fraction': 0.972300736115961, 'bagging_freq': 9, 'min_gain_to_split': 0.12177030235397296, 'lambda_l1': 9.258366662594531e-07, 'lambda_l2': 2.001368216296986e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:53,939] Trial 97 finished with value: 0.2486465725515521 and parameters: {'learning_rate': 0.023022110277289322, 'num_leaves': 81, 'min_data_in_leaf': 37, 'feature_fraction': 0.9679629829303605, 'bagging_fraction': 0.9710745052726403, 'bagging_freq': 9, 'min_gain_to_split': 0.7203515320313109, 'lambda_l1': 2.58246378128805e-06, 'lambda_l2': 1.9589294337446315e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:54,551] Trial 98 finished with value: 0.20858896889613487 and parameters: {'learning_rate': 0.01968184132536089, 'num_leaves': 72, 'min_data_in_leaf': 26, 'feature_fraction': 0.951260719509533, 'bagging_fraction': 0.937232147577698, 'bagging_freq': 9, 'min_gain_to_split': 0.09917600869106515, 'lambda_l1': 5.825195975470095e-06, 'lambda_l2': 1.831075148649809e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:54,954] Trial 99 finished with value: 0.24113310745337607 and parameters: {'learning_rate': 0.019252913037998823, 'num_leaves': 74, 'min_data_in_leaf': 26, 'feature_fraction': 0.9894844167044321, 'bagging_fraction': 0.9625507318331971, 'bagging_freq': 9, 'min_gain_to_split': 0.5959219785089205, 'lambda_l1': 4.650920351155254e-06, 'lambda_l2': 2.2197525195789325e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:55,274] Trial 100 finished with value: 0.2670857192709419 and parameters: {'learning_rate': 0.02078566126820988, 'num_leaves': 65, 'min_data_in_leaf': 16, 'feature_fraction': 0.9540554232293985, 'bagging_fraction': 0.9715474825906931, 'bagging_freq': 9, 'min_gain_to_split': 1.2960749132066538, 'lambda_l1': 2.9250707983462156e-05, 'lambda_l2': 6.439005699010731e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:55,780] Trial 101 finished with value: 0.21173644586258317 and parameters: {'learning_rate': 0.022912357691488916, 'num_leaves': 98, 'min_data_in_leaf': 28, 'feature_fraction': 0.9427792694050597, 'bagging_fraction': 0.9358215694797247, 'bagging_freq': 8, 'min_gain_to_split': 0.1253259012241541, 'lambda_l1': 6.848377430618904e-06, 'lambda_l2': 2.7619698997751268e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:56,327] Trial 102 finished with value: 0.2184929146306346 and parameters: {'learning_rate': 0.015013558318630719, 'num_leaves': 51, 'min_data_in_leaf': 16, 'feature_fraction': 0.9752507129873845, 'bagging_fraction': 0.946352717043504, 'bagging_freq': 9, 'min_gain_to_split': 0.251501143303062, 'lambda_l1': 1.2807517979692365e-05, 'lambda_l2': 6.84870058034609e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:56,765] Trial 103 finished with value: 0.20752075021661023 and parameters: {'learning_rate': 0.026271230031844128, 'num_leaves': 85, 'min_data_in_leaf': 24, 'feature_fraction': 0.9279412372739358, 'bagging_fraction': 0.9247222722836625, 'bagging_freq': 8, 'min_gain_to_split': 0.10040429499838707, 'lambda_l1': 1.8143878966961633e-06, 'lambda_l2': 1.0231473487088183e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:57,166] Trial 104 finished with value: 0.2100641876503339 and parameters: {'learning_rate': 0.02957772358965245, 'num_leaves': 82, 'min_data_in_leaf': 22, 'feature_fraction': 0.9291173147714886, 'bagging_fraction': 0.9176141289675231, 'bagging_freq': 9, 'min_gain_to_split': 0.10908692691067265, 'lambda_l1': 1.7813690572125495e-06, 'lambda_l2': 1.571215630575015e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:57,545] Trial 105 finished with value: 0.23183345172317402 and parameters: {'learning_rate': 0.01931130868476861, 'num_leaves': 82, 'min_data_in_leaf': 33, 'feature_fraction': 0.9270013494047942, 'bagging_fraction': 0.9169888533526799, 'bagging_freq': 9, 'min_gain_to_split': 0.3943056117564292, 'lambda_l1': 9.046351326001063e-07, 'lambda_l2': 1.36987834587568e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:57,784] Trial 106 finished with value: 0.29373224456714825 and parameters: {'learning_rate': 0.029009171471899915, 'num_leaves': 87, 'min_data_in_leaf': 24, 'feature_fraction': 0.9544740305186685, 'bagging_fraction': 0.8981589868423381, 'bagging_freq': 10, 'min_gain_to_split': 2.089191522601637, 'lambda_l1': 2.072974065365558e-06, 'lambda_l2': 1.0431174172929371e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:58,272] Trial 107 finished with value: 0.20807033883044 and parameters: {'learning_rate': 0.02666975416958631, 'num_leaves': 96, 'min_data_in_leaf': 22, 'feature_fraction': 0.9352691546085743, 'bagging_fraction': 0.9371179669871191, 'bagging_freq': 8, 'min_gain_to_split': 0.10795514712376252, 'lambda_l1': 5.198649327713941e-05, 'lambda_l2': 5.80586929497209e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:58,671] Trial 108 finished with value: 0.2275615040443625 and parameters: {'learning_rate': 0.029951140878637414, 'num_leaves': 94, 'min_data_in_leaf': 38, 'feature_fraction': 0.9242098495856644, 'bagging_fraction': 0.9333233183306591, 'bagging_freq': 8, 'min_gain_to_split': 0.2608002920965702, 'lambda_l1': 1.9461152275706573e-05, 'lambda_l2': 2.973974665944587e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:59,160] Trial 109 finished with value: 0.2103385761595077 and parameters: {'learning_rate': 0.033494759971133825, 'num_leaves': 105, 'min_data_in_leaf': 30, 'feature_fraction': 0.9340182234010355, 'bagging_fraction': 0.8879672716539408, 'bagging_freq': 7, 'min_gain_to_split': 0.09108713029420805, 'lambda_l1': 5.0999021186404604e-05, 'lambda_l2': 5.380846746657734e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:59,404] Trial 110 finished with value: 0.3373149781065926 and parameters: {'learning_rate': 0.026464606184803934, 'num_leaves': 106, 'min_data_in_leaf': 21, 'feature_fraction': 0.9353058869399081, 'bagging_fraction': 0.9226145477807345, 'bagging_freq': 7, 'min_gain_to_split': 4.3737209899690015, 'lambda_l1': 6.767326651795815e-05, 'lambda_l2': 1.6009009607241491e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:16:59,822] Trial 111 finished with value: 0.21131575998403887 and parameters: {'learning_rate': 0.028184164173949866, 'num_leaves': 76, 'min_data_in_leaf': 32, 'feature_fraction': 0.8922986940809259, 'bagging_fraction': 0.8904021163175355, 'bagging_freq': 7, 'min_gain_to_split': 0.09643180657583393, 'lambda_l1': 0.0001545102076918536, 'lambda_l2': 5.350534991819584e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:00,126] Trial 112 finished with value: 0.2259294163406696 and parameters: {'learning_rate': 0.031977428835091644, 'num_leaves': 103, 'min_data_in_leaf': 24, 'feature_fraction': 0.9158047352649994, 'bagging_fraction': 0.9116595428453459, 'bagging_freq': 8, 'min_gain_to_split': 0.33268972843689126, 'lambda_l1': 5.634125299570767e-05, 'lambda_l2': 2.0313768641749332e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:00,414] Trial 113 finished with value: 0.2406710501878222 and parameters: {'learning_rate': 0.03318357450137145, 'num_leaves': 85, 'min_data_in_leaf': 46, 'feature_fraction': 0.9490572836372261, 'bagging_fraction': 0.9052314972486974, 'bagging_freq': 9, 'min_gain_to_split': 0.46715733347107524, 'lambda_l1': 3.3831736429526117e-06, 'lambda_l2': 3.493814965955355e-08}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:00,847] Trial 114 finished with value: 0.20961966209960048 and parameters: {'learning_rate': 0.02629683583255122, 'num_leaves': 95, 'min_data_in_leaf': 29, 'feature_fraction': 0.9601144457134271, 'bagging_fraction': 0.9221706971675699, 'bagging_freq': 8, 'min_gain_to_split': 0.08886046417545032, 'lambda_l1': 0.0004681235855785215, 'lambda_l2': 5.066157541714004e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:01,336] Trial 115 finished with value: 0.20866959751184272 and parameters: {'learning_rate': 0.02389257292998487, 'num_leaves': 96, 'min_data_in_leaf': 30, 'feature_fraction': 0.9608296246071869, 'bagging_fraction': 0.9468473103727371, 'bagging_freq': 8, 'min_gain_to_split': 0.0798094369921248, 'lambda_l1': 0.0021909578141599663, 'lambda_l2': 1.1494101059634499e-06}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:01,734] Trial 116 finished with value: 0.22282783134035572 and parameters: {'learning_rate': 0.023705463394532063, 'num_leaves': 71, 'min_data_in_leaf': 31, 'feature_fraction': 0.9615118060445729, 'bagging_fraction': 0.9487140245596365, 'bagging_freq': 8, 'min_gain_to_split': 0.24763686759895973, 'lambda_l1': 0.0008738519394859486, 'lambda_l2': 4.759996783686443e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:02,151] Trial 117 finished with value: 0.2107595188646208 and parameters: {'learning_rate': 0.026889160086099827, 'num_leaves': 89, 'min_data_in_leaf': 35, 'feature_fraction': 0.92974430382744, 'bagging_fraction': 0.9236797000901481, 'bagging_freq': 7, 'min_gain_to_split': 0.09484378830905994, 'lambda_l1': 0.0013894974796417067, 'lambda_l2': 2.2335708087833827e-06}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:02,698] Trial 118 finished with value: 0.20578119134142506 and parameters: {'learning_rate': 0.021573577138141356, 'num_leaves': 77, 'min_data_in_leaf': 28, 'feature_fraction': 0.9388577067144702, 'bagging_fraction': 0.9376317820002389, 'bagging_freq': 8, 'min_gain_to_split': 0.06388636078174136, 'lambda_l1': 0.0004978285978821803, 'lambda_l2': 1.6893506338208244e-07}. Best is trial 78 with value: 0.19543550590460007.
# [I 2025-09-15 01:17:03,066] Trial 119 finished with value: 0.23252425217946207 and parameters: {'learning_rate': 0.022843914302981907, 'num_leaves': 79, 'min_data_in_leaf': 41, 'feature_fraction': 0.9649391358495911, 'bagging_fraction': 0.9403718975200368, 'bagging_freq': 8, 'min_gain_to_split': 0.3595328745026516, 'lambda_l1': 0.005312465048687385, 'lambda_l2': 6.676260042777356e-07}. Best is trial 78 with value: 0.19543550590460007.
# {'setting': 'Deflate OFF + Image OFF', 'RMSLE': 0.1764, 'R2_log': 0.9383, 'RMSE_yen': 19549605, 'MAE_yen': 12528039, 'MAPE_pct': 13.47, 'best_round': 286, 'optuna_best_rmsle': 0.1954, 'minutes': 0.8, 'features': 39}
# \n=== Summary (lower is better for errors) ===
#                           RMSLE  R2_log  RMSE_yen   MAE_yen  MAPE_pct  \
# setting
# Deflate ON + Image ON    0.1755  0.9386  19429959  12402259     13.34
# Deflate ON + Image OFF   0.1755  0.9386  19429959  12402259     13.34
# Deflate OFF + Image ON   0.1764  0.9383  19549605  12528039     13.47
# Deflate OFF + Image OFF  0.1764  0.9383  19549605  12528039     13.47
#
#                          best_round  optuna_best_rmsle  minutes  features
# setting
# Deflate ON + Image ON           708             0.1942      1.2        39
# Deflate ON + Image OFF          708             0.1942      1.2        39
# Deflate OFF + Image ON          286             0.1954      0.8        39
# Deflate OFF + Image OFF         286             0.1954      0.8        39
