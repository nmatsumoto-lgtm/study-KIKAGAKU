# %% [markdown]
# <a href="https://colab.research.google.com/github/nmatsumoto-lgtm/study-KIKAGAKU/blob/main/%E4%B8%8D%E5%8B%95%E7%94%A3%E4%BE%A1%E6%A0%BC%E4%BA%88%E6%B8%AC%E3%82%A2%E3%83%97%E3%83%AA_Ver_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install lightgbm==4.5.0 optuna==3.6.1 joblib pandas numpy scikit-learn

# %%
from __future__ import annotations
import json
from pathlib import Path
from dataclasses import dataclass


import numpy as np
import pandas as pd
import optuna
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_log_error
from joblib import dump
from optuna.samplers import TPESampler

# %%
# ===== 再現性セット（最上部の import の後に）=====
import os, random
SEED = 42  # ← 好きな固定値（既存の SEED=0 があれば 0 のままでもOK）
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
import os, re
import numpy as np
import pandas as pd

# 1) アップした元CSVのパス（ファイル名は自分のに合わせて変更）
SRC = "/content/drive/MyDrive/project/data/external/平均売買㎡単価推移_東京都中央区.csv"

# 2) 出力先（学習コードが読む場所）
DST_DIR = "data/external"
DST = f"{DST_DIR}/avg_psm.csv"
os.makedirs(DST_DIR, exist_ok=True)

# 3) 読み込み
df = pd.read_csv(SRC)

# 4) 列の推定（period or year/month, そして avg_psm_yen）
cols_lower = {c.lower(): c for c in df.columns}

def pick_price_col(df):
    # まず既に英名があればそれを使う
    if "avg_psm_yen" in cols_lower:
        return cols_lower["avg_psm_yen"]
    # 日本語っぽい列名の自動検出（「平均」「㎡」「単価」「売買」などを含む列）
    for c in df.columns:
        s = str(c)
        if ("㎡" in s or "平米" in s or "m2" in s.lower()) and ("単価" in s or "価格" in s or "売買" in s):
            return c
    # 予備
    for c in df.columns:
        if "psm" in c.lower():
            return c
    raise ValueError("平均㎡単価の列が見つかりません。'avg_psm_yen' または日本語列名（例: '平均㎡売買単価'）を用意してください。")

def to_num(x):
    # "1,647,000 円" みたいな表記を数値化
    return (str(x)
            .replace(",", "")
            .replace("円", "")
            .replace("¥", "")
            .strip())

price_col = pick_price_col(df)
df[price_col] = pd.to_numeric(df[price_col].map(to_num), errors="coerce")

# period or year/month を作成
if "period" in cols_lower:
    period_col = cols_lower["period"]
    df["period"] = pd.to_numeric(df[period_col], errors="coerce").astype("Int64")
else:
    # 年月の列名を推測（year, month / 年, 月, 年月など）
    def pick_year_col():
        for k in ["year", "年"]:
            if k in cols_lower: return cols_lower[k]
        for c in df.columns:
            if re.search(r"年", str(c)): return c
        return None
    def pick_month_col():
        for k in ["month", "月"]:
            if k in cols_lower: return cols_lower[k]
        for c in df.columns:
            if re.search(r"月", str(c)): return c
        return None
    ycol = pick_year_col()
    mcol = pick_month_col()
    if ycol is not None and mcol is not None:
        yy = pd.to_numeric(df[ycol], errors="coerce").astype("Int64")
        mm = pd.to_numeric(df[mcol], errors="coerce").astype("Int64")
        df["period"] = (yy*100 + mm).astype("Int64")
    else:
        # "YYYYMM" 形式の列（例: 年月, yyyymm）を探す
        c_ym = None
        for c in df.columns:
            s = str(c).lower()
            if "yyyymm" in s or "年月" in s:
                c_ym = c; break
        if c_ym is None:
            raise ValueError("period か year/month（または 年/月/年月）の列が見つかりません。")
        df["period"] = pd.to_numeric(df[c_ym], errors="coerce").astype("Int64")

# 5) 最低限の2列だけに整形して保存
out = df[["period", price_col]].rename(columns={price_col: "avg_psm_yen"}).dropna()
out["period"] = out["period"].astype(int)
out["avg_psm_yen"] = out["avg_psm_yen"].astype(float)
out = out.sort_values("period")

out.to_csv(DST, index=False, encoding="utf-8-sig")
print("Saved ->", DST)
print(out.head())
# Out:
# Saved -> data/external/avg_psm.csv
#    period  avg_psm_yen
# 0  202406    1290000.0
# 1  202408    1330000.0
# 2  202410    1380000.0
# 3  202412    1440000.0
# 4  202502    1520000.0

# %%
SEED = 0
np.random.seed(SEED)

# %%
IN = Path("data/interim/train_tabular.csv")
OUT_DIR = Path("models"); OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# === 追加（先頭の定数定義あたり）========================
IDX_CSV = Path("data/external/avg_psm.csv")  # 平均㎡単価CSV
USE_DEFLATE = True  # ← True: ②デフレート学習を有効化 / False: ①の特徴量化のみ
# =======================================================

# %%
# === 追加：指数CSVを読み込み、月次(YYYYMM)に整えて返す =========
def _load_avg_psm_monthly(csv_path: Path) -> pd.DataFrame:
    idx = pd.read_csv(csv_path)

    # period が無ければ year,month から作成
    cols = {c.lower(): c for c in idx.columns}
    if "period" not in cols:
        ycol = cols.get("year"); mcol = cols.get("month")
        if ycol is None or mcol is None:
            raise ValueError("avg_psm.csv には period か year,month が必要です。")
        idx["period"] = idx[ycol].astype(int) * 100 + idx[mcol].astype(int)

    # 月次にリサンプリング（2か月置き→月次へ・線形補間）
    idx["ym"] = pd.to_datetime(idx["period"].astype(str), format="%Y%m")
    idx = (idx[["ym", "avg_psm_yen"]]
             .set_index("ym")
             .resample("MS")
             .interpolate("time")
             .ffill()
             .reset_index())
    idx["period"] = (idx["ym"].dt.year * 100 + idx["ym"].dt.month).astype(int)

    # MoM/YoYなど派生（任意）
    idx = idx.sort_values("period").reset_index(drop=True)
    idx["log_idx_psm"] = np.log(idx["avg_psm_yen"].astype(float))
    idx["idx_mom"] = idx["avg_psm_yen"].pct_change().fillna(0.0)
    idx["idx_yoy"] = idx["avg_psm_yen"].pct_change(12).fillna(0.0)
    return idx[["period", "avg_psm_yen", "log_idx_psm", "idx_mom", "idx_yoy"]]
# =========================================================

def compute_calibration(period_arr, idx_csv: Path, smooth_months: int = 2) -> float:
    """
    学習末月の外部平均㎡単価と最新月の外部平均㎡単価の比（移動平均で平滑化）を返す。
    deflate有無に関わらず、最終の円スケールに掛けるだけでOK。
    """
    try:
        idx = _load_avg_psm_monthly(idx_csv).sort_values("period")
        last_train = int(np.max(period_arr))

        p_train = idx.loc[idx["period"] <= last_train, "avg_psm_yen"]
        if len(p_train) == 0:
            return 1.0
        base = float(p_train.tail(smooth_months).mean())

        latest = float(idx["avg_psm_yen"].tail(smooth_months).mean())
        return latest / base if base > 0 else 1.0
    except Exception:
        return 1.0

# %%
# === 中央区 5エリア：駅→エリアの固定マップ ===
STATION_TO_AREA = {
    # ① 銀座・京橋
    "銀座": "銀座・京橋",
    "東銀座": "銀座・京橋",
    "銀座一丁目": "銀座・京橋",
    "京橋(東京)": "銀座・京橋",
    "宝町(東京)": "銀座・京橋",
    "新橋": "銀座・京橋",
    "汐留": "銀座・京橋",
    "東京": "銀座・京橋",  # 日本橋側に寄せたい場合は「日本橋・人形町」へ変更可

    # ② 日本橋・人形町
    "日本橋(東京)": "日本橋・人形町",
    "三越前": "日本橋・人形町",
    "新日本橋": "日本橋・人形町",
    "茅場町": "日本橋・人形町",
    "人形町": "日本橋・人形町",
    "水天宮前": "日本橋・人形町",
    "浜町": "日本橋・人形町",
    "東日本橋": "日本橋・人形町",
    "小伝馬町": "日本橋・人形町",
    "馬喰横山": "日本橋・人形町",
    "馬喰町": "日本橋・人形町",

    # ③ 月島・勝どき・晴海
    "月島": "月島・勝どき・晴海",
    "勝どき": "月島・勝どき・晴海",

    # ④ 築地・八丁堀
    "築地": "築地・八丁堀",
    "築地市場": "築地・八丁堀",
    "新富町(東京)": "築地・八丁堀",
    "八丁堀(東京)": "築地・八丁堀",
}

AREA_LIST = ["銀座・京橋", "日本橋・人形町", "月島・勝どき・晴海", "築地・八丁堀", "佃・新川・湊", "その他"]

def station_to_area(station_name: str) -> str:
    """駅名を5エリアに変換。未登録は 'その他'。"""
    if not isinstance(station_name, str) or station_name.strip() == "":
        return "その他"
    return STATION_TO_AREA.get(station_name.strip(), "その他")

# %%
# ============================
# 1) データ読み込み & 追加特徴量
# ============================

def _oof_target_median(df: pd.DataFrame, key: str, y: np.ndarray, n_splits: int = 5) -> np.ndarray:
    """キー列ごとの OOF 中央値エンコーディング（リーク防止）。
    戻り値は各行に対応する OOF 推定値（学習折ごとに学習外の中央値を使う）。
    """
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    oof = np.zeros(len(df), dtype=float)
    for tr_idx, va_idx in kf.split(df):
        med = (
            pd.DataFrame({key: df.iloc[tr_idx][key].values, "y": y[tr_idx]})
            .groupby(key)["y"].median()
        )
        oof[va_idx] = df.iloc[va_idx][key].map(med).fillna(med.median()).values
    return oof

def _oof_target_mean(df, key, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    oof = np.zeros(len(df), dtype=float)
    for tr_idx, va_idx in kf.split(df):
        m = (pd.DataFrame({key: df.iloc[tr_idx][key].values, "y": y[tr_idx]})
             .groupby(key)["y"].mean())
        oof[va_idx] = df.iloc[va_idx][key].map(m).fillna(m.mean()).values
    return oof

def build_table_and_features() -> tuple[pd.DataFrame, list[str], list[str], list[str], list[int]]:
    df = pd.read_csv(IN)
     # ---- 駅単位の人口・浸水などの環境特徴を付与 ----
    # df = _merge_station_features(df, prefix="st_")
    df = _merge_station_features(df)

    # ===== 対数ターゲット =====
    y = df["price_yen"].astype(float).values
    # ★ 追加：指数CSVを読み込み & マージ
    idx = _load_avg_psm_monthly(IDX_CSV)

    # 学習データ側 period が無ければ作成（あなたのCSVには既にありますが保険）
    if "period" not in df.columns and {"year","month"} <= set(df.columns):
        df["period"] = df["year"].astype(int)*100 + df["month"].astype(int)

    # マージ（相場水準をくっつける）
    df = df.merge(idx, on="period", how="left")
    # 欠損は前方/後方で埋める（学習期間内なら埋まります）
    for c in ["avg_psm_yen","log_idx_psm","idx_mom","idx_yoy"]:
      df[c] = df[c].ffill().bfill()

    # ★ ここが“②デフレート学習”の切替ポイント
    if USE_DEFLATE:
        # 相場水準(avg_psm)を引いた「相対価格（対数）」を学習
        y_log = np.log1p(y) - np.log(df["avg_psm_yen"].astype(float).values)
    else:
        # 従来どおり
        y_log = np.log1p(y)

    # # ===== 対数ターゲット =====
    # y = df["price_yen"].astype(float).values
    # y_log = np.log1p(y)

    # ===== 5エリアを駅から自動付与（入力は駅のまま）=====
    df["area_group"] = df["station"].astype(str).apply(station_to_area)

    # ===== 追加特徴量 =====
    df["access_score"] = 1.0 / (1.0 + df["walk_min"].astype(float))
    df["sqrt_area"]    = np.sqrt(np.clip(df["area_sqm"].astype(float), 0, None))
    df["log_area"]     = np.log1p(np.clip(df["area_sqm"].astype(float), 0, None))
    df["age_sqrt"]     = np.sqrt(np.clip(df["築年数"].astype(float), 0, None))
    df["area_x_access"]= df["area_sqm"].astype(float) * df["access_score"].astype(float)

    # ===== 頻度特徴量 =====
    station_cnt = df["station"].value_counts()
    layout_cnt  = df["layout"].value_counts()
    area_cnt    = df["area_group"].value_counts()

    df["station_count"] = df["station"].map(station_cnt).fillna(0).astype(int)
    df["layout_count"]  = df["layout"].map(layout_cnt).fillna(0).astype(int)
    df["area_count"]    = df["area_group"].map(area_cnt).fillna(0).astype(int)

    # ===== OOF 目標エンコード（対数ターゲットで中央値）=====
    df["station_oof_median_log"] = _oof_target_median(df, "station",     y_log)
    df["layout_oof_median_log"]  = _oof_target_median(df, "layout",      y_log)
    df["area_oof_median_log"]    = _oof_target_median(df, "area_group",  y_log)

    # ===== OOF 目標エンコード（対数ターゲットで平均）=====  ←★ ここを追加
    df["station_oof_mean_log"] = _oof_target_mean(df, "station",    y_log)
    df["layout_oof_mean_log"]  = _oof_target_mean(df, "layout",     y_log)
    df["area_oof_mean_log"]    = _oof_target_mean(df, "area_group", y_log)


    # ===== 推論用に学習時統計を準備 =====
    station_med_map = (
        pd.DataFrame({"station": df["station"], "y_log": y_log})
        .groupby("station")["y_log"].median().to_dict()
    )
    layout_med_map = (
        pd.DataFrame({"layout": df["layout"], "y_log": y_log})
        .groupby("layout")["y_log"].median().to_dict()
    )
    area_med_map = (
        pd.DataFrame({"area_group": df["area_group"], "y_log": y_log})
        .groupby("area_group")["y_log"].median().to_dict()
    )

    # ←★ ここから “平均” を追加
    station_mean_map = (
        pd.DataFrame({"station": df["station"], "y_log": y_log})
        .groupby("station")["y_log"].mean().to_dict()
    )
    layout_mean_map = (
        pd.DataFrame({"layout": df["layout"], "y_log": y_log})
        .groupby("layout")["y_log"].mean().to_dict()
    )
    area_mean_map = (
        pd.DataFrame({"area_group": df["area_group"], "y_log": y_log})
        .groupby("area_group")["y_log"].mean().to_dict()
    )

    global_station_med = float(np.median(list(station_med_map.values()))) if len(station_med_map) else float(np.median(y_log))
    global_layout_med  = float(np.median(list(layout_med_map.values())))  if len(layout_med_map)  else float(np.median(y_log))
    global_area_med    = float(np.median(list(area_med_map.values())))    if len(area_med_map)    else float(np.median(y_log))

    # 参考：平均の“全体値”も欲しければ
    global_station_mean = float(np.mean(list(station_mean_map.values()))) if len(station_mean_map) else float(np.mean(y_log))
    global_layout_mean  = float(np.mean(list(layout_mean_map.values())))  if len(layout_mean_map)  else float(np.mean(y_log))
    global_area_mean    = float(np.mean(list(area_mean_map.values())))    if len(area_mean_map)    else float(np.mean(y_log))

    # ===== カテゴリ列（area を先頭に追加）=====
    feat_cat = ["area_group", "station", "layout"]

    # ===== 数値列 =====
    feat_num_base = ["walk_min", "築年数", "area_sqm"]
    feat_num_extra = [
        "access_score", "sqrt_area", "log_area", "age_sqrt",
        "area_x_access",
        "station_count", "layout_count", "area_count",
        "station_oof_median_log", "layout_oof_median_log", "area_oof_median_log",
        "station_oof_mean_log", "layout_oof_mean_log", "area_oof_mean_log",
        # ★ 追加：指数の特徴量（①）
        "log_idx_psm",   # 水準（対数）
        "idx_mom",       # 前月比
        "idx_yoy",       # 前年同月比
        "st_pop_sum",        # 駅400m内の総人口
        "st_pop_min",        # 駅400m内の最小人口
        "st_flood_ratio",    # 駅400m内の浸水面積比
        "land25_mean",       # 今年の平均地価（円/㎡）
        "land_yoy_rate",     # 地価前年比（率）
        "land_logdiff",      # 地価ログ差,
    ]
    feat_num_all = feat_num_base + feat_num_extra

    # 単調制約を「名前で」安全に指定
    mono_dict = {name: 0 for name in feat_num_all}
    mono_dict.update({
        "walk_min": -1,      # 遠いほど↓
        "築年数": -1,         # 古いほど↓
        "area_sqm": +1,      # 広いほど↑
        # ← 派生も一貫させる
        "access_score": +1,  # 駅近スコアが高いほど↑（walk_minと反対符号に注意だが整合的）
        "sqrt_area": +1,
        "log_area": +1,
        "age_sqrt": -1,
     })
    monotone_constraints = [0] * len(feat_cat) + [mono_dict[c] for c in feat_num_all]

    # # ===== 単調性制約（[cat..., num...] の順）=====
    # n_cat = len(feat_cat)
    # # walk_min↓, 築年数↓, area_sqm↑、その他は制約なし
    # mono_num = [-1, -1, +1] + [0] * (len(feat_num_all) - 3)
    # monotone_constraints = [0] * n_cat + mono_num

    # ===== ここから：新しいほど重くする sample_weight =====
    # 年月を「通算月」に変換（最新月との差＝どれだけ古いか）
    year_s  = pd.to_numeric(df["year"],  errors="coerce").astype(int)
    month_s = pd.to_numeric(df["month"], errors="coerce").astype(int)

    latest_m = int(year_s.max())*12 + int(month_s.max())          # スカラ
    this_m   = (year_s*12 + month_s)                               # Series（ベクトル計算）
    months_old = (latest_m - this_m).clip(lower=0)

    HALF_LIFE_MONTHS = 12.0  # 半減期（例：12ヶ月）。強めに効かせたいなら 6 にする等
    w = np.power(0.5, months_old / HALF_LIFE_MONTHS)
    w = np.clip(w, 0.2, None)  # 古すぎるデータにも最低限の重み（お好みで調整）
    sample_weight = w.values.astype(float)
    # ===== ここまで =====

    # ===== エンコードして学習用テーブル =====
    oe = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
    X_cat = oe.fit_transform(df[feat_cat].fillna("NA")).astype("int32")
    X_num = df[feat_num_all].astype(float).values
    X = np.hstack([X_cat, X_num])

    cat_cols = [f"cat__{c}" for c in feat_cat]
    num_cols = feat_num_all.copy()
    X_df = pd.DataFrame(X, columns=cat_cols + num_cols)
    categorical_feature = cat_cols

    meta = {
        "feat_cat": feat_cat,
        "feat_num": num_cols,
        "categorical_feature": categorical_feature,
        "monotone_constraints": monotone_constraints,
    }

    # ===== 推論用マップ（station→area を含めて保存）=====
    infer_maps = {
        "station_count_map": station_cnt.to_dict(),
        "layout_count_map":  layout_cnt.to_dict(),
        "area_count_map":    area_cnt.to_dict(),

        "station_median_log_map": station_med_map,
        "layout_median_log_map":  layout_med_map,
        "area_median_log_map":    area_med_map,

        "global_station_median_log": global_station_med,
        "global_layout_median_log":  global_layout_med,
        "global_area_median_log":    global_area_med,

        # ↓↓↓ 追加（平均）
        "station_mean_log_map": station_mean_map,
        "layout_mean_log_map":  layout_mean_map,
        "area_mean_log_map":    area_mean_map,

        "global_station_median_log": global_station_med,
        "global_layout_median_log":  global_layout_med,
        "global_area_median_log":    global_area_med,

        # （必要なら平均の全体値も）
        "global_station_mean_log": global_station_mean,
        "global_layout_mean_log":  global_layout_mean,
        "global_area_mean_log":    global_area_mean,

        "station_to_area_map": {s: station_to_area(s) for s in sorted(df["station"].astype(str).unique())},
        "area_groups": AREA_LIST,

        "feat_cat": feat_cat,
        "feat_num": num_cols,

        # 駅→エリア（推論で駅入力から自動付与）
        "station_to_area_map": {s: station_to_area(s) for s in sorted(df["station"].astype(str).unique())},
        "area_groups": AREA_LIST,

        "feat_cat": feat_cat,
        "feat_num": num_cols,
    }

    avg_psm_arr = df["avg_psm_yen"].to_numpy() if "avg_psm_yen" in df.columns else None
    period_arr = df["period"].to_numpy().astype(int)

    # 返り値（従来どおり）
    return (X_df, y_log, categorical_feature, monotone_constraints, meta, oe,infer_maps, sample_weight, avg_psm_arr,np.log1p(df["price_yen"].astype(float).values),period_arr)

# %%
# ============================
# 駅単位の環境特徴量を学習テーブルにマージ
# ============================
from pathlib import Path
import pandas as pd
import numpy as np

# ← 末尾スペースに注意！本当にファイル名にスペースが無いなら消してください
PATH_STATIONS_FEATURES = Path("/content/drive/MyDrive/project/data/external/stations_with_features .csv")
# もし本当にスペース付きファイルなら↑を ".csv" の前に半角スペース入りへ戻す

def _safe_read_csv(p: Path) -> pd.DataFrame:
    try:
        return pd.read_csv(p)
    except UnicodeDecodeError:
        return pd.read_csv(p, encoding="cp932")

def _normalize_station_name(s: str) -> str:
    """駅名のゆらぎを軽く吸収（全角記号→半角、全角スペース除去など）"""
    if not isinstance(s, str):
        return ""
    t = (
        s.replace("（", "(").replace("）", ")")
         .replace("　", " ")
         .strip()
    )
    return t

def _prepare_station_features() -> pd.DataFrame:
    """
    stations_with_features.csv を station をキーに統一し、
    人口/浸水は st_ 接頭辞、地価は元の列名のままで返す。
    """
    assert PATH_STATIONS_FEATURES.exists(), f"Not found: {PATH_STATIONS_FEATURES}"
    sf = _safe_read_csv(PATH_STATIONS_FEATURES).copy()

    # 駅名列を station に統一
    name_col = None
    for c in sf.columns:
        lc = c.lower()
        if lc in ("station_name", "station") or "駅" in c:
            name_col = c
            break
    if name_col is None:
        raise ValueError("stations_with_features.csv に駅名列(station_name/station/駅名など)が必要です。")

    sf = sf.rename(columns={name_col: "station"})
    sf["station"] = sf["station"].astype(str).map(_normalize_station_name)

    # --- 列名の正規化マップ ---
    # 人口/浸水 → st_ 接頭辞に変換
    rename_pop_flood = {
        "pop_sum": "st_pop_sum",
        "pop_min": "st_pop_min",
        "flood_ratio": "st_flood_ratio",
        "flood_flag": "st_flood_flag",
    }
    sf = sf.rename(columns=rename_pop_flood)

    # 地価系はそのまま使う（改名しない）
    # 想定: land25_mean, land_yoy_rate, land_logdiff

    # 使う列だけ残す（lat/lonなどは落とす）
    keep = ["station",
            "st_pop_sum", "st_pop_min", "st_flood_ratio", "st_flood_flag",
            "land25_mean", "land_yoy_rate", "land_logdiff"]
    exist = [c for c in keep if c in sf.columns]
    missing = [c for c in keep if c not in sf.columns]
    if missing:
        print("[WARN] station features missing cols:", missing)
    sf = sf[exist].copy()

    # 型の整理：フラグは int、数値は float
    for c in sf.columns:
        if c == "station":
            continue
        if sf[c].dropna().isin([0,1,True,False]).all():
            sf[c] = sf[c].astype(int)
        else:
            sf[c] = pd.to_numeric(sf[c], errors="coerce")

    # 欠損は0で埋める（安全側）
    for c in sf.columns:
        if c != "station":
            sf[c] = sf[c].fillna(0)

    return sf

def _merge_station_features(df: pd.DataFrame) -> pd.DataFrame:
    """train_tabular（各取引行）に駅別特徴を station で LEFT JOIN"""
    df2 = df.copy()
    df2["station"] = df2["station"].astype(str).map(_normalize_station_name)

    # prefix は不要になった
    stf = _prepare_station_features()
    merged = df2.merge(stf, how="left", on="station")

    # 欠損を安全側で埋める
    for c in merged.columns:
        if c != "station":
            if merged[c].dtype.kind in "fi":
                merged[c] = merged[c].fillna(0.0)
            else:
                merged[c] = merged[c].fillna(0)
    return merged

# %%
df2 = _merge_station_features(pd.read_csv("data/interim/train_tabular.csv"))
print(df2[["station", "st_pop_sum", "land25_mean"]].head(20))
# Out:
#     station  st_pop_sum   land25_mean
# 0   新富町(東京)  14100.0624  5.433333e+06
# 1   新富町(東京)  14100.0624  5.433333e+06
# 2   新富町(東京)  14100.0624  5.433333e+06
# 3   新富町(東京)  14100.0624  5.433333e+06
# 4   新富町(東京)  14100.0624  5.433333e+06
# 5   新富町(東京)  14100.0624  5.433333e+06
# 6   新富町(東京)  14100.0624  5.433333e+06
# 7      水天宮前  24007.1686  2.050000e+06
# 8      水天宮前  24007.1686  2.050000e+06
# 9      水天宮前  24007.1686  2.050000e+06
# 10      茅場町  16270.5289  5.200000e+06
# 11      茅場町  16270.5289  5.200000e+06
# 12     小伝馬町  21434.9836  3.352000e+06
# 13     小伝馬町  21434.9836  3.352000e+06
# 14      三越前   3656.4900  5.435000e+06
# 15      人形町  25334.3031  2.800000e+06
# 16      人形町  25334.3031  2.800000e+06
# 17      人形町  25334.3031  2.800000e+06
# 18      人形町  25334.3031  2.800000e+06
# 19      人形町  25334.3031  2.800000e+06

# %%
# ============================
# 2) Optuna でハイパラ探索（時系列CV）
# ============================
def tune_with_optuna(
    X_df, y_log, y_log_true, categorical_feature, monotone_constraints,
    period_arr,  # ★追加（YYYYMMの配列）
    n_trials=200, sample_weight=None, avg_psm=None
) -> tuple[dict, int, float]:

    from sklearn.model_selection import TimeSeriesSplit  # 先頭に移しても可

    # 並び替え（古い→新しい）
    order = np.argsort(period_arr)
    X_ord = X_df.iloc[order]
    y_ord = y_log[order]
    y_true_ord = y_log_true[order]
    w_ord = None if sample_weight is None else sample_weight[order]
    avg_ord = None if avg_psm is None else avg_psm[order]

    tscv = TimeSeriesSplit(n_splits=5)

    def objective(trial: optuna.Trial) -> float:
        params = {
            "objective": "rmse", "metric": "rmse",
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
            "num_leaves": trial.suggest_int("num_leaves", 31, 255),
            "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 200),
            "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 1.0),
            "bagging_fraction": trial.suggest_float("bagging_fraction", 0.6, 1.0),
            "bagging_freq": trial.suggest_int("bagging_freq", 0, 10),
            "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0.0, 5.0),
            "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
            "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
            "verbosity": -1, "seed": SEED,
            "monotone_constraints": monotone_constraints,
        }

        rmsles, best_iters = [], []
        for tr_rel, va_rel in tscv.split(X_ord):
            X_tr, X_va = X_ord.iloc[tr_rel], X_ord.iloc[va_rel]
            y_tr, y_va = y_ord[tr_rel], y_ord[va_rel]
            w_tr = None if w_ord is None else w_ord[tr_rel]
            w_va = None if w_ord is None else w_ord[va_rel]

            dtr = lgb.Dataset(
                X_tr, label=y_tr, weight=w_tr,
                categorical_feature=categorical_feature, free_raw_data=True
            )
            dva = lgb.Dataset(
                X_va, label=y_va, weight=w_va,
                categorical_feature=categorical_feature, free_raw_data=True
            )

            model = lgb.train(
                params, dtr, valid_sets=[dva],
                num_boost_round=4000,
                callbacks=[lgb.early_stopping(200, verbose=False)]
            )
            pred_log = model.predict(X_va, num_iteration=model.best_iteration)

            if USE_DEFLATE and (avg_ord is not None):
                # 相対ログ + 相場ログ → 円に戻してRMSLE
                yhat_yen  = np.expm1(pred_log + np.log(avg_ord[va_rel]))
                ytrue_yen = np.expm1(y_true_ord[va_rel])
                rmsle = float(np.sqrt(mean_squared_log_error(ytrue_yen, yhat_yen)))
            else:
                rmsle = float(np.sqrt(mean_squared_log_error(np.expm1(y_va), np.expm1(pred_log))))

            rmsles.append(rmsle)
            best_iters.append(model.best_iteration)

        trial.set_user_attr("best_iters", best_iters)
        return float(np.mean(rmsles))

    study = optuna.create_study(direction="minimize",sampler=TPESampler(seed=SEED))
    study.optimize(objective, n_trials=n_trials)

    best_params = study.best_params
    best_iters_list = study.best_trial.user_attrs.get("best_iters", [1000])
    best_round = int(np.clip(np.mean(best_iters_list), 100, 4000))
    best_score = study.best_value
    return best_params, best_round, best_score

# %%
# ============================
# 3) 最終学習（ポイント & 分位点）
# ============================

def train_final_models(
    X_df: pd.DataFrame,
    y_log: np.ndarray,
    categorical_feature: list[str],
    monotone_constraints: list[int],
    best_params: dict,
    best_round: int,
    sample_weight: np.ndarray | None = None  # ★ 追加
):
    base_params = dict(best_params)
    base_params.update({
        "objective": "rmse",
        "metric": "rmse",
        "verbosity": -1,
        "seed": SEED,
        # ★ ポイントモデルでは単調性制約を使う
        "monotone_constraints": monotone_constraints,
    })

    # 生データを解放しない（categorical_feature を後で使えるように）
    dtrain = lgb.Dataset(
        X_df,
        label=y_log,
        weight=sample_weight,
        categorical_feature=categorical_feature,
        free_raw_data=False
    )

    # ---- ポイント（対数価格）----
    model_point = lgb.train(base_params, dtrain, num_boost_round=best_round)

    # ---- smearing（log1p → 円の戻し補正）----
    pred_log_tr = model_point.predict(X_df, num_iteration=getattr(model_point, "best_iteration", None))
    resid = y_log - pred_log_tr  # eps = y_log - yhat_log
    # ★ 直近重視の設計と整合：重み付き平均（重みが無いときは従来どおり）
    smearing = (
        float(np.average(np.exp(resid), weights=sample_weight))
        if sample_weight is not None else
        float(np.mean(np.exp(resid)))
    )

    # ---- 分位点（q10/q90）----
    models_q = {}
    for alpha, tag in [(0.1, "q10"), (0.9, "q90")]:
        q_params = dict(best_params)
        q_params.update({
            "objective": "quantile",
            "alpha": alpha,
            "metric": "quantile",
            "verbosity": -1,
            "seed": SEED,
            # ★ ここが重要：quantile では単調性制約を外す
            # "monotone_constraints": monotone_constraints,  # ←入れない
        })
        models_q[tag] = lgb.train(q_params, dtrain, num_boost_round=best_round)

    return model_point, models_q, smearing

# %%
# ===== 入力CSV→中間CSVの自動生成（なければ作る） =====
from pathlib import Path
import pandas as pd, numpy as np, re
from datetime import datetime

RAW_CSV = Path("/content/drive/MyDrive/project/data/external/Tokyo_Chuo Ward_20242_20251.csv")
IN = Path("data/interim/train_tabular.csv")
ST_OUT = Path("data/interim/stations.csv")
IN.parent.mkdir(parents=True, exist_ok=True)

# ===== _read_chuo_and_save() の先頭付近に追加（関数の外でOK）=====
def _parse_period(s):
    """'2025年8月', '2025/08', '2025-8', '2025年第2四半期' などを (year, month) に直す"""
    import re, math
    if pd.isna(s): return (np.nan, np.nan)
    s = str(s)

    # 年月パターン
    m = re.search(r"(\d{4})[年/\-\. ]+(\d{1,2})", s)
    if m:
        y, mo = int(m.group(1)), int(m.group(2))
        mo = int(np.clip(mo, 1, 12))
        return (y, mo)

    # 四半期パターン
    m = re.search(r"(\d{4})年?第?([1-4])四半期", s)
    if m:
        y, q = int(m.group(1)), int(m.group(2))
        q2m = {1:1, 2:4, 3:7, 4:10}
        return (y, q2m[q])

    # 年だけ
    m = re.search(r"(\d{4})年", s)
    if m:
        return (int(m.group(1)), 1)

    return (np.nan, np.nan)

def _read_chuo_and_save(raw_csv: Path, out_csv: Path, stations_csv: Path):
    # エンコーディングを順に試す（Excel想定）
    last_err = None
    for enc in ("cp932", "utf-8-sig", "utf-8", "utf-16", "utf-16le", "utf-16be"):
        try:
            raw = pd.read_csv(raw_csv, encoding=enc)
            break
        except Exception as e:
            last_err = e
            raw = None
    if raw is None:
        raise last_err

    def _to_year(x):
        if pd.isna(x):
            return np.nan
        m = re.search(r"(\d{4})年", str(x))
        return int(m.group(1)) if m else np.nan

    # 必要列だけ取り出し
    df = raw[["最寄駅：名称","最寄駅：距離（分）","間取り","面積（㎡）","建築年","取引価格（総額）"]].copy()

    build_year = df["建築年"].apply(_to_year)
    current_year = datetime.now().year
    df["築年数"] = (current_year - build_year).clip(lower=0)

    for col in ["最寄駅：距離（分）","面積（㎡）","築年数"]:
        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(df[col].median())

    def _normalize_layout(s):
        if not isinstance(s, str):
            return "その他"
        s = (s.upper()
               .replace("Ｌ","L").replace("Ｄ","D").replace("Ｋ","K").replace("Ｒ","R"))
        m = re.search(r"(\d+)(LDK|DK|K|R)", s)
        return m.group(0) if m else "その他"

    # ★ ここは _normalize_layout の「外」（= 同じインデント階層）
    period_col = None
    for c in ["取引時期", "取引時点", "成約年月", "契約年月", "年月", "取引年月"]:
        if c in raw.columns:
            period_col = c
            break

    if period_col is not None:
        ym = raw[period_col].apply(_parse_period)
        year  = ym.apply(lambda t: t[0]).astype("Int64")
        month = ym.apply(lambda t: t[1]).astype("Int64")
    else:
        year  = pd.Series([np.nan] * len(raw), dtype="Int64")
        month = pd.Series([np.nan] * len(raw), dtype="Int64")

    # 欠損処理
    if year.isna().all():
        now = datetime.now()
        year  = pd.Series([now.year]  * len(raw))
        month = pd.Series([now.month] * len(raw))
    else:
        year  = year.fillna(method="ffill").fillna(method="bfill").astype(int)
        month = month.fillna(method="ffill").fillna(method="bfill").astype(int)

    # 学習用テーブル作成
    train = df.rename(columns={
        "最寄駅：名称": "station",
        "最寄駅：距離（分）": "walk_min",
        "面積（㎡）": "area_sqm",
        "取引価格（総額）": "price_yen",
    })[["station","walk_min","築年数","area_sqm","price_yen"]].copy()

    train["layout"] = df["間取り"].astype(str).apply(_normalize_layout)
    train["year"]   = year.astype(int)
    train["month"]  = month.astype(int)
    train["period"] = train["year"] * 100 + train["month"]

    # 保存
    train.to_csv(out_csv, index=False)

    # 駅リスト保存（utf-8-sig）
    s = (raw["最寄駅：名称"].astype(str)
           .replace({"nan": np.nan, "None": np.nan, "": np.nan})
           .dropna()
           .str.normalize("NFKC")
           .str.replace("（","(",regex=False).str.replace("）",")",regex=False)
           .str.replace("　"," ",regex=False).str.strip()
           .str.replace(r"\s+"," ",regex=True))
    pd.Series(sorted(s.unique())).to_csv(stations_csv, index=False, header=False, encoding="utf-8-sig")

# まだ中間CSVがない場合は作る
# if not IN.exists():
#     if not RAW_CSV.exists():
#         raise FileNotFoundError(f"Raw CSV が見つかりません: {RAW_CSV.resolve()}")
#     _read_chuo_and_save(RAW_CSV, IN, ST_OUT)
# ★ 一度だけ True にしてCSVを作り直す（year/month/period列を付与）
FORCE_REBUILD = True   # 生成が終わったら False に戻す/この行を消す

if FORCE_REBUILD or not IN.exists():
   if not RAW_CSV.exists():
      raise FileNotFoundError(f"Raw CSV が見つかりません: {RAW_CSV.resolve()}")
   _read_chuo_and_save(RAW_CSV, IN, ST_OUT)
# Out:
# /tmp/ipython-input-1409479088.py:97: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   year  = year.fillna(method="ffill").fillna(method="bfill").astype(int)
# /tmp/ipython-input-1409479088.py:98: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   month = month.fillna(method="ffill").fillna(method="bfill").astype(int)

# %%
tmp = pd.read_csv(IN)
print(tmp.columns.tolist())
# 'year', 'month', 'period' が含まれていること
print(tmp.head())
# Out:
# ['station', 'walk_min', '築年数', 'area_sqm', 'price_yen', 'layout', 'year', 'month', 'period']
#    station  walk_min   築年数  area_sqm  price_yen layout  year  month  period
# 0  新富町(東京)       3.0  24.0        75  140000000   ３LDK  2024      4  202404
# 1  新富町(東京)       3.0  46.0        40   26000000     ２K  2024      4  202404
# 2  新富町(東京)       3.0  18.0        45   56000000   １LDK  2024      4  202404
# 3  新富町(東京)       1.0  27.0        35   47000000   １LDK  2024      4  202404
# 4  新富町(東京)       3.0  18.0        45   58000000   １LDK  2024      4  202404

# %%
# ============================
# 4) 実行
# ============================

if __name__ == "__main__":
    assert IN.exists(), f"Not found: {IN}"

    # ★ infer_maps まで受け取る（関数が infer_maps を返す実装になっている前提）
    X_df, y_log, cat_cols, mono_cons, meta, oe, infer_maps, sample_weight, avg_psm_arr, y_log_true, period_arr = build_table_and_features()

    print(f"Train rows: {len(X_df):,}, cols: {X_df.shape[1]} (cats={len(cat_cols)})")

    best_params, best_round, best_score = tune_with_optuna(
    X_df, y_log, y_log_true, cat_cols, mono_cons, period_arr,   # ★ period_arr を追加
    n_trials=200, sample_weight=sample_weight, avg_psm=avg_psm_arr
)
    print("[OPTUNA] best RMSLE:", round(best_score, 4))
    print("[OPTUNA] best params:")
    for k, v in best_params.items():
        print(f"  {k}: {v}")
    print("[OPTUNA] best_round:", best_round)

    model_point, models_q, smearing = train_final_models(
        X_df, y_log, cat_cols, mono_cons, best_params, best_round,
    sample_weight=sample_weight
    )

    # 直近水準の倍率キャリブを外部指数から計算（保存の前！）
    calib = compute_calibration(period_arr, IDX_CSV, smooth_months=2)
    print(f"[CALIB] multiplier to latest: {calib:.4f}")

    # ===== 保存 =====
    # 予測時に使うメタ情報（列順や制約）とエンコーダを一緒に保存しておく
    dump({
        "model": model_point,
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen",
        "smearing": smearing,
        "calibration": calib,          # ★追加
        "use_deflate": USE_DEFLATE,    # ★追加（推論コード用に）
    }, OUT_DIR / "lgbm_optuna_point.pkl")

    dump({
        "model": models_q["q10"],
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen",
        "alpha": 0.1,
        "smearing": smearing,
        "calibration": calib,          # ★追加
        "use_deflate": USE_DEFLATE,    # ★追加（推論コード用に）
    }, OUT_DIR / "lgbm_optuna_q10.pkl")

    dump({
        "model": models_q["q90"],
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen",
        "alpha": 0.9,
        "smearing": smearing,
        "calibration": calib,          # ★追加
        "use_deflate": USE_DEFLATE,    # ★追加（推論コード用に）
    }, OUT_DIR / "lgbm_optuna_q90.pkl")

    with open(OUT_DIR / "feature_config.json", "w", encoding="utf-8") as f:
        json.dump({
            "feat_cat": meta["feat_cat"],
            "feat_num": meta["feat_num"],
            "categorical_feature": meta["categorical_feature"],
            "monotone_constraints": meta["monotone_constraints"],
            "notes": "y is log1p(price_yen). During inference, apply expm1 to predictions.",
        }, f, ensure_ascii=False, indent=2)

    # ★ 推論用マップも保存（カッコを閉じるのを忘れない）
    with open(OUT_DIR / "infer_maps.json", "w", encoding="utf-8") as f:
        json.dump(infer_maps, f, ensure_ascii=False, indent=2)

    print("Saved models →", OUT_DIR)
# Out:
# [I 2025-09-21 12:47:34,750] A new study created in memory with name: no-name-5e9d8dfc-006b-4178-b956-f29109f4de13
# Train rows: 1,784, cols: 29 (cats=3)
# [I 2025-09-21 12:47:35,088] Trial 0 finished with value: 0.3921300634791881 and parameters: {'learning_rate': 0.05176340429875833, 'num_leaves': 191, 'min_data_in_leaf': 125, 'feature_fraction': 0.8179532731987588, 'bagging_fraction': 0.7694619197355619, 'bagging_freq': 7, 'min_gain_to_split': 2.1879360563134624, 'lambda_l1': 1.0615904599004014, 'lambda_l2': 4.709392030276881}. Best is trial 0 with value: 0.3921300634791881.
# [I 2025-09-21 12:47:37,796] Trial 1 finished with value: 0.25977582730749277 and parameters: {'learning_rate': 0.03154052496956797, 'num_leaves': 209, 'min_data_in_leaf': 111, 'feature_fraction': 0.827217824437573, 'bagging_fraction': 0.9702386553170644, 'bagging_freq': 0, 'min_gain_to_split': 0.43564649850770354, 'lambda_l1': 1.5204270129130175e-08, 'lambda_l2': 0.31158648353398066}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:47:39,724] Trial 2 finished with value: 0.3742739813805384 and parameters: {'learning_rate': 0.10289760686796066, 'num_leaves': 226, 'min_data_in_leaf': 196, 'feature_fraction': 0.9196634256866895, 'bagging_fraction': 0.7845917449011728, 'bagging_freq': 8, 'min_gain_to_split': 0.5913721293446661, 'lambda_l1': 0.005744988873954126, 'lambda_l2': 1.9506510537765813e-07}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:47:42,160] Trial 3 finished with value: 0.3109505134157186 and parameters: {'learning_rate': 0.16945039949066026, 'num_leaves': 148, 'min_data_in_leaf': 89, 'feature_fraction': 0.7058222448418507, 'bagging_fraction': 0.9096934757736866, 'bagging_freq': 5, 'min_gain_to_split': 2.8421697443432423, 'lambda_l1': 1.4760742495197955e-08, 'lambda_l2': 0.003620090882797527}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:47:46,149] Trial 4 finished with value: 0.4251286294091431 and parameters: {'learning_rate': 0.06256837783419193, 'num_leaves': 169, 'min_data_in_leaf': 190, 'feature_fraction': 0.8727281196413934, 'bagging_fraction': 0.7438031602295144, 'bagging_freq': 4, 'min_gain_to_split': 3.4881559796363244, 'lambda_l1': 3.483607722774873e-08, 'lambda_l2': 0.010020754882942}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:47:49,235] Trial 5 finished with value: 0.41161214186745915 and parameters: {'learning_rate': 0.07456241820636361, 'num_leaves': 78, 'min_data_in_leaf': 34, 'feature_fraction': 0.7261713403696736, 'bagging_fraction': 0.745484308377049, 'bagging_freq': 6, 'min_gain_to_split': 2.193007567311602, 'lambda_l1': 7.858950304147583, 'lambda_l2': 8.287113686365243e-08}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:47:52,360] Trial 6 finished with value: 0.35972581935673725 and parameters: {'learning_rate': 0.018696268012559407, 'num_leaves': 67, 'min_data_in_leaf': 134, 'feature_fraction': 0.7013166410159128, 'bagging_fraction': 0.7865243091425225, 'bagging_freq': 2, 'min_gain_to_split': 0.7948479182275986, 'lambda_l1': 9.848640172873773e-08, 'lambda_l2': 0.008071724032088088}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:47:58,574] Trial 7 finished with value: 0.3558107242101674 and parameters: {'learning_rate': 0.015127952931538244, 'num_leaves': 75, 'min_data_in_leaf': 80, 'feature_fraction': 0.9283972919391741, 'bagging_fraction': 0.6388405103172244, 'bagging_freq': 9, 'min_gain_to_split': 0.48049203946981534, 'lambda_l1': 6.139530838198258, 'lambda_l2': 0.00016514324529254103}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:01,448] Trial 8 finished with value: 0.3732233475490645 and parameters: {'learning_rate': 0.18655009491114, 'num_leaves': 167, 'min_data_in_leaf': 151, 'feature_fraction': 0.6156751169017283, 'bagging_fraction': 0.7131227850305638, 'bagging_freq': 1, 'min_gain_to_split': 1.4807009876107247, 'lambda_l1': 1.1709799813329268e-07, 'lambda_l2': 7.275261607979148e-06}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:01,746] Trial 9 finished with value: 0.3596781151463644 and parameters: {'learning_rate': 0.034591435253679685, 'num_leaves': 45, 'min_data_in_leaf': 142, 'feature_fraction': 0.8266405816826301, 'bagging_fraction': 0.7061557963757782, 'bagging_freq': 5, 'min_gain_to_split': 0.4697025537922084, 'lambda_l1': 0.0015258732517912485, 'lambda_l2': 2.3102861693191303}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:02,079] Trial 10 finished with value: 0.32996668933983425 and parameters: {'learning_rate': 0.026313243719781314, 'num_leaves': 252, 'min_data_in_leaf': 13, 'feature_fraction': 0.9718561420111322, 'bagging_fraction': 0.9874235852979864, 'bagging_freq': 0, 'min_gain_to_split': 4.266444012048565, 'lambda_l1': 3.812573778417783e-06, 'lambda_l2': 0.1576163230730776}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:02,307] Trial 11 finished with value: 0.3081912510581458 and parameters: {'learning_rate': 0.1963897039336736, 'num_leaves': 124, 'min_data_in_leaf': 79, 'feature_fraction': 0.7336547345887859, 'bagging_fraction': 0.941933353477239, 'bagging_freq': 3, 'min_gain_to_split': 3.153147734051915, 'lambda_l1': 5.472680033298529e-06, 'lambda_l2': 0.0020554981135760013}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:02,638] Trial 12 finished with value: 0.3455052628488938 and parameters: {'learning_rate': 0.029994630887823576, 'num_leaves': 113, 'min_data_in_leaf': 55, 'feature_fraction': 0.761002745881162, 'bagging_fraction': 0.8925544545393606, 'bagging_freq': 3, 'min_gain_to_split': 4.703132171701716, 'lambda_l1': 1.8464626590054624e-05, 'lambda_l2': 0.00018209025984283314}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:03,036] Trial 13 finished with value: 0.3284060981031992 and parameters: {'learning_rate': 0.0104734539761103, 'num_leaves': 106, 'min_data_in_leaf': 105, 'feature_fraction': 0.6270136740544179, 'bagging_fraction': 0.9966653349505291, 'bagging_freq': 0, 'min_gain_to_split': 3.2847998828328775, 'lambda_l1': 4.243597632266006e-06, 'lambda_l2': 0.17235871773429867}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:03,285] Trial 14 finished with value: 0.27745636776574967 and parameters: {'learning_rate': 0.11191293910735194, 'num_leaves': 205, 'min_data_in_leaf': 63, 'feature_fraction': 0.7697290059002225, 'bagging_fraction': 0.8828672827489938, 'bagging_freq': 2, 'min_gain_to_split': 1.419255063685207, 'lambda_l1': 5.7547551550948315e-05, 'lambda_l2': 7.280839535804753e-06}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:03,578] Trial 15 finished with value: 0.27477040790795043 and parameters: {'learning_rate': 0.09580155796250439, 'num_leaves': 214, 'min_data_in_leaf': 49, 'feature_fraction': 0.8528057033837755, 'bagging_fraction': 0.850192272167609, 'bagging_freq': 2, 'min_gain_to_split': 1.3930335438129569, 'lambda_l1': 0.10112699832080597, 'lambda_l2': 4.3376796093213965e-06}. Best is trial 1 with value: 0.25977582730749277.
# [I 2025-09-21 12:48:04,749] Trial 16 finished with value: 0.23955343603559948 and parameters: {'learning_rate': 0.04100379402482349, 'num_leaves': 250, 'min_data_in_leaf': 110, 'feature_fraction': 0.8533979699031061, 'bagging_fraction': 0.8614849151905116, 'bagging_freq': 1, 'min_gain_to_split': 0.016504669608224498, 'lambda_l1': 0.0754388300231872, 'lambda_l2': 3.5078756137711755e-06}. Best is trial 16 with value: 0.23955343603559948.
# [I 2025-09-21 12:48:05,325] Trial 17 finished with value: 0.33015034847052005 and parameters: {'learning_rate': 0.040473758735960846, 'num_leaves': 255, 'min_data_in_leaf': 164, 'feature_fraction': 0.8908780805798382, 'bagging_fraction': 0.8433373601708026, 'bagging_freq': 0, 'min_gain_to_split': 0.01296129609539982, 'lambda_l1': 0.03274375558738424, 'lambda_l2': 1.6632420209060216e-08}. Best is trial 16 with value: 0.23955343603559948.
# [I 2025-09-21 12:48:05,965] Trial 18 finished with value: 0.28229588364841907 and parameters: {'learning_rate': 0.02224728520689278, 'num_leaves': 228, 'min_data_in_leaf': 118, 'feature_fraction': 0.976669324808731, 'bagging_fraction': 0.9407549214394862, 'bagging_freq': 1, 'min_gain_to_split': 1.0402757312178261, 'lambda_l1': 0.00031408944989802956, 'lambda_l2': 9.204008004204431e-07}. Best is trial 16 with value: 0.23955343603559948.
# [I 2025-09-21 12:48:06,415] Trial 19 finished with value: 0.2969954697865995 and parameters: {'learning_rate': 0.04275204727279851, 'num_leaves': 189, 'min_data_in_leaf': 103, 'feature_fraction': 0.7880319552413594, 'bagging_fraction': 0.8214040515296359, 'bagging_freq': 1, 'min_gain_to_split': 1.656066554055904, 'lambda_l1': 0.13722766058970015, 'lambda_l2': 4.022568907004666e-05}. Best is trial 16 with value: 0.23955343603559948.
# [I 2025-09-21 12:48:08,575] Trial 20 finished with value: 0.3334762379844015 and parameters: {'learning_rate': 0.011949809812196486, 'num_leaves': 236, 'min_data_in_leaf': 180, 'feature_fraction': 0.8384201900092699, 'bagging_fraction': 0.9510822927516864, 'bagging_freq': 10, 'min_gain_to_split': 0.01132627839293976, 'lambda_l1': 3.333774952321156e-07, 'lambda_l2': 0.15596268382509007}. Best is trial 16 with value: 0.23955343603559948.
# [I 2025-09-21 12:48:08,846] Trial 21 finished with value: 0.2659189117377997 and parameters: {'learning_rate': 0.07112133760302723, 'num_leaves': 208, 'min_data_in_leaf': 46, 'feature_fraction': 0.8542476996660545, 'bagging_fraction': 0.8445612636480443, 'bagging_freq': 2, 'min_gain_to_split': 1.0348809252392803, 'lambda_l1': 0.13087681903838458, 'lambda_l2': 4.391052876407009e-06}. Best is trial 16 with value: 0.23955343603559948.
# [I 2025-09-21 12:48:10,342] Trial 22 finished with value: 0.22794083022438913 and parameters: {'learning_rate': 0.06442637237877033, 'num_leaves': 198, 'min_data_in_leaf': 96, 'feature_fraction': 0.9003038148609065, 'bagging_fraction': 0.8618495781703216, 'bagging_freq': 3, 'min_gain_to_split': 0.002669635093123013, 'lambda_l1': 0.007704288519366065, 'lambda_l2': 8.671002568144424e-07}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:11,022] Trial 23 finished with value: 0.2466471546142967 and parameters: {'learning_rate': 0.03640054291990616, 'num_leaves': 183, 'min_data_in_leaf': 116, 'feature_fraction': 0.9107702656406316, 'bagging_fraction': 0.8741534786359838, 'bagging_freq': 4, 'min_gain_to_split': 0.02432051897517451, 'lambda_l1': 0.008236584427836958, 'lambda_l2': 4.92696931076956e-07}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:11,555] Trial 24 finished with value: 0.22942701626424356 and parameters: {'learning_rate': 0.054853987482098666, 'num_leaves': 176, 'min_data_in_leaf': 89, 'feature_fraction': 0.9267276329740006, 'bagging_fraction': 0.8727566839287973, 'bagging_freq': 4, 'min_gain_to_split': 0.03194460369011835, 'lambda_l1': 0.006543587818302081, 'lambda_l2': 5.287069763505016e-07}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:13,117] Trial 25 finished with value: 0.27786904210337826 and parameters: {'learning_rate': 0.04957517735388509, 'num_leaves': 154, 'min_data_in_leaf': 95, 'feature_fraction': 0.9446391329037549, 'bagging_fraction': 0.9152452479975249, 'bagging_freq': 4, 'min_gain_to_split': 0.9808360212390712, 'lambda_l1': 0.0006052949396669011, 'lambda_l2': 1.0963917452484431e-08}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:15,493] Trial 26 finished with value: 0.24544691416488643 and parameters: {'learning_rate': 0.055974338150454814, 'num_leaves': 239, 'min_data_in_leaf': 70, 'feature_fraction': 0.9927737330936679, 'bagging_fraction': 0.829265932466143, 'bagging_freq': 6, 'min_gain_to_split': 0.26285737033474205, 'lambda_l1': 0.5719044759012035, 'lambda_l2': 3.6226851797117455e-05}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:16,175] Trial 27 finished with value: 0.299688967881431 and parameters: {'learning_rate': 0.09065704879168264, 'num_leaves': 128, 'min_data_in_leaf': 87, 'feature_fraction': 0.8924312212499107, 'bagging_fraction': 0.8088129427282205, 'bagging_freq': 3, 'min_gain_to_split': 1.7714851835980365, 'lambda_l1': 0.013050154105290233, 'lambda_l2': 1.2109044093413328e-07}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:16,491] Trial 28 finished with value: 0.3057133879883537 and parameters: {'learning_rate': 0.06605083177033338, 'num_leaves': 170, 'min_data_in_leaf': 130, 'feature_fraction': 0.9583253689771997, 'bagging_fraction': 0.8648785985933766, 'bagging_freq': 3, 'min_gain_to_split': 1.1383036313909756, 'lambda_l1': 0.0011411030386211936, 'lambda_l2': 1.0585964376600756e-06}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:16,721] Trial 29 finished with value: 0.3627891173983617 and parameters: {'learning_rate': 0.12945142175043575, 'num_leaves': 196, 'min_data_in_leaf': 160, 'feature_fraction': 0.7975026483396321, 'bagging_fraction': 0.9124841933171561, 'bagging_freq': 6, 'min_gain_to_split': 0.7829900115040289, 'lambda_l1': 1.2037854354467148, 'lambda_l2': 3.1232698816525305e-05}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:16,983] Trial 30 finished with value: 0.3223965513071357 and parameters: {'learning_rate': 0.04867744047925191, 'num_leaves': 182, 'min_data_in_leaf': 98, 'feature_fraction': 0.8787755913522964, 'bagging_fraction': 0.7623044347723663, 'bagging_freq': 7, 'min_gain_to_split': 2.0103251036354206, 'lambda_l1': 0.00020291188795794885, 'lambda_l2': 4.744814010569935e-08}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:17,312] Trial 31 finished with value: 0.24989616753327298 and parameters: {'learning_rate': 0.05670079573442515, 'num_leaves': 244, 'min_data_in_leaf': 69, 'feature_fraction': 0.9986008113216092, 'bagging_fraction': 0.8163565296621466, 'bagging_freq': 6, 'min_gain_to_split': 0.30995103432183835, 'lambda_l1': 0.703738270669634, 'lambda_l2': 1.9578059340170388e-06}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:17,661] Trial 32 finished with value: 0.24514703062468204 and parameters: {'learning_rate': 0.08166900081905536, 'num_leaves': 231, 'min_data_in_leaf': 75, 'feature_fraction': 0.989890486455164, 'bagging_fraction': 0.8361836287999312, 'bagging_freq': 5, 'min_gain_to_split': 0.21287299452411107, 'lambda_l1': 0.7028144018279896, 'lambda_l2': 4.3647852330470936e-05}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:17,922] Trial 33 finished with value: 0.2796209514770363 and parameters: {'learning_rate': 0.13263935154855752, 'num_leaves': 219, 'min_data_in_leaf': 113, 'feature_fraction': 0.9363059757854553, 'bagging_fraction': 0.8663383857253921, 'bagging_freq': 4, 'min_gain_to_split': 0.7311832883000761, 'lambda_l1': 0.042437841688004456, 'lambda_l2': 3.926355765730281e-07}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:18,228] Trial 34 finished with value: 0.24410609272345854 and parameters: {'learning_rate': 0.08137491453233976, 'num_leaves': 229, 'min_data_in_leaf': 77, 'feature_fraction': 0.912371851227812, 'bagging_fraction': 0.8977946762385113, 'bagging_freq': 7, 'min_gain_to_split': 0.2821208019113467, 'lambda_l1': 0.004354895666733827, 'lambda_l2': 0.0007069782058322467}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:18,565] Trial 35 finished with value: 0.2611789811467598 and parameters: {'learning_rate': 0.05966896914196635, 'num_leaves': 196, 'min_data_in_leaf': 90, 'feature_fraction': 0.9086597283798101, 'bagging_fraction': 0.9053665640119809, 'bagging_freq': 8, 'min_gain_to_split': 0.5522425254350553, 'lambda_l1': 0.0031225509826298715, 'lambda_l2': 0.0007164052728520821}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:18,831] Trial 36 finished with value: 0.3025308970007669 and parameters: {'learning_rate': 0.07933493361477949, 'num_leaves': 226, 'min_data_in_leaf': 59, 'feature_fraction': 0.866440379346383, 'bagging_fraction': 0.935055220420182, 'bagging_freq': 7, 'min_gain_to_split': 2.580368448621678, 'lambda_l1': 0.024491598611883814, 'lambda_l2': 0.03629387530391871}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:19,177] Trial 37 finished with value: 0.2331870440230895 and parameters: {'learning_rate': 0.04511022646904873, 'num_leaves': 161, 'min_data_in_leaf': 36, 'feature_fraction': 0.9043240530713412, 'bagging_fraction': 0.7878338737147175, 'bagging_freq': 8, 'min_gain_to_split': 0.35985679192063813, 'lambda_l1': 0.003217515710778334, 'lambda_l2': 0.00042151641492088994}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:19,501] Trial 38 finished with value: 0.2484165708330314 and parameters: {'learning_rate': 0.04242339590595099, 'num_leaves': 141, 'min_data_in_leaf': 30, 'feature_fraction': 0.8148541074723962, 'bagging_fraction': 0.7755639128903431, 'bagging_freq': 9, 'min_gain_to_split': 0.649526601237656, 'lambda_l1': 0.0032260753817850286, 'lambda_l2': 3.1362596380470926e-07}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:19,863] Trial 39 finished with value: 0.3292961703050933 and parameters: {'learning_rate': 0.026791152747702305, 'num_leaves': 159, 'min_data_in_leaf': 11, 'feature_fraction': 0.9479902329933856, 'bagging_fraction': 0.8003227984906178, 'bagging_freq': 5, 'min_gain_to_split': 3.831639356000006, 'lambda_l1': 0.00015501305950783325, 'lambda_l2': 4.326711473700806e-08}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:20,565] Trial 40 finished with value: 0.2631636471430713 and parameters: {'learning_rate': 0.03514385172745845, 'num_leaves': 144, 'min_data_in_leaf': 37, 'feature_fraction': 0.8944391924817344, 'bagging_fraction': 0.7153713961206656, 'bagging_freq': 1, 'min_gain_to_split': 0.4287114315845856, 'lambda_l1': 2.3349011261215753, 'lambda_l2': 1.3463968744518941e-05}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:20,960] Trial 41 finished with value: 0.24539174922364854 and parameters: {'learning_rate': 0.04898648582216611, 'num_leaves': 177, 'min_data_in_leaf': 85, 'feature_fraction': 0.921614060028699, 'bagging_fraction': 0.891065911218327, 'bagging_freq': 8, 'min_gain_to_split': 0.2291685079799777, 'lambda_l1': 0.011677315220449805, 'lambda_l2': 0.0009153912976694202}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:21,280] Trial 42 finished with value: 0.26230296549780635 and parameters: {'learning_rate': 0.06612432925167959, 'num_leaves': 202, 'min_data_in_leaf': 106, 'feature_fraction': 0.875261234627316, 'bagging_fraction': 0.7906404806358137, 'bagging_freq': 7, 'min_gain_to_split': 0.25429889955019863, 'lambda_l1': 0.003149044429032955, 'lambda_l2': 0.0003393290640550436}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:22,308] Trial 43 finished with value: 0.3317662370821962 and parameters: {'learning_rate': 0.0847570036652448, 'num_leaves': 246, 'min_data_in_leaf': 126, 'feature_fraction': 0.9061985837903227, 'bagging_fraction': 0.6137341643486445, 'bagging_freq': 8, 'min_gain_to_split': 0.001160868021027471, 'lambda_l1': 0.06883917462392476, 'lambda_l2': 0.00698172166331611}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:22,552] Trial 44 finished with value: 0.35584057441860084 and parameters: {'learning_rate': 0.1087190753090222, 'num_leaves': 217, 'min_data_in_leaf': 137, 'feature_fraction': 0.8447652973512888, 'bagging_fraction': 0.8571748251049114, 'bagging_freq': 9, 'min_gain_to_split': 0.5842076328833282, 'lambda_l1': 0.2739748157981893, 'lambda_l2': 9.621649888697579e-05}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:22,964] Trial 45 finished with value: 0.28287553315521546 and parameters: {'learning_rate': 0.03043851588938733, 'num_leaves': 162, 'min_data_in_leaf': 120, 'feature_fraction': 0.9299150584305697, 'bagging_fraction': 0.9693352721984949, 'bagging_freq': 10, 'min_gain_to_split': 0.8239355981134362, 'lambda_l1': 0.0013179175453270377, 'lambda_l2': 0.001153636747598308}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:23,219] Trial 46 finished with value: 0.2726985514739676 and parameters: {'learning_rate': 0.07218861815548959, 'num_leaves': 172, 'min_data_in_leaf': 18, 'feature_fraction': 0.8647050262904558, 'bagging_fraction': 0.67791220438591, 'bagging_freq': 4, 'min_gain_to_split': 1.2661412002588308, 'lambda_l1': 0.018332129072973307, 'lambda_l2': 0.029469664548535283}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:23,577] Trial 47 finished with value: 0.268000118153559 and parameters: {'learning_rate': 0.03868123840810294, 'num_leaves': 187, 'min_data_in_leaf': 94, 'feature_fraction': 0.9682360638796409, 'bagging_fraction': 0.7590387386292151, 'bagging_freq': 6, 'min_gain_to_split': 0.4305947449185266, 'lambda_l1': 0.0005450432088269217, 'lambda_l2': 0.0003813134990197277}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:23,925] Trial 48 finished with value: 0.26366985281366445 and parameters: {'learning_rate': 0.053796673017603304, 'num_leaves': 223, 'min_data_in_leaf': 79, 'feature_fraction': 0.8204979619327412, 'bagging_fraction': 0.9226334432550508, 'bagging_freq': 3, 'min_gain_to_split': 0.822925527083791, 'lambda_l1': 6.0630343843686895e-05, 'lambda_l2': 1.7105196578377078e-06}. Best is trial 22 with value: 0.22794083022438913.
# [I 2025-09-21 12:48:24,337] Trial 49 finished with value: 0.2147226741880052 and parameters: {'learning_rate': 0.04521758925766285, 'num_leaves': 131, 'min_data_in_leaf': 22, 'feature_fraction': 0.8852228445097815, 'bagging_fraction': 0.8833806227651908, 'bagging_freq': 7, 'min_gain_to_split': 0.17970760776602468, 'lambda_l1': 0.005650548122167724, 'lambda_l2': 1.3792871283612694e-05}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:24,711] Trial 50 finished with value: 0.21645594671586704 and parameters: {'learning_rate': 0.0455887462653091, 'num_leaves': 92, 'min_data_in_leaf': 25, 'feature_fraction': 0.6536345103231103, 'bagging_fraction': 0.7328833628648713, 'bagging_freq': 2, 'min_gain_to_split': 0.1376511868777655, 'lambda_l1': 0.2956846060272799, 'lambda_l2': 1.2704746483021038e-05}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:25,104] Trial 51 finished with value: 0.220947200678766 and parameters: {'learning_rate': 0.045546242004603284, 'num_leaves': 90, 'min_data_in_leaf': 24, 'feature_fraction': 0.694565476452962, 'bagging_fraction': 0.7331801417777603, 'bagging_freq': 2, 'min_gain_to_split': 0.17487585634790717, 'lambda_l1': 0.2885420899389742, 'lambda_l2': 9.254669681265696e-06}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:25,405] Trial 52 finished with value: 0.2940903319681293 and parameters: {'learning_rate': 0.046949630470139066, 'num_leaves': 100, 'min_data_in_leaf': 24, 'feature_fraction': 0.7052248013243381, 'bagging_fraction': 0.6700770339619578, 'bagging_freq': 2, 'min_gain_to_split': 0.4614491594737023, 'lambda_l1': 3.1761976766880844, 'lambda_l2': 1.78382926210156e-05}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:25,737] Trial 53 finished with value: 0.22376321134918836 and parameters: {'learning_rate': 0.06183473795302729, 'num_leaves': 83, 'min_data_in_leaf': 40, 'feature_fraction': 0.6552062408185966, 'bagging_fraction': 0.7427316803699282, 'bagging_freq': 2, 'min_gain_to_split': 0.17964738068355024, 'lambda_l1': 0.007559953751312536, 'lambda_l2': 0.0001350032059849057}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:26,022] Trial 54 finished with value: 0.3537970027881425 and parameters: {'learning_rate': 0.05919036158814819, 'num_leaves': 89, 'min_data_in_leaf': 43, 'feature_fraction': 0.6615027019997929, 'bagging_fraction': 0.7436240212434541, 'bagging_freq': 2, 'min_gain_to_split': 4.96654105879613, 'lambda_l1': 0.39447623730504955, 'lambda_l2': 0.00011329550176356319}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:27,735] Trial 55 finished with value: 0.21624655750289845 and parameters: {'learning_rate': 0.03310543813873337, 'num_leaves': 62, 'min_data_in_leaf': 23, 'feature_fraction': 0.6736112822354872, 'bagging_fraction': 0.7329576522397755, 'bagging_freq': 3, 'min_gain_to_split': 0.14137579614775778, 'lambda_l1': 0.16586061870640328, 'lambda_l2': 9.609645936169333e-06}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:29,835] Trial 56 finished with value: 0.2464117264144467 and parameters: {'learning_rate': 0.026122479095440333, 'num_leaves': 57, 'min_data_in_leaf': 23, 'feature_fraction': 0.6513023778071777, 'bagging_fraction': 0.7010254393973055, 'bagging_freq': 2, 'min_gain_to_split': 0.5940467563106999, 'lambda_l1': 0.21463867394260314, 'lambda_l2': 1.0963490782262395e-05}. Best is trial 49 with value: 0.2147226741880052.
# [I 2025-09-21 12:48:31,482] Trial 57 finished with value: 0.21196497106189902 and parameters: {'learning_rate': 0.032294363011811905, 'num_leaves': 32, 'min_data_in_leaf': 29, 'feature_fraction': 0.6795895350044038, 'bagging_fraction': 0.7286400859385544, 'bagging_freq': 1, 'min_gain_to_split': 0.18015512789820082, 'lambda_l1': 0.06634067502037058, 'lambda_l2': 7.96170779469034e-05}. Best is trial 57 with value: 0.21196497106189902.
# [I 2025-09-21 12:48:32,290] Trial 58 finished with value: 0.24674683318439827 and parameters: {'learning_rate': 0.017802334459251536, 'num_leaves': 31, 'min_data_in_leaf': 28, 'feature_fraction': 0.6832288900196585, 'bagging_fraction': 0.7333160326017973, 'bagging_freq': 1, 'min_gain_to_split': 0.8771187300238326, 'lambda_l1': 0.05627579263110663, 'lambda_l2': 7.600380975769967e-05}. Best is trial 57 with value: 0.21196497106189902.
# [I 2025-09-21 12:48:32,706] Trial 59 finished with value: 0.28807535460349426 and parameters: {'learning_rate': 0.032160203414489996, 'num_leaves': 69, 'min_data_in_leaf': 16, 'feature_fraction': 0.7251247983038106, 'bagging_fraction': 0.7221292601805005, 'bagging_freq': 0, 'min_gain_to_split': 0.17446496373827206, 'lambda_l1': 5.87577267076432, 'lambda_l2': 3.831765389734149e-06}. Best is trial 57 with value: 0.21196497106189902.
# [I 2025-09-21 12:48:33,016] Trial 60 finished with value: 0.3206786717677045 and parameters: {'learning_rate': 0.023930933896432232, 'num_leaves': 87, 'min_data_in_leaf': 39, 'feature_fraction': 0.6029181690444088, 'bagging_fraction': 0.6894280014823027, 'bagging_freq': 0, 'min_gain_to_split': 2.880946476947805, 'lambda_l1': 1.346888346012475, 'lambda_l2': 2.3538550575549162e-05}. Best is trial 57 with value: 0.21196497106189902.
# [I 2025-09-21 12:48:33,403] Trial 61 finished with value: 0.22856987638031817 and parameters: {'learning_rate': 0.03726652313158772, 'num_leaves': 54, 'min_data_in_leaf': 49, 'feature_fraction': 0.6380779573903549, 'bagging_fraction': 0.7320655843277479, 'bagging_freq': 3, 'min_gain_to_split': 0.17059790498524138, 'lambda_l1': 0.17821932004554292, 'lambda_l2': 1.1438967316926188e-05}. Best is trial 57 with value: 0.21196497106189902.
# [I 2025-09-21 12:48:33,776] Trial 62 finished with value: 0.23968460191866897 and parameters: {'learning_rate': 0.03488429666130911, 'num_leaves': 32, 'min_data_in_leaf': 22, 'feature_fraction': 0.6743569144468099, 'bagging_fraction': 0.660544714063758, 'bagging_freq': 2, 'min_gain_to_split': 0.48084708564490203, 'lambda_l1': 0.027324037353559268, 'lambda_l2': 0.00016657957751236674}. Best is trial 57 with value: 0.21196497106189902.
# [I 2025-09-21 12:48:34,793] Trial 63 finished with value: 0.20832400769419782 and parameters: {'learning_rate': 0.03237888278498259, 'num_leaves': 80, 'min_data_in_leaf': 31, 'feature_fraction': 0.6884494354104765, 'bagging_fraction': 0.7496111858200617, 'bagging_freq': 1, 'min_gain_to_split': 0.11979634364715072, 'lambda_l1': 0.06446164763076885, 'lambda_l2': 6.914828338350438e-06}. Best is trial 63 with value: 0.20832400769419782.
# [I 2025-09-21 12:48:35,894] Trial 64 finished with value: 0.21088132261678236 and parameters: {'learning_rate': 0.029083156956190313, 'num_leaves': 79, 'min_data_in_leaf': 31, 'feature_fraction': 0.6874711217456102, 'bagging_fraction': 0.7492112067976231, 'bagging_freq': 1, 'min_gain_to_split': 0.15332763987921705, 'lambda_l1': 0.08772548125788684, 'lambda_l2': 6.531751283539497e-05}. Best is trial 63 with value: 0.20832400769419782.
# [I 2025-09-21 12:48:36,657] Trial 65 finished with value: 0.24090321873958712 and parameters: {'learning_rate': 0.02011432140270731, 'num_leaves': 97, 'min_data_in_leaf': 30, 'feature_fraction': 0.6895501355511757, 'bagging_fraction': 0.7584452050626009, 'bagging_freq': 1, 'min_gain_to_split': 0.7150000257027356, 'lambda_l1': 0.12245929242559497, 'lambda_l2': 6.262526640234556e-06}. Best is trial 63 with value: 0.20832400769419782.
# [I 2025-09-21 12:48:37,026] Trial 66 finished with value: 0.266945378895096 and parameters: {'learning_rate': 0.03247990663403641, 'num_leaves': 119, 'min_data_in_leaf': 11, 'feature_fraction': 0.7226037891038967, 'bagging_fraction': 0.7738620447714124, 'bagging_freq': 0, 'min_gain_to_split': 1.200558474982616, 'lambda_l1': 0.3952055072603699, 'lambda_l2': 6.75229898996325e-05}. Best is trial 63 with value: 0.20832400769419782.
# [I 2025-09-21 12:48:37,630] Trial 67 finished with value: 0.25991323093547203 and parameters: {'learning_rate': 0.027981614777017497, 'num_leaves': 76, 'min_data_in_leaf': 55, 'feature_fraction': 0.7522506233385866, 'bagging_fraction': 0.6935150828979241, 'bagging_freq': 1, 'min_gain_to_split': 0.9589946057907635, 'lambda_l1': 0.08790247980880252, 'lambda_l2': 3.123359175442005e-06}. Best is trial 63 with value: 0.20832400769419782.
# [I 2025-09-21 12:48:38,797] Trial 68 finished with value: 0.20464758448847956 and parameters: {'learning_rate': 0.021910912749444716, 'num_leaves': 61, 'min_data_in_leaf': 19, 'feature_fraction': 0.6328533922591206, 'bagging_fraction': 0.7210782928418831, 'bagging_freq': 1, 'min_gain_to_split': 0.14272291974076717, 'lambda_l1': 0.047119547567821864, 'lambda_l2': 8.567288315428531e-06}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:39,280] Trial 69 finished with value: 0.2290752832977713 and parameters: {'learning_rate': 0.022410956508647578, 'num_leaves': 46, 'min_data_in_leaf': 32, 'feature_fraction': 0.6313979242409375, 'bagging_fraction': 0.7197138866440702, 'bagging_freq': 0, 'min_gain_to_split': 0.37023852241962485, 'lambda_l1': 0.039833589308052295, 'lambda_l2': 2.1362422924600563e-05}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:40,121] Trial 70 finished with value: 0.2346837527771164 and parameters: {'learning_rate': 0.01750860718766284, 'num_leaves': 65, 'min_data_in_leaf': 18, 'feature_fraction': 0.6688287129525468, 'bagging_fraction': 0.657325024052934, 'bagging_freq': 1, 'min_gain_to_split': 0.6142867090682722, 'lambda_l1': 0.0525242134370111, 'lambda_l2': 4.9196882810537944e-05}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:43,950] Trial 71 finished with value: 0.21121682183264007 and parameters: {'learning_rate': 0.014706448252019578, 'num_leaves': 63, 'min_data_in_leaf': 25, 'feature_fraction': 0.6921534282828006, 'bagging_fraction': 0.7535409385585018, 'bagging_freq': 1, 'min_gain_to_split': 0.1535947915104296, 'lambda_l1': 0.23158244035236505, 'lambda_l2': 6.36584140841091e-06}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:47,215] Trial 72 finished with value: 0.21793474057216597 and parameters: {'learning_rate': 0.013943791868817019, 'num_leaves': 58, 'min_data_in_leaf': 48, 'feature_fraction': 0.6140658104162443, 'bagging_fraction': 0.7096869237202736, 'bagging_freq': 1, 'min_gain_to_split': 0.11703489462920427, 'lambda_l1': 0.016060349509292506, 'lambda_l2': 1.8588339277258113e-06}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:48,610] Trial 73 finished with value: 0.22195646861340163 and parameters: {'learning_rate': 0.010257916811275148, 'num_leaves': 48, 'min_data_in_leaf': 19, 'feature_fraction': 0.6419720369024771, 'bagging_fraction': 0.7521108103939982, 'bagging_freq': 1, 'min_gain_to_split': 0.36849232800349296, 'lambda_l1': 0.12184322865124073, 'lambda_l2': 5.234628824140706e-06}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:50,161] Trial 74 finished with value: 0.22467422459847947 and parameters: {'learning_rate': 0.016258144355320074, 'num_leaves': 109, 'min_data_in_leaf': 10, 'feature_fraction': 0.7117364161521494, 'bagging_fraction': 0.7657418121508397, 'bagging_freq': 1, 'min_gain_to_split': 0.10050222932138564, 'lambda_l1': 1.5461933859243664, 'lambda_l2': 2.4103698850010392e-05}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:50,851] Trial 75 finished with value: 0.23903702462225782 and parameters: {'learning_rate': 0.013394946541931251, 'num_leaves': 65, 'min_data_in_leaf': 27, 'feature_fraction': 0.7426913803013099, 'bagging_fraction': 0.7779420543049292, 'bagging_freq': 0, 'min_gain_to_split': 0.33859031641218584, 'lambda_l1': 0.7081153339897777, 'lambda_l2': 3.090855472001954}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:51,527] Trial 76 finished with value: 0.24195592168512778 and parameters: {'learning_rate': 0.02878756375032153, 'num_leaves': 71, 'min_data_in_leaf': 32, 'feature_fraction': 0.6786128698600541, 'bagging_fraction': 0.7268338360675601, 'bagging_freq': 1, 'min_gain_to_split': 0.5069517573025801, 'lambda_l1': 0.18604021732156298, 'lambda_l2': 8.585314870933916}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:51,857] Trial 77 finished with value: 0.34645202849549916 and parameters: {'learning_rate': 0.025131699895128007, 'num_leaves': 40, 'min_data_in_leaf': 43, 'feature_fraction': 0.6189705570730765, 'bagging_fraction': 0.7458991065909444, 'bagging_freq': 2, 'min_gain_to_split': 4.106624472472921, 'lambda_l1': 0.07421129985297499, 'lambda_l2': 8.505284598388625e-06}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:52,315] Trial 78 finished with value: 0.23990253309335907 and parameters: {'learning_rate': 0.020843475957388332, 'num_leaves': 80, 'min_data_in_leaf': 16, 'feature_fraction': 0.7767593031349448, 'bagging_fraction': 0.7984381205624306, 'bagging_freq': 0, 'min_gain_to_split': 0.6472421027711746, 'lambda_l1': 0.028803678810852124, 'lambda_l2': 1.0960358662989656e-06}. Best is trial 68 with value: 0.20464758448847956.
# [I 2025-09-21 12:48:53,538] Trial 79 finished with value: 0.20243401817665813 and parameters: {'learning_rate': 0.04102412506704369, 'num_leaves': 61, 'min_data_in_leaf': 35, 'feature_fraction': 0.6646121847038102, 'bagging_fraction': 0.7008564517028978, 'bagging_freq': 1, 'min_gain_to_split': 0.0041751175356012915, 'lambda_l1': 0.4245538961431425, 'lambda_l2': 2.798569620304474e-06}. Best is trial 79 with value: 0.20243401817665813.
# [I 2025-09-21 12:48:53,929] Trial 80 finished with value: 0.2361285507708367 and parameters: {'learning_rate': 0.039377827040953, 'num_leaves': 61, 'min_data_in_leaf': 56, 'feature_fraction': 0.7121394055659216, 'bagging_fraction': 0.6996244923851663, 'bagging_freq': 0, 'min_gain_to_split': 0.28632406754372175, 'lambda_l1': 0.5114929842822533, 'lambda_l2': 1.9699186681426472e-07}. Best is trial 79 with value: 0.20243401817665813.
# [I 2025-09-21 12:48:55,215] Trial 81 finished with value: 0.2022280396271002 and parameters: {'learning_rate': 0.032215574654455174, 'num_leaves': 51, 'min_data_in_leaf': 35, 'feature_fraction': 0.664579686831841, 'bagging_fraction': 0.7073576065954736, 'bagging_freq': 1, 'min_gain_to_split': 0.006540052583668743, 'lambda_l1': 0.27083499913500275, 'lambda_l2': 1.8643861993342268e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:48:57,737] Trial 82 finished with value: 0.2104892304111612 and parameters: {'learning_rate': 0.03385366295904736, 'num_leaves': 39, 'min_data_in_leaf': 34, 'feature_fraction': 0.6646310864383209, 'bagging_fraction': 0.6872579913994499, 'bagging_freq': 1, 'min_gain_to_split': 0.020759694531475997, 'lambda_l1': 0.9015007734445936, 'lambda_l2': 2.4697889394253586e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:02,130] Trial 83 finished with value: 0.27611857337234275 and parameters: {'learning_rate': 0.023825245710846, 'num_leaves': 39, 'min_data_in_leaf': 34, 'feature_fraction': 0.6950831426856631, 'bagging_fraction': 0.6858539576437576, 'bagging_freq': 1, 'min_gain_to_split': 0.023814844261379045, 'lambda_l1': 5.546878973334843, 'lambda_l2': 2.6213478316835282e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:04,146] Trial 84 finished with value: 0.23667990710977277 and parameters: {'learning_rate': 0.030191711029738645, 'num_leaves': 50, 'min_data_in_leaf': 64, 'feature_fraction': 0.6627922692940774, 'bagging_fraction': 0.6448758639351555, 'bagging_freq': 1, 'min_gain_to_split': 0.004224263452789007, 'lambda_l1': 2.000221143650768, 'lambda_l2': 6.662477683617215e-07}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:04,858] Trial 85 finished with value: 0.23622288330314412 and parameters: {'learning_rate': 0.011780022520152282, 'num_leaves': 39, 'min_data_in_leaf': 42, 'feature_fraction': 0.6873865508499266, 'bagging_fraction': 0.7123228472756331, 'bagging_freq': 0, 'min_gain_to_split': 0.2629536581345231, 'lambda_l1': 0.9759497567097791, 'lambda_l2': 1.5627790571160412e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:05,473] Trial 86 finished with value: 0.28004611118838163 and parameters: {'learning_rate': 0.04168589629926898, 'num_leaves': 43, 'min_data_in_leaf': 51, 'feature_fraction': 0.6403714252783179, 'bagging_fraction': 0.6812283896109277, 'bagging_freq': 1, 'min_gain_to_split': 0.38505012370588687, 'lambda_l1': 3.3377285755691743, 'lambda_l2': 0.00023095603189761084}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:06,074] Trial 87 finished with value: 0.2453225629928582 and parameters: {'learning_rate': 0.03669556210667327, 'num_leaves': 53, 'min_data_in_leaf': 35, 'feature_fraction': 0.6470905028851377, 'bagging_fraction': 0.70184094482131, 'bagging_freq': 1, 'min_gain_to_split': 0.478341199507794, 'lambda_l1': 0.9841936501270436, 'lambda_l2': 5.82144514851986e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:06,388] Trial 88 finished with value: 0.29167979405718125 and parameters: {'learning_rate': 0.02839094119122621, 'num_leaves': 70, 'min_data_in_leaf': 37, 'feature_fraction': 0.6226467244527366, 'bagging_fraction': 0.6687018168416372, 'bagging_freq': 0, 'min_gain_to_split': 2.2799750192753137, 'lambda_l1': 0.011486283729458278, 'lambda_l2': 2.549439155097729e-07}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:06,896] Trial 89 finished with value: 0.20904704807611885 and parameters: {'learning_rate': 0.03389278519227796, 'num_leaves': 35, 'min_data_in_leaf': 14, 'feature_fraction': 0.6673787124031462, 'bagging_fraction': 0.7476350694879534, 'bagging_freq': 2, 'min_gain_to_split': 0.11522910244152451, 'lambda_l1': 1.9142176929134857e-06, 'lambda_l2': 5.2778252343893396e-05}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:07,292] Trial 90 finished with value: 0.22237428148828214 and parameters: {'learning_rate': 0.033529591598172516, 'num_leaves': 38, 'min_data_in_leaf': 16, 'feature_fraction': 0.663220079707209, 'bagging_fraction': 0.7495119855185081, 'bagging_freq': 2, 'min_gain_to_split': 0.2863934009732429, 'lambda_l1': 1.45141293573733e-05, 'lambda_l2': 5.457324121348918e-05}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:08,217] Trial 91 finished with value: 0.20830955190706835 and parameters: {'learning_rate': 0.030853992997613305, 'num_leaves': 35, 'min_data_in_leaf': 29, 'feature_fraction': 0.7024160778876315, 'bagging_fraction': 0.7168031315704522, 'bagging_freq': 1, 'min_gain_to_split': 0.1287211298498239, 'lambda_l1': 3.269879175532676e-08, 'lambda_l2': 2.7344177928231426e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:09,142] Trial 92 finished with value: 0.20421960351057997 and parameters: {'learning_rate': 0.030612404568057625, 'num_leaves': 35, 'min_data_in_leaf': 29, 'feature_fraction': 0.6955384432801385, 'bagging_fraction': 0.7084921966622756, 'bagging_freq': 1, 'min_gain_to_split': 0.06490653230813109, 'lambda_l1': 2.101356029357812e-08, 'lambda_l2': 1.191258767396271e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:10,111] Trial 93 finished with value: 0.21475835717539296 and parameters: {'learning_rate': 0.030036452200021987, 'num_leaves': 45, 'min_data_in_leaf': 46, 'feature_fraction': 0.7165216753353704, 'bagging_fraction': 0.7070942990048104, 'bagging_freq': 1, 'min_gain_to_split': 0.08176321751747849, 'lambda_l1': 6.325632115266004e-08, 'lambda_l2': 1.1553264867992505e-06}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:10,498] Trial 94 finished with value: 0.37666874974318354 and parameters: {'learning_rate': 0.026248409197421694, 'num_leaves': 51, 'min_data_in_leaf': 198, 'feature_fraction': 0.7001666108320498, 'bagging_fraction': 0.7172662982405716, 'bagging_freq': 2, 'min_gain_to_split': 0.3678903192960731, 'lambda_l1': 3.030310187838658e-08, 'lambda_l2': 1.0971524565549188e-07}. Best is trial 81 with value: 0.2022280396271002.
# [I 2025-09-21 12:49:12,755] Trial 95 finished with value: 0.2001253350387268 and parameters: {'learning_rate': 0.03818558557602797, 'num_leaves': 74, 'min_data_in_leaf': 13, 'feature_fraction': 0.7317570744458382, 'bagging_fraction': 0.6911158677893643, 'bagging_freq': 1, 'min_gain_to_split': 0.10188725461814893, 'lambda_l1': 2.907411999003523e-07, 'lambda_l2': 5.921841276263714e-07}. Best is trial 95 with value: 0.2001253350387268.
# [I 2025-09-21 12:49:16,658] Trial 96 finished with value: 0.22630102802390795 and parameters: {'learning_rate': 0.038862103808950485, 'num_leaves': 36, 'min_data_in_leaf': 14, 'feature_fraction': 0.7027699532270452, 'bagging_fraction': 0.6958592154633144, 'bagging_freq': 1, 'min_gain_to_split': 0.519423066287207, 'lambda_l1': 4.0782776468998325e-07, 'lambda_l2': 5.453976351280377e-07}. Best is trial 95 with value: 0.2001253350387268.
# [I 2025-09-21 12:49:20,998] Trial 97 finished with value: 0.3441659403359593 and parameters: {'learning_rate': 0.03550133595448743, 'num_leaves': 74, 'min_data_in_leaf': 187, 'feature_fraction': 0.6669778189409779, 'bagging_fraction': 0.6795204751187777, 'bagging_freq': 0, 'min_gain_to_split': 0.08762061680112507, 'lambda_l1': 4.931859369965913e-07, 'lambda_l2': 2.7345885297203387e-06}. Best is trial 95 with value: 0.2001253350387268.
# [I 2025-09-21 12:49:24,085] Trial 98 finished with value: 0.2526239357826828 and parameters: {'learning_rate': 0.027504230718349437, 'num_leaves': 43, 'min_data_in_leaf': 33, 'feature_fraction': 0.7340949763916033, 'bagging_fraction': 0.6383762699836232, 'bagging_freq': 2, 'min_gain_to_split': 0.6811476805521066, 'lambda_l1': 1.3956040790676615e-08, 'lambda_l2': 8.768171124644216e-07}. Best is trial 95 with value: 0.2001253350387268.
# [I 2025-09-21 12:49:26,113] Trial 99 finished with value: 0.21394906704867395 and parameters: {'learning_rate': 0.02455729274205161, 'num_leaves': 56, 'min_data_in_leaf': 19, 'feature_fraction': 0.6328444381117087, 'bagging_fraction': 0.6903420328752855, 'bagging_freq': 1, 'min_gain_to_split': 0.2725312802544711, 'lambda_l1': 7.3747753833901e-07, 'lambda_l2': 3.0618623492552666e-07}. Best is trial 95 with value: 0.2001253350387268.
# [I 2025-09-21 12:49:31,404] Trial 100 finished with value: 0.19526278154504345 and parameters: {'learning_rate': 0.05092740069819052, 'num_leaves': 83, 'min_data_in_leaf': 28, 'feature_fraction': 0.6550881059844753, 'bagging_fraction': 0.7426264011340711, 'bagging_freq': 2, 'min_gain_to_split': 0.00372905589184927, 'lambda_l1': 2.298272244499854e-07, 'lambda_l2': 2.4801669394369293e-06}. Best is trial 100 with value: 0.19526278154504345.
# [I 2025-09-21 12:49:31,984] Trial 101 finished with value: 0.2022846366265143 and parameters: {'learning_rate': 0.040939465966868586, 'num_leaves': 81, 'min_data_in_leaf': 27, 'feature_fraction': 0.6485678952546621, 'bagging_fraction': 0.7128231844761476, 'bagging_freq': 2, 'min_gain_to_split': 0.033238930356652194, 'lambda_l1': 1.9097099147946016e-07, 'lambda_l2': 2.350343074872796e-06}. Best is trial 100 with value: 0.19526278154504345.
# [I 2025-09-21 12:49:32,375] Trial 102 finished with value: 0.20779098715678357 and parameters: {'learning_rate': 0.051185701070244616, 'num_leaves': 84, 'min_data_in_leaf': 27, 'feature_fraction': 0.6548535200382959, 'bagging_fraction': 0.7225313855335236, 'bagging_freq': 2, 'min_gain_to_split': 0.07839108397201094, 'lambda_l1': 1.1235630910317375e-06, 'lambda_l2': 2.5249029624434185e-06}. Best is trial 100 with value: 0.19526278154504345.
# [I 2025-09-21 12:49:32,747] Trial 103 finished with value: 0.21940341773728572 and parameters: {'learning_rate': 0.050577760248665414, 'num_leaves': 84, 'min_data_in_leaf': 20, 'feature_fraction': 0.6546997823024021, 'bagging_fraction': 0.7386417282882191, 'bagging_freq': 2, 'min_gain_to_split': 0.2484158391621063, 'lambda_l1': 1.4962444010304834e-06, 'lambda_l2': 1.3206120450547887e-06}. Best is trial 100 with value: 0.19526278154504345.
# [I 2025-09-21 12:49:33,204] Trial 104 finished with value: 0.2032225457599084 and parameters: {'learning_rate': 0.04253353356448144, 'num_leaves': 73, 'min_data_in_leaf': 10, 'feature_fraction': 0.6776524848789354, 'bagging_fraction': 0.7229538024156404, 'bagging_freq': 3, 'min_gain_to_split': 0.0700139007373823, 'lambda_l1': 2.5639648008195587e-07, 'lambda_l2': 3.693575172323978e-06}. Best is trial 100 with value: 0.19526278154504345.
# [I 2025-09-21 12:49:34,315] Trial 105 finished with value: 0.1967626525125245 and parameters: {'learning_rate': 0.05277381920620847, 'num_leaves': 103, 'min_data_in_leaf': 27, 'feature_fraction': 0.6056169382735141, 'bagging_fraction': 0.7224710156981777, 'bagging_freq': 2, 'min_gain_to_split': 0.005089040235617279, 'lambda_l1': 1.6114000758570457e-07, 'lambda_l2': 7.19684683861364e-07}. Best is trial 100 with value: 0.19526278154504345.
# [I 2025-09-21 12:49:34,885] Trial 106 finished with value: 0.1994392894970774 and parameters: {'learning_rate': 0.052653698523898715, 'num_leaves': 95, 'min_data_in_leaf': 26, 'feature_fraction': 0.6017571255454045, 'bagging_fraction': 0.7224612901463008, 'bagging_freq': 3, 'min_gain_to_split': 0.017431213837599567, 'lambda_l1': 1.6496578508970297e-07, 'lambda_l2': 6.766315656971718e-07}. Best is trial 100 with value: 0.19526278154504345.
# [I 2025-09-21 12:49:36,100] Trial 107 finished with value: 0.18848994785603645 and parameters: {'learning_rate': 0.05316473604488651, 'num_leaves': 72, 'min_data_in_leaf': 10, 'feature_fraction': 0.601238085428045, 'bagging_fraction': 0.7228246463042114, 'bagging_freq': 3, 'min_gain_to_split': 0.0022076333245390246, 'lambda_l1': 1.871045422326418e-07, 'lambda_l2': 6.950488885019888e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:49:36,639] Trial 108 finished with value: 0.19259510934053475 and parameters: {'learning_rate': 0.05451136618267775, 'num_leaves': 96, 'min_data_in_leaf': 10, 'feature_fraction': 0.6030075198529595, 'bagging_fraction': 0.7059489261577299, 'bagging_freq': 3, 'min_gain_to_split': 0.016527799968263278, 'lambda_l1': 1.2015733825915475e-07, 'lambda_l2': 8.561678289152332e-08}. Best is trial 107 with value: 0.18848994785603645.
# ...
# [I 2025-09-21 12:50:21,032] Trial 165 finished with value: 0.21559741414987205 and parameters: {'learning_rate': 0.06115065520802845, 'num_leaves': 78, 'min_data_in_leaf': 22, 'feature_fraction': 0.6073438520748042, 'bagging_fraction': 0.8064816560372258, 'bagging_freq': 4, 'min_gain_to_split': 0.19478331536266139, 'lambda_l1': 6.55247277833331e-08, 'lambda_l2': 1.8490136209634654e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:21,431] Trial 166 finished with value: 0.20643770747580642 and parameters: {'learning_rate': 0.055977961533108606, 'num_leaves': 89, 'min_data_in_leaf': 17, 'feature_fraction': 0.6000914244956688, 'bagging_fraction': 0.8008630220452698, 'bagging_freq': 3, 'min_gain_to_split': 0.1093707139458719, 'lambda_l1': 1.6652460655452742e-07, 'lambda_l2': 5.467666055937845e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:21,805] Trial 167 finished with value: 0.21756460259060875 and parameters: {'learning_rate': 0.049224017328726215, 'num_leaves': 100, 'min_data_in_leaf': 10, 'feature_fraction': 0.6129704026012474, 'bagging_fraction': 0.7922200573146051, 'bagging_freq': 5, 'min_gain_to_split': 0.2612257489437963, 'lambda_l1': 1.0343350993624666e-07, 'lambda_l2': 3.4734555088604285e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:22,419] Trial 168 finished with value: 0.19802787096803365 and parameters: {'learning_rate': 0.05282927785656598, 'num_leaves': 107, 'min_data_in_leaf': 25, 'feature_fraction': 0.6218126563156988, 'bagging_fraction': 0.766852515897275, 'bagging_freq': 4, 'min_gain_to_split': 0.011874303248072865, 'lambda_l1': 6.116002938353011e-08, 'lambda_l2': 1.3688691650675624e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:22,836] Trial 169 finished with value: 0.21536510698134914 and parameters: {'learning_rate': 0.04076816013375414, 'num_leaves': 83, 'min_data_in_leaf': 21, 'feature_fraction': 0.6107511631279586, 'bagging_fraction': 0.7782809329212247, 'bagging_freq': 5, 'min_gain_to_split': 0.19028140661518572, 'lambda_l1': 2.0493769524280857e-07, 'lambda_l2': 4.145437824283026e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:23,089] Trial 170 finished with value: 0.35129280485812037 and parameters: {'learning_rate': 0.04344226897429837, 'num_leaves': 94, 'min_data_in_leaf': 14, 'feature_fraction': 0.6327766860402559, 'bagging_fraction': 0.7570772062834203, 'bagging_freq': 3, 'min_gain_to_split': 4.517978105028114, 'lambda_l1': 1.2234739942743524e-07, 'lambda_l2': 2.2048029253914012e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:24,055] Trial 171 finished with value: 0.19780563904875076 and parameters: {'learning_rate': 0.046453895779444795, 'num_leaves': 99, 'min_data_in_leaf': 28, 'feature_fraction': 0.6384437359309995, 'bagging_fraction': 0.7869260051905375, 'bagging_freq': 4, 'min_gain_to_split': 0.006852902256765667, 'lambda_l1': 6.409711622860189e-07, 'lambda_l2': 1.0367697241813355e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:24,467] Trial 172 finished with value: 0.20526783594362671 and parameters: {'learning_rate': 0.04793503950842765, 'num_leaves': 120, 'min_data_in_leaf': 19, 'feature_fraction': 0.6208560602647556, 'bagging_fraction': 0.8121782959212953, 'bagging_freq': 4, 'min_gain_to_split': 0.10413656779621987, 'lambda_l1': 2.87706444522033e-07, 'lambda_l2': 8.339076688206194e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:24,824] Trial 173 finished with value: 0.2086878505107439 and parameters: {'learning_rate': 0.057374910213514346, 'num_leaves': 112, 'min_data_in_leaf': 25, 'feature_fraction': 0.6070771481475951, 'bagging_fraction': 0.7799203298460604, 'bagging_freq': 4, 'min_gain_to_split': 0.09816307750568945, 'lambda_l1': 5.43220602122534e-07, 'lambda_l2': 5.049274963515753e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:25,186] Trial 174 finished with value: 0.22082096232544113 and parameters: {'learning_rate': 0.05123189173025653, 'num_leaves': 132, 'min_data_in_leaf': 17, 'feature_fraction': 0.6535189456931775, 'bagging_fraction': 0.7984224249213331, 'bagging_freq': 4, 'min_gain_to_split': 0.30297754460953624, 'lambda_l1': 7.964497342113395e-08, 'lambda_l2': 1.4806831709878954e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:30,915] Trial 175 finished with value: 0.19751721523883886 and parameters: {'learning_rate': 0.045521720751653234, 'num_leaves': 105, 'min_data_in_leaf': 32, 'feature_fraction': 0.6268102537831953, 'bagging_fraction': 0.7889263979111881, 'bagging_freq': 4, 'min_gain_to_split': 0.0027490847856955513, 'lambda_l1': 1.7272793016811226e-07, 'lambda_l2': 0.504955784647991}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:32,244] Trial 176 finished with value: 0.19472816750598776 and parameters: {'learning_rate': 0.05044440227303831, 'num_leaves': 127, 'min_data_in_leaf': 22, 'feature_fraction': 0.617969947952169, 'bagging_fraction': 0.8357114132242902, 'bagging_freq': 4, 'min_gain_to_split': 0.007547197057575776, 'lambda_l1': 3.08043854175893e-07, 'lambda_l2': 1.2256224317360043e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:32,632] Trial 177 finished with value: 0.21446307585807473 and parameters: {'learning_rate': 0.05446487729019252, 'num_leaves': 126, 'min_data_in_leaf': 13, 'feature_fraction': 0.6157454922352431, 'bagging_fraction': 0.841722668949586, 'bagging_freq': 3, 'min_gain_to_split': 0.22250579566336254, 'lambda_l1': 3.212634072008192e-07, 'lambda_l2': 2.599774527248661e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:32,994] Trial 178 finished with value: 0.21095577084048625 and parameters: {'learning_rate': 0.050464314937366146, 'num_leaves': 94, 'min_data_in_leaf': 22, 'feature_fraction': 0.6002198700376802, 'bagging_fraction': 0.8314935179688407, 'bagging_freq': 5, 'min_gain_to_split': 0.13729808112259761, 'lambda_l1': 1.3805454176463965e-07, 'lambda_l2': 1.459015901785363e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:33,249] Trial 179 finished with value: 0.3085178518563198 and parameters: {'learning_rate': 0.06411668925256521, 'num_leaves': 102, 'min_data_in_leaf': 10, 'feature_fraction': 0.6098704202352523, 'bagging_fraction': 0.8168416797443657, 'bagging_freq': 5, 'min_gain_to_split': 2.6970883913863224, 'lambda_l1': 2.3438767140058292e-07, 'lambda_l2': 3.513305311012281e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:33,694] Trial 180 finished with value: 0.21110783627188087 and parameters: {'learning_rate': 0.041648193929953205, 'num_leaves': 114, 'min_data_in_leaf': 17, 'feature_fraction': 0.6220316981046248, 'bagging_fraction': 0.8458235660605312, 'bagging_freq': 3, 'min_gain_to_split': 0.17707835101824743, 'lambda_l1': 4.222519859305315e-08, 'lambda_l2': 6.756792210771039e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:34,201] Trial 181 finished with value: 0.20280318693004565 and parameters: {'learning_rate': 0.047879977467539296, 'num_leaves': 138, 'min_data_in_leaf': 29, 'feature_fraction': 0.6334897908956172, 'bagging_fraction': 0.858565433937317, 'bagging_freq': 4, 'min_gain_to_split': 0.02495851899081279, 'lambda_l1': 4.2906696246853475e-07, 'lambda_l2': 1.096492722808436e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:34,577] Trial 182 finished with value: 0.2082394867881398 and parameters: {'learning_rate': 0.05862610802543251, 'num_leaves': 128, 'min_data_in_leaf': 24, 'feature_fraction': 0.6472491127211495, 'bagging_fraction': 0.8216491147717296, 'bagging_freq': 4, 'min_gain_to_split': 0.0956513574573252, 'lambda_l1': 7.951041283099316e-07, 'lambda_l2': 1.72902442956212e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:35,454] Trial 183 finished with value: 0.1938042884556513 and parameters: {'learning_rate': 0.04408852040849894, 'num_leaves': 89, 'min_data_in_leaf': 20, 'feature_fraction': 0.6159448392833038, 'bagging_fraction': 0.8051945688955977, 'bagging_freq': 4, 'min_gain_to_split': 0.007043020687972815, 'lambda_l1': 1.0789608154720423e-07, 'lambda_l2': 8.087221575456723e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:35,883] Trial 184 finished with value: 0.20512711265883476 and parameters: {'learning_rate': 0.052663818081143614, 'num_leaves': 90, 'min_data_in_leaf': 20, 'feature_fraction': 0.6168653705240754, 'bagging_fraction': 0.8033025129086017, 'bagging_freq': 4, 'min_gain_to_split': 0.10067439137645506, 'lambda_l1': 8.73679758024737e-08, 'lambda_l2': 4.639102064928569e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:36,653] Trial 185 finished with value: 0.1923381773098316 and parameters: {'learning_rate': 0.04330371081885696, 'num_leaves': 87, 'min_data_in_leaf': 15, 'feature_fraction': 0.606855373731604, 'bagging_fraction': 0.8377759695338393, 'bagging_freq': 4, 'min_gain_to_split': 0.009732820068157724, 'lambda_l1': 1.4047987535850394e-07, 'lambda_l2': 4.3867835043413056e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:37,064] Trial 186 finished with value: 0.21871952647137452 and parameters: {'learning_rate': 0.03805060791593961, 'num_leaves': 86, 'min_data_in_leaf': 14, 'feature_fraction': 0.6065418339214568, 'bagging_fraction': 0.8411137194565239, 'bagging_freq': 4, 'min_gain_to_split': 0.25297203655219286, 'lambda_l1': 6.265628365711697e-08, 'lambda_l2': 5.742735994628332e-08}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:38,207] Trial 187 finished with value: 0.1907790389033436 and parameters: {'learning_rate': 0.04386830891002386, 'num_leaves': 78, 'min_data_in_leaf': 16, 'feature_fraction': 0.6280785043904885, 'bagging_fraction': 0.8534235631755827, 'bagging_freq': 4, 'min_gain_to_split': 0.003538056145082489, 'lambda_l1': 2.2439079897683455e-08, 'lambda_l2': 2.2825353960726314e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:38,611] Trial 188 finished with value: 0.21278329045594302 and parameters: {'learning_rate': 0.04322718616985424, 'num_leaves': 77, 'min_data_in_leaf': 16, 'feature_fraction': 0.6279183558481983, 'bagging_fraction': 0.855048374828165, 'bagging_freq': 4, 'min_gain_to_split': 0.16641815003658714, 'lambda_l1': 4.328419451652493e-08, 'lambda_l2': 2.4221739225845524e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:40,179] Trial 189 finished with value: 0.18995888725011784 and parameters: {'learning_rate': 0.04131878043881981, 'num_leaves': 82, 'min_data_in_leaf': 10, 'feature_fraction': 0.8034932315081433, 'bagging_fraction': 0.8783883175618772, 'bagging_freq': 3, 'min_gain_to_split': 0.0018485672030530262, 'lambda_l1': 1.0429640530149247e-07, 'lambda_l2': 0.0027708359730111796}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:41,085] Trial 190 finished with value: 0.22333096502992214 and parameters: {'learning_rate': 0.03968281585400684, 'num_leaves': 80, 'min_data_in_leaf': 11, 'feature_fraction': 0.8162714826701938, 'bagging_fraction': 0.87554566857082, 'bagging_freq': 3, 'min_gain_to_split': 0.35032940848861666, 'lambda_l1': 1.950044577560386e-08, 'lambda_l2': 0.006476466746793514}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:45,490] Trial 191 finished with value: 0.192794330867394 and parameters: {'learning_rate': 0.0439820517549221, 'num_leaves': 82, 'min_data_in_leaf': 15, 'feature_fraction': 0.8053677738844923, 'bagging_fraction': 0.866373526409936, 'bagging_freq': 3, 'min_gain_to_split': 0.00529376390207535, 'lambda_l1': 2.9742833314564627e-08, 'lambda_l2': 3.2884245098985416e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:45,827] Trial 192 finished with value: 0.27262086648750117 and parameters: {'learning_rate': 0.037040637174488536, 'num_leaves': 89, 'min_data_in_leaf': 14, 'feature_fraction': 0.8036650603056231, 'bagging_fraction': 0.8647298672738696, 'bagging_freq': 3, 'min_gain_to_split': 1.4887797270398866, 'lambda_l1': 2.7449012165872328e-08, 'lambda_l2': 0.021654964087709987}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:46,303] Trial 193 finished with value: 0.20621290728891858 and parameters: {'learning_rate': 0.04187409628197707, 'num_leaves': 67, 'min_data_in_leaf': 16, 'feature_fraction': 0.7941239262226506, 'bagging_fraction': 0.8685784373195372, 'bagging_freq': 3, 'min_gain_to_split': 0.10424086950198802, 'lambda_l1': 1.9955792179957854e-08, 'lambda_l2': 3.289041028145919e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:46,758] Trial 194 finished with value: 0.21195069664254707 and parameters: {'learning_rate': 0.044056113266689984, 'num_leaves': 76, 'min_data_in_leaf': 10, 'feature_fraction': 0.7937204438122571, 'bagging_fraction': 0.8495945468873582, 'bagging_freq': 3, 'min_gain_to_split': 0.19159181063695752, 'lambda_l1': 1.4420103551862364e-08, 'lambda_l2': 0.003924090665323084}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:48,973] Trial 195 finished with value: 0.1925434315072978 and parameters: {'learning_rate': 0.03962925684610953, 'num_leaves': 82, 'min_data_in_leaf': 18, 'feature_fraction': 0.8061351638138065, 'bagging_fraction': 0.8807772446319773, 'bagging_freq': 3, 'min_gain_to_split': 0.0006400471390464016, 'lambda_l1': 9.684615351035101e-08, 'lambda_l2': 1.6736604466239508e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:49,421] Trial 196 finished with value: 0.20694430422755877 and parameters: {'learning_rate': 0.03984761248798174, 'num_leaves': 71, 'min_data_in_leaf': 18, 'feature_fraction': 0.621129440335995, 'bagging_fraction': 0.8854650625252283, 'bagging_freq': 3, 'min_gain_to_split': 0.11175614874473655, 'lambda_l1': 9.076633536278971e-08, 'lambda_l2': 7.218559441055437e-07}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:50,708] Trial 197 finished with value: 0.19282851631668357 and parameters: {'learning_rate': 0.03730369431826666, 'num_leaves': 83, 'min_data_in_leaf': 13, 'feature_fraction': 0.8110549945455314, 'bagging_fraction': 0.8779415328138185, 'bagging_freq': 3, 'min_gain_to_split': 0.004086404034397551, 'lambda_l1': 3.042277966786616e-08, 'lambda_l2': 0.0014917107921144726}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:51,027] Trial 198 finished with value: 0.2958784237368528 and parameters: {'learning_rate': 0.036668196744467293, 'num_leaves': 83, 'min_data_in_leaf': 13, 'feature_fraction': 0.8072210996676293, 'bagging_fraction': 0.8766078805927278, 'bagging_freq': 3, 'min_gain_to_split': 2.3263899819473712, 'lambda_l1': 2.9677035091668066e-08, 'lambda_l2': 0.001151111898023946}. Best is trial 107 with value: 0.18848994785603645.
# [I 2025-09-21 12:50:51,491] Trial 199 finished with value: 0.2170865230730758 and parameters: {'learning_rate': 0.03545485027239883, 'num_leaves': 85, 'min_data_in_leaf': 14, 'feature_fraction': 0.8372871914351064, 'bagging_fraction': 0.8781333205347314, 'bagging_freq': 3, 'min_gain_to_split': 0.23048638323882023, 'lambda_l1': 4.1856474956199467e-08, 'lambda_l2': 0.004180861273283208}. Best is trial 107 with value: 0.18848994785603645.
# [OPTUNA] best RMSLE: 0.1885
# [OPTUNA] best params:
#   learning_rate: 0.05316473604488651
#   num_leaves: 72
#   min_data_in_leaf: 10
#   feature_fraction: 0.601238085428045
#   bagging_fraction: 0.7228246463042114
#   bagging_freq: 3
#   min_gain_to_split: 0.0022076333245390246
#   lambda_l1: 1.871045422326418e-07
#   lambda_l2: 6.950488885019888e-08
# [OPTUNA] best_round: 133
# [CALIB] multiplier to latest: 1.1386
# Saved models → models

# %%
import matplotlib.pyplot as plt

# 重要度を取得
importance = model_point.feature_importance(importance_type="gain")
feature_names = model_point.feature_name()

# DataFrame化
import pandas as pd
fi = pd.DataFrame({
    "feature": feature_names,
    "importance": importance
}).sort_values("importance", ascending=False)

print(fi)

# 棒グラフで可視化
plt.figure(figsize=(8, 6))
plt.barh(fi["feature"], fi["importance"])
plt.gca().invert_yaxis()
plt.title("Feature Importance (by gain)")
plt.show()
# Out:
#                    feature   importance
# 5                 area_sqm  1082.405101
# 7                sqrt_area   968.061298
# 9                 age_sqrt   191.812286
# 4                      築年数   168.030872
# 18     layout_oof_mean_log   123.462297
# 8                 log_area    93.351674
# 10           area_x_access    58.463483
# 15   layout_oof_median_log    51.253071
# 12            layout_count    29.317095
# 3                 walk_min    17.860385
# 24              st_pop_min    14.810559
# 17    station_oof_mean_log    13.187880
# 14  station_oof_median_log    13.085687
# 6             access_score     9.888063
# 26             land25_mean     7.693977
# 11           station_count     7.476686
# 27           land_yoy_rate     6.705821
# 19       area_oof_mean_log     6.440046
# 20             log_idx_psm     5.978857
# 23              st_pop_sum     5.759675
# 16     area_oof_median_log     5.259457
# 25          st_flood_ratio     4.518387
# 2              cat__layout     3.382473
# 28            land_logdiff     3.353233
# 1             cat__station     3.116824
# 21                 idx_mom     2.075707
# 13              area_count     1.852994
# 0          cat__area_group     0.027732
# 22                 idx_yoy     0.000000
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# ===== ここから追加：学習＆検証（OOF）精度の表示 =====
from sklearn.metrics import r2_score
import numpy as np

def _fmt_metric_row(tag, rmsle, r2, rmse_y, mae_y, mape):
    print(f"[{tag}] RMSLE={rmsle:.4f} | R2(log)={r2:.4f} | RMSE(円)={rmse_y:,.0f} | MAE(円)={mae_y:,.0f} | MAPE={mape:.2f}%")

def _yen_metrics(y_true_yen: np.ndarray, y_pred_yen: np.ndarray):
    rmse_y = float(np.sqrt(np.mean((y_true_yen - y_pred_yen) ** 2)))
    mae_y  = float(np.mean(np.abs(y_true_yen - y_pred_yen)))
    mape   = float(np.mean(np.abs((y_true_yen - y_pred_yen) / np.clip(y_true_yen, 1.0, None))) * 100.0)
    return rmse_y, mae_y, mape

# --- 学習データ上の精度 ---
best_it = getattr(model_point, "best_iteration", None)
y_log_pred_tr = model_point.predict(X_df, num_iteration=best_it)

# deflated のままのRMSE（RMSLE相当）
rmsle_tr = float(np.sqrt(np.mean((y_log - y_log_pred_tr) ** 2)))
r2_tr    = float(r2_score(y_log, y_log_pred_tr))

# ←← 真の価格は必ず y_log_true から戻す！
y_true_yen = np.expm1(y_log_true)

try:
    smear = float(smearing)
except NameError:
    smear = 1.0

if USE_DEFLATE:
    # 予測（相対ログ）に相場ログを足してから円に戻す（★ df[...] ではなく avg_psm_arr を使う）
    yhat_log1p_tr = y_log_pred_tr + np.log(avg_psm_arr)
    y_pred_yen_tr = smear * np.expm1(yhat_log1p_tr)
else:
    y_pred_yen_tr = smear * np.expm1(y_log_pred_tr)

rmse_y_tr, mae_y_tr, mape_tr = _yen_metrics(y_true_yen, y_pred_yen_tr)
_fmt_metric_row("TRAIN", rmsle_tr, r2_tr, rmse_y_tr, mae_y_tr, mape_tr)

# ② KFold OOF（疑似バリデーション）での精度
from sklearn.model_selection import KFold
import lightgbm as lgb

kf = KFold(n_splits=5, shuffle=True, random_state=SEED)
oof_pred_log = np.zeros_like(y_log, dtype=float)

# best_params / best_round / cat_cols / mono_cons は既存の変数を使用
for tr_idx, va_idx in kf.split(X_df):
    X_tr, X_va = X_df.iloc[tr_idx], X_df.iloc[va_idx]
    y_tr, y_va = y_log[tr_idx], y_log[va_idx]

     # ★ 追加：重みをfoldごとにスライス
    w_tr = None if 'sample_weight' not in globals() or sample_weight is None else sample_weight[tr_idx]
    w_va = None if 'sample_weight' not in globals() or sample_weight is None else sample_weight[va_idx]

    # ★ ここで weight=... を渡す
    dtr = lgb.Dataset(
        X_tr, label=y_tr, weight=w_tr,
        categorical_feature=cat_cols, free_raw_data=True
    )
    dva = lgb.Dataset(
        X_va, label=y_va, weight=w_va,
        categorical_feature=cat_cols, free_raw_data=True
    )

    params = dict(best_params)
    params.update({
        "objective": "rmse",
        "metric": "rmse",
        "verbosity": -1,
        "seed": SEED,
        "monotone_constraints": mono_cons,
    })

    booster = lgb.train(
        params, dtr,
        num_boost_round=best_round,
        valid_sets=[dva],
        callbacks=[],  # ここでは早停なし（best_round固定）
    )
    oof_pred_log[va_idx] = booster.predict(X_va, num_iteration=getattr(booster, "best_iteration", None))

# --- OOF（疑似バリデーション）---
# log空間のRMSE（deflated RMSE）
rmsle_oof = float(np.sqrt(np.mean((y_log - oof_pred_log) ** 2)))
r2_oof    = float(r2_score(y_log, oof_pred_log))

# 円スケール（deflate時は相場ログを足す）
if USE_DEFLATE and (avg_psm_arr is not None):
    y_pred_oof_yen = np.expm1(oof_pred_log + np.log(avg_psm_arr))
else:
    y_pred_oof_yen = np.expm1(oof_pred_log)

y_true_yen = np.expm1(y_log_true)
rmse_y_oof, mae_y_oof, mape_oof = _yen_metrics(y_true_yen, y_pred_oof_yen)
_fmt_metric_row("OOF", rmsle_oof, r2_oof, rmse_y_oof, mae_y_oof, mape_oof)

# === 直近水準の倍率キャリブ（最近 K ヶ月） ===
CALIB_RECENT_K = 2   # ← 好みで 2〜3 を推奨
uniq = np.unique(period_arr)
recent = uniq[-CALIB_RECENT_K:]
mask_recent = np.isin(period_arr, recent)
ratio = y_true_yen[mask_recent] / np.clip(y_pred_oof_yen[mask_recent], 1.0, None)
calib = float(np.median(np.clip(ratio, 0.7, 1.3)))  # クリップは安定化のため
print(f"[Calib] factor={calib:.4f} (recent {CALIB_RECENT_K} months)")

# 参考：キャリブ適用後の円スケール指標も表示
rmse_y_oof_c, mae_y_oof_c, mape_oof_c = _yen_metrics(y_true_yen, calib * y_pred_oof_yen)
_fmt_metric_row("OOF × Calib", rmsle_oof, r2_oof, rmse_y_oof_c, mae_y_oof_c, mape_oof_c)

# 直近重み付き（任意）
if 'sample_weight' in globals() and sample_weight is not None:
    # log側の重み付き誤差
    def _weighted_mean(x, w): return float(np.sum(w*x)/np.sum(w))
    rmsle_oof_w = float(np.sqrt(_weighted_mean((y_log - oof_pred_log)**2, sample_weight)))
    # 円スケール重み付き
    def _yen_metrics_weighted(y_true_yen, y_pred_yen, w):
        rmse_y = float(np.sqrt(_weighted_mean((y_true_yen - y_pred_yen)**2, w)))
        mae_y  = float(_weighted_mean(np.abs(y_true_yen - y_pred_yen), w))
        mape   = float(_weighted_mean(np.abs((y_true_yen - y_pred_yen) / np.clip(y_true_yen, 1.0, None)), w) * 100.0)
        return rmse_y, mae_y, mape
    rmse_y_oof_w, mae_y_oof_w, mape_oof_w = _yen_metrics_weighted(y_true_yen, y_pred_oof_yen, sample_weight)
    rmse_y_oof_w_c, mae_y_oof_w_c, mape_oof_w_c = _yen_metrics_weighted(y_true_yen, calib * y_pred_oof_yen, sample_weight)
    _fmt_metric_row("OOF[w]",   rmsle_oof_w, r2_oof, rmse_y_oof_w,   mae_y_oof_w,   mape_oof_w)
    _fmt_metric_row("OOF[w]×C", rmsle_oof_w, r2_oof, rmse_y_oof_w_c, mae_y_oof_w_c, mape_oof_w_c)
# Out:
# [TRAIN] RMSLE=0.1188 | R2(log)=0.9719 | RMSE(円)=13,218,605 | MAE(円)=8,641,244 | MAPE=9.04%
# [OOF] RMSLE=0.1729 | R2(log)=0.9404 | RMSE(円)=18,756,023 | MAE(円)=12,194,339 | MAPE=13.12%
# [Calib] factor=1.0132 (recent 2 months)
# [OOF × Calib] RMSLE=0.1729 | R2(log)=0.9404 | RMSE(円)=18,729,194 | MAE(円)=12,268,205 | MAPE=13.36%
# [OOF[w]] RMSLE=0.1722 | R2(log)=0.9404 | RMSE(円)=18,942,615 | MAE(円)=12,315,999 | MAPE=13.07%
# [OOF[w]×C] RMSLE=0.1722 | R2(log)=0.9404 | RMSE(円)=18,893,990 | MAE(円)=12,366,569 | MAPE=13.29%
