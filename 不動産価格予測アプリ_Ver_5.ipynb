# %% [markdown]
# <a href="https://colab.research.google.com/github/nmatsumoto-lgtm/study-KIKAGAKU/blob/main/%E4%B8%8D%E5%8B%95%E7%94%A3%E4%BE%A1%E6%A0%BC%E4%BA%88%E6%B8%AC%E3%82%A2%E3%83%97%E3%83%AA_Ver_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install lightgbm==4.5.0 optuna==3.6.1 joblib pandas numpy scikit-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 32.4 MB/s eta 0:00:00

# %%
from __future__ import annotations
import json
from pathlib import Path
from dataclasses import dataclass


import numpy as np
import pandas as pd
import optuna
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_log_error
from joblib import dump

# %%
SEED = 0
np.random.seed(SEED)

# %%
IN = Path("data/interim/train_tabular.csv")
OUT_DIR = Path("models"); OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ============================
# 1) データ読み込み & 追加特徴量
# ============================

def _oof_target_median(df: pd.DataFrame, key, y: np.ndarray, n_splits: int = 5) -> np.ndarray:
    """key は str でも list[str] でもOK。OOFで groupby(key) の中央値を割り当て。"""
    if isinstance(key, str):
        key_cols = [key]
    else:
        key_cols = list(key)
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    oof = np.zeros(len(df), dtype=float)
    key_df = df[key_cols].copy()
    for tr_idx, va_idx in kf.split(df):
        g = pd.DataFrame({"y": y[tr_idx]})
        for c in key_cols:
            g[c] = key_df.iloc[tr_idx][c].values
        med = g.groupby(key_cols)["y"].median()
        # map 用の結合キー（高速・簡易）
        tr_key = key_df.iloc[va_idx].astype(str).agg("§".join, axis=1)
        med_key = med.reset_index()
        med_key["__k__"] = med_key[key_cols].astype(str).agg("§".join, axis=1)
        map_dict = pd.Series(med_key["y"].values, index=med_key["__k__"]).to_dict()
        mapped = tr_key.map(map_dict)
        oof[va_idx] = mapped.fillna(float(np.median(y[tr_idx]))).values
    return oof

def build_table_and_features() -> tuple[ pd.DataFrame,            # X_df
    np.ndarray,              # y_log
    np.ndarray,              # y_rel
    list[str],               # categorical_feature (cat_cols)
    list[int],               # monotone_constraints
    dict,                    # meta
    OrdinalEncoder,          # oe
    dict                     # infer_maps
]:
    df = pd.read_csv(IN)

    # ===== 目標（対数）=====
    y = df["price_yen"].astype(float).values
    y_log = np.log1p(y)

    # ===== 追加特徴量 =====
    df["access_score"] = 1.0 / (1.0 + df["walk_min"].astype(float))
    df["sqrt_area"] = np.sqrt(np.clip(df["area_sqm"].astype(float), 0, None))
    df["log_area"] = np.log1p(np.clip(df["area_sqm"].astype(float), 0, None))
    df["age_sqrt"] = np.sqrt(np.clip(df["築年数"].astype(float), 0, None))
    df["area_x_access"] = df["area_sqm"].astype(float) * df["access_score"].astype(float)

    # 取引年（欠損は全体中央値で補完）
    if "txn_year" in df.columns:
        df["txn_year"] = pd.to_numeric(df["txn_year"], errors="coerce")
        df["txn_year"] = df["txn_year"].fillna(df["txn_year"].median())
    else:
        # 取引年が無いデータでも動くように、現在年で埋める
        df["txn_year"] = datetime.now().year

    # 年の離散化（木が扱いやすい整数カテゴリ）
    df["txn_year_int"] = df["txn_year"].round().astype(int)

    # ★ 追加：半年ビン（例: 2024H1=4048, 2024H2=4049）
    df["txn_half"] = (df["txn_year"] * 2).round().astype(int)

    # 頻度特徴量
    station_cnt = df["station"].value_counts()
    layout_cnt  = df["layout"].value_counts()
    df["station_count"] = df["station"].map(station_cnt).fillna(0).astype(int)
    df["layout_count"]  = df["layout"].map(layout_cnt).fillna(0).astype(int)

    # OOF 目標エンコード（駅/間取り/駅×年） ※対数ターゲットで作る
    df["station_oof_median_log"]      = _oof_target_median(df, "station", y_log)
    df["layout_oof_median_log"]       = _oof_target_median(df, "layout",  y_log)
    df["station_year_oof_median_log"] = _oof_target_median(df, ["station", "txn_year_int"], y_log)
    # ★ 追加
    df["station_half_oof_median_log"] = _oof_target_median(df, ["station", "txn_half"], y_log)

    # 推論時に使う学習時統計
    station_med_map = pd.DataFrame({"station": df["station"], "y_log": y_log}).groupby("station")["y_log"].median().to_dict()
    layout_med_map  = pd.DataFrame({"layout":  df["layout"],  "y_log": y_log}).groupby("layout")["y_log"].median().to_dict()
    st_year_med_map = (pd.DataFrame({"station": df["station"], "year": df["txn_year_int"], "y_log": y_log})
                       .groupby(["station","year"])["y_log"].median().to_dict())
    # ★ 追加：駅×半年の中央値
    st_half_med_map = (pd.DataFrame({"station": df["station"], "half": df["txn_half"], "y_log": y_log})
                   .groupby(["station","half"])["y_log"].median().to_dict())

    global_station_med = float(np.median(list(station_med_map.values()))) if len(station_med_map) else float(np.median(y_log))
    global_layout_med  = float(np.median(list(layout_med_map.values())))  if len(layout_med_map)  else float(np.median(y_log))

    # カテゴリ列
    feat_cat = ["station", "layout", "txn_year_int"]  # 年もカテゴリとして持たせる

    # 数値列（順序固定）
    feat_num_base = ["walk_min", "築年数", "area_sqm"]
    feat_num_extra = [
        "access_score", "sqrt_area", "log_area", "age_sqrt",
        "area_x_access", "station_count", "layout_count",
        "station_oof_median_log", "layout_oof_median_log",
        "station_year_oof_median_log",
        # ★ 追加
        "station_half_oof_median_log",
    ]
    feat_num_all = feat_num_base + feat_num_extra

    # 単調性制約（[cat..., num...] の順）— 名前ベースで安全に設定
    mono_dict = {name: 0 for name in feat_num_all}
    mono_dict.update({
        "walk_min": -1,     # 遠いほど価格↓
        "築年数": -1,        # 古いほど価格↓
        "area_sqm": +1,     # 広いほど価格↑
        "access_score": +1, # 駅近スコアが高いほど価格↑
        "age_sqrt": -1,     # 平滑化した築年数も価格↓
    })
    mono_num = [mono_dict[name] for name in feat_num_all]
    monotone_constraints = [0] * len(feat_cat) + mono_num

    # ====== エンコードして学習用テーブル ======
    oe = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
    X_cat = oe.fit_transform(df[feat_cat].fillna("NA")).astype("int32")
    X_num = df[feat_num_all].astype(float).values
    X = np.hstack([X_cat, X_num])

    cat_cols = [f"cat__{c}" for c in feat_cat]
    num_cols = feat_num_all.copy()
    X_df = pd.DataFrame(X, columns=cat_cols + num_cols)
    categorical_feature = cat_cols

    meta = {
        "feat_cat": feat_cat,
        "feat_num": num_cols,
        "categorical_feature": categorical_feature,
        "monotone_constraints": monotone_constraints,
    }

    meta["cv_info"] = {
       "year_int": df["txn_year_int"].astype(int).values.tolist(),
       "station":  df["station"].astype(str).values.tolist(),
    }

    infer_maps = {
        "station_count_map": station_cnt.to_dict(),
        "layout_count_map": layout_cnt.to_dict(),
        "station_median_log_map": station_med_map,
        "layout_median_log_map": layout_med_map,
        "station_year_median_log_map": {f"{k[0]}§{k[1]}": float(v) for k, v in st_year_med_map.items()},
        # ★ 追加
        "station_half_median_log_map": {f"{k[0]}§{k[1]}": float(v) for k, v in st_half_med_map.items()},
        "global_station_median_log": global_station_med,
        "global_layout_median_log": global_layout_med,
        "feat_cat": feat_cat,
        "feat_num": num_cols,
    }

    # ★ 追加：学習用の相対ターゲット y_rel = y_log - base_log
    base_key = df["station"].astype(str) + "§" + df["txn_half"].astype(int).astype(str)
    base_log = base_key.map(infer_maps["station_half_median_log_map"]).fillna(float(np.median(y_log)))
    y_rel = y_log - base_log.values

    return X_df, y_log, y_rel, categorical_feature, monotone_constraints, meta, oe, infer_maps

# %% [markdown]
# #LightGBMの単調性制約
# 単調性制約とは？
# LightGBMに「この特徴量は必ず上がる／下がる方向に効くはずだよ」と教える機能です。
#
# 例：
#
# * 徒歩時間（walk_min） → 長くなると価格は 下がる はず → 制約「負」
# * 面積（area_sqm） → 広くなると価格は 上がる はず → 制約「正」
# * 築年数 → 古くなると価格は 下がる はず → 制約「負」
#
# なぜ必要なのか？
#
# 木モデルは柔軟すぎるので、
# データが少ない領域では「徒歩20分のほうが徒歩10分より高い」といった直感に反する予測をしてしまうことがあります。
#
# 単調性制約を入れると、それを防いで「人間の常識に合った」予測を保証できます。
#
#
# -->単調性制約は「ドメイン知識を組み込む」ためのテクニック。

# %% [markdown]
# #特徴量一覧
# * カテゴリ特徴量（OrdinalEncoder で数値化）
#   - station … 最寄駅の名称
#   - layout … 間取り（例: 2LDK, 1K などを正規化したもの）
#   - txn_year_int … 取引年（整数化したカテゴリ）
# * 数値特徴量
#   - walk_min … 最寄駅からの徒歩分数
#   - 築年数 … 取引年 − 建築年
#   - area_sqm … 専有面積（㎡）
# * 数値特徴量（追加で作った派生＆統計的特徴量）
#   - access_score = 1 / (1 + walk_min)
#    → 駅近ほど大きい値になるアクセススコア
#   - sqrt_area = sqrt(area_sqm)
#    → 面積の平方根（非線形性を吸収）
#   - log_area = log1p(area_sqm)
#    → 面積の対数（大きい面積の伸びを抑える）
#   - age_sqrt = sqrt(築年数)
#    → 築年数の平方根（築年数の影響を平滑化）
#   - area_x_access = area_sqm × access_score
#    → 面積とアクセスを掛け合わせた交互作用特徴量
#   - station_count = 各駅の出現回数（頻度エンコード）
#   - layout_count = 各間取りの出現回数（頻度エンコード）
#   - station_oof_median_log = 駅ごとの取引価格中央値（OOF方式で計算）
#   - layout_oof_median_log = 間取りごとの取引価格中央値（OOF方式で計算）
#   - station_year_oof_median_log = 駅 × 年ごとの取引価格中央値（OOF方式で計算）

# %%
# ============================
# 2) Optuna でハイパラ探索
# ============================
def iter_ts_station_cv(year_int: np.ndarray, station: np.ndarray,
                       n_folds: int = 5, holdout_frac: float = 0.2, seed: int = 0):
    years = np.array(year_int).astype(int)
    st    = np.array(station).astype(str)
    uniq_years = np.unique(years)
    if len(uniq_years) < n_folds:
        n_folds = len(uniq_years)
    fold_years = uniq_years[-n_folds:]

    for i, vy in enumerate(fold_years):
        va_mask_year = (years == vy)
        rng = np.random.RandomState(seed + int(vy))
        st_in_year = np.unique(st[va_mask_year])
        k = max(1, int(np.ceil(len(st_in_year) * holdout_frac)))
        hold_st = rng.choice(st_in_year, size=k, replace=False)
        va_mask = va_mask_year & np.isin(st, hold_st)
        tr_mask = years < vy
        tr_idx = np.where(tr_mask)[0]
        va_idx = np.where(va_mask)[0]
        if len(va_idx) == 0 or len(tr_idx) == 0:
            continue
        yield tr_idx, va_idx

def tune_with_optuna(
    X_df: pd.DataFrame,
    y_log: np.ndarray,
    categorical_feature: list[str],
    monotone_constraints: list[int],
    n_trials: int = 120,
    cv_mode: str = "kfold",         # ★ 追加: "kfold" | "ts_station"
    cv_info: dict | None = None,    # ★ 追加
) -> tuple[dict, int, float]:
    # kf = KFold(n_splits=5, shuffle=True, random_state=SEED)

    # 新（★ cv_mode 切替）
    if cv_mode == "ts_station" and cv_info is not None:
          splits = list(iter_ts_station_cv(
              np.array(cv_info["year_int"]), np.array(cv_info["station"]),
              n_folds=5, holdout_frac=0.2, seed=SEED))
    else:
          from sklearn.model_selection import KFold
          splits = list(KFold(n_splits=5, shuffle=True, random_state=SEED).split(X_df))

    def objective(trial: optuna.Trial) -> float:
        params = {
                "objective": "rmse",
                "metric": "rmse",
                "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.08, log=True),
                "num_leaves": trial.suggest_int("num_leaves", 31, 255),              # ★ 広げる
                "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 30, 300),  # ★ 広げる
                "min_sum_hessian_in_leaf": trial.suggest_float("min_sum_hessian_in_leaf", 1e-3, 1e-1, log=True),  # ★ 追加
                "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 0.95),
                "feature_fraction_bynode": trial.suggest_float("feature_fraction_bynode", 0.6, 0.95),             # ★ 追加
                "bagging_fraction": trial.suggest_float("bagging_fraction", 0.7, 1.0),
                "bagging_freq": trial.suggest_int("bagging_freq", 1, 10),
                "max_bin": trial.suggest_int("max_bin", 255, 1023),                  # ★ 追加
                "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0.0, 3.0),
                "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 3.0, log=True),  # ★ 上限↑
                "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 3.0, log=True),  # ★ 上限↑
                "extra_trees": trial.suggest_categorical("extra_trees", [False, True]),  # ★ 追加
                "verbosity": -1,
                "seed": SEED,
                "monotone_constraints": monotone_constraints,
         }

        rmsles, best_iters = [], []
        for tr_idx, va_idx in splits:
            X_tr, X_va = X_df.iloc[tr_idx], X_df.iloc[va_idx]
            y_tr, y_va = y_log[tr_idx], y_log[va_idx]
            dtr = lgb.Dataset(X_tr, label=y_tr, categorical_feature=categorical_feature, free_raw_data=True)
            dva = lgb.Dataset(X_va, label=y_va, categorical_feature=categorical_feature, free_raw_data=True)

            model = lgb.train(
                params,
                dtr,
                valid_sets=[dva],
                num_boost_round=4000,
                callbacks=[lgb.early_stopping(300, verbose=False)],  # ← 少し長めに
            )
            pred_log = model.predict(X_va, num_iteration=model.best_iteration)
            # rmsle = float(np.sqrt(mean_squared_log_error(np.expm1(y_va), np.expm1(pred_log))))
            # rmsles.append(rmsle)
            rmse_rel = float(np.sqrt(np.mean((y_va - pred_log) ** 2)))
            rmsles.append(rmse_rel)
            best_iters.append(model.best_iteration)
        trial.set_user_attr("best_iters", best_iters)
        return float(np.mean(rmsles))

    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=n_trials)

    best_params = study.best_params
    best_iters_list = study.best_trial.user_attrs.get("best_iters", [1000])
    best_round = int(np.clip(np.mean(best_iters_list), 100, 4000))
    best_score = study.best_value
    return best_params, best_round, best_score

# %%
# ============================
# 3) 最終学習（ポイント & 分位点）
# ============================

def train_final_models(
    X_df: pd.DataFrame,
    y_log: np.ndarray,
    categorical_feature: list[str],
    monotone_constraints: list[int],
    best_params: dict,
    best_round: int,
):
    base_params = dict(best_params)
    base_params.update({
        "objective": "rmse",
        "metric": "rmse",
        "verbosity": -1,
        "seed": SEED,
        # ★ ポイントモデルでは単調性制約を使う
        "monotone_constraints": monotone_constraints,
    })

    # 生データを解放しない（categorical_feature を後で使えるように）
    dtrain = lgb.Dataset(
        X_df,
        label=y_log,
        categorical_feature=categorical_feature,
        free_raw_data=False
    )

    # ---- ポイント（対数価格）----
    model_point = lgb.train(base_params, dtrain, num_boost_round=best_round)

    # ---- 分位点（q10/q90）----
    models_q = {}
    for alpha, tag in [(0.1, "q10"), (0.9, "q90")]:
        q_params = dict(best_params)
        q_params.update({
            "objective": "quantile",
            "alpha": alpha,
            "metric": "quantile",
            "verbosity": -1,
            "seed": SEED,
            # ★ ここが重要：quantile では単調性制約を外す
            # "monotone_constraints": monotone_constraints,  # ←入れない
        })
        models_q[tag] = lgb.train(q_params, dtrain, num_boost_round=best_round)

    return model_point, models_q

# %%
# ===== 入力CSV→中間CSVの自動生成（なければ作る） =====
from pathlib import Path
import pandas as pd, numpy as np, re
from datetime import datetime

RAW_CSV = Path("/content/Tokyo_Chuo Ward_20222_20251.csv")
IN = Path("data/interim/train_tabular.csv")
ST_OUT = Path("data/interim/stations.csv")
IN.parent.mkdir(parents=True, exist_ok=True)

def _read_chuo_and_save(raw_csv: Path, out_csv: Path, stations_csv: Path):
    # エンコーディングを順に試す（Excel想定）
    last_err = None
    for enc in ("cp932", "utf-8-sig", "utf-8", "utf-16", "utf-16le", "utf-16be"):
        try:
            raw = pd.read_csv(raw_csv, encoding=enc)
            break
        except Exception as e:
            last_err = e
            raw = None
    if raw is None:
        raise last_err

    # ---- 年の抽出（和暦/西暦対応）----
    def _to_year(x):
        if pd.isna(x): return np.nan
        s = str(x)
        m = re.search(r"(\d{4})年", s)
        if m: return int(m.group(1))
        era_base = {"令和":2018, "平成":1988, "昭和":1925}
        for era, base in era_base.items():
            m = re.search(fr"{era}\s*(\d+)年", s)
            if m: return base + int(m.group(1))
        return np.nan

    # ---- 取引年（列が無ければ建物の保存年やファイル名からフォールバック）----
    def _to_txn_year(s):
        if pd.isna(s): return np.nan
        ss = str(s)
        # 例: "2024年第2四半期", "2023年上半期" などから西暦抽出
        m = re.search(r"(\d{4})", ss)
        return float(m.group(1)) if m else np.nan

    # 欲しい列が増えても落ちないように存在チェック
    need_base = ["最寄駅：名称","最寄駅：距離（分）","間取り","面積（㎡）","建築年","取引価格（総額）"]
    miss = [c for c in need_base if c not in raw.columns]
    if miss:
        raise KeyError(f"必要列が見つかりません: {miss}")
    df = raw[need_base].copy()

    # 取引時期があれば読む
    txn_year = None
    if "取引時期" in raw.columns:
        txn_year = raw["取引時期"].apply(_to_txn_year)
    # 全欠損なら建築年からの近似（現行の現在年は避ける）
    if txn_year is None or txn_year.isna().all():
        # ファイル名に西暦があれば拾う（例: Tokyo_Chuo Ward_20242_20251.csv → 2024〜2025）
        mfile = re.findall(r"(20\d{2})", raw_csv.name)
        fallback_year = float(mfile[-1]) if mfile else np.nan
        txn_year = pd.Series(fallback_year, index=df.index, dtype="float64")

    # ---- 築年数 = 取引年 − 建築年 ----
    build_year = df["建築年"].apply(_to_year)
    df["txn_year"] = txn_year.astype(float)
    df["築年数"] = (df["txn_year"] - build_year).clip(lower=0)

    # ---- 数値化ユーティリティ ----
    def _to_num_series(s):
        s = s.astype(str).str.replace(r"[^\d\.]", "", regex=True)
        return pd.to_numeric(s, errors="coerce")

    # ---- 数値列の強制数値化 & 欠損補完 ----
    for col in ["最寄駅：距離（分）","面積（㎡）","築年数"]:
        s_num = _to_num_series(df[col])
        med = s_num.median()
        if pd.isna(med):
            defaults = {"最寄駅：距離（分）":10.0, "面積（㎡）":40.0, "築年数":20.0}
            med = defaults.get(col, 0.0)
        df[col] = s_num.fillna(med)

    # ---- 間取りの正規化 ----
    def _normalize_layout(s):
        if not isinstance(s,str): return "その他"
        s = s.upper().replace("Ｌ","L").replace("Ｄ","D").replace("Ｋ","K").replace("Ｒ","R")
        m = re.search(r"(\d+)(LDK|DK|K|R)", s)
        return m.group(0) if m else "その他"

    # ---- 学習用テーブル ----
    train = df.rename(columns={
        "最寄駅：名称":"station",
        "最寄駅：距離（分）":"walk_min",
        "面積（㎡）":"area_sqm",
        "取引価格（総額）":"price_yen",
    })[["station","walk_min","築年数","area_sqm","price_yen","txn_year"]].copy()
    train["layout"] = raw["間取り"].astype(str).apply(_normalize_layout)

    # 不適切値の除去とクリップ
    train["price_yen"] = _to_num_series(train["price_yen"]).fillna(0)
    train = train[
        (train["price_yen"] > 0) &
        (train["area_sqm"]  > 0) &
        (train["walk_min"]  >= 0) &
        (train["築年数"]      >= 0)
    ].copy()
    train["area_sqm"] = train["area_sqm"].clip(8, 300)
    train["walk_min"] = train["walk_min"].clip(0, 60)

    # 保存
    train.to_csv(out_csv, index=False)

    # 駅リスト
    s = (raw["最寄駅：名称"].astype(str)
           .replace({"nan":np.nan,"None":np.nan,"":np.nan})
           .dropna()
           .str.normalize("NFKC")
           .str.replace("（","(",regex=False).str.replace("）",")",regex=False)
           .str.replace("　"," ",regex=False).str.strip()
           .str.replace(r"\s+"," ",regex=True))
    pd.Series(sorted(s.unique())).to_csv(stations_csv, index=False, header=False, encoding="utf-8-sig")


# まだ中間CSVがない場合は作る
if not IN.exists():
    if not RAW_CSV.exists():
        raise FileNotFoundError(f"Raw CSV が見つかりません: {RAW_CSV.resolve()}")
    _read_chuo_and_save(RAW_CSV, IN, ST_OUT)

# %%
# ============================
# 4) 実行
# ============================

if __name__ == "__main__":
    assert IN.exists(), f"Not found: {IN}"

    # # ★ infer_maps まで受け取る（関数が infer_maps を返す実装になっている前提）
    # X_df, y_log, cat_cols, mono_cons, meta, oe, infer_maps = build_table_and_features()
    X_df, y_log, y_rel, cat_cols, mono_cons, meta, oe, infer_maps = build_table_and_features()
    print(f"Train rows: {len(X_df):,}, cols: {X_df.shape[1]} (cats={len(cat_cols)})")

    # best_params, best_round, best_score = tune_with_optuna(
    #     X_df, y_log, cat_cols, mono_cons, n_trials=80
    # )
    # print("[OPTUNA] best RMSLE:", round(best_score, 4))
    # print("[OPTUNA] best params:")
    # for k, v in best_params.items():
    #     print(f"  {k}: {v}")
    # print("[OPTUNA] best_round:", best_round)

    # ★ 学習・探索は y_rel を使う（相対ターゲット）
    best_params, best_round, best_score = tune_with_optuna(
       X_df, y_rel, cat_cols, mono_cons,
       n_trials=120,                # 後述の探索拡大に合わせて少し増やす
       cv_mode="kfold",        # 後述のCV切替
       cv_info=meta.get("cv_info")  # 後述のCV用情報
    )

    model_point, models_q = train_final_models(
    X_df, y_rel, cat_cols, mono_cons, best_params, best_round
    )

    # ===== 保存 =====
    # 予測時に使うメタ情報（列順や制約）とエンコーダを一緒に保存しておく
    dump({
         "model": model_point,
         "encoder": oe,
         "cat_cols": meta["feat_cat"],
         "num_cols": meta["feat_num"],
         "categorical_feature": meta["categorical_feature"],
         "monotone_constraints": meta["monotone_constraints"],
         "target": "log_price_yen_rel",   # ★ 相対ターゲットで学習した場合はこちら
         "relative_info": {               # ★ 予測時に基準へ戻すための情報
         "base_key": "station§txn_half",
         "maps": {"station_half_median_log_map": True}
         },
    }, OUT_DIR / "lgbm_optuna_point.pkl")


    dump({
        "model": models_q["q10"],
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen_rel",   # ★ 相対ターゲット
        "alpha": 0.1,
        "relative_info": {               # ★ 基準へ戻すための情報
        "base_key": "station§txn_half",
        "maps": {"station_half_median_log_map": True}
        },
    }, OUT_DIR / "lgbm_optuna_q10.pkl")

    dump({
        "model": models_q["q90"],
        "encoder": oe,
        "cat_cols": meta["feat_cat"],
        "num_cols": meta["feat_num"],
        "categorical_feature": meta["categorical_feature"],
        "monotone_constraints": meta["monotone_constraints"],
        "target": "log_price_yen_rel",   # ★ 相対ターゲット
        "alpha": 0.9,
        "relative_info": {               # ★ 同上
        "base_key": "station§txn_half",
        "maps": {"station_half_median_log_map": True}
        },
   }, OUT_DIR / "lgbm_optuna_q90.pkl")

    with open(OUT_DIR / "feature_config.json", "w", encoding="utf-8") as f:
        json.dump({
            "feat_cat": meta["feat_cat"],
            "feat_num": meta["feat_num"],
            "categorical_feature": meta["categorical_feature"],
            "monotone_constraints": meta["monotone_constraints"],
            "notes": (
            "target is relative: y_rel = log1p(price_yen) - base_log(station×half). "
            "During inference, add base_log back then apply expm1."
           ),
    }, f, ensure_ascii=False, indent=2)

    # ★ 推論用マップも保存（カッコを閉じるのを忘れない）
    with open(OUT_DIR / "infer_maps.json", "w", encoding="utf-8") as f:
        json.dump(infer_maps, f, ensure_ascii=False, indent=2)

    # === 手早く確認：学習データに対する MAE / RMSLE ===
    from sklearn.metrics import mean_absolute_error, mean_squared_log_error
    import numpy as np, pandas as pd

    # 駅×半年キー（学習時に作った map を使う）
    station_s = pd.Series(meta["cv_info"]["station"], dtype=str)
    half_s    = pd.Series(meta["cv_info"]["year_int"], dtype=int) * 2  # txn_half ≒ 年×2
    key = station_s + "§" + half_s.astype(str)

    st_half_map = infer_maps["station_half_median_log_map"]
    fallback_log = float(np.median(y_log))
    base_log = key.map(st_half_map).fillna(fallback_log).to_numpy()

    # 相対ログ予測 → 絶対ログ → 円スケール
    pred_rel_log = model_point.predict(X_df, num_iteration=getattr(model_point, "best_iteration", None))
    pred_price   = np.expm1(pred_rel_log + base_log)

    y_true = np.expm1(y_log)

    mae   = float(np.mean(np.abs(y_true - pred_price)))
    rmsle = float(np.sqrt(mean_squared_log_error(y_true, pred_price)))
    print(f"[Train/In-sample] MAE: {mae:,.0f} JPY  |  RMSLE: {rmsle:.5f}")

    print("Saved models →", OUT_DIR)
# Out:
# [I 2025-09-05 06:00:27,908] A new study created in memory with name: no-name-918a992d-1b9d-4293-95b7-8fbef2438962
# Train rows: 5,333, cols: 17 (cats=3)
# [I 2025-09-05 06:00:30,441] Trial 0 finished with value: 0.21023266208350183 and parameters: {'learning_rate': 0.0461692580947478, 'num_leaves': 212, 'min_data_in_leaf': 145, 'min_sum_hessian_in_leaf': 0.01584485839675602, 'feature_fraction': 0.8313257887744573, 'feature_fraction_bynode': 0.829384035003913, 'bagging_fraction': 0.9678229079291909, 'bagging_freq': 1, 'max_bin': 852, 'min_gain_to_split': 1.8125829978452128, 'lambda_l1': 0.011263817901477433, 'lambda_l2': 1.1855373359256385e-05, 'extra_trees': True}. Best is trial 0 with value: 0.21023266208350183.
# [I 2025-09-05 06:00:31,559] Trial 1 finished with value: 0.21791806596321503 and parameters: {'learning_rate': 0.02420808642444136, 'num_leaves': 218, 'min_data_in_leaf': 210, 'min_sum_hessian_in_leaf': 0.017497146740845387, 'feature_fraction': 0.8077428399986616, 'feature_fraction_bynode': 0.6906498102252326, 'bagging_fraction': 0.7377166605150834, 'bagging_freq': 7, 'max_bin': 277, 'min_gain_to_split': 1.3461081374555715, 'lambda_l1': 0.004266705589621132, 'lambda_l2': 3.0787531327511574e-07, 'extra_trees': True}. Best is trial 0 with value: 0.21023266208350183.
# [I 2025-09-05 06:00:31,857] Trial 2 finished with value: 0.2049582823446107 and parameters: {'learning_rate': 0.07045716125433814, 'num_leaves': 55, 'min_data_in_leaf': 97, 'min_sum_hessian_in_leaf': 0.0012727523213842827, 'feature_fraction': 0.7657602282541894, 'feature_fraction_bynode': 0.6615747961337622, 'bagging_fraction': 0.8618543542973055, 'bagging_freq': 8, 'max_bin': 447, 'min_gain_to_split': 2.1249169773884375, 'lambda_l1': 0.07184096200183782, 'lambda_l2': 0.00029928226825496907, 'extra_trees': False}. Best is trial 2 with value: 0.2049582823446107.
# [I 2025-09-05 06:00:32,370] Trial 3 finished with value: 0.2185188098275233 and parameters: {'learning_rate': 0.025255311961709104, 'num_leaves': 183, 'min_data_in_leaf': 250, 'min_sum_hessian_in_leaf': 0.0026270682467338232, 'feature_fraction': 0.8473535647071484, 'feature_fraction_bynode': 0.6436215919377573, 'bagging_fraction': 0.7062836497362844, 'bagging_freq': 5, 'max_bin': 630, 'min_gain_to_split': 1.995796848717947, 'lambda_l1': 4.838301375929212e-07, 'lambda_l2': 2.3230260948616298e-05, 'extra_trees': False}. Best is trial 2 with value: 0.2049582823446107.
# [I 2025-09-05 06:00:33,549] Trial 4 finished with value: 0.214649846092177 and parameters: {'learning_rate': 0.016509882771927015, 'num_leaves': 38, 'min_data_in_leaf': 210, 'min_sum_hessian_in_leaf': 0.01733859039442324, 'feature_fraction': 0.7064423067785544, 'feature_fraction_bynode': 0.8634000970305971, 'bagging_fraction': 0.9505277826660599, 'bagging_freq': 10, 'max_bin': 707, 'min_gain_to_split': 1.8221901841902082, 'lambda_l1': 0.0005773637448338301, 'lambda_l2': 0.05333688977649949, 'extra_trees': True}. Best is trial 2 with value: 0.2049582823446107.
# [I 2025-09-05 06:00:34,034] Trial 5 finished with value: 0.20356860430498247 and parameters: {'learning_rate': 0.030903001358585157, 'num_leaves': 210, 'min_data_in_leaf': 135, 'min_sum_hessian_in_leaf': 0.001461266447886768, 'feature_fraction': 0.8439469138854248, 'feature_fraction_bynode': 0.889779789028325, 'bagging_fraction': 0.8644366588189025, 'bagging_freq': 4, 'max_bin': 357, 'min_gain_to_split': 1.6191304536494266, 'lambda_l1': 0.00032937999195259166, 'lambda_l2': 8.42013578199336e-06, 'extra_trees': False}. Best is trial 5 with value: 0.20356860430498247.
# [I 2025-09-05 06:00:35,852] Trial 6 finished with value: 0.21080975044374878 and parameters: {'learning_rate': 0.04572233599582033, 'num_leaves': 156, 'min_data_in_leaf': 164, 'min_sum_hessian_in_leaf': 0.04596236092475325, 'feature_fraction': 0.8033643078707335, 'feature_fraction_bynode': 0.8369894139541111, 'bagging_fraction': 0.7305106188974939, 'bagging_freq': 1, 'max_bin': 932, 'min_gain_to_split': 1.1897535231327243, 'lambda_l1': 0.3741310911194159, 'lambda_l2': 0.000575431981977863, 'extra_trees': True}. Best is trial 5 with value: 0.20356860430498247.
# [I 2025-09-05 06:00:37,423] Trial 7 finished with value: 0.19689228628596056 and parameters: {'learning_rate': 0.013513918664262728, 'num_leaves': 117, 'min_data_in_leaf': 228, 'min_sum_hessian_in_leaf': 0.01216121813783904, 'feature_fraction': 0.7370150366313499, 'feature_fraction_bynode': 0.7048294595283072, 'bagging_fraction': 0.7241627373829459, 'bagging_freq': 6, 'max_bin': 779, 'min_gain_to_split': 0.18331546029353818, 'lambda_l1': 0.7052291345382479, 'lambda_l2': 2.446692030187806e-08, 'extra_trees': False}. Best is trial 7 with value: 0.19689228628596056.
# [I 2025-09-05 06:00:38,149] Trial 8 finished with value: 0.19011104700693507 and parameters: {'learning_rate': 0.03254328941781628, 'num_leaves': 112, 'min_data_in_leaf': 124, 'min_sum_hessian_in_leaf': 0.0025101144374448494, 'feature_fraction': 0.7387341992382478, 'feature_fraction_bynode': 0.6820781950749578, 'bagging_fraction': 0.7362875180541073, 'bagging_freq': 2, 'max_bin': 605, 'min_gain_to_split': 0.2526805771078805, 'lambda_l1': 5.181106643503105e-08, 'lambda_l2': 0.7079106371277663, 'extra_trees': False}. Best is trial 8 with value: 0.19011104700693507.
# [I 2025-09-05 06:00:38,749] Trial 9 finished with value: 0.208614215555771 and parameters: {'learning_rate': 0.0720164936111713, 'num_leaves': 184, 'min_data_in_leaf': 178, 'min_sum_hessian_in_leaf': 0.02365900579656382, 'feature_fraction': 0.7900378029036701, 'feature_fraction_bynode': 0.6149006289829956, 'bagging_fraction': 0.8598242229281056, 'bagging_freq': 9, 'max_bin': 421, 'min_gain_to_split': 0.6207036958516966, 'lambda_l1': 1.4346355218741236, 'lambda_l2': 1.299670525757895e-05, 'extra_trees': True}. Best is trial 8 with value: 0.19011104700693507.
# [I 2025-09-05 06:00:39,642] Trial 10 finished with value: 0.22245584495802556 and parameters: {'learning_rate': 0.010560744650675396, 'num_leaves': 100, 'min_data_in_leaf': 300, 'min_sum_hessian_in_leaf': 0.0049943844475177105, 'feature_fraction': 0.6058491668230664, 'feature_fraction_bynode': 0.7529682307953537, 'bagging_fraction': 0.7858798591074069, 'bagging_freq': 3, 'max_bin': 561, 'min_gain_to_split': 2.9037197693313197, 'lambda_l1': 1.4122981435893986e-08, 'lambda_l2': 1.9854923128013848, 'extra_trees': False}. Best is trial 8 with value: 0.19011104700693507.
# [I 2025-09-05 06:00:46,427] Trial 11 finished with value: 0.1724704377447906 and parameters: {'learning_rate': 0.010772863608672413, 'num_leaves': 114, 'min_data_in_leaf': 32, 'min_sum_hessian_in_leaf': 0.004848179290487556, 'feature_fraction': 0.9337864424225779, 'feature_fraction_bynode': 0.7274837338783476, 'bagging_fraction': 0.7912466258787499, 'bagging_freq': 6, 'max_bin': 790, 'min_gain_to_split': 0.03790836669856218, 'lambda_l1': 5.116435573723643e-06, 'lambda_l2': 2.7966655228314678e-08, 'extra_trees': False}. Best is trial 11 with value: 0.1724704377447906.
# [I 2025-09-05 06:00:52,103] Trial 12 finished with value: 0.1710231178035926 and parameters: {'learning_rate': 0.01808793996201269, 'num_leaves': 90, 'min_data_in_leaf': 53, 'min_sum_hessian_in_leaf': 0.004737344934196089, 'feature_fraction': 0.934740509259326, 'feature_fraction_bynode': 0.755280784258115, 'bagging_fraction': 0.7966788417176062, 'bagging_freq': 2, 'max_bin': 560, 'min_gain_to_split': 0.02059881535162538, 'lambda_l1': 3.7908145874085226e-06, 'lambda_l2': 0.03340363779698455, 'extra_trees': False}. Best is trial 12 with value: 0.1710231178035926.
# [I 2025-09-05 06:00:53,219] Trial 13 finished with value: 0.18867836946603928 and parameters: {'learning_rate': 0.01708425018476709, 'num_leaves': 74, 'min_data_in_leaf': 36, 'min_sum_hessian_in_leaf': 0.005899669650374571, 'feature_fraction': 0.9449380905870465, 'feature_fraction_bynode': 0.7700589299255869, 'bagging_fraction': 0.7975910668094791, 'bagging_freq': 5, 'max_bin': 1008, 'min_gain_to_split': 0.6806461453033241, 'lambda_l1': 1.0313310875378311e-05, 'lambda_l2': 0.010410341645915927, 'extra_trees': False}. Best is trial 12 with value: 0.1710231178035926.
# [I 2025-09-05 06:01:03,241] Trial 14 finished with value: 0.17027921514944033 and parameters: {'learning_rate': 0.010081702185807652, 'num_leaves': 143, 'min_data_in_leaf': 36, 'min_sum_hessian_in_leaf': 0.005533322399768172, 'feature_fraction': 0.9411623924873165, 'feature_fraction_bynode': 0.7499789579862957, 'bagging_fraction': 0.7931425678667665, 'bagging_freq': 3, 'max_bin': 515, 'min_gain_to_split': 0.02238705477661018, 'lambda_l1': 4.83465611978215e-06, 'lambda_l2': 0.008172582516848045, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:04,348] Trial 15 finished with value: 0.19193980079158485 and parameters: {'learning_rate': 0.015681124221118576, 'num_leaves': 253, 'min_data_in_leaf': 77, 'min_sum_hessian_in_leaf': 0.0028967836361861263, 'feature_fraction': 0.8941463748079109, 'feature_fraction_bynode': 0.803173881076283, 'bagging_fraction': 0.8162911422623792, 'bagging_freq': 3, 'max_bin': 525, 'min_gain_to_split': 0.757507213919218, 'lambda_l1': 1.3986584204223933e-05, 'lambda_l2': 0.01944295318771684, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:05,462] Trial 16 finished with value: 0.18691860591157802 and parameters: {'learning_rate': 0.019047285272239624, 'num_leaves': 147, 'min_data_in_leaf': 68, 'min_sum_hessian_in_leaf': 0.00817200574840952, 'feature_fraction': 0.8888530885899347, 'feature_fraction_bynode': 0.9124996703977584, 'bagging_fraction': 0.9124176492494154, 'bagging_freq': 3, 'max_bin': 481, 'min_gain_to_split': 0.45362468797110617, 'lambda_l1': 5.381507252671667e-07, 'lambda_l2': 0.002890110269689101, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:06,777] Trial 17 finished with value: 0.19476978662036581 and parameters: {'learning_rate': 0.012642267292262753, 'num_leaves': 84, 'min_data_in_leaf': 65, 'min_sum_hessian_in_leaf': 0.03788998628842361, 'feature_fraction': 0.8892207473000174, 'feature_fraction_bynode': 0.7922332146938743, 'bagging_fraction': 0.828566608318082, 'bagging_freq': 2, 'max_bin': 694, 'min_gain_to_split': 1.1259084501193712, 'lambda_l1': 5.4401908512539826e-05, 'lambda_l2': 0.05358321422367705, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:09,147] Trial 18 finished with value: 0.19674429825752524 and parameters: {'learning_rate': 0.020306947697643397, 'num_leaves': 137, 'min_data_in_leaf': 103, 'min_sum_hessian_in_leaf': 0.00840140594626685, 'feature_fraction': 0.6589018141841734, 'feature_fraction_bynode': 0.7387325107727694, 'bagging_fraction': 0.76571444563266, 'bagging_freq': 4, 'max_bin': 378, 'min_gain_to_split': 0.9879059551070902, 'lambda_l1': 1.5723162211124909e-06, 'lambda_l2': 0.24906273230782358, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:10,090] Trial 19 finished with value: 0.20468894355937647 and parameters: {'learning_rate': 0.013799796752029213, 'num_leaves': 75, 'min_data_in_leaf': 50, 'min_sum_hessian_in_leaf': 0.07291416464973499, 'feature_fraction': 0.919860659386244, 'feature_fraction_bynode': 0.7224471786043789, 'bagging_fraction': 0.8869254001191001, 'bagging_freq': 2, 'max_bin': 531, 'min_gain_to_split': 2.647191109692135, 'lambda_l1': 1.1017196764720067e-07, 'lambda_l2': 0.002743871242094622, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:15,062] Trial 20 finished with value: 0.17322349090538788 and parameters: {'learning_rate': 0.041688788523916574, 'num_leaves': 169, 'min_data_in_leaf': 98, 'min_sum_hessian_in_leaf': 0.0034578649503431568, 'feature_fraction': 0.9046571714510125, 'feature_fraction_bynode': 0.8071126113219054, 'bagging_fraction': 0.7623537249367821, 'bagging_freq': 4, 'max_bin': 690, 'min_gain_to_split': 0.00035108738067196263, 'lambda_l1': 7.5620466828288e-05, 'lambda_l2': 0.25214489352024017, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:17,230] Trial 21 finished with value: 0.18233716630178792 and parameters: {'learning_rate': 0.010486173632006265, 'num_leaves': 125, 'min_data_in_leaf': 31, 'min_sum_hessian_in_leaf': 0.005149782576612921, 'feature_fraction': 0.9491316608350522, 'feature_fraction_bynode': 0.756134541890678, 'bagging_fraction': 0.8242747652381727, 'bagging_freq': 6, 'max_bin': 805, 'min_gain_to_split': 0.3335259395814495, 'lambda_l1': 3.4322742809016886e-06, 'lambda_l2': 8.138148281807409e-08, 'extra_trees': False}. Best is trial 14 with value: 0.17027921514944033.
# [I 2025-09-05 06:01:29,883] Trial 22 finished with value: 0.16929724099182458 and parameters: {'learning_rate': 0.0101372405270164, 'num_leaves': 102, 'min_data_in_leaf': 31, 'min_sum_hessian_in_leaf': 0.004123964403533336, 'feature_fraction': 0.8670371154170791, 'feature_fraction_bynode': 0.7221647428654899, 'bagging_fraction': 0.7776524758686608, 'bagging_freq': 8, 'max_bin': 764, 'min_gain_to_split': 0.014904968168692849, 'lambda_l1': 9.385238792805085e-06, 'lambda_l2': 5.161454324231525e-07, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:31,401] Trial 23 finished with value: 0.18781196456475427 and parameters: {'learning_rate': 0.012441586157493887, 'num_leaves': 91, 'min_data_in_leaf': 59, 'min_sum_hessian_in_leaf': 0.0019411876361814687, 'feature_fraction': 0.8710638019336724, 'feature_fraction_bynode': 0.7693512925582048, 'bagging_fraction': 0.7623805906925314, 'bagging_freq': 7, 'max_bin': 590, 'min_gain_to_split': 0.49240144169955613, 'lambda_l1': 3.3417628898805275e-05, 'lambda_l2': 1.527963081484261e-06, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:40,591] Trial 24 finished with value: 0.17138930669247088 and parameters: {'learning_rate': 0.021930382116153613, 'num_leaves': 57, 'min_data_in_leaf': 86, 'min_sum_hessian_in_leaf': 0.0039867091764086, 'feature_fraction': 0.8581577962776294, 'feature_fraction_bynode': 0.7170798260907444, 'bagging_fraction': 0.8334282638152125, 'bagging_freq': 10, 'max_bin': 672, 'min_gain_to_split': 0.008172336642664294, 'lambda_l1': 7.461657541752171e-07, 'lambda_l2': 6.204015990715613e-05, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:42,274] Trial 25 finished with value: 0.1910175331601604 and parameters: {'learning_rate': 0.010042851724333113, 'num_leaves': 132, 'min_data_in_leaf': 55, 'min_sum_hessian_in_leaf': 0.008099015583419146, 'feature_fraction': 0.9161460594767526, 'feature_fraction_bynode': 0.6689127993476991, 'bagging_fraction': 0.8014730053338058, 'bagging_freq': 8, 'max_bin': 861, 'min_gain_to_split': 0.8130087450281342, 'lambda_l1': 0.0011042372036562326, 'lambda_l2': 0.0010917765686359335, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:47,712] Trial 26 finished with value: 0.1939774535818652 and parameters: {'learning_rate': 0.014769127208104927, 'num_leaves': 95, 'min_data_in_leaf': 121, 'min_sum_hessian_in_leaf': 0.0018439272163595184, 'feature_fraction': 0.8740885686917772, 'feature_fraction_bynode': 0.6275434321366238, 'bagging_fraction': 0.7737250402034265, 'bagging_freq': 1, 'max_bin': 636, 'min_gain_to_split': 0.3191857524998849, 'lambda_l1': 2.0870344021976102e-07, 'lambda_l2': 1.1590361237919994e-06, 'extra_trees': True}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:49,505] Trial 27 finished with value: 0.18673558557492198 and parameters: {'learning_rate': 0.011585655806478308, 'num_leaves': 158, 'min_data_in_leaf': 51, 'min_sum_hessian_in_leaf': 0.011159506862609038, 'feature_fraction': 0.9255656194800805, 'feature_fraction_bynode': 0.7813292965166285, 'bagging_fraction': 0.9062158661358515, 'bagging_freq': 8, 'max_bin': 750, 'min_gain_to_split': 0.48091674840150356, 'lambda_l1': 0.00010738823114609049, 'lambda_l2': 9.72906526317849e-05, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:50,496] Trial 28 finished with value: 0.1936327003109911 and parameters: {'learning_rate': 0.01790407460718067, 'num_leaves': 60, 'min_data_in_leaf': 81, 'min_sum_hessian_in_leaf': 0.006614684997446671, 'feature_fraction': 0.8294114090789584, 'feature_fraction_bynode': 0.8296862604050086, 'bagging_fraction': 0.8444675045353093, 'bagging_freq': 2, 'max_bin': 493, 'min_gain_to_split': 0.929622502197458, 'lambda_l1': 1.927107727066846e-06, 'lambda_l2': 0.004049043378267737, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:53,304] Trial 29 finished with value: 0.18902617954580406 and parameters: {'learning_rate': 0.038648322485399865, 'num_leaves': 106, 'min_data_in_leaf': 111, 'min_sum_hessian_in_leaf': 0.012740871315216064, 'feature_fraction': 0.8297962138299385, 'feature_fraction_bynode': 0.9441005678297187, 'bagging_fraction': 0.9857662382797725, 'bagging_freq': 1, 'max_bin': 864, 'min_gain_to_split': 0.21210200537606155, 'lambda_l1': 1.9362126168322533e-05, 'lambda_l2': 0.012183419578065765, 'extra_trees': True}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:53,670] Trial 30 finished with value: 0.21261879050551738 and parameters: {'learning_rate': 0.0621570330232365, 'num_leaves': 141, 'min_data_in_leaf': 155, 'min_sum_hessian_in_leaf': 0.0035451721096680924, 'feature_fraction': 0.9103083532776917, 'feature_fraction_bynode': 0.7448793495054603, 'bagging_fraction': 0.8095381742607495, 'bagging_freq': 9, 'max_bin': 933, 'min_gain_to_split': 2.4227547234560953, 'lambda_l1': 0.004931605239788567, 'lambda_l2': 0.07090419636399334, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:56,367] Trial 31 finished with value: 0.17571067850691144 and parameters: {'learning_rate': 0.021585410620586245, 'num_leaves': 40, 'min_data_in_leaf': 87, 'min_sum_hessian_in_leaf': 0.003926618412324082, 'feature_fraction': 0.8648800272990699, 'feature_fraction_bynode': 0.714652568782505, 'bagging_fraction': 0.8377919806838768, 'bagging_freq': 10, 'max_bin': 681, 'min_gain_to_split': 0.03149378042864672, 'lambda_l1': 7.645313248379372e-07, 'lambda_l2': 0.00014740243991635956, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:01:57,751] Trial 32 finished with value: 0.17994502632370807 and parameters: {'learning_rate': 0.022636507279203723, 'num_leaves': 59, 'min_data_in_leaf': 44, 'min_sum_hessian_in_leaf': 0.004222552535698172, 'feature_fraction': 0.9484637621732952, 'feature_fraction_bynode': 0.7097648940199834, 'bagging_fraction': 0.7551681716530594, 'bagging_freq': 9, 'max_bin': 570, 'min_gain_to_split': 0.13917009435357305, 'lambda_l1': 5.931069245873677e-06, 'lambda_l2': 3.5192585323701194e-05, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:00,249] Trial 33 finished with value: 0.18703693583452555 and parameters: {'learning_rate': 0.02797271501010615, 'num_leaves': 74, 'min_data_in_leaf': 73, 'min_sum_hessian_in_leaf': 0.006494463913088352, 'feature_fraction': 0.8584735750437777, 'feature_fraction_bynode': 0.6909759075686877, 'bagging_fraction': 0.786282705040056, 'bagging_freq': 7, 'max_bin': 281, 'min_gain_to_split': 0.3965502082601357, 'lambda_l1': 7.674875379582196e-08, 'lambda_l2': 2.4781340094719033e-06, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:06,720] Trial 34 finished with value: 0.1697036812597114 and parameters: {'learning_rate': 0.02572458029378345, 'num_leaves': 49, 'min_data_in_leaf': 30, 'min_sum_hessian_in_leaf': 0.0018963994109958246, 'feature_fraction': 0.830236998993766, 'feature_fraction_bynode': 0.6460106452550141, 'bagging_fraction': 0.8794744328683152, 'bagging_freq': 10, 'max_bin': 751, 'min_gain_to_split': 0.0023943978107106648, 'lambda_l1': 9.699891417920647e-07, 'lambda_l2': 3.3727390717635627e-07, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:07,989] Trial 35 finished with value: 0.1939249071573772 and parameters: {'learning_rate': 0.025895319432166976, 'num_leaves': 32, 'min_data_in_leaf': 31, 'min_sum_hessian_in_leaf': 0.0020648138261800853, 'feature_fraction': 0.7687114211184137, 'feature_fraction_bynode': 0.6486926809156814, 'bagging_fraction': 0.8810359953251168, 'bagging_freq': 9, 'max_bin': 739, 'min_gain_to_split': 0.6226579303099026, 'lambda_l1': 2.623084857422286e-08, 'lambda_l2': 3.077400556608972e-07, 'extra_trees': True}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:08,429] Trial 36 finished with value: 0.19675281739597866 and parameters: {'learning_rate': 0.05820052859416252, 'num_leaves': 45, 'min_data_in_leaf': 49, 'min_sum_hessian_in_leaf': 0.0010495762395486292, 'feature_fraction': 0.8225627690667404, 'feature_fraction_bynode': 0.6784956123585928, 'bagging_fraction': 0.9374078789773537, 'bagging_freq': 8, 'max_bin': 439, 'min_gain_to_split': 1.44103075934122, 'lambda_l1': 2.5431712563662294e-07, 'lambda_l2': 4.179467069202796e-07, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:09,239] Trial 37 finished with value: 0.1930566686534667 and parameters: {'learning_rate': 0.03504059936993772, 'num_leaves': 82, 'min_data_in_leaf': 183, 'min_sum_hessian_in_leaf': 0.001401146735474624, 'feature_fraction': 0.7967850791418063, 'feature_fraction_bynode': 0.6010036779736924, 'bagging_fraction': 0.7117356639011164, 'bagging_freq': 5, 'max_bin': 636, 'min_gain_to_split': 0.17243322390745236, 'lambda_l1': 0.0002635976785162596, 'lambda_l2': 1.0879678510983134e-08, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:13,680] Trial 38 finished with value: 0.19436294566506757 and parameters: {'learning_rate': 0.012203820742961764, 'num_leaves': 183, 'min_data_in_leaf': 63, 'min_sum_hessian_in_leaf': 0.0022627863054807116, 'feature_fraction': 0.8429512046348856, 'feature_fraction_bynode': 0.6507171942183548, 'bagging_fraction': 0.8608150202042885, 'bagging_freq': 3, 'max_bin': 832, 'min_gain_to_split': 0.5468252094149554, 'lambda_l1': 0.04241964364001599, 'lambda_l2': 1.2383774790477644e-07, 'extra_trees': True}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:14,609] Trial 39 finished with value: 0.2001614970851519 and parameters: {'learning_rate': 0.014687775647477416, 'num_leaves': 124, 'min_data_in_leaf': 43, 'min_sum_hessian_in_leaf': 0.0027137303302921007, 'feature_fraction': 0.815076338142379, 'feature_fraction_bynode': 0.6930768188639473, 'bagging_fraction': 0.745993394615924, 'bagging_freq': 7, 'max_bin': 743, 'min_gain_to_split': 1.682696494005985, 'lambda_l1': 1.807179386068192e-06, 'lambda_l2': 6.393591322971195e-06, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:15,212] Trial 40 finished with value: 0.21439224189151132 and parameters: {'learning_rate': 0.027826595416485363, 'num_leaves': 201, 'min_data_in_leaf': 296, 'min_sum_hessian_in_leaf': 0.0016293096064004516, 'feature_fraction': 0.893973693422137, 'feature_fraction_bynode': 0.8579098604126799, 'bagging_fraction': 0.8833651838720418, 'bagging_freq': 4, 'max_bin': 904, 'min_gain_to_split': 2.0359227920193943, 'lambda_l1': 2.1872844755459662e-05, 'lambda_l2': 0.0007077262775225156, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:21,727] Trial 41 finished with value: 0.1712755376523627 and parameters: {'learning_rate': 0.02416111244708492, 'num_leaves': 54, 'min_data_in_leaf': 88, 'min_sum_hessian_in_leaf': 0.003432990078126227, 'feature_fraction': 0.8504873987022118, 'feature_fraction_bynode': 0.731509178323352, 'bagging_fraction': 0.8387059217715024, 'bagging_freq': 10, 'max_bin': 678, 'min_gain_to_split': 0.006007699641745067, 'lambda_l1': 1.0282019825751751e-06, 'lambda_l2': 3.7925594496524654e-05, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:22,596] Trial 42 finished with value: 0.1836985671492632 and parameters: {'learning_rate': 0.030691865464935467, 'num_leaves': 72, 'min_data_in_leaf': 43, 'min_sum_hessian_in_leaf': 0.0032736340335661144, 'feature_fraction': 0.7830182384110005, 'feature_fraction_bynode': 0.7387707793423225, 'bagging_fraction': 0.7761177794745601, 'bagging_freq': 10, 'max_bin': 599, 'min_gain_to_split': 0.27329568058245984, 'lambda_l1': 6.707217010789401e-06, 'lambda_l2': 3.684046035324671e-06, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:25,720] Trial 43 finished with value: 0.17862808314715278 and parameters: {'learning_rate': 0.02491553632173326, 'num_leaves': 48, 'min_data_in_leaf': 30, 'min_sum_hessian_in_leaf': 0.0027843149097018668, 'feature_fraction': 0.7507477195524206, 'feature_fraction_bynode': 0.7635969136537304, 'bagging_fraction': 0.8088190751732375, 'bagging_freq': 9, 'max_bin': 715, 'min_gain_to_split': 0.13609439850906793, 'lambda_l1': 2.8223230866843876e-07, 'lambda_l2': 6.669992175961249e-07, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:26,871] Trial 44 finished with value: 0.1854646193897526 and parameters: {'learning_rate': 0.01905129550882663, 'num_leaves': 65, 'min_data_in_leaf': 61, 'min_sum_hessian_in_leaf': 0.0010962147855840918, 'feature_fraction': 0.8479997983414153, 'feature_fraction_bynode': 0.8117763781708452, 'bagging_fraction': 0.8454859079825868, 'bagging_freq': 10, 'max_bin': 655, 'min_gain_to_split': 0.360517662705479, 'lambda_l1': 2.5468353490355357e-06, 'lambda_l2': 1.9002284845482732e-07, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:28,030] Trial 45 finished with value: 0.18281987998315105 and parameters: {'learning_rate': 0.023448051693203756, 'num_leaves': 100, 'min_data_in_leaf': 91, 'min_sum_hessian_in_leaf': 0.004743301680430719, 'feature_fraction': 0.8818977475654869, 'feature_fraction_bynode': 0.6986389579207004, 'bagging_fraction': 0.8732549225617456, 'bagging_freq': 10, 'max_bin': 484, 'min_gain_to_split': 0.15322888839928922, 'lambda_l1': 1.3984401031878612e-06, 'lambda_l2': 5.559599168704979e-08, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:29,802] Trial 46 finished with value: 0.1897618167740605 and parameters: {'learning_rate': 0.011369911247408633, 'num_leaves': 49, 'min_data_in_leaf': 139, 'min_sum_hessian_in_leaf': 0.006123788725569043, 'feature_fraction': 0.9303530565991774, 'feature_fraction_bynode': 0.7298327023300942, 'bagging_fraction': 0.8186899122840897, 'bagging_freq': 9, 'max_bin': 540, 'min_gain_to_split': 0.2643757712278856, 'lambda_l1': 0.0008555398942984944, 'lambda_l2': 1.780200288862514e-05, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:33,559] Trial 47 finished with value: 0.18172411532394453 and parameters: {'learning_rate': 0.01617163965282447, 'num_leaves': 84, 'min_data_in_leaf': 74, 'min_sum_hessian_in_leaf': 0.020588647496093782, 'feature_fraction': 0.8067678002673524, 'feature_fraction_bynode': 0.6306741088103037, 'bagging_fraction': 0.7913521063872502, 'bagging_freq': 8, 'max_bin': 817, 'min_gain_to_split': 0.09252559582671924, 'lambda_l1': 1.1019814799937572e-05, 'lambda_l2': 0.0002643631300996798, 'extra_trees': True}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:40,306] Trial 48 finished with value: 0.17005981863089464 and parameters: {'learning_rate': 0.03434815567274163, 'num_leaves': 33, 'min_data_in_leaf': 42, 'min_sum_hessian_in_leaf': 0.008884835629025091, 'feature_fraction': 0.6933442926638762, 'feature_fraction_bynode': 0.7917872428576496, 'bagging_fraction': 0.9027664130816265, 'bagging_freq': 1, 'max_bin': 781, 'min_gain_to_split': 0.004727419350495081, 'lambda_l1': 3.890658948165566e-05, 'lambda_l2': 0.12492847217723037, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:41,613] Trial 49 finished with value: 0.20034878831178915 and parameters: {'learning_rate': 0.04863241958902435, 'num_leaves': 33, 'min_data_in_leaf': 247, 'min_sum_hessian_in_leaf': 0.014605509110408602, 'feature_fraction': 0.6960605356347361, 'feature_fraction_bynode': 0.7874445825094857, 'bagging_fraction': 0.9035317533643, 'bagging_freq': 1, 'max_bin': 774, 'min_gain_to_split': 0.7390463812946401, 'lambda_l1': 3.815132053948579e-05, 'lambda_l2': 1.878374291242257, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:42,282] Trial 50 finished with value: 0.1945081327096787 and parameters: {'learning_rate': 0.03252950778255073, 'num_leaves': 243, 'min_data_in_leaf': 41, 'min_sum_hessian_in_leaf': 0.009709979915131239, 'feature_fraction': 0.7161785779039873, 'feature_fraction_bynode': 0.8437211967617526, 'bagging_fraction': 0.9429423411900266, 'bagging_freq': 2, 'max_bin': 890, 'min_gain_to_split': 1.3183630783652422, 'lambda_l1': 0.0002944426849101682, 'lambda_l2': 0.10688049648763605, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:47,757] Trial 51 finished with value: 0.1708430818990791 and parameters: {'learning_rate': 0.029152400755621324, 'num_leaves': 66, 'min_data_in_leaf': 55, 'min_sum_hessian_in_leaf': 0.00693473606171084, 'feature_fraction': 0.9031761292440061, 'feature_fraction_bynode': 0.7482859390452139, 'bagging_fraction': 0.9185658456964184, 'bagging_freq': 1, 'max_bin': 714, 'min_gain_to_split': 0.01226467402822715, 'lambda_l1': 0.00013375278986636478, 'lambda_l2': 0.03377243439813589, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:51,603] Trial 52 finished with value: 0.1807626598732046 and parameters: {'learning_rate': 0.036549260363304546, 'num_leaves': 46, 'min_data_in_leaf': 55, 'min_sum_hessian_in_leaf': 0.007242583016137048, 'feature_fraction': 0.6558433992810536, 'feature_fraction_bynode': 0.7512834836636887, 'bagging_fraction': 0.9287679027471035, 'bagging_freq': 1, 'max_bin': 777, 'min_gain_to_split': 0.2218145956813325, 'lambda_l1': 0.00011302969689436695, 'lambda_l2': 0.019384725120763027, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:53,401] Trial 53 finished with value: 0.18416567652150898 and parameters: {'learning_rate': 0.04255608460851893, 'num_leaves': 66, 'min_data_in_leaf': 70, 'min_sum_hessian_in_leaf': 0.0052876992383344605, 'feature_fraction': 0.9070057847217053, 'feature_fraction_bynode': 0.8148054900900137, 'bagging_fraction': 0.9001929226688178, 'bagging_freq': 1, 'max_bin': 712, 'min_gain_to_split': 0.40531133623463467, 'lambda_l1': 4.924637065132402e-06, 'lambda_l2': 0.2888690222971311, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:54,679] Trial 54 finished with value: 0.17834521178342735 and parameters: {'learning_rate': 0.03016929857148167, 'num_leaves': 107, 'min_data_in_leaf': 41, 'min_sum_hessian_in_leaf': 0.009413527907281167, 'feature_fraction': 0.9349745126261756, 'feature_fraction_bynode': 0.7949694733663376, 'bagging_fraction': 0.9186948658118325, 'bagging_freq': 2, 'max_bin': 407, 'min_gain_to_split': 0.10644336042244781, 'lambda_l1': 4.28879043098586e-05, 'lambda_l2': 0.005017075891674605, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:55,268] Trial 55 finished with value: 0.18684164970137923 and parameters: {'learning_rate': 0.04946323511305669, 'num_leaves': 86, 'min_data_in_leaf': 30, 'min_sum_hessian_in_leaf': 0.015554861410686302, 'feature_fraction': 0.8995796234348474, 'feature_fraction_bynode': 0.7742029178497172, 'bagging_fraction': 0.9549488849490484, 'bagging_freq': 3, 'max_bin': 755, 'min_gain_to_split': 0.559872764009531, 'lambda_l1': 1.1371702160916718e-05, 'lambda_l2': 0.7471612925815877, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:57,513] Trial 56 finished with value: 0.19190698551574323 and parameters: {'learning_rate': 0.03506462360320889, 'num_leaves': 39, 'min_data_in_leaf': 205, 'min_sum_hessian_in_leaf': 0.008006793897005897, 'feature_fraction': 0.6252110028482489, 'feature_fraction_bynode': 0.7617924681995911, 'bagging_fraction': 0.9198257494517831, 'bagging_freq': 1, 'max_bin': 611, 'min_gain_to_split': 0.29280940736082745, 'lambda_l1': 0.0014569413476753963, 'lambda_l2': 0.04249127669688876, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:02:58,887] Trial 57 finished with value: 0.17974990560829965 and parameters: {'learning_rate': 0.02621070422726987, 'num_leaves': 68, 'min_data_in_leaf': 60, 'min_sum_hessian_in_leaf': 0.02731198482723057, 'feature_fraction': 0.8823851863015493, 'feature_fraction_bynode': 0.6661681351688336, 'bagging_fraction': 0.8918265183817674, 'bagging_freq': 2, 'max_bin': 510, 'min_gain_to_split': 0.1105876849355392, 'lambda_l1': 2.1266762150297408e-05, 'lambda_l2': 0.1334503402224261, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:03:00,016] Trial 58 finished with value: 0.2055495831503404 and parameters: {'learning_rate': 0.010988913023949866, 'num_leaves': 151, 'min_data_in_leaf': 104, 'min_sum_hessian_in_leaf': 0.010961557322652313, 'feature_fraction': 0.935149354088408, 'feature_fraction_bynode': 0.7836487779089768, 'bagging_fraction': 0.8682446080150262, 'bagging_freq': 6, 'max_bin': 568, 'min_gain_to_split': 2.326103050061566, 'lambda_l1': 0.00017827133485754144, 'lambda_l2': 0.03165248425846239, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:03:08,626] Trial 59 finished with value: 0.17522850232921644 and parameters: {'learning_rate': 0.012789958660612735, 'num_leaves': 80, 'min_data_in_leaf': 50, 'min_sum_hessian_in_leaf': 0.004318648888792994, 'feature_fraction': 0.920364317870164, 'feature_fraction_bynode': 0.7531260328411515, 'bagging_fraction': 0.8548694700376643, 'bagging_freq': 3, 'max_bin': 838, 'min_gain_to_split': 0.013455629903124282, 'lambda_l1': 3.2724574067916347e-06, 'lambda_l2': 0.5940246636040667, 'extra_trees': True}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:03:11,276] Trial 60 finished with value: 0.18525685239822956 and parameters: {'learning_rate': 0.020246040209050215, 'num_leaves': 92, 'min_data_in_leaf': 77, 'min_sum_hessian_in_leaf': 0.0057384508984297785, 'feature_fraction': 0.8757998792524223, 'feature_fraction_bynode': 0.7986748826144919, 'bagging_fraction': 0.956939581443201, 'bagging_freq': 1, 'max_bin': 804, 'min_gain_to_split': 0.4161795015274778, 'lambda_l1': 0.00047249342928410635, 'lambda_l2': 0.0014452059283355295, 'extra_trees': False}. Best is trial 22 with value: 0.16929724099182458.
# [I 2025-09-05 06:03:19,156] Trial 61 finished with value: 0.16915700564024888 and parameters: {'learning_rate': 0.02899667063799121, 'num_leaves': 55, 'min_data_in_leaf': 37, 'min_sum_hessian_in_leaf': 0.0034697286635163084, 'feature_fraction': 0.8438730794108039, 'feature_fraction_bynode': 0.7356787820458489, 'bagging_fraction': 0.894268363720718, 'bagging_freq': 2, 'max_bin': 661, 'min_gain_to_split': 0.00528335249688709, 'lambda_l1': 5.035209648458265e-07, 'lambda_l2': 0.0068218346128700496, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:03:20,169] Trial 62 finished with value: 0.18004568407420074 and parameters: {'learning_rate': 0.03225793476634805, 'num_leaves': 60, 'min_data_in_leaf': 38, 'min_sum_hessian_in_leaf': 0.003051504548156303, 'feature_fraction': 0.6823564577450532, 'feature_fraction_bynode': 0.739383554455384, 'bagging_fraction': 0.8933102349629798, 'bagging_freq': 2, 'max_bin': 717, 'min_gain_to_split': 0.18886516250253702, 'lambda_l1': 3.586888498816908e-07, 'lambda_l2': 0.006755147480164438, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:03:21,162] Trial 63 finished with value: 0.18282694614468736 and parameters: {'learning_rate': 0.029214742227470374, 'num_leaves': 53, 'min_data_in_leaf': 53, 'min_sum_hessian_in_leaf': 0.0023287017185765133, 'feature_fraction': 0.8426035190059269, 'feature_fraction_bynode': 0.706473409132826, 'bagging_fraction': 0.8773842571739469, 'bagging_freq': 2, 'max_bin': 647, 'min_gain_to_split': 0.28071731190833843, 'lambda_l1': 1.0446804885659076e-07, 'lambda_l2': 0.01953077012280966, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:03:39,169] Trial 64 finished with value: 0.1708554882213163 and parameters: {'learning_rate': 0.010021676606112738, 'num_leaves': 118, 'min_data_in_leaf': 67, 'min_sum_hessian_in_leaf': 0.0068904135463433375, 'feature_fraction': 0.9077831829283383, 'feature_fraction_bynode': 0.773530032638421, 'bagging_fraction': 0.9267994623395596, 'bagging_freq': 2, 'max_bin': 615, 'min_gain_to_split': 0.00037257598621049173, 'lambda_l1': 7.649839873223891e-07, 'lambda_l2': 0.0023642988289382023, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:03:45,910] Trial 65 finished with value: 0.17750896293007518 and parameters: {'learning_rate': 0.010254475594653454, 'num_leaves': 165, 'min_data_in_leaf': 37, 'min_sum_hessian_in_leaf': 0.09785410616258698, 'feature_fraction': 0.8989837069119246, 'feature_fraction_bynode': 0.7744063016476138, 'bagging_fraction': 0.9692950013627558, 'bagging_freq': 1, 'max_bin': 620, 'min_gain_to_split': 0.10496242117420332, 'lambda_l1': 1.636784311732114e-07, 'lambda_l2': 0.010314424645930726, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:01,347] Trial 66 finished with value: 0.17040330990696578 and parameters: {'learning_rate': 0.013386453170551165, 'num_leaves': 128, 'min_data_in_leaf': 70, 'min_sum_hessian_in_leaf': 0.007147135048694258, 'feature_fraction': 0.7445318960828722, 'feature_fraction_bynode': 0.8204655934942592, 'bagging_fraction': 0.9220252988362796, 'bagging_freq': 3, 'max_bin': 661, 'min_gain_to_split': 7.779360784545934e-05, 'lambda_l1': 4.513978631983825e-08, 'lambda_l2': 0.0015565839621734595, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:03,170] Trial 67 finished with value: 0.18160272427582413 and parameters: {'learning_rate': 0.013243957840021928, 'num_leaves': 133, 'min_data_in_leaf': 48, 'min_sum_hessian_in_leaf': 0.0130664202934361, 'feature_fraction': 0.725924955774458, 'feature_fraction_bynode': 0.8808927819731787, 'bagging_fraction': 0.9124211930998742, 'bagging_freq': 4, 'max_bin': 733, 'min_gain_to_split': 0.21467734735263455, 'lambda_l1': 1.0650042589245543e-08, 'lambda_l2': 0.0012416310189841185, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:05,120] Trial 68 finished with value: 0.18424566696613937 and parameters: {'learning_rate': 0.011749925967668747, 'num_leaves': 145, 'min_data_in_leaf': 58, 'min_sum_hessian_in_leaf': 0.008934234167265675, 'feature_fraction': 0.671992390742872, 'feature_fraction_bynode': 0.8426639583526381, 'bagging_fraction': 0.8949270354726747, 'bagging_freq': 3, 'max_bin': 766, 'min_gain_to_split': 0.35530235069506655, 'lambda_l1': 3.0315382993136065e-08, 'lambda_l2': 0.008998182494118191, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:07,103] Trial 69 finished with value: 0.17770107719693756 and parameters: {'learning_rate': 0.07920718511610736, 'num_leaves': 31, 'min_data_in_leaf': 38, 'min_sum_hessian_in_leaf': 0.0016364745652707015, 'feature_fraction': 0.756834637055408, 'feature_fraction_bynode': 0.8158827127034978, 'bagging_fraction': 0.937723025099856, 'bagging_freq': 4, 'max_bin': 658, 'min_gain_to_split': 0.08608491230209653, 'lambda_l1': 4.3859401998188175e-08, 'lambda_l2': 0.000264908377639098, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:07,611] Trial 70 finished with value: 0.20683724481315865 and parameters: {'learning_rate': 0.03769557584191842, 'num_leaves': 171, 'min_data_in_leaf': 30, 'min_sum_hessian_in_leaf': 0.005581465446743396, 'feature_fraction': 0.7344025328147961, 'feature_fraction_bynode': 0.8220932307266582, 'bagging_fraction': 0.9065442265147662, 'bagging_freq': 3, 'max_bin': 698, 'min_gain_to_split': 2.9865859540769293, 'lambda_l1': 5.164706644054293e-07, 'lambda_l2': 0.08121119243828627, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:24,000] Trial 71 finished with value: 0.1705274515123617 and parameters: {'learning_rate': 0.010017506319449941, 'num_leaves': 119, 'min_data_in_leaf': 69, 'min_sum_hessian_in_leaf': 0.004601784846796488, 'feature_fraction': 0.8655676934138475, 'feature_fraction_bynode': 0.7465989547652331, 'bagging_fraction': 0.926977365321137, 'bagging_freq': 2, 'max_bin': 788, 'min_gain_to_split': 0.005323711760664178, 'lambda_l1': 7.100900360923459e-07, 'lambda_l2': 0.0024279746240156875, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:26,216] Trial 72 finished with value: 0.18229847784617953 and parameters: {'learning_rate': 0.010963339931863842, 'num_leaves': 118, 'min_data_in_leaf': 65, 'min_sum_hessian_in_leaf': 0.007341189684916305, 'feature_fraction': 0.8669306940725118, 'feature_fraction_bynode': 0.7281770075686202, 'bagging_fraction': 0.9195067154718851, 'bagging_freq': 2, 'max_bin': 797, 'min_gain_to_split': 0.20137380754797157, 'lambda_l1': 8.076677416468003e-06, 'lambda_l2': 0.0021440849177975225, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:27,615] Trial 73 finished with value: 0.17835216654004926 and parameters: {'learning_rate': 0.026970672438405632, 'num_leaves': 126, 'min_data_in_leaf': 45, 'min_sum_hessian_in_leaf': 0.004037282389052042, 'feature_fraction': 0.8346358441793491, 'feature_fraction_bynode': 0.6824934005333414, 'bagging_fraction': 0.9251373487949022, 'bagging_freq': 5, 'max_bin': 670, 'min_gain_to_split': 0.077532290644165, 'lambda_l1': 8.877322759462815e-05, 'lambda_l2': 0.004664050557967373, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:29,502] Trial 74 finished with value: 0.18471415685841558 and parameters: {'learning_rate': 0.011894365305874588, 'num_leaves': 107, 'min_data_in_leaf': 79, 'min_sum_hessian_in_leaf': 0.004587849289039699, 'feature_fraction': 0.8195539389031465, 'feature_fraction_bynode': 0.7150368812443267, 'bagging_fraction': 0.9443734860540854, 'bagging_freq': 3, 'max_bin': 729, 'min_gain_to_split': 0.3196920281496399, 'lambda_l1': 1.1987590912899205e-06, 'lambda_l2': 0.00045320036447048966, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:34,089] Trial 75 finished with value: 0.18601432846077393 and parameters: {'learning_rate': 0.01463351701716884, 'num_leaves': 135, 'min_data_in_leaf': 55, 'min_sum_hessian_in_leaf': 0.011000717433734299, 'feature_fraction': 0.7840558602138739, 'feature_fraction_bynode': 0.7433994923539631, 'bagging_fraction': 0.9654625837126303, 'bagging_freq': 1, 'max_bin': 790, 'min_gain_to_split': 0.5263521476010852, 'lambda_l1': 2.0368783066585616e-08, 'lambda_l2': 0.023763915692667656, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:37,660] Trial 76 finished with value: 0.18314239657300774 and parameters: {'learning_rate': 0.013813662970018962, 'num_leaves': 42, 'min_data_in_leaf': 37, 'min_sum_hessian_in_leaf': 0.005048274815299743, 'feature_fraction': 0.8557508344101907, 'feature_fraction_bynode': 0.7225159990949716, 'bagging_fraction': 0.9090261690312426, 'bagging_freq': 2, 'max_bin': 830, 'min_gain_to_split': 0.1690297365713609, 'lambda_l1': 1.457237336549311e-07, 'lambda_l2': 0.0007775434450722183, 'extra_trees': True}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:40,037] Trial 77 finished with value: 0.18063239734205733 and parameters: {'learning_rate': 0.040474328165911344, 'num_leaves': 151, 'min_data_in_leaf': 121, 'min_sum_hessian_in_leaf': 0.007719028267645259, 'feature_fraction': 0.7035471118616836, 'feature_fraction_bynode': 0.7604105687998776, 'bagging_fraction': 0.8887953063719166, 'bagging_freq': 1, 'max_bin': 760, 'min_gain_to_split': 0.06861371026617688, 'lambda_l1': 3.018827062828751e-06, 'lambda_l2': 0.16698387599731146, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:40,904] Trial 78 finished with value: 0.1830754479548212 and parameters: {'learning_rate': 0.03422879686169965, 'num_leaves': 141, 'min_data_in_leaf': 69, 'min_sum_hessian_in_leaf': 0.006103350112535924, 'feature_fraction': 0.8890235122181788, 'feature_fraction_bynode': 0.8033760805125354, 'bagging_fraction': 0.9334657165730902, 'bagging_freq': 2, 'max_bin': 691, 'min_gain_to_split': 0.2274328004275415, 'lambda_l1': 6.080168505973292e-08, 'lambda_l2': 0.003499015814503229, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:42,442] Trial 79 finished with value: 0.19009709654888668 and parameters: {'learning_rate': 0.010618652941794543, 'num_leaves': 99, 'min_data_in_leaf': 94, 'min_sum_hessian_in_leaf': 0.003587773629574705, 'feature_fraction': 0.8324789553503543, 'feature_fraction_bynode': 0.7828950052036692, 'bagging_fraction': 0.7447846895455541, 'bagging_freq': 7, 'max_bin': 891, 'min_gain_to_split': 0.42974230481355463, 'lambda_l1': 3.9537667392345383e-07, 'lambda_l2': 0.042432652563464734, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:04:51,194] Trial 80 finished with value: 0.1725458073609895 and parameters: {'learning_rate': 0.011186828311899627, 'num_leaves': 123, 'min_data_in_leaf': 50, 'min_sum_hessian_in_leaf': 0.0030719665143012446, 'feature_fraction': 0.7982840670029494, 'feature_fraction_bynode': 0.8325668843593452, 'bagging_fraction': 0.9152015411313258, 'bagging_freq': 1, 'max_bin': 334, 'min_gain_to_split': 0.022732446643533154, 'lambda_l1': 1.786024437056468e-05, 'lambda_l2': 0.013937896910665137, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:05:11,071] Trial 81 finished with value: 0.17061608773794873 and parameters: {'learning_rate': 0.010036765344727135, 'num_leaves': 114, 'min_data_in_leaf': 66, 'min_sum_hessian_in_leaf': 0.006912424452593174, 'feature_fraction': 0.9157481394895182, 'feature_fraction_bynode': 0.7482102558519895, 'bagging_fraction': 0.9286257582555852, 'bagging_freq': 2, 'max_bin': 628, 'min_gain_to_split': 0.0015561979917893107, 'lambda_l1': 9.741071476673208e-07, 'lambda_l2': 0.002229968429271416, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:05:13,785] Trial 82 finished with value: 0.1795006730956689 and parameters: {'learning_rate': 0.010382159053287758, 'num_leaves': 111, 'min_data_in_leaf': 58, 'min_sum_hessian_in_leaf': 0.006720575001004273, 'feature_fraction': 0.9142468893931667, 'feature_fraction_bynode': 0.7474630750109919, 'bagging_fraction': 0.7734497922072208, 'bagging_freq': 4, 'max_bin': 731, 'min_gain_to_split': 0.11216121681462526, 'lambda_l1': 2.194668781599353e-06, 'lambda_l2': 0.0013605427560477983, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# ...
# [I 2025-09-05 06:06:06,578] Trial 93 finished with value: 0.17524978559178034 and parameters: {'learning_rate': 0.0111669272353969, 'num_leaves': 120, 'min_data_in_leaf': 36, 'min_sum_hessian_in_leaf': 0.013879837181819444, 'feature_fraction': 0.8541791046745474, 'feature_fraction_bynode': 0.7388700587571395, 'bagging_fraction': 0.9467584731565446, 'bagging_freq': 1, 'max_bin': 458, 'min_gain_to_split': 0.055764426117181326, 'lambda_l1': 6.902366080050274e-05, 'lambda_l2': 4.562305005798929e-06, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:08,638] Trial 94 finished with value: 0.18366729973329882 and parameters: {'learning_rate': 0.010799811995195542, 'num_leaves': 112, 'min_data_in_leaf': 41, 'min_sum_hessian_in_leaf': 0.012114741470950529, 'feature_fraction': 0.8748856341235113, 'feature_fraction_bynode': 0.7576931663430145, 'bagging_fraction': 0.8622733772756546, 'bagging_freq': 2, 'max_bin': 696, 'min_gain_to_split': 0.3461554377691131, 'lambda_l1': 2.8343582720484807e-05, 'lambda_l2': 1.9458041271679864e-06, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:22,628] Trial 95 finished with value: 0.16932556689725325 and parameters: {'learning_rate': 0.011636582611240657, 'num_leaves': 138, 'min_data_in_leaf': 31, 'min_sum_hessian_in_leaf': 0.010196974025466326, 'feature_fraction': 0.8155211723760908, 'feature_fraction_bynode': 0.7800767310183906, 'bagging_fraction': 0.8804908580186999, 'bagging_freq': 3, 'max_bin': 552, 'min_gain_to_split': 0.006786151980845992, 'lambda_l1': 1.53684212406357e-05, 'lambda_l2': 2.5286862939103135e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:26,853] Trial 96 finished with value: 0.17828289295370495 and parameters: {'learning_rate': 0.012324389555970787, 'num_leaves': 158, 'min_data_in_leaf': 30, 'min_sum_hessian_in_leaf': 0.01789371946231093, 'feature_fraction': 0.811464189074628, 'feature_fraction_bynode': 0.7788049787050249, 'bagging_fraction': 0.8841161487942568, 'bagging_freq': 3, 'max_bin': 465, 'min_gain_to_split': 0.14438794337779431, 'lambda_l1': 5.213627697536757e-05, 'lambda_l2': 3.458794724306497e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:28,216] Trial 97 finished with value: 0.19057559664699522 and parameters: {'learning_rate': 0.01536608050008743, 'num_leaves': 151, 'min_data_in_leaf': 153, 'min_sum_hessian_in_leaf': 0.00982901834240612, 'feature_fraction': 0.8393459628356212, 'feature_fraction_bynode': 0.8234283126729429, 'bagging_fraction': 0.8792493580182332, 'bagging_freq': 4, 'max_bin': 515, 'min_gain_to_split': 0.23486647651968634, 'lambda_l1': 0.0002174723383911183, 'lambda_l2': 2.1756282328331759e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:43,272] Trial 98 finished with value: 0.16955149169272463 and parameters: {'learning_rate': 0.010552653132199132, 'num_leaves': 130, 'min_data_in_leaf': 36, 'min_sum_hessian_in_leaf': 0.017108734888187718, 'feature_fraction': 0.646921232620431, 'feature_fraction_bynode': 0.7921055921251786, 'bagging_fraction': 0.8966773201118156, 'bagging_freq': 8, 'max_bin': 550, 'min_gain_to_split': 0.0034086696681878232, 'lambda_l1': 1.9293367872557544e-06, 'lambda_l2': 9.445783858465803e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:45,388] Trial 99 finished with value: 0.17853494780705442 and parameters: {'learning_rate': 0.013213064430368179, 'num_leaves': 138, 'min_data_in_leaf': 36, 'min_sum_hessian_in_leaf': 0.019180815765411276, 'feature_fraction': 0.6544654265623341, 'feature_fraction_bynode': 0.8011134724853601, 'bagging_fraction': 0.8975725843699796, 'bagging_freq': 7, 'max_bin': 545, 'min_gain_to_split': 0.15462877246415202, 'lambda_l1': 1.2390285195188552e-05, 'lambda_l2': 9.256755882826944e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:46,970] Trial 100 finished with value: 0.20341130497242688 and parameters: {'learning_rate': 0.011563364239448624, 'num_leaves': 132, 'min_data_in_leaf': 42, 'min_sum_hessian_in_leaf': 0.016842677958390635, 'feature_fraction': 0.8242802892231704, 'feature_fraction_bynode': 0.8072810545319994, 'bagging_fraction': 0.8482178924684274, 'bagging_freq': 8, 'max_bin': 556, 'min_gain_to_split': 1.6043070098083843, 'lambda_l1': 2.2760739415846723e-05, 'lambda_l2': 7.633176586699579e-07, 'extra_trees': True}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:06:51,923] Trial 101 finished with value: 0.17552732787876393 and parameters: {'learning_rate': 0.010564563559391636, 'num_leaves': 122, 'min_data_in_leaf': 35, 'min_sum_hessian_in_leaf': 0.024015596944700734, 'feature_fraction': 0.602343729321175, 'feature_fraction_bynode': 0.7869099873348555, 'bagging_fraction': 0.8708970494447478, 'bagging_freq': 9, 'max_bin': 533, 'min_gain_to_split': 0.06192439231875649, 'lambda_l1': 2.420136260087045e-06, 'lambda_l2': 2.952285728140701e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:00,732] Trial 102 finished with value: 0.17027389598274473 and parameters: {'learning_rate': 0.011835941840380663, 'num_leaves': 130, 'min_data_in_leaf': 47, 'min_sum_hessian_in_leaf': 0.01141038716046752, 'feature_fraction': 0.6657948148551895, 'feature_fraction_bynode': 0.7711042218569599, 'bagging_fraction': 0.9096276734802249, 'bagging_freq': 6, 'max_bin': 590, 'min_gain_to_split': 0.011344437867686599, 'lambda_l1': 1.462495993703016e-05, 'lambda_l2': 2.634176366450198e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:04,991] Trial 103 finished with value: 0.1777286817358353 and parameters: {'learning_rate': 0.012677818232221789, 'num_leaves': 129, 'min_data_in_leaf': 47, 'min_sum_hessian_in_leaf': 0.011140659328880639, 'feature_fraction': 0.6160968210169229, 'feature_fraction_bynode': 0.7941442891208896, 'bagging_fraction': 0.8903518670436789, 'bagging_freq': 7, 'max_bin': 604, 'min_gain_to_split': 0.0839039416472449, 'lambda_l1': 1.6305172982998965e-05, 'lambda_l2': 3.00257323387634e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:07,299] Trial 104 finished with value: 0.17952182498846836 and parameters: {'learning_rate': 0.011925759507493021, 'num_leaves': 147, 'min_data_in_leaf': 51, 'min_sum_hessian_in_leaf': 0.012396732201396176, 'feature_fraction': 0.650824000837982, 'feature_fraction_bynode': 0.7704687951022247, 'bagging_fraction': 0.9119161204326873, 'bagging_freq': 6, 'max_bin': 584, 'min_gain_to_split': 0.13532442299143596, 'lambda_l1': 4.706613200294198e-06, 'lambda_l2': 7.455842267652976e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:09,051] Trial 105 finished with value: 0.180917004219678 and parameters: {'learning_rate': 0.014223175527282458, 'num_leaves': 164, 'min_data_in_leaf': 33, 'min_sum_hessian_in_leaf': 0.015285089695371108, 'feature_fraction': 0.6644007996648628, 'feature_fraction_bynode': 0.7751226060805455, 'bagging_fraction': 0.9053529872675072, 'bagging_freq': 5, 'max_bin': 565, 'min_gain_to_split': 0.27453505616387935, 'lambda_l1': 7.357703203266814e-06, 'lambda_l2': 1.2937196963526489e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:10,066] Trial 106 finished with value: 0.20586928355983183 and parameters: {'learning_rate': 0.011199211288688603, 'num_leaves': 137, 'min_data_in_leaf': 41, 'min_sum_hessian_in_leaf': 0.008853799262778992, 'feature_fraction': 0.6862886491244968, 'feature_fraction_bynode': 0.8543752853064727, 'bagging_fraction': 0.8797959966649411, 'bagging_freq': 8, 'max_bin': 520, 'min_gain_to_split': 2.7016772244607554, 'lambda_l1': 0.00013763228793962378, 'lambda_l2': 6.285772257484718e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:14,214] Trial 107 finished with value: 0.1846623993803072 and parameters: {'learning_rate': 0.011480511248377628, 'num_leaves': 176, 'min_data_in_leaf': 180, 'min_sum_hessian_in_leaf': 0.013782490279726719, 'feature_fraction': 0.6370815495230467, 'feature_fraction_bynode': 0.7817764353056154, 'bagging_fraction': 0.7819386053402076, 'bagging_freq': 9, 'max_bin': 485, 'min_gain_to_split': 0.05243468118531727, 'lambda_l1': 2.9207742235849182e-05, 'lambda_l2': 3.707812693435983e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:18,008] Trial 108 finished with value: 0.17916557610903291 and parameters: {'learning_rate': 0.013199669076425368, 'num_leaves': 192, 'min_data_in_leaf': 30, 'min_sum_hessian_in_leaf': 0.010356803090239312, 'feature_fraction': 0.6323157903942207, 'feature_fraction_bynode': 0.7026948353037459, 'bagging_fraction': 0.803042177269008, 'bagging_freq': 6, 'max_bin': 649, 'min_gain_to_split': 0.19593563389834698, 'lambda_l1': 1.8881226077544613e-06, 'lambda_l2': 1.0890223486960123e-06, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:19,254] Trial 109 finished with value: 0.18527368709439346 and parameters: {'learning_rate': 0.0172087970262361, 'num_leaves': 108, 'min_data_in_leaf': 60, 'min_sum_hessian_in_leaf': 0.016934977866844957, 'feature_fraction': 0.6647247385823489, 'feature_fraction_bynode': 0.6552406951788071, 'bagging_fraction': 0.8553981148494595, 'bagging_freq': 8, 'max_bin': 604, 'min_gain_to_split': 0.3838643328560651, 'lambda_l1': 0.0005055974014205462, 'lambda_l2': 1.0939737967129366e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:22,055] Trial 110 finished with value: 0.1799792500862937 and parameters: {'learning_rate': 0.010648594456932337, 'num_leaves': 137, 'min_data_in_leaf': 54, 'min_sum_hessian_in_leaf': 0.007834582099323785, 'feature_fraction': 0.94201684243681, 'feature_fraction_bynode': 0.7560249145772238, 'bagging_fraction': 0.8970700603709676, 'bagging_freq': 4, 'max_bin': 744, 'min_gain_to_split': 0.11790743727418176, 'lambda_l1': 0.28552300426642857, 'lambda_l2': 2.758863176285345e-06, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:39,173] Trial 111 finished with value: 0.17026103880636717 and parameters: {'learning_rate': 0.010443467760047738, 'num_leaves': 119, 'min_data_in_leaf': 47, 'min_sum_hessian_in_leaf': 0.01163848123878587, 'feature_fraction': 0.6809511760923364, 'feature_fraction_bynode': 0.7668284546495665, 'bagging_fraction': 0.9218455811841973, 'bagging_freq': 3, 'max_bin': 818, 'min_gain_to_split': 0.002525623799122735, 'lambda_l1': 1.4426003700098386e-05, 'lambda_l2': 2.354380564582926e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:49,549] Trial 112 finished with value: 0.17013997247192306 and parameters: {'learning_rate': 0.012496512417159194, 'num_leaves': 124, 'min_data_in_leaf': 47, 'min_sum_hessian_in_leaf': 0.011925114675615476, 'feature_fraction': 0.6853762117213095, 'feature_fraction_bynode': 0.7671931583257546, 'bagging_fraction': 0.9211526257378895, 'bagging_freq': 3, 'max_bin': 823, 'min_gain_to_split': 0.009108420549325744, 'lambda_l1': 1.3340405623250431e-05, 'lambda_l2': 2.667373845644155e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:50,559] Trial 113 finished with value: 0.18055642646825065 and parameters: {'learning_rate': 0.03172239287290898, 'num_leaves': 128, 'min_data_in_leaf': 38, 'min_sum_hessian_in_leaf': 0.02214054618873073, 'feature_fraction': 0.6808778186552075, 'feature_fraction_bynode': 0.7924321921181242, 'bagging_fraction': 0.9371605861045694, 'bagging_freq': 3, 'max_bin': 827, 'min_gain_to_split': 0.19184219243325512, 'lambda_l1': 1.4165574612742998e-05, 'lambda_l2': 2.583200100389421e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:56,057] Trial 114 finished with value: 0.176345519629226 and parameters: {'learning_rate': 0.010391448851228677, 'num_leaves': 148, 'min_data_in_leaf': 48, 'min_sum_hessian_in_leaf': 0.014146323592396029, 'feature_fraction': 0.6900433574324376, 'feature_fraction_bynode': 0.807454374231023, 'bagging_fraction': 0.9235324289227208, 'bagging_freq': 3, 'max_bin': 873, 'min_gain_to_split': 0.051095652955170455, 'lambda_l1': 3.2556397624073947e-06, 'lambda_l2': 5.084481819005677e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:07:58,449] Trial 115 finished with value: 0.17950074367452437 and parameters: {'learning_rate': 0.01211910266867807, 'num_leaves': 155, 'min_data_in_leaf': 57, 'min_sum_hessian_in_leaf': 0.011912318281648562, 'feature_fraction': 0.6421825854870984, 'feature_fraction_bynode': 0.7682418851508449, 'bagging_fraction': 0.9049797575061552, 'bagging_freq': 6, 'max_bin': 781, 'min_gain_to_split': 0.12066073682874803, 'lambda_l1': 9.717438931376802e-06, 'lambda_l2': 1.7157963978664984e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:08:00,580] Trial 116 finished with value: 0.18076499839378193 and parameters: {'learning_rate': 0.011028772296241213, 'num_leaves': 144, 'min_data_in_leaf': 34, 'min_sum_hessian_in_leaf': 0.012899523321874662, 'feature_fraction': 0.6758485167179227, 'feature_fraction_bynode': 0.7870508815773253, 'bagging_fraction': 0.9140940762158407, 'bagging_freq': 10, 'max_bin': 758, 'min_gain_to_split': 0.2497062307331393, 'lambda_l1': 5.74031343812192e-06, 'lambda_l2': 1.7046327103689923e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:08:01,838] Trial 117 finished with value: 0.1761464521836386 and parameters: {'learning_rate': 0.03423715414185264, 'num_leaves': 43, 'min_data_in_leaf': 43, 'min_sum_hessian_in_leaf': 0.010452143119813899, 'feature_fraction': 0.7009402730167628, 'feature_fraction_bynode': 0.7348322460038026, 'bagging_fraction': 0.8910588254524509, 'bagging_freq': 4, 'max_bin': 800, 'min_gain_to_split': 0.05821596096905748, 'lambda_l1': 3.829850872625028e-05, 'lambda_l2': 5.0600878055602484e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:08:03,645] Trial 118 finished with value: 0.18533243214221296 and parameters: {'learning_rate': 0.01261609254725145, 'num_leaves': 124, 'min_data_in_leaf': 131, 'min_sum_hessian_in_leaf': 0.011549131654471282, 'feature_fraction': 0.6704148616605103, 'feature_fraction_bynode': 0.7775116427778866, 'bagging_fraction': 0.9098210759266656, 'bagging_freq': 3, 'max_bin': 841, 'min_gain_to_split': 0.17512093615865204, 'lambda_l1': 1.6738065251641077e-05, 'lambda_l2': 1.1858934568381814e-07, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [I 2025-09-05 06:08:04,883] Trial 119 finished with value: 0.1912224029231279 and parameters: {'learning_rate': 0.013563481431560505, 'num_leaves': 133, 'min_data_in_leaf': 52, 'min_sum_hessian_in_leaf': 0.009499292723429007, 'feature_fraction': 0.7130078864838496, 'feature_fraction_bynode': 0.7976607808452629, 'bagging_fraction': 0.9192806056011529, 'bagging_freq': 7, 'max_bin': 822, 'min_gain_to_split': 0.8609512479431076, 'lambda_l1': 2.3157689906769292e-05, 'lambda_l2': 7.86681063603434e-08, 'extra_trees': False}. Best is trial 61 with value: 0.16915700564024888.
# [Train/In-sample] MAE: 7,274,221 JPY  |  RMSLE: 0.11751
# Saved models → models

# %%
import matplotlib.pyplot as plt

# 重要度を取得
importance = model_point.feature_importance(importance_type="gain")
feature_names = model_point.feature_name()

# DataFrame化
import pandas as pd
fi = pd.DataFrame({
    "feature": feature_names,
    "importance": importance
}).sort_values("importance", ascending=False)

print(fi)

# 棒グラフで可視化
plt.figure(figsize=(8, 6))
plt.barh(fi["feature"], fi["importance"])
plt.gca().invert_yaxis()
plt.title("Feature Importance (by gain)")
plt.show()
# Out:
#                         feature   importance
# 5                      area_sqm  8510.022296
# 7                     sqrt_area  3594.138701
# 14        layout_oof_median_log  2905.378586
# 15  station_year_oof_median_log  2324.067183
# 4                           築年数  2310.731418
# 13       station_oof_median_log  1726.316828
# 8                      log_area  1663.928940
# 1                   cat__layout  1158.053422
# 10                area_x_access   805.343760
# 16  station_half_oof_median_log   800.067077
# 9                      age_sqrt   724.034992
# 0                  cat__station   610.885138
# 11                station_count   437.670489
# 3                      walk_min   120.685277
# 2             cat__txn_year_int    81.345600
# 12                 layout_count    65.883743
# 6                  access_score    52.952839
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.48.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
import shap

# 学習済みモデル（model_point）と学習データ（X_df）がある前提

# SHAPのExplainerを作成
explainer = shap.TreeExplainer(model_point)
shap_values = explainer.shap_values(X_df)

# ① 全体の重要度＋影響方向（サマリープロット）
shap.summary_plot(shap_values, X_df, plot_type="dot")

# ② 棒グラフ版（特徴量の寄与度だけ）
shap.summary_plot(shap_values, X_df, plot_type="bar")

# ③ 個別予測の説明（1件だけ取り出す例）
shap.force_plot(explainer.expected_value, shap_values[0,:], X_df.iloc[0,:])
# Out:
# /tmp/ipython-input-550421581.py:10: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_df, plot_type="dot")
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipython-input-550421581.py:13: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_df, plot_type="bar")
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <div id='i55548RMZJOF0B52GFPQ1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.0724968622384106, "outValue": -0.5043035775080149, "link": "identity", "featureNames": ["cat__station", "cat__layout", "cat__txn_year_int", "walk_min", "\u7bc9\u5e74\u6570", "area_sqm", "access_score", "sqrt_area", "log_area", "age_sqrt", "area_x_access", "station_count", "layout_count", "station_oof_median_log", "layout_oof_median_log", "station_year_oof_median_log", "station_half_oof_median_log"], "features": {"0": {"effect": 0.05545406771587188, "value": 8.0}, "1": {"effect": -0.010545295979101029, "value": 3.0}, "2": {"effect": -0.02776287126706382, "value": 0.0}, "3": {"effect": 0.004379994207985302, "value": 3.0}, "4": {"effect": -0.2974063825435131, "value": 43.0}, "5": {"effect": -0.07928191895606017, "value": 45.0}, "6": {"effect": 0.0016834152836276957, "value": 0.25}, "7": {"effect": -0.03643915433639187, "value": 6.708203932499369}, "8": {"effect": -0.029594528405351147, "value": 3.828641396489095}, "9": {"effect": -0.10704839137179926, "value": 6.557438524302}, "10": {"effect": 0.008913966484494341, "value": 11.25}, "11": {"effect": 0.006627013641145724, "value": 335.0}, "12": {"effect": -0.0002664172241531358, "value": 1130.0}, "13": {"effect": 0.010707354689310465, "value": 17.858561843342684}, "14": {"effect": 0.020445395977355712, "value": 17.87595358575207}, "15": {"effect": 0.03856574855460951, "value": 17.884500802285608}, "16": {"effect": 0.009761288259428612, "value": 17.884500802285608}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i55548RMZJOF0B52GFPQ1')
#   );
# </script>
